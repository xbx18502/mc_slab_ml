# %%
# 同时计算mua和mus
import os  
import numpy as np
import struct
import matplotlib.pyplot as plt
import gc
import random
import math
from tensorflow import keras
import sklearn
# from scipy.interpolate import CubicSpline
from scipy.signal import find_peaks
from scipy.interpolate import interp1d
import keras_tuner

# %%
with open("C:\\Users\\Administrator\\source\\data\\dataset_test.bin", "rb") as file0:
    data1 = file0.read(4)
    NM1 = struct.unpack("i", data1)[0]
    sig2 = np.zeros((NM1,200),dtype = np.float32)
    an2 = np.zeros((NM1,4),dtype = np.float32)
    for i in range(NM1):
        for k in range(4):
            data1 = file0.read(4)
            an2[i,k] = struct.unpack("f", data1)[0]
        for k in range(200):
            data1 = file0.read(4)
            sig2[i,k] = struct.unpack("f", data1)[0]  
    # data1 = file0.read(len('end\0'))
    # end = struct.unpack("4s", data1)[0]

# %%
with open("C:\\Users\\Administrator\\source\\data\\dataset.bin", "rb") as file0:
    data1 = file0.read(4)
    NM1 = struct.unpack("i", data1)[0]
    sig1 = np.zeros((NM1,200),dtype = np.float32)
    an1 = np.zeros((NM1,4),dtype = np.float32)
    for i in range(NM1):
        for k in range(4):
            data1 = file0.read(4)
            an1[i,k] = struct.unpack("f", data1)[0]
        for k in range(200):
            data1 = file0.read(4)
            sig1[i,k] = struct.unpack("f", data1)[0]  
    # data1 = file0.read(len('end\0'))
    # end = struct.unpack("4s", data1)[0]

# %%
plt.axes(yscale = "log") 
for n in range(sig1.shape[0]):
    plt.plot(sig1[n])
plt.show()
print(NM1)
print(an2[-1])
# Out:
# 1262
# [1.24224685e-02 9.14926987e+01 1.54261023e+03 8.50000024e-01]

# %%
# def labeling(y,N):
#     ##############
#     a,b = y.shape
#     min0 = np.min(y,0)
#     max0 = np.max(y,0)
#     step = (max0-min0)/N
#     y2 = np.zeros((a,b,N))
    
#     # kernel = np.array([1]) 
#     # kernel = kernel/np.sum(kernel)
    
#     for i in range(a):
#         for j in range(b):
#             if(step[j]!=0):
#                 idx = (y[i,j]-min0[j])/step[j]-1
#                 y2[i,j,int(idx)] = 1
#             else:
#                 y2[i,j,0] = 1
#             # y2[i,j] = np.convolve(y2[i,j],kernel,mode='same')
            
#     return y2

# %%
xsig = sig1[0]
peaks, _ = find_peaks(xsig, height=0)
plt.plot(xsig)
plt.plot(peaks, xsig[peaks], "x")
plt.plot(np.zeros_like(xsig), "--", color="gray")
plt.show()

x = np.zeros((peaks.shape[0]+2,))
y = np.zeros((peaks.shape[0]+2,))
x[1:-1] = peaks
y[1:-1] = xsig[peaks]
x[-1] = sig1.shape[1]
plt.plot(x,y)
plt.show()

f2 = interp1d(x, y, kind='linear')
N = 200
xnew = np.linspace(0, N,num=N)
ynew = f2(xnew)

# plt.axes(yscale = "log") 
plt.plot(ynew)
plt.show()

# %%
def smooth_peak(xsig):
    peaks, _ = find_peaks(xsig, height=0)
    # plt.plot(xsig)
    # plt.plot(peaks, xsig[peaks], "x")
    # plt.plot(np.zeros_like(xsig), "--", color="gray")
    # plt.show()
    if(peaks.shape[0]!=0):
        x = np.zeros((peaks.shape[0]+3,))
        y = np.zeros((peaks.shape[0]+3,))
        x[1:-2] = peaks
        y[1:-2] = xsig[peaks]
        x[-1] = sig1.shape[1]
        y[-1] = 0
        x[-2] = peaks[-1]+5
        y[-2] = 0
        # plt.plot(x,y)
        # plt.show()

        f2 = interp1d(x, y, kind='linear')
        N = xsig.shape[0]
        xnew = np.linspace(0, N,num=N)
        ynew = f2(xnew)
    
    else:
        ynew = np.zeros((xsig.shape[0],))
    
    return ynew
#     # plt.axes(yscale = "log") 
#     plt.plot(ynew)
#     plt.show()

# %%
msig1 = np.zeros((sig1.shape[0],sig1.shape[1]))
an3 = np.zeros((an1.shape))
i_invalid = 0
flag = 0
for i in range(sig1.shape[0]):
    ynew = smooth_peak(sig1[i])
    if(np.all(ynew == 0)):
        i_invalid = i_invalid+1
    else:
        msig1[flag] = ynew
        an3[flag] = an1[i]
        flag = flag+1
msig1 = msig1[0:msig1.shape[0]-i_invalid,:]  
an3 = an3[0:an3.shape[0]-i_invalid,:]

i_invalid = 0
flag = 0
msig2 = np.zeros((sig2.shape[0],sig2.shape[1]))
an4 = np.zeros((an2.shape))
for i in range(sig2.shape[0]):
    ynew = smooth_peak(sig2[i])
    if(np.all(ynew == 0)):
        i_invalid = i_invalid+1
    
    else:
        msig2[flag] = ynew
        an4[flag] = an2[i]
        flag = flag+1
msig2 = msig2[0:msig2.shape[0]-i_invalid,:] 
an4 = an4[0:an4.shape[0]-i_invalid,:]

# msig1 = np.zeros((sig1.shape[0],sig1.shape[1]))
# for i in range(sig1.shape[0]):
#     msig1[i] = smooth_peak(sig1[i])
    
# msig2 = np.zeros((sig2.shape[0],sig2.shape[1]))
# for i in range(sig2.shape[0]):
#     msig2[i] = smooth_peak(sig2[i])

# %%
plt.axes(yscale = "log") 
for n in range(msig1.shape[0]):
    plt.plot(msig1[n])
plt.show()

# %%
x_train = msig1
y_train = an3
x_test = msig2
y_test = an4

x_train = (np.log10((x_train+1e-6)/1000)+9)/9
x_test = (np.log10((x_test+1e-6)/1000)+9)/9
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))
d_train = np.reshape(y_train[:,0],(y_train[:,0].shape[0],1,1)) # add thickness of sample into input data
d_test = np.reshape(y_test[:,0],(y_test[:,0].shape[0],1,1))

x_train = np.concatenate((d_train,x_train),axis = 1) 
x_test = np.concatenate((d_test,x_test),axis = 1)
y_train[:,1] = y_train[:,1]/1e2
y_test[:,1] = y_test[:,1]/1e2
y_train[:,2] = y_train[:,2]/200e2
y_test[:,2] = y_test[:,2]/200e2
y_train = y_train[:,1:3]
y_test = y_test[:,1:3]
# y_train = labeling(y_train,num_labels)[:,1,:] # select to predict what : 0:thickness 1:mua 2: mus
# y_test = labeling(y_test,num_labels)[:,1,:]
print('x_train.shape = '+str(x_train.shape)) 
print('y_train.shape = '+str(y_train.shape))
# Out:
# x_train.shape = (1258, 201, 1)
# y_train.shape = (1258, 2)

# %%
for n in range(x_train.shape[0]):
    plt.plot(x_train[n,1:])
plt.show()

# %%
# num_classes = y_train.shape[1]
########################################
# input_shape = (1,5,1)
# x = np.arange(np.prod(input_shape)).reshape(input_shape)      # test cropping#
# print(x)
# y = keras.layers.Cropping1D(cropping=(0,4))(x)
# z = keras.layers.Cropping1D(cropping=(1,0))(x)
# print(y)
# print(z)

# %%
#####################################################
index = [i for i in range(x_train.shape[0])]  
np.random.shuffle(index) 
x_train = x_train[index]
y_train = y_train[index]

# x_train = np.split(x_train, [int(x_train.shape[0]*0.6), x_train.shape[0]])[0]
# x_val = np.split(x_train, [int(x_train.shape[0]*0.6), x_train.shape[0]])[1]
# y_train = np.split(y_train, [int(y_train.shape[0]*0.6), y_train.shape[0]])[0]
# y_val = np.split(y_train, [int(y_train.shape[0]*0.6), y_train.shape[0]])[1]
####################################################

# %%
class MyHyperModel(keras_tuner.HyperModel) :
    
    # def __int__(self, input_shape):
    #     self.input_shape = input_shape
        
    def build(self, hp) :  
        input_layer = keras.layers.Input((201,1))

        d_1 = keras.layers.Cropping1D(cropping=(0,200))(input_layer)
        sig = keras.layers.Cropping1D(cropping=(1,0))(input_layer)

        d_1 = keras.layers.Reshape((1,))(d_1)
        conv1 = keras.layers.Reshape((200,1))(sig)
        
        for i in range( hp.Int("num_conv", min_value=1, max_value=5, step=1)) :
            conv1 = keras.layers.Conv1D(filters=hp.Int(name=f"filters_{i}", min_value=8, max_value=64, step=15), 
            kernel_size=hp.Int(name=f"kernel_{i}", min_value=3, max_value=7, step=2), 
                                        padding="same",
                                       activation=hp.Choice(f"conv_act_{i}", ["relu","leaky_relu", "sigmoid"] ))(conv1)
            # Batch Norm and Dropout layers as hyperparameters to be searched 
            if hp.Boolean("batch_norm"): 
                conv1 = keras.layers.BatchNormalization()(conv1) 
            if hp.Boolean("dropout"): 
                conv1 = keras.layers.Dropout(0.5)(conv1)

       

        gap = keras.layers.GlobalAveragePooling1D()(conv1)

        for i in range(hp.Int("num_dense_gap", min_value=1, max_value=5, step=1)):
            gap = keras.layers.Dense(hp.Int(name=f"dense_gap_{i}", min_value=4, max_value=64, step=2)
                                    ,activation=hp.Choice("mlp_activ_gap", ['sigmoid', 'relu']))(gap)
            if hp.Boolean("batch_norm"): 
                gap = keras.layers.BatchNormalization()(gap) 
            if hp.Boolean("dropout"): 
                gap = keras.layers.Dropout(0.5)(gap)
            


        for i in range(hp.Int("num_dense_d1", min_value=1, max_value=5, step=1)):
            d_1 = keras.layers.Dense(hp.Int(name=f"dense_d1_{i}", min_value=4, max_value=64, step=2)
                                    ,activation=hp.Choice("mlp_activ_d1", ['sigmoid', 'relu']))(d_1)
            if hp.Boolean("batch_norm"): 
                d_1 = keras.layers.BatchNormalization()(d_1) 
            if hp.Boolean("dropout"): 
                d_1 = keras.layers.Dropout(0.5)(d_1)
                
        # d_1 = keras.layers.Reshape((d_1.shape[0],))(d_1)



        merged = keras.layers.Concatenate()([d_1, gap])
        
        for i in range(hp.Int("num_dense_o", min_value=1, max_value=5, step=1)):
            merged = keras.layers.Dense(hp.Int(name=f"dense_o_{i}", min_value=2, max_value=64, step=2)
                                    ,activation=hp.Choice("mlp_activ_o", ['sigmoid', 'relu']))(merged)
            if hp.Boolean("batch_norm"): 
                merged= keras.layers.BatchNormalization()(merged) 
            if hp.Boolean("dropout"): 
                merged = keras.layers.Dropout(0.5)(merged)
                
        # merged = keras.layers.Dense(8, activation='relu')(merged)

        output_layer = keras.layers.Dense(2, activation="linear")(merged)
        
        model = keras.models.Model(inputs=input_layer, outputs=output_layer)
        
        model.compile(
                optimizer="adam",
                # loss="mean_squared_error",
                loss="mean_squared_error",
                metrics=["MeanAbsoluteError"],
            )
        
        return model
    
    def fit(self, hp, model,x, *args, **kwargs) : 
 
        return model.fit( x,  
                         *args, 
                         shuffle=hp.Boolean("shuffle"), 
                         **kwargs)
# hp = keras_tuner.HyperParameters()
# model = MyHyperModel().build(hp,)
# keras.utils.plot_model(model, show_shapes=True)

# %%
hp = keras_tuner.HyperParameters() 
hypermodel = MyHyperModel() 
model = hypermodel.build(hp) 
hypermodel.fit(hp,model,x_train,y_train)
# Out:
# 40/40 [==============================] - 5s 7ms/step - loss: 1.2507 - mean_absolute_error: 1.0248

# %%
tuner = keras_tuner.BayesianOptimization( 
                        hypermodel=MyHyperModel(), 
                        objective = "val_loss", 
                        max_trials =10, #max candidates to test 
                        overwrite=True, 
                        directory='BO_search_dir', 
                        project_name='sign_language_cnn')

# %%
tuner = keras_tuner.Hyperband(hypermodel=MyHyperModel(),
                     objective='val_loss',
                     max_epochs=50,
                     factor=3,
                     directory='my_dir',
                     project_name='intro_to_kt',
                             overwrite=True)

# %%
stop_early = keras.callbacks.EarlyStopping(monitor='val_loss', patience=15)

tuner.search(x_train, y_train, epochs=50, validation_split=0.4, callbacks=[stop_early])
# Out:
# Trial 77 Complete [00h 00m 21s]
# val_loss: 0.08515260368585587
#
# Best val_loss So Far: 0.03749648481607437
# Total elapsed time: 00h 08m 05s
#
# Search: Running Trial #78
#
# Value             |Best Value So Far |Hyperparameter
# 4                 |4                 |num_conv
# 53                |53                |filters_0
# 5                 |3                 |kernel_0
# leaky_relu        |relu              |conv_act_0
# False             |False             |batch_norm
# False             |False             |dropout
# 4                 |3                 |num_dense_gap
# 38                |50                |dense_gap_0
# sigmoid           |relu              |mlp_activ_gap
# 3                 |5                 |num_dense_d1
# 46                |24                |dense_d1_0
# relu              |sigmoid           |mlp_activ_d1
# 3                 |1                 |num_dense_o
# 46                |42                |dense_o_0
# relu              |relu              |mlp_activ_o
# 53                |23                |filters_1
# 5                 |5                 |kernel_1
# relu              |leaky_relu        |conv_act_1
# 38                |23                |filters_2
# 5                 |3                 |kernel_2
# sigmoid           |leaky_relu        |conv_act_2
# 10                |40                |dense_gap_1
# 36                |20                |dense_d1_1
# 30                |62                |dense_o_1
# 36                |38                |dense_o_2
# 14                |14                |dense_o_3
# True              |False             |shuffle
# 20                |64                |dense_d1_2
# 12                |26                |dense_d1_3
# 36                |36                |dense_d1_4
# 10                |16                |dense_gap_2
# 30                |28                |dense_gap_3
# 22                |10                |dense_o_4
# 53                |23                |filters_3
# 5                 |5                 |kernel_3
# relu              |relu              |conv_act_3
# 36                |None              |dense_gap_4
# 53                |None              |filters_4
# 5                 |None              |kernel_4
# leaky_relu        |None              |conv_act_4
# 17                |50                |tuner/epochs
# 0                 |17                |tuner/initial_epoch
# 1                 |3                 |tuner/bracket
# 0                 |3                 |tuner/round
#
# Epoch 1/17
# 24/24 [==============================] - 2s 34ms/step - loss: 0.1916 - mean_absolute_error: 0.3492 - val_loss: 0.0974 - val_mean_absolute_error: 0.2645
# Epoch 2/17
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0826 - mean_absolute_error: 0.2444 - val_loss: 0.0825 - val_mean_absolute_error: 0.2463
# Epoch 3/17
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0802 - mean_absolute_error: 0.2430 - val_loss: 0.0824 - val_mean_absolute_error: 0.2472
# Epoch 4/17
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0803 - mean_absolute_error: 0.2425 - val_loss: 0.0822 - val_mean_absolute_error: 0.2466
# Epoch 5/17
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0801 - mean_absolute_error: 0.2425 - val_loss: 0.0821 - val_mean_absolute_error: 0.2463
# Epoch 6/17
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0803 - mean_absolute_error: 0.2424 - val_loss: 0.0818 - val_mean_absolute_error: 0.2461
# Epoch 7/17
# 24/24 [==============================] - ETA: 0s - loss: 0.0804 - mean_absolute_error: 0.2430

# %%
# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

# %%
tuner.search(x_train, y_train,epochs=5, 
             validation_data = (x_val,y_val))
# Out:
# Trial 5 Complete [00h 00m 06s]
# val_loss: 0.3138510286808014
#
# Best val_loss So Far: 0.2357691526412964
# Total elapsed time: 00h 04m 44s
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.results_summary(1)
# Out:
# Results summary
# Results in my_dir\intro_to_kt
# Showing 1 best trials
# <keras_tuner.engine.objective.Objective object at 0x00000213F55C0D60>
# Trial summary
# Hyperparameters:
# num_conv: 1
# filters_0: 23
# kernel_0: 7
# conv_act_0: sigmoid
# batch_norm: False
# dropout: False
# num_dense_gap: 4
# dense_gap_0: 62
# mlp_activ_gap: sigmoid
# num_dense_d1: 3
# dense_d1_0: 4
# mlp_activ_d1: relu
# num_dense_o: 4
# dense_o_0: 32
# mlp_activ_o: relu
# filters_1: 53
# kernel_1: 5
# conv_act_1: relu
# filters_2: 38
# kernel_2: 3
# conv_act_2: leaky_relu
# dense_gap_1: 40
# dense_d1_1: 48
# shuffle: True
# dense_o_1: 34
# dense_o_2: 30
# dense_o_3: 36
# dense_gap_2: 16
# dense_gap_3: 58
# dense_d1_2: 20
# dense_d1_3: 12
# dense_gap_4: 36
# filters_3: 8
# kernel_3: 5
# conv_act_3: leaky_relu
# dense_d1_4: 48
# filters_4: 53
# kernel_4: 3
# conv_act_4: sigmoid
# tuner/epochs: 10
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.0813927873969078

# %%
best_hps = tuner.get_best_hyperparameters(1) 
h_model = MyHyperModel() 
model = h_model.build(best_hps[0])
model.save('hp_model01.h5')

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 201, 1)]     0
# __________________________________________________________________________________________________
# cropping1d_3 (Cropping1D)       (None, 200, 1)       0           input_2[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 200, 1)       0           cropping1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 200, 23)      184         reshape_3[0][0]
# __________________________________________________________________________________________________
# cropping1d_2 (Cropping1D)       (None, 1, 1)         0           input_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 23)           0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1)            0           cropping1d_2[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 62)           1488        global_average_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 4)            8           reshape_2[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 40)           2520        dense_9[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 48)           240         dense_13[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 16)           656         dense_10[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 20)           980         dense_14[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 58)           986         dense_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 78)           0           dense_15[0][0]
#                                                                  dense_12[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 32)           2528        concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 34)           1122        dense_16[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 30)           1050        dense_17[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 36)           1116        dense_18[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 2)            74          dense_19[0][0]
# ==================================================================================================
# Total params: 12,952
# Trainable params: 12,952
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
epochs = 500
batch_size = 32
#####################################################
index = [i for i in range(x_train.shape[0])]  
np.random.shuffle(index) 
x_train = x_train[index]
y_train = y_train[index]
####################################################
callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model3.2.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    # loss="mean_squared_error",
    loss="mean_absolute_error",
    metrics=["MeanAbsoluteError"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.4,
    verbose=1,
)
# Out:
# Epoch 1/500
# 24/24 [==============================] - 1s 19ms/step - loss: 0.2876 - mean_absolute_error: 0.2876 - val_loss: 0.2463 - val_mean_absolute_error: 0.2463
# Epoch 2/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2427 - mean_absolute_error: 0.2427 - val_loss: 0.2477 - val_mean_absolute_error: 0.2477
# Epoch 3/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2446 - mean_absolute_error: 0.2446 - val_loss: 0.2475 - val_mean_absolute_error: 0.2475
# Epoch 4/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2460 - mean_absolute_error: 0.2460 - val_loss: 0.2480 - val_mean_absolute_error: 0.2480
# Epoch 5/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2439 - mean_absolute_error: 0.2439 - val_loss: 0.2472 - val_mean_absolute_error: 0.2472
# Epoch 6/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2436 - mean_absolute_error: 0.2436 - val_loss: 0.2475 - val_mean_absolute_error: 0.2475
# Epoch 7/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2442 - mean_absolute_error: 0.2442 - val_loss: 0.2474 - val_mean_absolute_error: 0.2474
# Epoch 8/500
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2431 - mean_absolute_error: 0.2431 - val_loss: 0.2459 - val_mean_absolute_error: 0.2459
# Epoch 9/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2440 - mean_absolute_error: 0.2440 - val_loss: 0.2459 - val_mean_absolute_error: 0.2459
# Epoch 10/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2437 - mean_absolute_error: 0.2437 - val_loss: 0.2498 - val_mean_absolute_error: 0.2498
# Epoch 11/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2435 - mean_absolute_error: 0.2435 - val_loss: 0.2469 - val_mean_absolute_error: 0.2469
# Epoch 12/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2443 - mean_absolute_error: 0.2443 - val_loss: 0.2460 - val_mean_absolute_error: 0.2460
# Epoch 13/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2439 - mean_absolute_error: 0.2439 - val_loss: 0.2460 - val_mean_absolute_error: 0.2460
# Epoch 14/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2448 - mean_absolute_error: 0.2448 - val_loss: 0.2460 - val_mean_absolute_error: 0.2460
# Epoch 15/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2436 - mean_absolute_error: 0.2436 - val_loss: 0.2526 - val_mean_absolute_error: 0.2526
# Epoch 16/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2446 - mean_absolute_error: 0.2446 - val_loss: 0.2469 - val_mean_absolute_error: 0.2469
# Epoch 17/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2430 - mean_absolute_error: 0.2430 - val_loss: 0.2463 - val_mean_absolute_error: 0.2463
# Epoch 18/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2428 - mean_absolute_error: 0.2428 - val_loss: 0.2483 - val_mean_absolute_error: 0.2483
# Epoch 19/500
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2444 - mean_absolute_error: 0.2444 - val_loss: 0.2462 - val_mean_absolute_error: 0.2462
# Epoch 20/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2451 - mean_absolute_error: 0.2451 - val_loss: 0.2480 - val_mean_absolute_error: 0.2480
# Epoch 21/500
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2436 - mean_absolute_error: 0.2436 - val_loss: 0.2471 - val_mean_absolute_error: 0.2471
# Epoch 22/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2436 - mean_absolute_error: 0.2436 - val_loss: 0.2459 - val_mean_absolute_error: 0.2459
# Epoch 23/500
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2439 - mean_absolute_error: 0.2439 - val_loss: 0.2479 - val_mean_absolute_error: 0.2479
# Epoch 24/500
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2447 - mean_absolute_error: 0.2447 - val_loss: 0.2482 - val_mean_absolute_error: 0.2482
# Epoch 25/500
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2436 - mean_absolute_error: 0.2436 - val_loss: 0.2478 - val_mean_absolute_error: 0.2478
# Epoch 26/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2429 - mean_absolute_error: 0.2429 - val_loss: 0.2481 - val_mean_absolute_error: 0.2481
# Epoch 27/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2437 - mean_absolute_error: 0.2437 - val_loss: 0.2463 - val_mean_absolute_error: 0.2463
# Epoch 28/500
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2451 - mean_absolute_error: 0.2451 - val_loss: 0.2466 - val_mean_absolute_error: 0.2466
# Epoch 29/500
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2435 - mean_absolute_error: 0.2435 - val_loss: 0.2466 - val_mean_absolute_error: 0.2466
# Epoch 30/500
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2436 - mean_absolute_error: 0.2436 - val_loss: 0.2464 - val_mean_absolute_error: 0.2464
# Epoch 31/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2427 - mean_absolute_error: 0.2427 - val_loss: 0.2462 - val_mean_absolute_error: 0.2462
# Epoch 32/500
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2427 - mean_absolute_error: 0.2427 - val_loss: 0.2467 - val_mean_absolute_error: 0.2467
# Epoch 33/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2429 - mean_absolute_error: 0.2429 - val_loss: 0.2460 - val_mean_absolute_error: 0.2460
# Epoch 34/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2433 - mean_absolute_error: 0.2433 - val_loss: 0.2467 - val_mean_absolute_error: 0.2467
# Epoch 35/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2425 - mean_absolute_error: 0.2425 - val_loss: 0.2464 - val_mean_absolute_error: 0.2464
# Epoch 36/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2428 - mean_absolute_error: 0.2428 - val_loss: 0.2460 - val_mean_absolute_error: 0.2460
# Epoch 37/500
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2431 - mean_absolute_error: 0.2431 - val_loss: 0.2475 - val_mean_absolute_error: 0.2475
# Epoch 38/500
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2440 - mean_absolute_error: 0.2440 - val_loss: 0.2461 - val_mean_absolute_error: 0.2461
# Epoch 39/500
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2427 - mean_absolute_error: 0.2427 - val_loss: 0.2469 - val_mean_absolute_error: 0.2469
# Epoch 40/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2432 - mean_absolute_error: 0.2432 - val_loss: 0.2461 - val_mean_absolute_error: 0.2461
# Epoch 41/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2424 - mean_absolute_error: 0.2424 - val_loss: 0.2464 - val_mean_absolute_error: 0.2464
# Epoch 42/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2434 - mean_absolute_error: 0.2434 - val_loss: 0.2470 - val_mean_absolute_error: 0.2470
# Epoch 43/500
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2431 - mean_absolute_error: 0.2431 - val_loss: 0.2461 - val_mean_absolute_error: 0.2461
# Epoch 44/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2424 - mean_absolute_error: 0.2424 - val_loss: 0.2469 - val_mean_absolute_error: 0.2469
# Epoch 45/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2431 - mean_absolute_error: 0.2431 - val_loss: 0.2474 - val_mean_absolute_error: 0.2474
# Epoch 46/500
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2425 - mean_absolute_error: 0.2425 - val_loss: 0.2487 - val_mean_absolute_error: 0.2487
# Epoch 47/500
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2430 - mean_absolute_error: 0.2430 - val_loss: 0.2468 - val_mean_absolute_error: 0.2468
# Epoch 48/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2428 - mean_absolute_error: 0.2428 - val_loss: 0.2470 - val_mean_absolute_error: 0.2470
# Epoch 49/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2429 - mean_absolute_error: 0.2429 - val_loss: 0.2460 - val_mean_absolute_error: 0.2460
# Epoch 50/500
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2427 - mean_absolute_error: 0.2427 - val_loss: 0.2461 - val_mean_absolute_error: 0.2461
# Epoch 51/500
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2431 - mean_absolute_error: 0.2431 - val_loss: 0.2466 - val_mean_absolute_error: 0.2466
# Epoch 52/500
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2425 - mean_absolute_error: 0.2425 - val_loss: 0.2460 - val_mean_absolute_error: 0.2460
# Epoch 53/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2425 - mean_absolute_error: 0.2425 - val_loss: 0.2463 - val_mean_absolute_error: 0.2463
# Epoch 54/500
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2424 - mean_absolute_error: 0.2424 - val_loss: 0.2461 - val_mean_absolute_error: 0.2461
# Epoch 55/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2424 - mean_absolute_error: 0.2424 - val_loss: 0.2461 - val_mean_absolute_error: 0.2461
# Epoch 56/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2425 - mean_absolute_error: 0.2425 - val_loss: 0.2463 - val_mean_absolute_error: 0.2463
# Epoch 57/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2424 - mean_absolute_error: 0.2424 - val_loss: 0.2464 - val_mean_absolute_error: 0.2464
# Epoch 58/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2423 - mean_absolute_error: 0.2423 - val_loss: 0.2459 - val_mean_absolute_error: 0.2459
# Epoch 59/500
# 24/24 [==============================] - 0s 12ms/step - loss: 0.2425 - mean_absolute_error: 0.2425 - val_loss: 0.2460 - val_mean_absolute_error: 0.2460
# Epoch 00059: early stopping

# %%
model = keras.models.load_model("best_model3.2.h5")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test error", test_acc)
print("Test loss", test_loss)
# Out:
# 1/1 [==============================] - 0s 168ms/step - loss: 0.2627 - mean_absolute_error: 0.2627
# Test error 0.26265206933021545
# Test loss 0.26265206933021545

# %%
mua = np.zeros((x_train.shape[0],))
mus = np.zeros((x_train.shape[0],))
d = np.zeros((x_train.shape[0],))
miu = np.zeros((x_train.shape[0],2))

miu = model.predict(x_train)
mua = miu[:,0]
mus = miu[:,1]
d = x_train[:,0,0]

# %%
err = np.zeros((x_train.shape[0],2))

err[:,0] = y_train[:,0]-mua
err[:,1] = y_train[:,1]-mus
# print(mua[k],mus[k],d[k])
# print(y_train[k])

# %%
k=np.random.randint(0,x_train.shape[0],1)[0]
print(mua[k],mus[k],d[k])
print(y_train[k])
# Out:
# 0.072649255 -0.027526274 0.007310018874704838
# [0.34187057 0.94397568]

# %%
plt.plot(d,err[:,1])
plt.plot(d,err[:,0])
plt.show()

# %%
# print(mua,mus,d)
# print(an2[i,1],an2[i,2],an2[i,0])
# plt.plot(abs(an1[:,1]-mua))
# plt.plot(abs(an1[:,2]-mus))
plt.hist(y_train[:,0]-mua, bins=40,  facecolor="blue", edgecolor="black", alpha=0.7)
plt.hist(y_train[:,1]-mus, bins=40,  facecolor="green", edgecolor="black", alpha=0.7)
plt.show()

# %%
metric = "mean_absolute_error"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()

# %%
# 你可以用pca或者一些降维方法把特征搞一下
