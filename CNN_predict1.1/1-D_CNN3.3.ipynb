# %%
# only output mua
import os  
import numpy as np
import struct
import matplotlib.pyplot as plt
import gc
import random
import math
from tensorflow import keras
import sklearn
# from scipy.interpolate import CubicSpline
from scipy.signal import find_peaks
from scipy.interpolate import interp1d

# %%
with open("C:\\Users\\Administrator\\source\\data\\dataset_test.bin", "rb") as file0:
    data1 = file0.read(4)
    NM1 = struct.unpack("i", data1)[0]
    sig2 = np.zeros((NM1,200),dtype = np.float32)
    an2 = np.zeros((NM1,4),dtype = np.float32)
    for i in range(NM1):
        for k in range(4):
            data1 = file0.read(4)
            an2[i,k] = struct.unpack("f", data1)[0]
        for k in range(200):
            data1 = file0.read(4)
            sig2[i,k] = struct.unpack("f", data1)[0]  
    # data1 = file0.read(len('end\0'))
    # end = struct.unpack("4s", data1)[0]

# %%
with open("C:\\Users\\Administrator\\source\\data\\dataset.bin", "rb") as file0:
    data1 = file0.read(4)
    NM1 = struct.unpack("i", data1)[0]
    sig1 = np.zeros((NM1,200),dtype = np.float32)
    an1 = np.zeros((NM1,4),dtype = np.float32)
    for i in range(NM1):
        for k in range(4):
            data1 = file0.read(4)
            an1[i,k] = struct.unpack("f", data1)[0]
        for k in range(200):
            data1 = file0.read(4)
            sig1[i,k] = struct.unpack("f", data1)[0]  
    # data1 = file0.read(len('end\0'))
    # end = struct.unpack("4s", data1)[0]

# %%
plt.axes(yscale = "log") 
for n in range(sig1.shape[0]):
    plt.plot(sig1[n])
plt.show()
print(NM1)
print(an2[-1])
# Out:
# 1262
# [1.24224685e-02 9.14926987e+01 1.54261023e+03 8.50000024e-01]

# %%
# def labeling(y,N):
#     ##############
#     a,b = y.shape
#     min0 = np.min(y,0)
#     max0 = np.max(y,0)
#     step = (max0-min0)/N
#     y2 = np.zeros((a,b,N))
    
#     # kernel = np.array([1]) 
#     # kernel = kernel/np.sum(kernel)
    
#     for i in range(a):
#         for j in range(b):
#             if(step[j]!=0):
#                 idx = (y[i,j]-min0[j])/step[j]-1
#                 y2[i,j,int(idx)] = 1
#             else:
#                 y2[i,j,0] = 1
#             # y2[i,j] = np.convolve(y2[i,j],kernel,mode='same')
            
#     return y2

# %%
xsig = sig1[0]
peaks, _ = find_peaks(xsig, height=0)
plt.plot(xsig)
plt.plot(peaks, xsig[peaks], "x")
plt.plot(np.zeros_like(xsig), "--", color="gray")
plt.show()

x = np.zeros((peaks.shape[0]+2,))
y = np.zeros((peaks.shape[0]+2,))
x[1:-1] = peaks
y[1:-1] = xsig[peaks]
x[-1] = sig1.shape[1]
plt.plot(x,y)
plt.show()

f2 = interp1d(x, y, kind='linear')
N = 200
xnew = np.linspace(0, N,num=N)
ynew = f2(xnew)

# plt.axes(yscale = "log") 
plt.plot(ynew)
plt.show()

# %%
def smooth_peak(xsig):
    peaks, _ = find_peaks(xsig, height=0)
    # plt.plot(xsig)
    # plt.plot(peaks, xsig[peaks], "x")
    # plt.plot(np.zeros_like(xsig), "--", color="gray")
    # plt.show()
    if(peaks.shape[0]!=0):
        x = np.zeros((peaks.shape[0]+3,))
        y = np.zeros((peaks.shape[0]+3,))
        x[1:-2] = peaks
        y[1:-2] = xsig[peaks]
        x[-1] = sig1.shape[1]
        y[-1] = 0
        x[-2] = peaks[-1]+5
        y[-2] = 0
        # plt.plot(x,y)
        # plt.show()

        f2 = interp1d(x, y, kind='linear')
        N = xsig.shape[0]
        xnew = np.linspace(0, N,num=N)
        ynew = f2(xnew)
    
    else:
        ynew = np.zeros((xsig.shape[0],))
    
    return ynew
#     # plt.axes(yscale = "log") 
#     plt.plot(ynew)
#     plt.show()

# %%
msig1 = np.zeros((sig1.shape[0],sig1.shape[1]))
for i in range(sig1.shape[0]):
    msig1[i] = smooth_peak(sig1[i])
    
msig2 = np.zeros((sig2.shape[0],sig2.shape[1]))
for i in range(sig2.shape[0]):
    msig2[i] = smooth_peak(sig2[i])

# %%
plt.axes(yscale = "log") 
for n in range(msig1.shape[0]):
    plt.plot(msig1[n])
plt.show()

# %%
print(sig1.shape)
print(an1.shape)
print(sig2.shape)
print(an2.shape)
# num_labels = 10
x_train = msig1
y_train = an1
x_test = msig2
y_test = an2

x_train = (np.log10((x_train+1e-6)/1000)+9)/9
x_test = (np.log10((x_test+1e-6)/1000)+9)/9
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))
d_train = np.reshape(y_train[:,0],(y_train[:,0].shape[0],1,1)) # add thickness of sample into input data
d_test = np.reshape(y_test[:,0],(y_test[:,0].shape[0],1,1))

x_train = np.concatenate((d_train,x_train),axis = 1) 
x_test = np.concatenate((d_test,x_test),axis = 1)
y_train[:,1] = y_train[:,1]/1e2
y_test[:,1] = y_test[:,1]/1e2
y_train[:,2] = y_train[:,2]/200e2
y_test[:,2] = y_test[:,2]/200e2
y_train = y_train[:,1:2] # determine the nn to output mua/mus or mua+mus
y_test = y_test[:,1:2]
# y_train = labeling(y_train,num_labels)[:,1,:] # select to predict what : 0:thickness 1:mua 2: mus
# y_test = labeling(y_test,num_labels)[:,1,:]
print('x_train.shape = '+str(x_train.shape)) 
print('y_train.shape = '+str(y_train.shape))
# Out:
# (1262, 200)
# (1262, 4)
# (30, 200)
# (30, 4)
# x_train.shape = (1262, 201, 1)
# y_train.shape = (1262, 1)

# %%
randindex0 = np.random.randint(0, x_train.shape[0], 10)
for n in randindex0:
    plt.plot(x_train[n,1:])
plt.show()

# %%
# num_classes = y_train.shape[1]
########################################
# input_shape = (1,5,1)
# x = np.arange(np.prod(input_shape)).reshape(input_shape)      # test cropping#
# print(x)
# y = keras.layers.Cropping1D(cropping=(0,4))(x)
# z = keras.layers.Cropping1D(cropping=(1,0))(x)
# print(y)
# print(z)

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)
    
    d_1 = keras.layers.Cropping1D(cropping=(0,200))(input_layer)
    sig = keras.layers.Cropping1D(cropping=(1,0))(input_layer)
    
    conv1 = keras.layers.Conv1D(filters=16, kernel_size=3, padding="same")(sig)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=16, kernel_size=3, padding="same")(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=16, kernel_size=3, padding="same")(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)
    
    gap = keras.layers.Dense(16, activation='relu')(gap)
    gap = keras.layers.BatchNormalization()(gap)
    gap = keras.layers.Dropout(0.5)(gap)
    gap = keras.layers.Dense(16, activation='relu')(gap)
    
    
    d_1 = keras.layers.Dense(16, activation='relu')(d_1)
    d_1 = keras.layers.Dense(16, activation='relu')(d_1)
    d_1 = keras.layers.Reshape((16,))(d_1)
    
    
    
    merged = keras.layers.Concatenate()([d_1, gap])
    merged = keras.layers.Dense(8, activation='relu')(merged)
    
    output_layer = keras.layers.Dense(1, activation="linear")(merged)
#######################################################################
#     d_1 = keras.layers.Dense(16, activation='relu')(d_1)
#     # d_1 = keras.layers.Dense(10, activation='relu')(d_1)
#     d_1 = keras.layers.Reshape((16,))(d_1)
    
#     d_1 = keras.layers.BatchNormalization()(d_1)
#     gap = keras.layers.Dense(8, activation='relu')(gap)
#     gap = keras.layers.BatchNormalization()(gap)
    
#     merged = keras.layers.Concatenate()([d_1, gap])
#     merged = keras.layers.Dense(8, activation='relu')(merged)
    
#     output_layer = keras.layers.Dense(2, activation="linear")(merged)
##########################################################################    
    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])
keras.utils.plot_model(model, show_shapes=True)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %%
epochs = 500
batch_size = 32
#####################################################
index = [i for i in range(x_train.shape[0])]  
np.random.shuffle(index) 
x_train = x_train[index]
y_train = y_train[index]
####################################################
callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    # loss="mean_squared_error",
    loss="mean_absolute_error",
    metrics=["MeanAbsoluteError"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.4,
    verbose=1,
)
# Out:
# Epoch 1/500
# 24/24 [==============================] - 2s 30ms/step - loss: 0.1087 - mean_absolute_error: 0.1087 - val_loss: 0.3353 - val_mean_absolute_error: 0.3353
# Epoch 2/500
# 24/24 [==============================] - 1s 22ms/step - loss: 0.1119 - mean_absolute_error: 0.1119 - val_loss: 0.2336 - val_mean_absolute_error: 0.2336
# Epoch 3/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1166 - mean_absolute_error: 0.1166 - val_loss: 0.9908 - val_mean_absolute_error: 0.9908
# Epoch 4/500
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1085 - mean_absolute_error: 0.1085 - val_loss: 1.1134 - val_mean_absolute_error: 1.1134
# Epoch 5/500
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1063 - mean_absolute_error: 0.1063 - val_loss: 0.9909 - val_mean_absolute_error: 0.9909
# Epoch 6/500
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1083 - mean_absolute_error: 0.1083 - val_loss: 0.2210 - val_mean_absolute_error: 0.2210
# Epoch 7/500
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1093 - mean_absolute_error: 0.1093 - val_loss: 0.4862 - val_mean_absolute_error: 0.4862
# Epoch 8/500
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1040 - mean_absolute_error: 0.1040 - val_loss: 0.2423 - val_mean_absolute_error: 0.2423
# Epoch 9/500
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1137 - mean_absolute_error: 0.1137 - val_loss: 0.6919 - val_mean_absolute_error: 0.6919
# Epoch 10/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1081 - mean_absolute_error: 0.1081 - val_loss: 0.3812 - val_mean_absolute_error: 0.3812
# Epoch 11/500
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1066 - mean_absolute_error: 0.1066 - val_loss: 0.3687 - val_mean_absolute_error: 0.3687
# Epoch 12/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1154 - mean_absolute_error: 0.1154 - val_loss: 0.9711 - val_mean_absolute_error: 0.9711
# Epoch 13/500
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1049 - mean_absolute_error: 0.1049 - val_loss: 1.0992 - val_mean_absolute_error: 1.0992
# Epoch 14/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1125 - mean_absolute_error: 0.1125 - val_loss: 0.7020 - val_mean_absolute_error: 0.7020
# Epoch 15/500
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1089 - mean_absolute_error: 0.1089 - val_loss: 0.3523 - val_mean_absolute_error: 0.3523
# Epoch 16/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1009 - mean_absolute_error: 0.1009 - val_loss: 0.3216 - val_mean_absolute_error: 0.3216
# Epoch 17/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1006 - mean_absolute_error: 0.1006 - val_loss: 0.6980 - val_mean_absolute_error: 0.6980
# Epoch 18/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1071 - mean_absolute_error: 0.1071 - val_loss: 0.8316 - val_mean_absolute_error: 0.8316
# Epoch 19/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1099 - mean_absolute_error: 0.1099 - val_loss: 0.5106 - val_mean_absolute_error: 0.5106
# Epoch 20/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1073 - mean_absolute_error: 0.1073 - val_loss: 1.0016 - val_mean_absolute_error: 1.0016
# Epoch 21/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0969 - mean_absolute_error: 0.0969 - val_loss: 0.7348 - val_mean_absolute_error: 0.7348
# Epoch 22/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1025 - mean_absolute_error: 0.1025 - val_loss: 0.7555 - val_mean_absolute_error: 0.7555
# Epoch 23/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1072 - mean_absolute_error: 0.1072 - val_loss: 1.2635 - val_mean_absolute_error: 1.2635
# Epoch 24/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1046 - mean_absolute_error: 0.1046 - val_loss: 2.3205 - val_mean_absolute_error: 2.3205
# Epoch 25/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0987 - mean_absolute_error: 0.0987 - val_loss: 0.9727 - val_mean_absolute_error: 0.9727
# Epoch 26/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1131 - mean_absolute_error: 0.1131 - val_loss: 0.9565 - val_mean_absolute_error: 0.9565
# Epoch 27/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1015 - mean_absolute_error: 0.1015 - val_loss: 0.7718 - val_mean_absolute_error: 0.7718
# Epoch 28/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1045 - mean_absolute_error: 0.1045 - val_loss: 0.2324 - val_mean_absolute_error: 0.2324
# Epoch 29/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0937 - mean_absolute_error: 0.0937 - val_loss: 0.2414 - val_mean_absolute_error: 0.2414
# Epoch 30/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0957 - mean_absolute_error: 0.0957 - val_loss: 0.1319 - val_mean_absolute_error: 0.1319
# Epoch 31/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0918 - mean_absolute_error: 0.0918 - val_loss: 0.1338 - val_mean_absolute_error: 0.1338
# Epoch 32/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0995 - mean_absolute_error: 0.0995 - val_loss: 0.2351 - val_mean_absolute_error: 0.2351
# Epoch 33/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0939 - mean_absolute_error: 0.0939 - val_loss: 0.2023 - val_mean_absolute_error: 0.2023
# Epoch 34/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1004 - mean_absolute_error: 0.1004 - val_loss: 0.1555 - val_mean_absolute_error: 0.1555
# Epoch 35/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0994 - mean_absolute_error: 0.0994 - val_loss: 0.2840 - val_mean_absolute_error: 0.2840
# Epoch 36/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0980 - mean_absolute_error: 0.0980 - val_loss: 0.9905 - val_mean_absolute_error: 0.9905
# Epoch 37/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0950 - mean_absolute_error: 0.0950 - val_loss: 0.6318 - val_mean_absolute_error: 0.6318
# Epoch 38/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0945 - mean_absolute_error: 0.0945 - val_loss: 0.7602 - val_mean_absolute_error: 0.7602
# Epoch 39/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0967 - mean_absolute_error: 0.0967 - val_loss: 1.0275 - val_mean_absolute_error: 1.0275
# Epoch 40/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0939 - mean_absolute_error: 0.0939 - val_loss: 0.3958 - val_mean_absolute_error: 0.3958
# Epoch 41/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0992 - mean_absolute_error: 0.0992 - val_loss: 0.1460 - val_mean_absolute_error: 0.1460
# Epoch 42/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0955 - mean_absolute_error: 0.0955 - val_loss: 0.4456 - val_mean_absolute_error: 0.4456
# Epoch 43/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0950 - mean_absolute_error: 0.0950 - val_loss: 0.2410 - val_mean_absolute_error: 0.2410
# Epoch 44/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1017 - mean_absolute_error: 0.1017 - val_loss: 0.3668 - val_mean_absolute_error: 0.3668
# Epoch 45/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1029 - mean_absolute_error: 0.1029 - val_loss: 0.5073 - val_mean_absolute_error: 0.5073
# Epoch 46/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0954 - mean_absolute_error: 0.0954 - val_loss: 1.4596 - val_mean_absolute_error: 1.4596
# Epoch 47/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1023 - mean_absolute_error: 0.1023 - val_loss: 1.1227 - val_mean_absolute_error: 1.1227
# Epoch 48/500
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1004 - mean_absolute_error: 0.1004 - val_loss: 1.0120 - val_mean_absolute_error: 1.0120
# Epoch 49/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1062 - mean_absolute_error: 0.1062 - val_loss: 0.7081 - val_mean_absolute_error: 0.7081
# Epoch 50/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0988 - mean_absolute_error: 0.0988 - val_loss: 1.1548 - val_mean_absolute_error: 1.1548
# Epoch 51/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0979 - mean_absolute_error: 0.0979 - val_loss: 0.8521 - val_mean_absolute_error: 0.8521
# Epoch 52/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0906 - mean_absolute_error: 0.0906 - val_loss: 0.6279 - val_mean_absolute_error: 0.6279
# Epoch 53/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0947 - mean_absolute_error: 0.0947 - val_loss: 0.6432 - val_mean_absolute_error: 0.6432
# Epoch 54/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0898 - mean_absolute_error: 0.0898 - val_loss: 0.3989 - val_mean_absolute_error: 0.3989
# Epoch 55/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0996 - mean_absolute_error: 0.0996 - val_loss: 0.1814 - val_mean_absolute_error: 0.1814
# Epoch 56/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0970 - mean_absolute_error: 0.0970 - val_loss: 0.1135 - val_mean_absolute_error: 0.1135
# Epoch 57/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0921 - mean_absolute_error: 0.0921 - val_loss: 0.2217 - val_mean_absolute_error: 0.2217
# Epoch 58/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0972 - mean_absolute_error: 0.0972 - val_loss: 0.2935 - val_mean_absolute_error: 0.2935
# Epoch 59/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0938 - mean_absolute_error: 0.0938 - val_loss: 0.4207 - val_mean_absolute_error: 0.4207
# Epoch 60/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0911 - mean_absolute_error: 0.0911 - val_loss: 0.2904 - val_mean_absolute_error: 0.2904
# Epoch 61/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0949 - mean_absolute_error: 0.0949 - val_loss: 0.1026 - val_mean_absolute_error: 0.1026
# Epoch 62/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0936 - mean_absolute_error: 0.0936 - val_loss: 0.1676 - val_mean_absolute_error: 0.1676
# Epoch 63/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0949 - mean_absolute_error: 0.0949 - val_loss: 0.2756 - val_mean_absolute_error: 0.2756
# Epoch 64/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0918 - mean_absolute_error: 0.0918 - val_loss: 0.6111 - val_mean_absolute_error: 0.6111
# Epoch 65/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0953 - mean_absolute_error: 0.0953 - val_loss: 0.4179 - val_mean_absolute_error: 0.4179
# Epoch 66/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0976 - mean_absolute_error: 0.0976 - val_loss: 0.3342 - val_mean_absolute_error: 0.3342
# Epoch 67/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0951 - mean_absolute_error: 0.0951 - val_loss: 0.4644 - val_mean_absolute_error: 0.4644
# Epoch 68/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0908 - mean_absolute_error: 0.0908 - val_loss: 0.1955 - val_mean_absolute_error: 0.1955
# Epoch 69/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0954 - mean_absolute_error: 0.0954 - val_loss: 0.5251 - val_mean_absolute_error: 0.5251
# Epoch 70/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0968 - mean_absolute_error: 0.0968 - val_loss: 0.4114 - val_mean_absolute_error: 0.4114
# Epoch 71/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0947 - mean_absolute_error: 0.0947 - val_loss: 0.1674 - val_mean_absolute_error: 0.1674
# Epoch 72/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0938 - mean_absolute_error: 0.0938 - val_loss: 0.2967 - val_mean_absolute_error: 0.2967
# Epoch 73/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0956 - mean_absolute_error: 0.0956 - val_loss: 0.2082 - val_mean_absolute_error: 0.2082
# Epoch 74/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0962 - mean_absolute_error: 0.0962 - val_loss: 0.1426 - val_mean_absolute_error: 0.1426
# Epoch 75/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0912 - mean_absolute_error: 0.0912 - val_loss: 0.3781 - val_mean_absolute_error: 0.3781
# Epoch 76/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0944 - mean_absolute_error: 0.0944 - val_loss: 0.2709 - val_mean_absolute_error: 0.2709
# Epoch 77/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0940 - mean_absolute_error: 0.0940 - val_loss: 0.2497 - val_mean_absolute_error: 0.2497
# Epoch 78/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0952 - mean_absolute_error: 0.0952 - val_loss: 0.1165 - val_mean_absolute_error: 0.1165
# Epoch 79/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0911 - mean_absolute_error: 0.0911 - val_loss: 0.1081 - val_mean_absolute_error: 0.1081
# Epoch 80/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0940 - mean_absolute_error: 0.0940 - val_loss: 0.3723 - val_mean_absolute_error: 0.3723
# Epoch 81/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0958 - mean_absolute_error: 0.0958 - val_loss: 0.2528 - val_mean_absolute_error: 0.2528
# Epoch 82/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0877 - mean_absolute_error: 0.0877 - val_loss: 0.1892 - val_mean_absolute_error: 0.1892
# Epoch 83/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0940 - mean_absolute_error: 0.0940 - val_loss: 0.0996 - val_mean_absolute_error: 0.0996
# Epoch 84/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0926 - mean_absolute_error: 0.0926 - val_loss: 0.1910 - val_mean_absolute_error: 0.1910
# Epoch 85/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0899 - mean_absolute_error: 0.0899 - val_loss: 0.2616 - val_mean_absolute_error: 0.2616
# Epoch 86/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0880 - mean_absolute_error: 0.0880 - val_loss: 0.4520 - val_mean_absolute_error: 0.4520
# Epoch 87/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0924 - mean_absolute_error: 0.0924 - val_loss: 0.2563 - val_mean_absolute_error: 0.2563
# Epoch 88/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0916 - mean_absolute_error: 0.0916 - val_loss: 0.1846 - val_mean_absolute_error: 0.1846
# Epoch 89/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0890 - mean_absolute_error: 0.0890 - val_loss: 0.1523 - val_mean_absolute_error: 0.1523
# Epoch 90/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0936 - mean_absolute_error: 0.0936 - val_loss: 0.1285 - val_mean_absolute_error: 0.1285
# Epoch 91/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0929 - mean_absolute_error: 0.0929 - val_loss: 0.1109 - val_mean_absolute_error: 0.1109
# Epoch 92/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0927 - mean_absolute_error: 0.0927 - val_loss: 0.1156 - val_mean_absolute_error: 0.1156
# Epoch 93/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0921 - mean_absolute_error: 0.0921 - val_loss: 0.2090 - val_mean_absolute_error: 0.2090
# Epoch 94/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0885 - mean_absolute_error: 0.0885 - val_loss: 0.1051 - val_mean_absolute_error: 0.1051
# Epoch 95/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0972 - mean_absolute_error: 0.0972 - val_loss: 0.1154 - val_mean_absolute_error: 0.1154
# Epoch 96/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0910 - mean_absolute_error: 0.0910 - val_loss: 0.5112 - val_mean_absolute_error: 0.5112
# Epoch 97/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0908 - mean_absolute_error: 0.0908 - val_loss: 0.2730 - val_mean_absolute_error: 0.2730
# Epoch 98/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0938 - mean_absolute_error: 0.0938 - val_loss: 0.1612 - val_mean_absolute_error: 0.1612
# Epoch 99/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0866 - mean_absolute_error: 0.0866 - val_loss: 0.1509 - val_mean_absolute_error: 0.1509
# Epoch 100/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0885 - mean_absolute_error: 0.0885 - val_loss: 0.3196 - val_mean_absolute_error: 0.3196
# Epoch 101/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0895 - mean_absolute_error: 0.0895 - val_loss: 0.2953 - val_mean_absolute_error: 0.2953
# Epoch 102/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0902 - mean_absolute_error: 0.0902 - val_loss: 0.2998 - val_mean_absolute_error: 0.2998
# Epoch 103/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0923 - mean_absolute_error: 0.0923 - val_loss: 0.2342 - val_mean_absolute_error: 0.2342
# Epoch 104/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0960 - mean_absolute_error: 0.0960 - val_loss: 0.2111 - val_mean_absolute_error: 0.2111
# Epoch 105/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0918 - mean_absolute_error: 0.0918 - val_loss: 0.1027 - val_mean_absolute_error: 0.1027
# Epoch 106/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0914 - mean_absolute_error: 0.0914 - val_loss: 0.2327 - val_mean_absolute_error: 0.2327
# Epoch 107/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0952 - mean_absolute_error: 0.0952 - val_loss: 0.2644 - val_mean_absolute_error: 0.2644
# Epoch 108/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0895 - mean_absolute_error: 0.0895 - val_loss: 0.3326 - val_mean_absolute_error: 0.3326
# Epoch 109/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0961 - mean_absolute_error: 0.0961 - val_loss: 0.2946 - val_mean_absolute_error: 0.2946
# Epoch 110/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0875 - mean_absolute_error: 0.0875 - val_loss: 0.2089 - val_mean_absolute_error: 0.2089
# Epoch 111/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0891 - mean_absolute_error: 0.0891 - val_loss: 0.1814 - val_mean_absolute_error: 0.1814
# Epoch 112/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0878 - mean_absolute_error: 0.0878 - val_loss: 0.2550 - val_mean_absolute_error: 0.2550
# Epoch 113/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0911 - mean_absolute_error: 0.0911 - val_loss: 0.2498 - val_mean_absolute_error: 0.2498
# Epoch 114/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0918 - mean_absolute_error: 0.0918 - val_loss: 0.2683 - val_mean_absolute_error: 0.2683
# Epoch 115/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0937 - mean_absolute_error: 0.0937 - val_loss: 0.2081 - val_mean_absolute_error: 0.2081
# Epoch 116/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0872 - mean_absolute_error: 0.0872 - val_loss: 0.0872 - val_mean_absolute_error: 0.0872
# Epoch 117/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0936 - mean_absolute_error: 0.0936 - val_loss: 0.1295 - val_mean_absolute_error: 0.1295
# Epoch 118/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0889 - mean_absolute_error: 0.0889 - val_loss: 0.1080 - val_mean_absolute_error: 0.1080
# Epoch 119/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0902 - mean_absolute_error: 0.0902 - val_loss: 0.1037 - val_mean_absolute_error: 0.1037
# Epoch 120/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0891 - mean_absolute_error: 0.0891 - val_loss: 0.1605 - val_mean_absolute_error: 0.1605
# Epoch 121/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0913 - mean_absolute_error: 0.0913 - val_loss: 0.0843 - val_mean_absolute_error: 0.0843
# Epoch 122/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0900 - mean_absolute_error: 0.0900 - val_loss: 0.0827 - val_mean_absolute_error: 0.0827
# Epoch 123/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0911 - mean_absolute_error: 0.0911 - val_loss: 0.1972 - val_mean_absolute_error: 0.1972
# Epoch 124/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0868 - mean_absolute_error: 0.0868 - val_loss: 0.1435 - val_mean_absolute_error: 0.1435
# Epoch 125/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0956 - mean_absolute_error: 0.0956 - val_loss: 0.0986 - val_mean_absolute_error: 0.0986
# Epoch 126/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0920 - mean_absolute_error: 0.0920 - val_loss: 0.1789 - val_mean_absolute_error: 0.1789
# Epoch 127/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0922 - mean_absolute_error: 0.0922 - val_loss: 0.1983 - val_mean_absolute_error: 0.1983
# Epoch 128/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0857 - mean_absolute_error: 0.0857 - val_loss: 0.2609 - val_mean_absolute_error: 0.2609
# Epoch 129/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0905 - mean_absolute_error: 0.0905 - val_loss: 0.0976 - val_mean_absolute_error: 0.0976
# Epoch 130/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0920 - mean_absolute_error: 0.0920 - val_loss: 0.0997 - val_mean_absolute_error: 0.0997
# Epoch 131/500
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0840 - mean_absolute_error: 0.0840 - val_loss: 0.1448 - val_mean_absolute_error: 0.1448
# Epoch 132/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0916 - mean_absolute_error: 0.0916 - val_loss: 0.1479 - val_mean_absolute_error: 0.1479
# Epoch 133/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0930 - mean_absolute_error: 0.0930 - val_loss: 0.0789 - val_mean_absolute_error: 0.0789
# Epoch 134/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0943 - mean_absolute_error: 0.0943 - val_loss: 0.1267 - val_mean_absolute_error: 0.1267
# Epoch 135/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0896 - mean_absolute_error: 0.0896 - val_loss: 0.1612 - val_mean_absolute_error: 0.1612
# Epoch 136/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0903 - mean_absolute_error: 0.0903 - val_loss: 0.2152 - val_mean_absolute_error: 0.2152
# Epoch 137/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0909 - mean_absolute_error: 0.0909 - val_loss: 0.0858 - val_mean_absolute_error: 0.0858
# Epoch 138/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0885 - mean_absolute_error: 0.0885 - val_loss: 0.1883 - val_mean_absolute_error: 0.1883
# Epoch 139/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0873 - mean_absolute_error: 0.0873 - val_loss: 0.0933 - val_mean_absolute_error: 0.0933
# Epoch 140/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0893 - mean_absolute_error: 0.0893 - val_loss: 0.1016 - val_mean_absolute_error: 0.1016
# Epoch 141/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0904 - mean_absolute_error: 0.0904 - val_loss: 0.0846 - val_mean_absolute_error: 0.0846
# Epoch 142/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0917 - mean_absolute_error: 0.0917 - val_loss: 0.1578 - val_mean_absolute_error: 0.1578
# Epoch 143/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0880 - mean_absolute_error: 0.0880 - val_loss: 0.1405 - val_mean_absolute_error: 0.1405
# Epoch 144/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0917 - mean_absolute_error: 0.0917 - val_loss: 0.1129 - val_mean_absolute_error: 0.1129
# Epoch 145/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0972 - mean_absolute_error: 0.0972 - val_loss: 0.1937 - val_mean_absolute_error: 0.1937
# Epoch 146/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0878 - mean_absolute_error: 0.0878 - val_loss: 0.1951 - val_mean_absolute_error: 0.1951
# Epoch 147/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0919 - mean_absolute_error: 0.0919 - val_loss: 0.3129 - val_mean_absolute_error: 0.3129
# Epoch 148/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0976 - mean_absolute_error: 0.0976 - val_loss: 0.1833 - val_mean_absolute_error: 0.1833
# Epoch 149/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0934 - mean_absolute_error: 0.0934 - val_loss: 0.1882 - val_mean_absolute_error: 0.1882
# Epoch 150/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0868 - mean_absolute_error: 0.0868 - val_loss: 0.2152 - val_mean_absolute_error: 0.2152
# Epoch 151/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0884 - mean_absolute_error: 0.0884 - val_loss: 0.3559 - val_mean_absolute_error: 0.3559
# Epoch 152/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0893 - mean_absolute_error: 0.0893 - val_loss: 0.1379 - val_mean_absolute_error: 0.1379
# Epoch 153/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0898 - mean_absolute_error: 0.0898 - val_loss: 0.1592 - val_mean_absolute_error: 0.1592
# Epoch 154/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0898 - mean_absolute_error: 0.0898 - val_loss: 0.2814 - val_mean_absolute_error: 0.2814
# Epoch 155/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0841 - mean_absolute_error: 0.0841 - val_loss: 0.1309 - val_mean_absolute_error: 0.1309
# Epoch 156/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0953 - mean_absolute_error: 0.0953 - val_loss: 0.1878 - val_mean_absolute_error: 0.1878
# Epoch 157/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0906 - mean_absolute_error: 0.0906 - val_loss: 0.1586 - val_mean_absolute_error: 0.1586
# Epoch 158/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0918 - mean_absolute_error: 0.0918 - val_loss: 0.1621 - val_mean_absolute_error: 0.1621
# Epoch 159/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0867 - mean_absolute_error: 0.0867 - val_loss: 0.1063 - val_mean_absolute_error: 0.1063
# Epoch 160/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0894 - mean_absolute_error: 0.0894 - val_loss: 0.1787 - val_mean_absolute_error: 0.1787
# Epoch 161/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0917 - mean_absolute_error: 0.0917 - val_loss: 0.2015 - val_mean_absolute_error: 0.2015
# Epoch 162/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0945 - mean_absolute_error: 0.0945 - val_loss: 0.1866 - val_mean_absolute_error: 0.1866
# Epoch 163/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0865 - mean_absolute_error: 0.0865 - val_loss: 0.1770 - val_mean_absolute_error: 0.1770
# Epoch 164/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0906 - mean_absolute_error: 0.0906 - val_loss: 0.1874 - val_mean_absolute_error: 0.1874
# Epoch 165/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0891 - mean_absolute_error: 0.0891 - val_loss: 0.2213 - val_mean_absolute_error: 0.2213
# Epoch 166/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0912 - mean_absolute_error: 0.0912 - val_loss: 0.1387 - val_mean_absolute_error: 0.1387
# Epoch 167/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0931 - mean_absolute_error: 0.0931 - val_loss: 0.4024 - val_mean_absolute_error: 0.4024
# Epoch 168/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0872 - mean_absolute_error: 0.0872 - val_loss: 0.3110 - val_mean_absolute_error: 0.3110
# Epoch 169/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0864 - mean_absolute_error: 0.0864 - val_loss: 0.2455 - val_mean_absolute_error: 0.2455
# Epoch 170/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0869 - mean_absolute_error: 0.0869 - val_loss: 0.2564 - val_mean_absolute_error: 0.2564
# Epoch 171/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0884 - mean_absolute_error: 0.0884 - val_loss: 0.3866 - val_mean_absolute_error: 0.3866
# Epoch 172/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0912 - mean_absolute_error: 0.0912 - val_loss: 0.2082 - val_mean_absolute_error: 0.2082
# Epoch 173/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0995 - mean_absolute_error: 0.0995 - val_loss: 0.2433 - val_mean_absolute_error: 0.2433
# Epoch 174/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0934 - mean_absolute_error: 0.0934 - val_loss: 0.2033 - val_mean_absolute_error: 0.2033
# Epoch 175/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0937 - mean_absolute_error: 0.0937 - val_loss: 0.1064 - val_mean_absolute_error: 0.1064
# Epoch 176/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0905 - mean_absolute_error: 0.0905 - val_loss: 0.2017 - val_mean_absolute_error: 0.2017
# Epoch 177/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0952 - mean_absolute_error: 0.0952 - val_loss: 0.1456 - val_mean_absolute_error: 0.1456
# Epoch 178/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0937 - mean_absolute_error: 0.0937 - val_loss: 0.1145 - val_mean_absolute_error: 0.1145
# Epoch 179/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0915 - mean_absolute_error: 0.0915 - val_loss: 0.0997 - val_mean_absolute_error: 0.0997
# Epoch 180/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0874 - mean_absolute_error: 0.0874 - val_loss: 0.1497 - val_mean_absolute_error: 0.1497
# Epoch 181/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0887 - mean_absolute_error: 0.0887 - val_loss: 0.1656 - val_mean_absolute_error: 0.1656
# Epoch 182/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0897 - mean_absolute_error: 0.0897 - val_loss: 0.1955 - val_mean_absolute_error: 0.1955
# Epoch 183/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0875 - mean_absolute_error: 0.0875 - val_loss: 0.1991 - val_mean_absolute_error: 0.1991
# Epoch 00183: early stopping

# %%
model = keras.models.load_model("best_model.h5")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test error", test_acc)
print("Test loss", test_loss)
# Out:
# 1/1 [==============================] - 1s 894ms/step - loss: 0.0929 - mean_absolute_error: 0.0929
# Test error 0.09287939965724945
# Test loss 0.09287939965724945

# %%
mua = np.zeros((x_train.shape[0],))
# mus = np.zeros((x_train.shape[0],))
d = np.zeros((x_train.shape[0],))
miu = np.zeros((x_train.shape[0],1))

miu = model.predict(x_train)
mua = miu[:,0]
# mus = miu[:,1]
d = x_train[:,0,0]

# %%
err = np.zeros((x_train.shape[0],))

err = y_train[:,0]-mua
# err[:,1] = y_train[:,1]-mus

# print(mua[k],mus[k],d[k])
# print(y_train[k])

# %%
k=np.random.randint(0,x_train.shape[0],1)[0]
print(mua[k],d[k])
print(y_train[k])
# Out:
# 0.24350923 0.00921740010380745
# [0.3249036]

# %%
plt.plot(d,err)
plt.show()

# %%
# print(mua,mus,d)
# print(an2[i,1],an2[i,2],an2[i,0])
# plt.plot(abs(an1[:,1]-mua))
# plt.plot(abs(an1[:,2]-mus))
plt.hist(abs(y_train[:,0]-mua), bins=40,  facecolor="blue", edgecolor="black", alpha=0.7)
# plt.hist(abs(y_train[:,1]-mus), bins=40,  facecolor="green", edgecolor="black", alpha=0.7)
plt.show()

# %%
metric = "mean_absolute_error"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()

# %%
# 你可以用pca或者一些降维方法把特征搞一下
