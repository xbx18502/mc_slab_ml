# %%
# 同时计算mua和mus
import os  
import numpy as np
import struct
import matplotlib.pyplot as plt
import gc
import random
import math
from tensorflow import keras
import sklearn
# from scipy.interpolate import CubicSpline
from scipy.signal import find_peaks
from scipy.interpolate import interp1d

# %%
with open("C:\\Users\\Administrator\\source\\data\\dataset_test.bin", "rb") as file0:
    data1 = file0.read(4)
    NM1 = struct.unpack("i", data1)[0]
    sig2 = np.zeros((NM1,200),dtype = np.float32)
    an2 = np.zeros((NM1,4),dtype = np.float32)
    for i in range(NM1):
        for k in range(4):
            data1 = file0.read(4)
            an2[i,k] = struct.unpack("f", data1)[0]
        for k in range(200):
            data1 = file0.read(4)
            sig2[i,k] = struct.unpack("f", data1)[0]  
    # data1 = file0.read(len('end\0'))
    # end = struct.unpack("4s", data1)[0]

# %%
with open("C:\\Users\\Administrator\\source\\data\\dataset.bin", "rb") as file0:
    data1 = file0.read(4)
    NM1 = struct.unpack("i", data1)[0]
    sig1 = np.zeros((NM1,200),dtype = np.float32)
    an1 = np.zeros((NM1,4),dtype = np.float32)
    for i in range(NM1):
        for k in range(4):
            data1 = file0.read(4)
            an1[i,k] = struct.unpack("f", data1)[0]
        for k in range(200):
            data1 = file0.read(4)
            sig1[i,k] = struct.unpack("f", data1)[0]  
    # data1 = file0.read(len('end\0'))
    # end = struct.unpack("4s", data1)[0]

# %%
plt.axes(yscale = "log") 
for n in range(sig1.shape[0]):
    plt.plot(sig1[n])
plt.show()
print(NM1)
print(an2[-1])
# Out:
# 1262
# [1.24224685e-02 9.14926987e+01 1.54261023e+03 8.50000024e-01]

# %%
# def labeling(y,N):
#     ##############
#     a,b = y.shape
#     min0 = np.min(y,0)
#     max0 = np.max(y,0)
#     step = (max0-min0)/N
#     y2 = np.zeros((a,b,N))
    
#     # kernel = np.array([1]) 
#     # kernel = kernel/np.sum(kernel)
    
#     for i in range(a):
#         for j in range(b):
#             if(step[j]!=0):
#                 idx = (y[i,j]-min0[j])/step[j]-1
#                 y2[i,j,int(idx)] = 1
#             else:
#                 y2[i,j,0] = 1
#             # y2[i,j] = np.convolve(y2[i,j],kernel,mode='same')
            
#     return y2

# %%
xsig = sig1[0]
peaks, _ = find_peaks(xsig, height=0)
plt.plot(xsig)
plt.plot(peaks, xsig[peaks], "x")
plt.plot(np.zeros_like(xsig), "--", color="gray")
plt.show()

x = np.zeros((peaks.shape[0]+2,))
y = np.zeros((peaks.shape[0]+2,))
x[1:-1] = peaks
y[1:-1] = xsig[peaks]
x[-1] = sig1.shape[1]
plt.plot(x,y)
plt.show()

f2 = interp1d(x, y, kind='linear')
N = 200
xnew = np.linspace(0, N,num=N)
ynew = f2(xnew)

# plt.axes(yscale = "log") 
plt.plot(ynew)
plt.show()

# %%
def smooth_peak(xsig):
    peaks, _ = find_peaks(xsig, height=0)
    # plt.plot(xsig)
    # plt.plot(peaks, xsig[peaks], "x")
    # plt.plot(np.zeros_like(xsig), "--", color="gray")
    # plt.show()
    if(peaks.shape[0]!=0):
        x = np.zeros((peaks.shape[0]+3,))
        y = np.zeros((peaks.shape[0]+3,))
        x[1:-2] = peaks
        y[1:-2] = xsig[peaks]
        x[-1] = sig1.shape[1]
        y[-1] = 0
        x[-2] = peaks[-1]+5
        y[-2] = 0
        # plt.plot(x,y)
        # plt.show()

        f2 = interp1d(x, y, kind='linear')
        N = xsig.shape[0]
        xnew = np.linspace(0, N,num=N)
        ynew = f2(xnew)
    
    else:
        ynew = np.zeros((xsig.shape[0],))
    
    return ynew
#     # plt.axes(yscale = "log") 
#     plt.plot(ynew)
#     plt.show()

# %%
msig1 = np.zeros((sig1.shape[0],sig1.shape[1]))
an3 = np.zeros((an1.shape))
i_invalid = 0
flag = 0
for i in range(sig1.shape[0]):
    ynew = smooth_peak(sig1[i])
    if(np.all(ynew == 0)):
        i_invalid = i_invalid+1
    else:
        msig1[flag] = ynew
        an3[flag] = an1[i]
        flag = flag+1
msig1 = msig1[0:msig1.shape[0]-i_invalid,:]  
an3 = an3[0:an3.shape[0]-i_invalid,:]

i_invalid = 0
flag = 0
msig2 = np.zeros((sig2.shape[0],sig2.shape[1]))
an4 = np.zeros((an2.shape))
for i in range(sig2.shape[0]):
    ynew = smooth_peak(sig2[i])
    if(np.all(ynew == 0)):
        i_invalid = i_invalid+1
    
    else:
        msig2[flag] = ynew
        an4[flag] = an2[i]
        flag = flag+1
msig2 = msig2[0:msig2.shape[0]-i_invalid,:] 
an4 = an4[0:an4.shape[0]-i_invalid,:]

# msig1 = np.zeros((sig1.shape[0],sig1.shape[1]))
# for i in range(sig1.shape[0]):
#     msig1[i] = smooth_peak(sig1[i])
    
# msig2 = np.zeros((sig2.shape[0],sig2.shape[1]))
# for i in range(sig2.shape[0]):
#     msig2[i] = smooth_peak(sig2[i])

# %%
plt.axes(yscale = "log") 
for n in range(msig1.shape[0]):
    plt.plot(msig1[n])
plt.show()

# %%
x_train = msig1
y_train = an3
x_test = msig2
y_test = an4

x_train = (np.log10((x_train+1e-6)/1000)+9)/9
x_test = (np.log10((x_test+1e-6)/1000)+9)/9
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))
d_train = np.reshape(y_train[:,0],(y_train[:,0].shape[0],1,1)) # add thickness of sample into input data
d_test = np.reshape(y_test[:,0],(y_test[:,0].shape[0],1,1))

x_train = np.concatenate((d_train,x_train),axis = 1) 
x_test = np.concatenate((d_test,x_test),axis = 1)
y_train[:,1] = y_train[:,1]/1e2
y_test[:,1] = y_test[:,1]/1e2
y_train[:,2] = y_train[:,2]/200e2
y_test[:,2] = y_test[:,2]/200e2
y_train = y_train[:,1:3]
y_test = y_test[:,1:3]
# y_train = labeling(y_train,num_labels)[:,1,:] # select to predict what : 0:thickness 1:mua 2: mus
# y_test = labeling(y_test,num_labels)[:,1,:]
print('x_train.shape = '+str(x_train.shape)) 
print('y_train.shape = '+str(y_train.shape))
# Out:
# x_train.shape = (1258, 201, 1)
# y_train.shape = (1258, 2)

# %%
for n in range(x_train.shape[0]):
    plt.plot(x_train[n,1:])
plt.show()

# %%
# num_classes = y_train.shape[1]
########################################
# input_shape = (1,5,1)
# x = np.arange(np.prod(input_shape)).reshape(input_shape)      # test cropping#
# print(x)
# y = keras.layers.Cropping1D(cropping=(0,4))(x)
# z = keras.layers.Cropping1D(cropping=(1,0))(x)
# print(y)
# print(z)

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)
    
    d_1 = keras.layers.Cropping1D(cropping=(0,200))(input_layer)
    sig = keras.layers.Cropping1D(cropping=(1,0))(input_layer)
    
    conv1 = keras.layers.Conv1D(filters=16, kernel_size=3, padding="same")(sig)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=16, kernel_size=3, padding="same")(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=16, kernel_size=3, padding="same")(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)
    
    gap = keras.layers.Dense(16, activation='relu')(gap)
    gap = keras.layers.BatchNormalization()(gap)
    gap = keras.layers.Dropout(0.5)(gap)
    gap = keras.layers.Dense(16, activation='relu')(gap)
    
    
    d_1 = keras.layers.Dense(16, activation='relu')(d_1)
    d_1 = keras.layers.Dense(16, activation='relu')(d_1)
    d_1 = keras.layers.Reshape((16,))(d_1)
    
    
    
    merged = keras.layers.Concatenate()([d_1, gap])
    merged = keras.layers.Dense(8, activation='relu')(merged)
    
    output_layer = keras.layers.Dense(2, activation="linear")(merged)
#######################################################################
#     d_1 = keras.layers.Dense(16, activation='relu')(d_1)
#     # d_1 = keras.layers.Dense(10, activation='relu')(d_1)
#     d_1 = keras.layers.Reshape((16,))(d_1)
    
#     d_1 = keras.layers.BatchNormalization()(d_1)
#     gap = keras.layers.Dense(8, activation='relu')(gap)
#     gap = keras.layers.BatchNormalization()(gap)
    
#     merged = keras.layers.Concatenate()([d_1, gap])
#     merged = keras.layers.Dense(8, activation='relu')(merged)
    
#     output_layer = keras.layers.Dense(2, activation="linear")(merged)
##########################################################################    
    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])
keras.utils.plot_model(model, show_shapes=True)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %%
epochs = 500
batch_size = 32
#####################################################
index = [i for i in range(x_train.shape[0])]  
np.random.shuffle(index) 
x_train = x_train[index]
y_train = y_train[index]
####################################################
callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    # loss="mean_squared_error",
    loss="mean_absolute_error",
    metrics=["MeanAbsoluteError"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.4,
    verbose=1,
)
# Out:
# Epoch 1/500
# 24/24 [==============================] - 4s 47ms/step - loss: 0.4237 - mean_absolute_error: 0.4237 - val_loss: 0.3833 - val_mean_absolute_error: 0.3833
# Epoch 2/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.3148 - mean_absolute_error: 0.3148 - val_loss: 0.3354 - val_mean_absolute_error: 0.3354
# Epoch 3/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.2743 - mean_absolute_error: 0.2743 - val_loss: 0.3106 - val_mean_absolute_error: 0.3106
# Epoch 4/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.2442 - mean_absolute_error: 0.2442 - val_loss: 0.2774 - val_mean_absolute_error: 0.2774
# Epoch 5/500
# 24/24 [==============================] - 0s 15ms/step - loss: 0.2291 - mean_absolute_error: 0.2291 - val_loss: 0.2507 - val_mean_absolute_error: 0.2507
# Epoch 6/500
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2156 - mean_absolute_error: 0.2156 - val_loss: 0.2422 - val_mean_absolute_error: 0.2422
# Epoch 7/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.2036 - mean_absolute_error: 0.2036 - val_loss: 0.2373 - val_mean_absolute_error: 0.2373
# Epoch 8/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.2029 - mean_absolute_error: 0.2029 - val_loss: 0.2357 - val_mean_absolute_error: 0.2357
# Epoch 9/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1979 - mean_absolute_error: 0.1979 - val_loss: 0.2378 - val_mean_absolute_error: 0.2378
# Epoch 10/500
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1979 - mean_absolute_error: 0.1979 - val_loss: 0.2370 - val_mean_absolute_error: 0.2370
# Epoch 11/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1923 - mean_absolute_error: 0.1923 - val_loss: 0.2374 - val_mean_absolute_error: 0.2374
# Epoch 12/500
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1905 - mean_absolute_error: 0.1905 - val_loss: 0.2537 - val_mean_absolute_error: 0.2537
# Epoch 13/500
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1809 - mean_absolute_error: 0.1809 - val_loss: 0.2595 - val_mean_absolute_error: 0.2595
# Epoch 14/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1826 - mean_absolute_error: 0.1826 - val_loss: 0.2488 - val_mean_absolute_error: 0.2488
# Epoch 15/500
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1771 - mean_absolute_error: 0.1771 - val_loss: 0.2720 - val_mean_absolute_error: 0.2720
# Epoch 16/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1756 - mean_absolute_error: 0.1756 - val_loss: 0.2842 - val_mean_absolute_error: 0.2842
# Epoch 17/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1758 - mean_absolute_error: 0.1758 - val_loss: 0.2910 - val_mean_absolute_error: 0.2910
# Epoch 18/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1708 - mean_absolute_error: 0.1708 - val_loss: 0.3124 - val_mean_absolute_error: 0.3124
# Epoch 19/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1745 - mean_absolute_error: 0.1745 - val_loss: 0.2941 - val_mean_absolute_error: 0.2941
# Epoch 20/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1724 - mean_absolute_error: 0.1724 - val_loss: 0.2935 - val_mean_absolute_error: 0.2935
# Epoch 21/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1690 - mean_absolute_error: 0.1690 - val_loss: 0.2956 - val_mean_absolute_error: 0.2956
# Epoch 22/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1696 - mean_absolute_error: 0.1696 - val_loss: 0.2519 - val_mean_absolute_error: 0.2519
# Epoch 23/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1671 - mean_absolute_error: 0.1671 - val_loss: 0.2502 - val_mean_absolute_error: 0.2502
# Epoch 24/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1655 - mean_absolute_error: 0.1655 - val_loss: 0.2390 - val_mean_absolute_error: 0.2390
# Epoch 25/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1638 - mean_absolute_error: 0.1638 - val_loss: 0.2932 - val_mean_absolute_error: 0.2932
# Epoch 26/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1640 - mean_absolute_error: 0.1640 - val_loss: 0.3800 - val_mean_absolute_error: 0.3800
# Epoch 27/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1643 - mean_absolute_error: 0.1643 - val_loss: 0.4710 - val_mean_absolute_error: 0.4710
# Epoch 28/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1671 - mean_absolute_error: 0.1671 - val_loss: 0.3125 - val_mean_absolute_error: 0.3125
# Epoch 29/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1642 - mean_absolute_error: 0.1642 - val_loss: 0.3340 - val_mean_absolute_error: 0.3340
# Epoch 30/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1600 - mean_absolute_error: 0.1600 - val_loss: 0.2792 - val_mean_absolute_error: 0.2792
# Epoch 31/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1532 - mean_absolute_error: 0.1532 - val_loss: 0.2738 - val_mean_absolute_error: 0.2738
# Epoch 32/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1549 - mean_absolute_error: 0.1549 - val_loss: 0.2551 - val_mean_absolute_error: 0.2551
# Epoch 33/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1616 - mean_absolute_error: 0.1616 - val_loss: 0.2538 - val_mean_absolute_error: 0.2538
# Epoch 34/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1600 - mean_absolute_error: 0.1600 - val_loss: 0.3663 - val_mean_absolute_error: 0.3663
# Epoch 35/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1577 - mean_absolute_error: 0.1577 - val_loss: 0.3769 - val_mean_absolute_error: 0.3769
# Epoch 36/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1584 - mean_absolute_error: 0.1584 - val_loss: 0.2735 - val_mean_absolute_error: 0.2735
# Epoch 37/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1576 - mean_absolute_error: 0.1576 - val_loss: 0.2916 - val_mean_absolute_error: 0.2916
# Epoch 38/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1573 - mean_absolute_error: 0.1573 - val_loss: 0.2528 - val_mean_absolute_error: 0.2528
# Epoch 39/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1613 - mean_absolute_error: 0.1613 - val_loss: 0.2793 - val_mean_absolute_error: 0.2793
# Epoch 40/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1562 - mean_absolute_error: 0.1562 - val_loss: 0.2603 - val_mean_absolute_error: 0.2603
# Epoch 41/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1524 - mean_absolute_error: 0.1524 - val_loss: 0.2156 - val_mean_absolute_error: 0.2156
# Epoch 42/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1581 - mean_absolute_error: 0.1581 - val_loss: 0.2150 - val_mean_absolute_error: 0.2150
# Epoch 43/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1567 - mean_absolute_error: 0.1567 - val_loss: 0.2232 - val_mean_absolute_error: 0.2232
# Epoch 44/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1510 - mean_absolute_error: 0.1510 - val_loss: 0.2672 - val_mean_absolute_error: 0.2672
# Epoch 45/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1580 - mean_absolute_error: 0.1580 - val_loss: 0.2915 - val_mean_absolute_error: 0.2915
# Epoch 46/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1554 - mean_absolute_error: 0.1554 - val_loss: 0.2878 - val_mean_absolute_error: 0.2878
# Epoch 47/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1579 - mean_absolute_error: 0.1579 - val_loss: 0.2156 - val_mean_absolute_error: 0.2156
# Epoch 48/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1616 - mean_absolute_error: 0.1616 - val_loss: 0.2239 - val_mean_absolute_error: 0.2239
# Epoch 49/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1587 - mean_absolute_error: 0.1587 - val_loss: 0.2448 - val_mean_absolute_error: 0.2448
# Epoch 50/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1570 - mean_absolute_error: 0.1570 - val_loss: 0.2528 - val_mean_absolute_error: 0.2528
# Epoch 51/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1604 - mean_absolute_error: 0.1604 - val_loss: 0.3162 - val_mean_absolute_error: 0.3162
# Epoch 52/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1578 - mean_absolute_error: 0.1578 - val_loss: 0.7013 - val_mean_absolute_error: 0.7013
# Epoch 53/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1583 - mean_absolute_error: 0.1583 - val_loss: 0.5545 - val_mean_absolute_error: 0.5545
# Epoch 54/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1538 - mean_absolute_error: 0.1538 - val_loss: 0.1904 - val_mean_absolute_error: 0.1904
# Epoch 55/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1564 - mean_absolute_error: 0.1564 - val_loss: 0.2019 - val_mean_absolute_error: 0.2019
# Epoch 56/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1583 - mean_absolute_error: 0.1583 - val_loss: 0.1737 - val_mean_absolute_error: 0.1737
# Epoch 57/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1547 - mean_absolute_error: 0.1547 - val_loss: 0.2430 - val_mean_absolute_error: 0.2430
# Epoch 58/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1507 - mean_absolute_error: 0.1507 - val_loss: 0.1968 - val_mean_absolute_error: 0.1968
# Epoch 59/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1603 - mean_absolute_error: 0.1603 - val_loss: 0.3107 - val_mean_absolute_error: 0.3107
# Epoch 60/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1572 - mean_absolute_error: 0.1572 - val_loss: 0.2063 - val_mean_absolute_error: 0.2063
# Epoch 61/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1509 - mean_absolute_error: 0.1509 - val_loss: 0.2336 - val_mean_absolute_error: 0.2336
# Epoch 62/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1535 - mean_absolute_error: 0.1535 - val_loss: 0.3332 - val_mean_absolute_error: 0.3332
# Epoch 63/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1583 - mean_absolute_error: 0.1583 - val_loss: 0.2727 - val_mean_absolute_error: 0.2727
# Epoch 64/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1554 - mean_absolute_error: 0.1554 - val_loss: 0.2363 - val_mean_absolute_error: 0.2363
# Epoch 65/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1505 - mean_absolute_error: 0.1505 - val_loss: 0.2054 - val_mean_absolute_error: 0.2054
# Epoch 66/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1541 - mean_absolute_error: 0.1541 - val_loss: 0.2173 - val_mean_absolute_error: 0.2173
# Epoch 67/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1534 - mean_absolute_error: 0.1534 - val_loss: 0.1862 - val_mean_absolute_error: 0.1862
# Epoch 68/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1492 - mean_absolute_error: 0.1492 - val_loss: 0.2709 - val_mean_absolute_error: 0.2709
# Epoch 69/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1496 - mean_absolute_error: 0.1496 - val_loss: 0.2494 - val_mean_absolute_error: 0.2494
# Epoch 70/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1535 - mean_absolute_error: 0.1535 - val_loss: 0.2759 - val_mean_absolute_error: 0.2759
# Epoch 71/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1554 - mean_absolute_error: 0.1554 - val_loss: 0.2595 - val_mean_absolute_error: 0.2595
# Epoch 72/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1533 - mean_absolute_error: 0.1533 - val_loss: 0.2445 - val_mean_absolute_error: 0.2445
# Epoch 73/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1548 - mean_absolute_error: 0.1548 - val_loss: 0.2458 - val_mean_absolute_error: 0.2458
# Epoch 74/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1510 - mean_absolute_error: 0.1510 - val_loss: 0.2787 - val_mean_absolute_error: 0.2787
# Epoch 75/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1569 - mean_absolute_error: 0.1569 - val_loss: 0.2654 - val_mean_absolute_error: 0.2654
# Epoch 76/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1556 - mean_absolute_error: 0.1556 - val_loss: 0.2697 - val_mean_absolute_error: 0.2697
# Epoch 77/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1498 - mean_absolute_error: 0.1498 - val_loss: 0.2603 - val_mean_absolute_error: 0.2603
# Epoch 78/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1522 - mean_absolute_error: 0.1522 - val_loss: 0.2776 - val_mean_absolute_error: 0.2776
# Epoch 79/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1525 - mean_absolute_error: 0.1525 - val_loss: 0.2482 - val_mean_absolute_error: 0.2482
# Epoch 80/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1516 - mean_absolute_error: 0.1516 - val_loss: 0.2052 - val_mean_absolute_error: 0.2052
# Epoch 81/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1534 - mean_absolute_error: 0.1534 - val_loss: 0.1989 - val_mean_absolute_error: 0.1989
# Epoch 82/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1486 - mean_absolute_error: 0.1486 - val_loss: 0.1855 - val_mean_absolute_error: 0.1855
# Epoch 83/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1479 - mean_absolute_error: 0.1479 - val_loss: 0.1804 - val_mean_absolute_error: 0.1804
# Epoch 84/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1552 - mean_absolute_error: 0.1552 - val_loss: 0.1615 - val_mean_absolute_error: 0.1615
# Epoch 85/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1551 - mean_absolute_error: 0.1551 - val_loss: 0.2085 - val_mean_absolute_error: 0.2085
# Epoch 86/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1505 - mean_absolute_error: 0.1505 - val_loss: 0.2885 - val_mean_absolute_error: 0.2885
# Epoch 87/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1467 - mean_absolute_error: 0.1467 - val_loss: 0.2229 - val_mean_absolute_error: 0.2229
# Epoch 88/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1520 - mean_absolute_error: 0.1520 - val_loss: 0.1604 - val_mean_absolute_error: 0.1604
# Epoch 89/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1536 - mean_absolute_error: 0.1536 - val_loss: 0.1788 - val_mean_absolute_error: 0.1788
# Epoch 90/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1492 - mean_absolute_error: 0.1492 - val_loss: 0.1777 - val_mean_absolute_error: 0.1777
# Epoch 91/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1526 - mean_absolute_error: 0.1526 - val_loss: 0.2458 - val_mean_absolute_error: 0.2458
# Epoch 92/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1502 - mean_absolute_error: 0.1502 - val_loss: 0.1975 - val_mean_absolute_error: 0.1975
# Epoch 93/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1515 - mean_absolute_error: 0.1515 - val_loss: 0.1742 - val_mean_absolute_error: 0.1742
# Epoch 94/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1524 - mean_absolute_error: 0.1524 - val_loss: 0.2344 - val_mean_absolute_error: 0.2344
# Epoch 95/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1535 - mean_absolute_error: 0.1535 - val_loss: 0.2191 - val_mean_absolute_error: 0.2191
# Epoch 96/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1500 - mean_absolute_error: 0.1500 - val_loss: 0.2085 - val_mean_absolute_error: 0.2085
# Epoch 97/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1479 - mean_absolute_error: 0.1479 - val_loss: 0.2398 - val_mean_absolute_error: 0.2398
# Epoch 98/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1493 - mean_absolute_error: 0.1493 - val_loss: 0.2816 - val_mean_absolute_error: 0.2816
# Epoch 99/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1497 - mean_absolute_error: 0.1497 - val_loss: 0.2819 - val_mean_absolute_error: 0.2819
# Epoch 100/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1501 - mean_absolute_error: 0.1501 - val_loss: 0.2638 - val_mean_absolute_error: 0.2638
# Epoch 101/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1475 - mean_absolute_error: 0.1475 - val_loss: 0.2590 - val_mean_absolute_error: 0.2590
# Epoch 102/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1459 - mean_absolute_error: 0.1459 - val_loss: 0.2703 - val_mean_absolute_error: 0.2703
# Epoch 103/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1488 - mean_absolute_error: 0.1488 - val_loss: 0.3766 - val_mean_absolute_error: 0.3766
# Epoch 104/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1500 - mean_absolute_error: 0.1500 - val_loss: 0.4866 - val_mean_absolute_error: 0.4866
# Epoch 105/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1520 - mean_absolute_error: 0.1520 - val_loss: 0.4227 - val_mean_absolute_error: 0.4227
# Epoch 106/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1484 - mean_absolute_error: 0.1484 - val_loss: 0.1876 - val_mean_absolute_error: 0.1876
# Epoch 107/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1497 - mean_absolute_error: 0.1497 - val_loss: 0.2968 - val_mean_absolute_error: 0.2968
# Epoch 108/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1496 - mean_absolute_error: 0.1496 - val_loss: 0.3263 - val_mean_absolute_error: 0.3263
# Epoch 109/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1480 - mean_absolute_error: 0.1480 - val_loss: 0.1662 - val_mean_absolute_error: 0.1662
# Epoch 110/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1500 - mean_absolute_error: 0.1500 - val_loss: 0.2329 - val_mean_absolute_error: 0.2329
# Epoch 111/500
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1489 - mean_absolute_error: 0.1489 - val_loss: 0.2606 - val_mean_absolute_error: 0.2606
# Epoch 112/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1503 - mean_absolute_error: 0.1503 - val_loss: 0.2251 - val_mean_absolute_error: 0.2251
# Epoch 113/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1502 - mean_absolute_error: 0.1502 - val_loss: 0.2456 - val_mean_absolute_error: 0.2456
# Epoch 114/500
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1504 - mean_absolute_error: 0.1504 - val_loss: 0.1350 - val_mean_absolute_error: 0.1350
# Epoch 115/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1466 - mean_absolute_error: 0.1466 - val_loss: 0.1383 - val_mean_absolute_error: 0.1383
# Epoch 116/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1462 - mean_absolute_error: 0.1462 - val_loss: 0.1518 - val_mean_absolute_error: 0.1518
# Epoch 117/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1508 - mean_absolute_error: 0.1508 - val_loss: 0.1412 - val_mean_absolute_error: 0.1412
# Epoch 118/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1489 - mean_absolute_error: 0.1489 - val_loss: 0.1377 - val_mean_absolute_error: 0.1377
# Epoch 119/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1478 - mean_absolute_error: 0.1478 - val_loss: 0.1643 - val_mean_absolute_error: 0.1643
# Epoch 120/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1479 - mean_absolute_error: 0.1479 - val_loss: 0.1385 - val_mean_absolute_error: 0.1385
# Epoch 121/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1459 - mean_absolute_error: 0.1459 - val_loss: 0.1751 - val_mean_absolute_error: 0.1751
# Epoch 122/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1475 - mean_absolute_error: 0.1475 - val_loss: 0.1559 - val_mean_absolute_error: 0.1559
# Epoch 123/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1486 - mean_absolute_error: 0.1486 - val_loss: 0.1490 - val_mean_absolute_error: 0.1490
# Epoch 124/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1503 - mean_absolute_error: 0.1503 - val_loss: 0.1455 - val_mean_absolute_error: 0.1455
# Epoch 125/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1476 - mean_absolute_error: 0.1476 - val_loss: 0.1443 - val_mean_absolute_error: 0.1443
# Epoch 126/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1467 - mean_absolute_error: 0.1467 - val_loss: 0.1625 - val_mean_absolute_error: 0.1625
# Epoch 127/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1465 - mean_absolute_error: 0.1465 - val_loss: 0.1654 - val_mean_absolute_error: 0.1654
# Epoch 128/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1441 - mean_absolute_error: 0.1441 - val_loss: 0.1503 - val_mean_absolute_error: 0.1503
# Epoch 129/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1435 - mean_absolute_error: 0.1435 - val_loss: 0.1546 - val_mean_absolute_error: 0.1546
# Epoch 130/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1476 - mean_absolute_error: 0.1476 - val_loss: 0.1632 - val_mean_absolute_error: 0.1632
# Epoch 131/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1493 - mean_absolute_error: 0.1493 - val_loss: 0.1494 - val_mean_absolute_error: 0.1494
# Epoch 132/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1485 - mean_absolute_error: 0.1485 - val_loss: 0.1626 - val_mean_absolute_error: 0.1626
# Epoch 133/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1473 - mean_absolute_error: 0.1473 - val_loss: 0.1900 - val_mean_absolute_error: 0.1900
# Epoch 134/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1498 - mean_absolute_error: 0.1498 - val_loss: 0.1357 - val_mean_absolute_error: 0.1357
# Epoch 135/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1464 - mean_absolute_error: 0.1464 - val_loss: 0.1497 - val_mean_absolute_error: 0.1497
# Epoch 136/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1510 - mean_absolute_error: 0.1510 - val_loss: 0.1880 - val_mean_absolute_error: 0.1880
# Epoch 137/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1509 - mean_absolute_error: 0.1509 - val_loss: 0.1876 - val_mean_absolute_error: 0.1876
# Epoch 138/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1483 - mean_absolute_error: 0.1483 - val_loss: 0.1505 - val_mean_absolute_error: 0.1505
# Epoch 139/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1499 - mean_absolute_error: 0.1499 - val_loss: 0.1358 - val_mean_absolute_error: 0.1358
# Epoch 140/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1476 - mean_absolute_error: 0.1476 - val_loss: 0.1394 - val_mean_absolute_error: 0.1394
# Epoch 141/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1459 - mean_absolute_error: 0.1459 - val_loss: 0.1481 - val_mean_absolute_error: 0.1481
# Epoch 142/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1449 - mean_absolute_error: 0.1449 - val_loss: 0.1374 - val_mean_absolute_error: 0.1374
# Epoch 143/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1450 - mean_absolute_error: 0.1450 - val_loss: 0.1679 - val_mean_absolute_error: 0.1679
# Epoch 144/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1500 - mean_absolute_error: 0.1500 - val_loss: 0.1879 - val_mean_absolute_error: 0.1879
# Epoch 145/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1486 - mean_absolute_error: 0.1486 - val_loss: 0.2279 - val_mean_absolute_error: 0.2279
# Epoch 146/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1498 - mean_absolute_error: 0.1498 - val_loss: 0.2225 - val_mean_absolute_error: 0.2225
# Epoch 147/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1467 - mean_absolute_error: 0.1467 - val_loss: 0.1690 - val_mean_absolute_error: 0.1690
# Epoch 148/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1454 - mean_absolute_error: 0.1454 - val_loss: 0.1327 - val_mean_absolute_error: 0.1327
# Epoch 149/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1525 - mean_absolute_error: 0.1525 - val_loss: 0.1494 - val_mean_absolute_error: 0.1494
# Epoch 150/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1463 - mean_absolute_error: 0.1463 - val_loss: 0.1329 - val_mean_absolute_error: 0.1329
# Epoch 151/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1498 - mean_absolute_error: 0.1498 - val_loss: 0.1390 - val_mean_absolute_error: 0.1390
# Epoch 152/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1500 - mean_absolute_error: 0.1500 - val_loss: 0.1448 - val_mean_absolute_error: 0.1448
# Epoch 153/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1459 - mean_absolute_error: 0.1459 - val_loss: 0.1339 - val_mean_absolute_error: 0.1339
# Epoch 154/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1488 - mean_absolute_error: 0.1488 - val_loss: 0.1361 - val_mean_absolute_error: 0.1361
# Epoch 155/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1454 - mean_absolute_error: 0.1454 - val_loss: 0.1386 - val_mean_absolute_error: 0.1386
# Epoch 156/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1487 - mean_absolute_error: 0.1487 - val_loss: 0.1671 - val_mean_absolute_error: 0.1671
# Epoch 157/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1452 - mean_absolute_error: 0.1452 - val_loss: 0.1869 - val_mean_absolute_error: 0.1869
# Epoch 158/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1473 - mean_absolute_error: 0.1473 - val_loss: 0.1411 - val_mean_absolute_error: 0.1411
# Epoch 159/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1480 - mean_absolute_error: 0.1480 - val_loss: 0.1380 - val_mean_absolute_error: 0.1380
# Epoch 160/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1468 - mean_absolute_error: 0.1468 - val_loss: 0.1493 - val_mean_absolute_error: 0.1493
# Epoch 161/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1429 - mean_absolute_error: 0.1429 - val_loss: 0.1602 - val_mean_absolute_error: 0.1602
# Epoch 162/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1432 - mean_absolute_error: 0.1432 - val_loss: 0.1711 - val_mean_absolute_error: 0.1711
# Epoch 163/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1490 - mean_absolute_error: 0.1490 - val_loss: 0.1343 - val_mean_absolute_error: 0.1343
# Epoch 164/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1475 - mean_absolute_error: 0.1475 - val_loss: 0.1378 - val_mean_absolute_error: 0.1378
# Epoch 165/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1444 - mean_absolute_error: 0.1444 - val_loss: 0.1610 - val_mean_absolute_error: 0.1610
# Epoch 166/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1464 - mean_absolute_error: 0.1464 - val_loss: 0.1608 - val_mean_absolute_error: 0.1608
# Epoch 167/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1472 - mean_absolute_error: 0.1472 - val_loss: 0.1544 - val_mean_absolute_error: 0.1544
# Epoch 168/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1486 - mean_absolute_error: 0.1486 - val_loss: 0.1688 - val_mean_absolute_error: 0.1688
# Epoch 169/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1494 - mean_absolute_error: 0.1494 - val_loss: 0.1593 - val_mean_absolute_error: 0.1593
# Epoch 170/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1454 - mean_absolute_error: 0.1454 - val_loss: 0.1875 - val_mean_absolute_error: 0.1875
# Epoch 171/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1458 - mean_absolute_error: 0.1458 - val_loss: 0.2180 - val_mean_absolute_error: 0.2180
# Epoch 172/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1438 - mean_absolute_error: 0.1438 - val_loss: 0.2197 - val_mean_absolute_error: 0.2197
# Epoch 173/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1469 - mean_absolute_error: 0.1469 - val_loss: 0.2695 - val_mean_absolute_error: 0.2695
# Epoch 174/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1466 - mean_absolute_error: 0.1466 - val_loss: 0.1510 - val_mean_absolute_error: 0.1510
# Epoch 175/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1473 - mean_absolute_error: 0.1473 - val_loss: 0.1450 - val_mean_absolute_error: 0.1450
# Epoch 176/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1448 - mean_absolute_error: 0.1448 - val_loss: 0.1588 - val_mean_absolute_error: 0.1588
# Epoch 177/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1477 - mean_absolute_error: 0.1477 - val_loss: 0.2023 - val_mean_absolute_error: 0.2023
# Epoch 178/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1452 - mean_absolute_error: 0.1452 - val_loss: 0.2022 - val_mean_absolute_error: 0.2022
# Epoch 179/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1477 - mean_absolute_error: 0.1477 - val_loss: 0.1395 - val_mean_absolute_error: 0.1395
# Epoch 180/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1480 - mean_absolute_error: 0.1480 - val_loss: 0.1901 - val_mean_absolute_error: 0.1901
# Epoch 181/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1465 - mean_absolute_error: 0.1465 - val_loss: 0.1510 - val_mean_absolute_error: 0.1510
# Epoch 182/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1490 - mean_absolute_error: 0.1490 - val_loss: 0.1415 - val_mean_absolute_error: 0.1415
# Epoch 183/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1458 - mean_absolute_error: 0.1458 - val_loss: 0.1528 - val_mean_absolute_error: 0.1528
# Epoch 184/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1478 - mean_absolute_error: 0.1478 - val_loss: 0.1843 - val_mean_absolute_error: 0.1843
# Epoch 185/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1474 - mean_absolute_error: 0.1474 - val_loss: 0.1521 - val_mean_absolute_error: 0.1521
# Epoch 186/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1482 - mean_absolute_error: 0.1482 - val_loss: 0.1523 - val_mean_absolute_error: 0.1523
# Epoch 187/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1473 - mean_absolute_error: 0.1473 - val_loss: 0.1564 - val_mean_absolute_error: 0.1564
# Epoch 188/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1438 - mean_absolute_error: 0.1438 - val_loss: 0.1457 - val_mean_absolute_error: 0.1457
# Epoch 189/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1438 - mean_absolute_error: 0.1438 - val_loss: 0.1354 - val_mean_absolute_error: 0.1354
# Epoch 190/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1497 - mean_absolute_error: 0.1497 - val_loss: 0.1399 - val_mean_absolute_error: 0.1399
# Epoch 191/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1459 - mean_absolute_error: 0.1459 - val_loss: 0.1331 - val_mean_absolute_error: 0.1331
# Epoch 192/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1449 - mean_absolute_error: 0.1449 - val_loss: 0.1454 - val_mean_absolute_error: 0.1454
# Epoch 193/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1458 - mean_absolute_error: 0.1458 - val_loss: 0.1935 - val_mean_absolute_error: 0.1935
# Epoch 194/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1459 - mean_absolute_error: 0.1459 - val_loss: 0.1847 - val_mean_absolute_error: 0.1847
# Epoch 195/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1482 - mean_absolute_error: 0.1482 - val_loss: 0.1633 - val_mean_absolute_error: 0.1633
# Epoch 196/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1499 - mean_absolute_error: 0.1499 - val_loss: 0.1579 - val_mean_absolute_error: 0.1579
# Epoch 197/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1449 - mean_absolute_error: 0.1449 - val_loss: 0.1662 - val_mean_absolute_error: 0.1662
# Epoch 198/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1472 - mean_absolute_error: 0.1472 - val_loss: 0.1957 - val_mean_absolute_error: 0.1957
# Epoch 00198: early stopping

# %%
model = keras.models.load_model("best_model.h5")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test error", test_acc)
print("Test loss", test_loss)
# Out:
# 1/1 [==============================] - 0s 381ms/step - loss: 0.1520 - mean_absolute_error: 0.1520
# Test error 0.15197467803955078
# Test loss 0.15197467803955078

# %%
mua = np.zeros((x_train.shape[0],))
mus = np.zeros((x_train.shape[0],))
d = np.zeros((x_train.shape[0],))
miu = np.zeros((x_train.shape[0],2))

miu = model.predict(x_train)
mua = miu[:,0]
mus = miu[:,1]
d = x_train[:,0,0]

# %%
err = np.zeros((x_train.shape[0],2))

err[:,0] = y_train[:,0]-mua
err[:,1] = y_train[:,1]-mus
# print(mua[k],mus[k],d[k])
# print(y_train[k])

# %%
plt.plot(d,err[:,1])
plt.plot(d,err[:,0])
plt.show()

# %%
# print(mua,mus,d)
# print(an2[i,1],an2[i,2],an2[i,0])
# plt.plot(abs(an1[:,1]-mua))
# plt.plot(abs(an1[:,2]-mus))
plt.hist(y_train[:,0]-mua, bins=40,  facecolor="blue", edgecolor="black", alpha=0.7)
plt.hist(y_train[:,1]-mus, bins=40,  facecolor="green", edgecolor="black", alpha=0.7)
plt.show()

# %%
metric = "mean_absolute_error"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()

# %%
# 你可以用pca或者一些降维方法把特征搞一下
