# %%
# 不用PCA 而是 重新预处理输入量
import os  
import numpy as np
import struct
import matplotlib.pyplot as plt
import gc
import random
import math
from tensorflow import keras
import sklearn
# from scipy.interpolate import CubicSpline
from scipy.signal import find_peaks
from scipy.interpolate import interp1d

# %%
with open("C:\\Users\\Administrator\\source\\data\\dataset_test.bin", "rb") as file0:
    data1 = file0.read(4)
    NM1 = struct.unpack("i", data1)[0]
    sig2 = np.zeros((NM1,200),dtype = np.float32)
    an2 = np.zeros((NM1,4),dtype = np.float32)
    for i in range(NM1):
        for k in range(4):
            data1 = file0.read(4)
            an2[i,k] = struct.unpack("f", data1)[0]
        for k in range(200):
            data1 = file0.read(4)
            sig2[i,k] = struct.unpack("f", data1)[0]  
    # data1 = file0.read(len('end\0'))
    # end = struct.unpack("4s", data1)[0]

# %%
with open("C:\\Users\\Administrator\\source\\data\\dataset.bin", "rb") as file0:
    data1 = file0.read(4)
    NM1 = struct.unpack("i", data1)[0]
    sig1 = np.zeros((NM1,200),dtype = np.float32)
    an1 = np.zeros((NM1,4),dtype = np.float32)
    for i in range(NM1):
        for k in range(4):
            data1 = file0.read(4)
            an1[i,k] = struct.unpack("f", data1)[0]
        for k in range(200):
            data1 = file0.read(4)
            sig1[i,k] = struct.unpack("f", data1)[0]  
    # data1 = file0.read(len('end\0'))
    # end = struct.unpack("4s", data1)[0]

# %%
plt.axes(yscale = "log") 
for n in range(sig1.shape[0]):
    plt.plot(sig1[n])
plt.show()
print(NM1)
print(an2[-1])
# Out:
# 1262
# [1.24224685e-02 9.14926987e+01 1.54261023e+03 8.50000024e-01]

# %%
# def labeling(y,N):
#     ##############
#     a,b = y.shape
#     min0 = np.min(y,0)
#     max0 = np.max(y,0)
#     step = (max0-min0)/N
#     y2 = np.zeros((a,b,N))
    
#     # kernel = np.array([1]) 
#     # kernel = kernel/np.sum(kernel)
    
#     for i in range(a):
#         for j in range(b):
#             if(step[j]!=0):
#                 idx = (y[i,j]-min0[j])/step[j]-1
#                 y2[i,j,int(idx)] = 1
#             else:
#                 y2[i,j,0] = 1
#             # y2[i,j] = np.convolve(y2[i,j],kernel,mode='same')
            
#     return y2

# %%
xsig = sig1[0]
peaks, _ = find_peaks(xsig, height=0)
plt.plot(xsig)
plt.plot(peaks, xsig[peaks], "x")
plt.plot(np.zeros_like(xsig), "--", color="gray")
plt.show()

x = np.zeros((peaks.shape[0]+2,))
y = np.zeros((peaks.shape[0]+2,))
x[1:-1] = peaks
y[1:-1] = xsig[peaks]
x[-1] = sig1.shape[1]
plt.plot(x,y)
plt.show()

f2 = interp1d(x, y, kind='linear')
N = 200
xnew = np.linspace(0, N,num=N)
ynew = f2(xnew)

# plt.axes(yscale = "log") 
plt.plot(ynew)
plt.show()

# %%
def smooth_peak(xsig):
    peaks, _ = find_peaks(xsig, height=0)
    # plt.plot(xsig)
    # plt.plot(peaks, xsig[peaks], "x")
    # plt.plot(np.zeros_like(xsig), "--", color="gray")
    # plt.show()
    if(peaks.shape[0]!=0):
        x = np.zeros((peaks.shape[0]+3,))
        y = np.zeros((peaks.shape[0]+3,))
        x[1:-2] = peaks
        y[1:-2] = xsig[peaks]
        x[-1] = sig1.shape[1]
        y[-1] = 0
        x[-2] = peaks[-1]+5
        y[-2] = 0
        # plt.plot(x,y)
        # plt.show()

        f2 = interp1d(x, y, kind='linear')
        N = xsig.shape[0]
        xnew = np.linspace(0, N,num=N)
        ynew = f2(xnew)
    
    else:
        ynew = np.zeros((xsig.shape[0],))
    
    return ynew
#     # plt.axes(yscale = "log") 
#     plt.plot(ynew)
#     plt.show()

# %%
msig1 = np.zeros((sig1.shape[0],sig1.shape[1]))
for i in range(sig1.shape[0]):
    msig1[i] = smooth_peak(sig1[i])
    
msig2 = np.zeros((sig2.shape[0],sig2.shape[1]))
for i in range(sig2.shape[0]):
    msig2[i] = smooth_peak(sig2[i])

# %%
plt.axes(yscale = "log") 
for n in range(msig1.shape[0]):
    plt.plot(msig1[n])
plt.show()

# %%
print(sig1.shape)
print(an1.shape)
print(sig2.shape)
print(an2.shape)
# num_labels = 10
x_train = msig1
y_train = an1
x_test = msig2
y_test = an2

x_train = np.log10((x_train+1e-6)/1000)+11
x_test = np.log10((x_test+1e-6)/1000)+11
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))
d_train = np.reshape(y_train[:,0],(y_train[:,0].shape[0],1,1)) # add thickness of sample into input data
d_test = np.reshape(y_test[:,0],(y_test[:,0].shape[0],1,1))

x_train = np.concatenate((d_train,x_train),axis = 1) 
x_test = np.concatenate((d_test,x_test),axis = 1)
y_train[:,1] = y_train[:,1]/1e2
y_test[:,1] = y_test[:,1]/1e2
y_train[:,2] = y_train[:,2]/200e2
y_test[:,2] = y_test[:,2]/200e2
y_train = y_train[:,1:3]
y_test = y_test[:,1:3]
# y_train = labeling(y_train,num_labels)[:,1,:] # select to predict what : 0:thickness 1:mua 2: mus
# y_test = labeling(y_test,num_labels)[:,1,:]
print('x_train.shape = '+str(x_train.shape)) 
print('y_train.shape = '+str(y_train.shape))
# Out:
# (1262, 200)
# (1262, 4)
# (30, 200)
# (30, 4)
# x_train.shape = (1262, 201, 1)
# y_train.shape = (1262, 2)

# %%
for n in range(x_train.shape[0]):
    plt.plot(x_train[n,1:])
plt.show()

# %%
# num_classes = y_train.shape[1]
########################################
# input_shape = (1,5,1)
# x = np.arange(np.prod(input_shape)).reshape(input_shape)      # test cropping#
# print(x)
# y = keras.layers.Cropping1D(cropping=(0,4))(x)
# z = keras.layers.Cropping1D(cropping=(1,0))(x)
# print(y)
# print(z)

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)
    
    d_1 = keras.layers.Cropping1D(cropping=(0,200))(input_layer)
    sig = keras.layers.Cropping1D(cropping=(1,0))(input_layer)
    
    conv1 = keras.layers.Conv1D(filters=16, kernel_size=3, padding="same")(sig)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=16, kernel_size=3, padding="same")(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=16, kernel_size=3, padding="same")(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)
    
    gap = keras.layers.Dense(16, activation='relu')(gap)
    gap = keras.layers.BatchNormalization()(gap)
    gap = keras.layers.Dropout(0.5)(gap)
    gap = keras.layers.Dense(16, activation='relu')(gap)
    
    
    d_1 = keras.layers.Dense(16, activation='relu')(d_1)
    d_1 = keras.layers.Dense(16, activation='relu')(d_1)
    d_1 = keras.layers.Reshape((16,))(d_1)
    
    
    
    merged = keras.layers.Concatenate()([d_1, gap])
    merged = keras.layers.Dense(8, activation='relu')(merged)
    
    output_layer = keras.layers.Dense(2, activation="linear")(merged)
#######################################################################
#     d_1 = keras.layers.Dense(16, activation='relu')(d_1)
#     # d_1 = keras.layers.Dense(10, activation='relu')(d_1)
#     d_1 = keras.layers.Reshape((16,))(d_1)
    
#     d_1 = keras.layers.BatchNormalization()(d_1)
#     gap = keras.layers.Dense(8, activation='relu')(gap)
#     gap = keras.layers.BatchNormalization()(gap)
    
#     merged = keras.layers.Concatenate()([d_1, gap])
#     merged = keras.layers.Dense(8, activation='relu')(merged)
    
#     output_layer = keras.layers.Dense(2, activation="linear")(merged)
##########################################################################    
    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])
keras.utils.plot_model(model, show_shapes=True)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %%
epochs = 500
batch_size = 32
#####################################################
index = [i for i in range(x_train.shape[0])]  
np.random.shuffle(index) 
x_train = x_train[index]
y_train = y_train[index]
####################################################
callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="mean_squared_error",
    metrics=["MeanAbsoluteError"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.4,
    verbose=1,
)
# Out:
# Epoch 1/500
# 24/24 [==============================] - 2s 33ms/step - loss: 0.6441 - mean_absolute_error: 0.6620 - val_loss: 0.2905 - val_mean_absolute_error: 0.4618
# Epoch 2/500
# 24/24 [==============================] - 1s 22ms/step - loss: 0.3414 - mean_absolute_error: 0.4941 - val_loss: 0.2530 - val_mean_absolute_error: 0.4231
# Epoch 3/500
# 24/24 [==============================] - 1s 22ms/step - loss: 0.2518 - mean_absolute_error: 0.4160 - val_loss: 0.2082 - val_mean_absolute_error: 0.3763
# Epoch 4/500
# 24/24 [==============================] - 1s 22ms/step - loss: 0.1744 - mean_absolute_error: 0.3382 - val_loss: 0.1538 - val_mean_absolute_error: 0.3178
# Epoch 5/500
# 24/24 [==============================] - 1s 22ms/step - loss: 0.1303 - mean_absolute_error: 0.2915 - val_loss: 0.1043 - val_mean_absolute_error: 0.2646
# Epoch 6/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.0955 - mean_absolute_error: 0.2502 - val_loss: 0.0807 - val_mean_absolute_error: 0.2396
# Epoch 7/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0786 - mean_absolute_error: 0.2285 - val_loss: 0.0747 - val_mean_absolute_error: 0.2328
# Epoch 8/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0710 - mean_absolute_error: 0.2184 - val_loss: 0.0725 - val_mean_absolute_error: 0.2302
# Epoch 9/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0680 - mean_absolute_error: 0.2116 - val_loss: 0.0746 - val_mean_absolute_error: 0.2331
# Epoch 10/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0662 - mean_absolute_error: 0.2129 - val_loss: 0.0813 - val_mean_absolute_error: 0.2422
# Epoch 11/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0629 - mean_absolute_error: 0.2086 - val_loss: 0.0758 - val_mean_absolute_error: 0.2345
# Epoch 12/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0598 - mean_absolute_error: 0.2002 - val_loss: 0.0697 - val_mean_absolute_error: 0.2251
# Epoch 13/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0632 - mean_absolute_error: 0.2079 - val_loss: 0.0776 - val_mean_absolute_error: 0.2369
# Epoch 14/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0619 - mean_absolute_error: 0.2049 - val_loss: 0.0754 - val_mean_absolute_error: 0.2331
# Epoch 15/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0628 - mean_absolute_error: 0.2058 - val_loss: 0.0612 - val_mean_absolute_error: 0.2090
# Epoch 16/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0589 - mean_absolute_error: 0.1999 - val_loss: 0.0658 - val_mean_absolute_error: 0.2169
# Epoch 17/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0605 - mean_absolute_error: 0.2012 - val_loss: 0.0692 - val_mean_absolute_error: 0.2200
# Epoch 18/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0591 - mean_absolute_error: 0.1982 - val_loss: 0.0592 - val_mean_absolute_error: 0.2023
# Epoch 19/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0575 - mean_absolute_error: 0.1959 - val_loss: 0.0625 - val_mean_absolute_error: 0.2076
# Epoch 20/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0575 - mean_absolute_error: 0.1963 - val_loss: 0.0765 - val_mean_absolute_error: 0.2257
# Epoch 21/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0577 - mean_absolute_error: 0.1965 - val_loss: 0.0576 - val_mean_absolute_error: 0.1996
# Epoch 22/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0567 - mean_absolute_error: 0.1934 - val_loss: 0.0490 - val_mean_absolute_error: 0.1813
# Epoch 23/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0559 - mean_absolute_error: 0.1918 - val_loss: 0.0671 - val_mean_absolute_error: 0.2100
# Epoch 24/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0576 - mean_absolute_error: 0.1954 - val_loss: 0.0668 - val_mean_absolute_error: 0.2099
# Epoch 25/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0576 - mean_absolute_error: 0.1944 - val_loss: 0.0527 - val_mean_absolute_error: 0.1841
# Epoch 26/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0578 - mean_absolute_error: 0.1964 - val_loss: 0.0446 - val_mean_absolute_error: 0.1713
# Epoch 27/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0558 - mean_absolute_error: 0.1920 - val_loss: 0.0440 - val_mean_absolute_error: 0.1690
# Epoch 28/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0571 - mean_absolute_error: 0.1941 - val_loss: 0.0558 - val_mean_absolute_error: 0.1906
# Epoch 29/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0569 - mean_absolute_error: 0.1939 - val_loss: 0.0475 - val_mean_absolute_error: 0.1759
# Epoch 30/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0571 - mean_absolute_error: 0.1936 - val_loss: 0.0752 - val_mean_absolute_error: 0.2260
# Epoch 31/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0565 - mean_absolute_error: 0.1934 - val_loss: 0.0770 - val_mean_absolute_error: 0.2328
# Epoch 32/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0557 - mean_absolute_error: 0.1912 - val_loss: 0.0816 - val_mean_absolute_error: 0.2383
# Epoch 33/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0599 - mean_absolute_error: 0.1982 - val_loss: 0.0849 - val_mean_absolute_error: 0.2443
# Epoch 34/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0568 - mean_absolute_error: 0.1928 - val_loss: 0.0677 - val_mean_absolute_error: 0.2132
# Epoch 35/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0580 - mean_absolute_error: 0.1950 - val_loss: 0.0535 - val_mean_absolute_error: 0.1856
# Epoch 36/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0578 - mean_absolute_error: 0.1956 - val_loss: 0.0501 - val_mean_absolute_error: 0.1800
# Epoch 37/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0529 - mean_absolute_error: 0.1855 - val_loss: 0.0439 - val_mean_absolute_error: 0.1682
# Epoch 38/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0537 - mean_absolute_error: 0.1876 - val_loss: 0.0399 - val_mean_absolute_error: 0.1579
# Epoch 39/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0551 - mean_absolute_error: 0.1892 - val_loss: 0.0783 - val_mean_absolute_error: 0.2289
# Epoch 40/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0556 - mean_absolute_error: 0.1920 - val_loss: 0.1612 - val_mean_absolute_error: 0.3358
# Epoch 41/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0559 - mean_absolute_error: 0.1901 - val_loss: 0.0823 - val_mean_absolute_error: 0.2371
# Epoch 42/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0556 - mean_absolute_error: 0.1918 - val_loss: 0.0427 - val_mean_absolute_error: 0.1699
# Epoch 43/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0536 - mean_absolute_error: 0.1864 - val_loss: 0.0492 - val_mean_absolute_error: 0.1781
# Epoch 44/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0553 - mean_absolute_error: 0.1913 - val_loss: 0.0450 - val_mean_absolute_error: 0.1789
# Epoch 45/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0534 - mean_absolute_error: 0.1861 - val_loss: 0.0763 - val_mean_absolute_error: 0.2335
# Epoch 46/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0532 - mean_absolute_error: 0.1854 - val_loss: 0.1104 - val_mean_absolute_error: 0.2718
# Epoch 47/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0526 - mean_absolute_error: 0.1844 - val_loss: 0.0550 - val_mean_absolute_error: 0.1904
# Epoch 48/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0550 - mean_absolute_error: 0.1887 - val_loss: 0.0647 - val_mean_absolute_error: 0.2120
# Epoch 49/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0543 - mean_absolute_error: 0.1865 - val_loss: 0.0446 - val_mean_absolute_error: 0.1711
# Epoch 50/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0549 - mean_absolute_error: 0.1904 - val_loss: 0.0917 - val_mean_absolute_error: 0.2491
# Epoch 51/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0532 - mean_absolute_error: 0.1853 - val_loss: 0.0582 - val_mean_absolute_error: 0.1956
# Epoch 52/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0533 - mean_absolute_error: 0.1852 - val_loss: 0.0773 - val_mean_absolute_error: 0.2281
# Epoch 53/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0535 - mean_absolute_error: 0.1863 - val_loss: 0.0783 - val_mean_absolute_error: 0.2247
# Epoch 54/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0552 - mean_absolute_error: 0.1884 - val_loss: 0.0774 - val_mean_absolute_error: 0.2258
# Epoch 55/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0551 - mean_absolute_error: 0.1894 - val_loss: 0.0489 - val_mean_absolute_error: 0.1776
# Epoch 56/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0512 - mean_absolute_error: 0.1821 - val_loss: 0.1272 - val_mean_absolute_error: 0.2960
# Epoch 57/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0545 - mean_absolute_error: 0.1885 - val_loss: 0.0479 - val_mean_absolute_error: 0.1746
# Epoch 58/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0537 - mean_absolute_error: 0.1848 - val_loss: 0.0418 - val_mean_absolute_error: 0.1653
# Epoch 59/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0542 - mean_absolute_error: 0.1871 - val_loss: 0.0419 - val_mean_absolute_error: 0.1678
# Epoch 60/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0522 - mean_absolute_error: 0.1832 - val_loss: 0.0385 - val_mean_absolute_error: 0.1551
# Epoch 61/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0506 - mean_absolute_error: 0.1810 - val_loss: 0.0413 - val_mean_absolute_error: 0.1603
# Epoch 62/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0545 - mean_absolute_error: 0.1879 - val_loss: 0.0531 - val_mean_absolute_error: 0.1859
# Epoch 63/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0524 - mean_absolute_error: 0.1812 - val_loss: 0.0381 - val_mean_absolute_error: 0.1545
# Epoch 64/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0521 - mean_absolute_error: 0.1822 - val_loss: 0.0379 - val_mean_absolute_error: 0.1527
# Epoch 65/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0561 - mean_absolute_error: 0.1901 - val_loss: 0.0365 - val_mean_absolute_error: 0.1496
# Epoch 66/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0526 - mean_absolute_error: 0.1842 - val_loss: 0.0451 - val_mean_absolute_error: 0.1702
# Epoch 67/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0518 - mean_absolute_error: 0.1826 - val_loss: 0.0779 - val_mean_absolute_error: 0.2234
# Epoch 68/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0543 - mean_absolute_error: 0.1868 - val_loss: 0.0383 - val_mean_absolute_error: 0.1551
# Epoch 69/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0522 - mean_absolute_error: 0.1822 - val_loss: 0.0454 - val_mean_absolute_error: 0.1767
# Epoch 70/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0526 - mean_absolute_error: 0.1826 - val_loss: 0.0571 - val_mean_absolute_error: 0.2012
# Epoch 71/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0551 - mean_absolute_error: 0.1857 - val_loss: 0.0406 - val_mean_absolute_error: 0.1634
# Epoch 72/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0506 - mean_absolute_error: 0.1789 - val_loss: 0.0384 - val_mean_absolute_error: 0.1573
# Epoch 73/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0519 - mean_absolute_error: 0.1822 - val_loss: 0.0449 - val_mean_absolute_error: 0.1717
# Epoch 74/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0519 - mean_absolute_error: 0.1809 - val_loss: 0.0838 - val_mean_absolute_error: 0.2390
# Epoch 75/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0522 - mean_absolute_error: 0.1816 - val_loss: 0.0518 - val_mean_absolute_error: 0.1876
# Epoch 76/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0519 - mean_absolute_error: 0.1814 - val_loss: 0.0479 - val_mean_absolute_error: 0.1747
# Epoch 77/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0528 - mean_absolute_error: 0.1853 - val_loss: 0.0510 - val_mean_absolute_error: 0.1838
# Epoch 78/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0515 - mean_absolute_error: 0.1833 - val_loss: 0.0570 - val_mean_absolute_error: 0.1948
# Epoch 79/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0518 - mean_absolute_error: 0.1813 - val_loss: 0.0388 - val_mean_absolute_error: 0.1586
# Epoch 80/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0544 - mean_absolute_error: 0.1877 - val_loss: 0.0479 - val_mean_absolute_error: 0.1769
# Epoch 81/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0522 - mean_absolute_error: 0.1836 - val_loss: 0.0373 - val_mean_absolute_error: 0.1541
# Epoch 82/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0513 - mean_absolute_error: 0.1810 - val_loss: 0.0407 - val_mean_absolute_error: 0.1653
# Epoch 83/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0511 - mean_absolute_error: 0.1793 - val_loss: 0.0942 - val_mean_absolute_error: 0.2581
# Epoch 84/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0509 - mean_absolute_error: 0.1806 - val_loss: 0.0648 - val_mean_absolute_error: 0.2036
# Epoch 85/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0517 - mean_absolute_error: 0.1818 - val_loss: 0.0729 - val_mean_absolute_error: 0.2241
# Epoch 86/500
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0523 - mean_absolute_error: 0.1825 - val_loss: 0.0543 - val_mean_absolute_error: 0.1879
# Epoch 87/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0525 - mean_absolute_error: 0.1826 - val_loss: 0.0418 - val_mean_absolute_error: 0.1653
# Epoch 88/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0527 - mean_absolute_error: 0.1836 - val_loss: 0.0479 - val_mean_absolute_error: 0.1783
# Epoch 89/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0522 - mean_absolute_error: 0.1816 - val_loss: 0.0396 - val_mean_absolute_error: 0.1594
# Epoch 90/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0516 - mean_absolute_error: 0.1803 - val_loss: 0.0483 - val_mean_absolute_error: 0.1787
# Epoch 91/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0509 - mean_absolute_error: 0.1793 - val_loss: 0.0402 - val_mean_absolute_error: 0.1616
# Epoch 92/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0510 - mean_absolute_error: 0.1791 - val_loss: 0.0387 - val_mean_absolute_error: 0.1587
# Epoch 93/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0519 - mean_absolute_error: 0.1811 - val_loss: 0.0429 - val_mean_absolute_error: 0.1671
# Epoch 94/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0528 - mean_absolute_error: 0.1834 - val_loss: 0.0430 - val_mean_absolute_error: 0.1675
# Epoch 95/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0518 - mean_absolute_error: 0.1833 - val_loss: 0.0535 - val_mean_absolute_error: 0.1879
# Epoch 96/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0511 - mean_absolute_error: 0.1797 - val_loss: 0.0400 - val_mean_absolute_error: 0.1614
# Epoch 97/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0508 - mean_absolute_error: 0.1782 - val_loss: 0.0415 - val_mean_absolute_error: 0.1654
# Epoch 98/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0504 - mean_absolute_error: 0.1796 - val_loss: 0.0384 - val_mean_absolute_error: 0.1619
# Epoch 99/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0529 - mean_absolute_error: 0.1838 - val_loss: 0.0657 - val_mean_absolute_error: 0.2100
# Epoch 100/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0527 - mean_absolute_error: 0.1842 - val_loss: 0.0407 - val_mean_absolute_error: 0.1578
# Epoch 101/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0545 - mean_absolute_error: 0.1871 - val_loss: 0.0384 - val_mean_absolute_error: 0.1569
# Epoch 102/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0533 - mean_absolute_error: 0.1844 - val_loss: 0.1004 - val_mean_absolute_error: 0.2617
# Epoch 103/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0508 - mean_absolute_error: 0.1809 - val_loss: 0.1011 - val_mean_absolute_error: 0.2603
# Epoch 104/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0527 - mean_absolute_error: 0.1833 - val_loss: 0.0775 - val_mean_absolute_error: 0.2244
# Epoch 105/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0516 - mean_absolute_error: 0.1812 - val_loss: 0.0468 - val_mean_absolute_error: 0.1700
# Epoch 106/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0512 - mean_absolute_error: 0.1800 - val_loss: 0.0435 - val_mean_absolute_error: 0.1691
# Epoch 107/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0520 - mean_absolute_error: 0.1824 - val_loss: 0.0416 - val_mean_absolute_error: 0.1653
# Epoch 108/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0504 - mean_absolute_error: 0.1780 - val_loss: 0.0410 - val_mean_absolute_error: 0.1633
# Epoch 109/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0527 - mean_absolute_error: 0.1824 - val_loss: 0.0436 - val_mean_absolute_error: 0.1691
# Epoch 110/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0528 - mean_absolute_error: 0.1841 - val_loss: 0.0387 - val_mean_absolute_error: 0.1581
# Epoch 111/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0522 - mean_absolute_error: 0.1818 - val_loss: 0.0524 - val_mean_absolute_error: 0.1930
# Epoch 112/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0511 - mean_absolute_error: 0.1784 - val_loss: 0.0540 - val_mean_absolute_error: 0.1940
# Epoch 113/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0533 - mean_absolute_error: 0.1842 - val_loss: 0.0366 - val_mean_absolute_error: 0.1518
# Epoch 114/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0522 - mean_absolute_error: 0.1840 - val_loss: 0.0397 - val_mean_absolute_error: 0.1612
# Epoch 115/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0518 - mean_absolute_error: 0.1817 - val_loss: 0.0387 - val_mean_absolute_error: 0.1587
# Epoch 00115: early stopping

# %%
model = keras.models.load_model("best_model.h5")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test error", test_acc)
print("Test loss", test_loss)
# Out:
# 1/1 [==============================] - 0s 225ms/step - loss: 0.0490 - mean_absolute_error: 0.1814
# Test error 0.18138332664966583
# Test loss 0.04901634901762009

# %%
mua = np.zeros((x_train.shape[0],))
mus = np.zeros((x_train.shape[0],))
d = np.zeros((x_train.shape[0],))
miu = np.zeros((x_train.shape[0],2))

miu = model.predict(x_train)
mua = miu[:,0]
mus = miu[:,1]
d = x_train[:,0,0]

# %%
err = np.zeros((x_train.shape[0],2))

err[:,0] = y_train[:,0]-mua
err[:,1] = y_train[:,1]-mus
# print(mua[k],mus[k],d[k])
# print(y_train[k])

# %%
plt.plot(d,err[:,1])
plt.show()

# %%
# print(mua,mus,d)
# print(an2[i,1],an2[i,2],an2[i,0])
# plt.plot(abs(an1[:,1]-mua))
# plt.plot(abs(an1[:,2]-mus))
plt.hist(abs(y_train[:,0]-mua), bins=40,  facecolor="blue", edgecolor="black", alpha=0.7)
plt.hist(abs(y_train[:,1]-mus), bins=40,  facecolor="green", edgecolor="black", alpha=0.7)
plt.show()

# %%
metric = "mean_absolute_error"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()

# %%
# 你可以用pca或者一些降维方法把特征搞一下
