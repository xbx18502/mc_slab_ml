# %%
# 不用PCA 而是 重新预处理输入量
import os  
import numpy as np
import struct
import matplotlib.pyplot as plt
import gc
import random
import math
from tensorflow import keras
import sklearn
# from scipy.interpolate import CubicSpline
from scipy.signal import find_peaks
from scipy.interpolate import interp1d

# %%
with open("C:\\Users\\Administrator\\source\\data\\dataset_test.bin", "rb") as file0:
    data1 = file0.read(4)
    NM1 = struct.unpack("i", data1)[0]
    sig2 = np.zeros((NM1,200),dtype = np.float32)
    an2 = np.zeros((NM1,4),dtype = np.float32)
    for i in range(NM1):
        for k in range(4):
            data1 = file0.read(4)
            an2[i,k] = struct.unpack("f", data1)[0]
        for k in range(200):
            data1 = file0.read(4)
            sig2[i,k] = struct.unpack("f", data1)[0]  
    # data1 = file0.read(len('end\0'))
    # end = struct.unpack("4s", data1)[0]

# %%
with open("C:\\Users\\Administrator\\source\\data\\dataset.bin", "rb") as file0:
    data1 = file0.read(4)
    NM1 = struct.unpack("i", data1)[0]
    sig1 = np.zeros((NM1,200),dtype = np.float32)
    an1 = np.zeros((NM1,4),dtype = np.float32)
    for i in range(NM1):
        for k in range(4):
            data1 = file0.read(4)
            an1[i,k] = struct.unpack("f", data1)[0]
        for k in range(200):
            data1 = file0.read(4)
            sig1[i,k] = struct.unpack("f", data1)[0]  
    # data1 = file0.read(len('end\0'))
    # end = struct.unpack("4s", data1)[0]

# %%
plt.axes(yscale = "log") 
for n in range(sig1.shape[0]):
    plt.plot(sig1[n])
plt.show()
print(NM1)
print(an2[-1])
# Out:
# 1262
# [1.24224685e-02 9.14926987e+01 1.54261023e+03 8.50000024e-01]

# %%
# def labeling(y,N):
#     ##############
#     a,b = y.shape
#     min0 = np.min(y,0)
#     max0 = np.max(y,0)
#     step = (max0-min0)/N
#     y2 = np.zeros((a,b,N))
    
#     # kernel = np.array([1]) 
#     # kernel = kernel/np.sum(kernel)
    
#     for i in range(a):
#         for j in range(b):
#             if(step[j]!=0):
#                 idx = (y[i,j]-min0[j])/step[j]-1
#                 y2[i,j,int(idx)] = 1
#             else:
#                 y2[i,j,0] = 1
#             # y2[i,j] = np.convolve(y2[i,j],kernel,mode='same')
            
#     return y2

# %%
xsig = sig1[0]
peaks, _ = find_peaks(xsig, height=0)
plt.plot(xsig)
plt.plot(peaks, xsig[peaks], "x")
plt.plot(np.zeros_like(xsig), "--", color="gray")
plt.show()

x = np.zeros((peaks.shape[0]+2,))
y = np.zeros((peaks.shape[0]+2,))
x[1:-1] = peaks
y[1:-1] = xsig[peaks]
x[-1] = sig1.shape[1]
plt.plot(x,y)
plt.show()

f2 = interp1d(x, y, kind='linear')
N = 200
xnew = np.linspace(0, N,num=N)
ynew = f2(xnew)

# plt.axes(yscale = "log") 
plt.plot(ynew)
plt.show()

# %%
def smooth_peak(xsig):
    peaks, _ = find_peaks(xsig, height=0)
    # plt.plot(xsig)
    # plt.plot(peaks, xsig[peaks], "x")
    # plt.plot(np.zeros_like(xsig), "--", color="gray")
    # plt.show()
    if(peaks.shape[0]!=0):
        x = np.zeros((peaks.shape[0]+3,))
        y = np.zeros((peaks.shape[0]+3,))
        x[1:-2] = peaks
        y[1:-2] = xsig[peaks]
        x[-1] = sig1.shape[1]
        y[-1] = 0
        x[-2] = peaks[-1]+5
        y[-2] = 0
        # plt.plot(x,y)
        # plt.show()

        f2 = interp1d(x, y, kind='linear')
        N = xsig.shape[0]
        xnew = np.linspace(0, N,num=N)
        ynew = f2(xnew)
    
    else:
        ynew = np.zeros((xsig.shape[0],))
    
    return ynew
#     # plt.axes(yscale = "log") 
#     plt.plot(ynew)
#     plt.show()

# %%
msig1 = np.zeros((sig1.shape[0],sig1.shape[1]))
for i in range(sig1.shape[0]):
    msig1[i] = smooth_peak(sig1[i])
    
msig2 = np.zeros((sig2.shape[0],sig2.shape[1]))
for i in range(sig2.shape[0]):
    msig2[i] = smooth_peak(sig2[i])

# %%
plt.axes(yscale = "log") 
for n in range(msig1.shape[0]):
    plt.plot(msig1[n])
plt.show()

# %%
print(sig1.shape)
print(an1.shape)
print(sig2.shape)
print(an2.shape)
# num_labels = 10
x_train = msig1
y_train = an1
x_test = msig2
y_test = an2

x_train = np.log10((x_train+1e-6)/1000)+11
x_test = np.log10((x_test+1e-6)/1000)+11
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))
d_train = np.reshape(y_train[:,0],(y_train[:,0].shape[0],1,1)) # add thickness of sample into input data
d_test = np.reshape(y_test[:,0],(y_test[:,0].shape[0],1,1))

x_train = np.concatenate((d_train,x_train),axis = 1) 
x_test = np.concatenate((d_test,x_test),axis = 1)
y_train[:,1] = y_train[:,1]/1e2
y_test[:,1] = y_test[:,1]/1e2
y_train[:,2] = y_train[:,2]/200e2
y_test[:,2] = y_test[:,2]/200e2
y_train = y_train[:,2:3] # determine the nn to output mua/mus or mua+mus
y_test = y_test[:,2:3]
# y_train = labeling(y_train,num_labels)[:,1,:] # select to predict what : 0:thickness 1:mua 2: mus
# y_test = labeling(y_test,num_labels)[:,1,:]
print('x_train.shape = '+str(x_train.shape)) 
print('y_train.shape = '+str(y_train.shape))
# Out:
# (1262, 200)
# (1262, 4)
# (30, 200)
# (30, 4)
# x_train.shape = (1262, 201, 1)
# y_train.shape = (1262, 1)

# %%
for n in range(x_train.shape[0]):
    plt.plot(x_train[n,1:])
plt.show()

# %%
# num_classes = y_train.shape[1]
########################################
# input_shape = (1,5,1)
# x = np.arange(np.prod(input_shape)).reshape(input_shape)      # test cropping#
# print(x)
# y = keras.layers.Cropping1D(cropping=(0,4))(x)
# z = keras.layers.Cropping1D(cropping=(1,0))(x)
# print(y)
# print(z)

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)
    
    d_1 = keras.layers.Cropping1D(cropping=(0,200))(input_layer)
    sig = keras.layers.Cropping1D(cropping=(1,0))(input_layer)
    
    conv1 = keras.layers.Conv1D(filters=16, kernel_size=3, padding="same")(sig)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=16, kernel_size=3, padding="same")(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=16, kernel_size=3, padding="same")(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)
    
    gap = keras.layers.Dense(16, activation='relu')(gap)
    gap = keras.layers.BatchNormalization()(gap)
    gap = keras.layers.Dropout(0.5)(gap)
    gap = keras.layers.Dense(16, activation='relu')(gap)
    
    
    d_1 = keras.layers.Dense(8, activation='relu')(d_1)
    d_1 = keras.layers.Dense(8, activation='relu')(d_1)
    d_1 = keras.layers.Reshape((8,))(d_1)
    
    
    
    merged = keras.layers.Concatenate()([d_1, gap])
    merged = keras.layers.Dense(4, activation='relu')(merged)
    
    output_layer = keras.layers.Dense(1, activation="linear")(merged)
#######################################################################
#     d_1 = keras.layers.Dense(16, activation='relu')(d_1)
#     # d_1 = keras.layers.Dense(10, activation='relu')(d_1)
#     d_1 = keras.layers.Reshape((16,))(d_1)
    
#     d_1 = keras.layers.BatchNormalization()(d_1)
#     gap = keras.layers.Dense(8, activation='relu')(gap)
#     gap = keras.layers.BatchNormalization()(gap)
    
#     merged = keras.layers.Concatenate()([d_1, gap])
#     merged = keras.layers.Dense(8, activation='relu')(merged)
    
#     output_layer = keras.layers.Dense(2, activation="linear")(merged)
##########################################################################    
    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])
keras.utils.plot_model(model, show_shapes=True)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %%
epochs = 500
batch_size = 32
#####################################################
index = [i for i in range(x_train.shape[0])]  
np.random.shuffle(index) 
x_train = x_train[index]
y_train = y_train[index]
####################################################
callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="mean_squared_error",
    metrics=["MeanAbsoluteError"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.4,
    verbose=1,
)
# Out:
# Epoch 1/500
# 24/24 [==============================] - 2s 33ms/step - loss: 0.1653 - mean_absolute_error: 0.3280 - val_loss: 0.2529 - val_mean_absolute_error: 0.4243
# Epoch 2/500
# 24/24 [==============================] - 1s 23ms/step - loss: 0.1084 - mean_absolute_error: 0.2525 - val_loss: 0.2279 - val_mean_absolute_error: 0.3974
# Epoch 3/500
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0947 - mean_absolute_error: 0.2391 - val_loss: 0.1984 - val_mean_absolute_error: 0.3654
# Epoch 4/500
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0832 - mean_absolute_error: 0.2272 - val_loss: 0.1686 - val_mean_absolute_error: 0.3340
# Epoch 5/500
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0881 - mean_absolute_error: 0.2357 - val_loss: 0.1578 - val_mean_absolute_error: 0.3234
# Epoch 6/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.0786 - mean_absolute_error: 0.2229 - val_loss: 0.1506 - val_mean_absolute_error: 0.3167
# Epoch 7/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0735 - mean_absolute_error: 0.2184 - val_loss: 0.1369 - val_mean_absolute_error: 0.3023
# Epoch 8/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0755 - mean_absolute_error: 0.2224 - val_loss: 0.1209 - val_mean_absolute_error: 0.2843
# Epoch 9/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0663 - mean_absolute_error: 0.2052 - val_loss: 0.0988 - val_mean_absolute_error: 0.2547
# Epoch 10/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0686 - mean_absolute_error: 0.2119 - val_loss: 0.0875 - val_mean_absolute_error: 0.2446
# Epoch 11/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0626 - mean_absolute_error: 0.2039 - val_loss: 0.1107 - val_mean_absolute_error: 0.2689
# Epoch 12/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0604 - mean_absolute_error: 0.1973 - val_loss: 0.0817 - val_mean_absolute_error: 0.2409
# Epoch 13/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0602 - mean_absolute_error: 0.2017 - val_loss: 0.0787 - val_mean_absolute_error: 0.2369
# Epoch 14/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0579 - mean_absolute_error: 0.1970 - val_loss: 0.0773 - val_mean_absolute_error: 0.2331
# Epoch 15/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0567 - mean_absolute_error: 0.1969 - val_loss: 0.0763 - val_mean_absolute_error: 0.2300
# Epoch 16/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0553 - mean_absolute_error: 0.1893 - val_loss: 0.0887 - val_mean_absolute_error: 0.2414
# Epoch 17/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0590 - mean_absolute_error: 0.1984 - val_loss: 0.0729 - val_mean_absolute_error: 0.2237
# Epoch 18/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0542 - mean_absolute_error: 0.1928 - val_loss: 0.0723 - val_mean_absolute_error: 0.2242
# Epoch 19/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0548 - mean_absolute_error: 0.1915 - val_loss: 0.0657 - val_mean_absolute_error: 0.2128
# Epoch 20/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0565 - mean_absolute_error: 0.1950 - val_loss: 0.0677 - val_mean_absolute_error: 0.2166
# Epoch 21/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0540 - mean_absolute_error: 0.1882 - val_loss: 0.0626 - val_mean_absolute_error: 0.2131
# Epoch 22/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0563 - mean_absolute_error: 0.1927 - val_loss: 0.0680 - val_mean_absolute_error: 0.2243
# Epoch 23/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0564 - mean_absolute_error: 0.1941 - val_loss: 0.0605 - val_mean_absolute_error: 0.2059
# Epoch 24/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0519 - mean_absolute_error: 0.1849 - val_loss: 0.0604 - val_mean_absolute_error: 0.2101
# Epoch 25/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0525 - mean_absolute_error: 0.1849 - val_loss: 0.0664 - val_mean_absolute_error: 0.2028
# Epoch 26/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0524 - mean_absolute_error: 0.1880 - val_loss: 0.0551 - val_mean_absolute_error: 0.1946
# Epoch 27/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0511 - mean_absolute_error: 0.1846 - val_loss: 0.0544 - val_mean_absolute_error: 0.1924
# Epoch 28/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0520 - mean_absolute_error: 0.1840 - val_loss: 0.0537 - val_mean_absolute_error: 0.1927
# Epoch 29/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0561 - mean_absolute_error: 0.1940 - val_loss: 0.0713 - val_mean_absolute_error: 0.2140
# Epoch 30/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0528 - mean_absolute_error: 0.1873 - val_loss: 0.0650 - val_mean_absolute_error: 0.2199
# Epoch 31/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0509 - mean_absolute_error: 0.1832 - val_loss: 0.0601 - val_mean_absolute_error: 0.1998
# Epoch 32/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0532 - mean_absolute_error: 0.1887 - val_loss: 0.0657 - val_mean_absolute_error: 0.2047
# Epoch 33/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0514 - mean_absolute_error: 0.1871 - val_loss: 0.0586 - val_mean_absolute_error: 0.2007
# Epoch 34/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0520 - mean_absolute_error: 0.1902 - val_loss: 0.0518 - val_mean_absolute_error: 0.1862
# Epoch 35/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0540 - mean_absolute_error: 0.1923 - val_loss: 0.0552 - val_mean_absolute_error: 0.1867
# Epoch 36/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0525 - mean_absolute_error: 0.1878 - val_loss: 0.0596 - val_mean_absolute_error: 0.1943
# Epoch 37/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0478 - mean_absolute_error: 0.1810 - val_loss: 0.0509 - val_mean_absolute_error: 0.1840
# Epoch 38/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0529 - mean_absolute_error: 0.1892 - val_loss: 0.0679 - val_mean_absolute_error: 0.2059
# Epoch 39/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0505 - mean_absolute_error: 0.1852 - val_loss: 0.0570 - val_mean_absolute_error: 0.2023
# Epoch 40/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0526 - mean_absolute_error: 0.1873 - val_loss: 0.0755 - val_mean_absolute_error: 0.2145
# Epoch 41/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0506 - mean_absolute_error: 0.1835 - val_loss: 0.1116 - val_mean_absolute_error: 0.2675
# Epoch 42/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0513 - mean_absolute_error: 0.1858 - val_loss: 0.0566 - val_mean_absolute_error: 0.1882
# Epoch 43/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0517 - mean_absolute_error: 0.1856 - val_loss: 0.0588 - val_mean_absolute_error: 0.1960
# Epoch 44/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0496 - mean_absolute_error: 0.1826 - val_loss: 0.0569 - val_mean_absolute_error: 0.1987
# Epoch 45/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0503 - mean_absolute_error: 0.1831 - val_loss: 0.0534 - val_mean_absolute_error: 0.1883
# Epoch 46/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0492 - mean_absolute_error: 0.1839 - val_loss: 0.0591 - val_mean_absolute_error: 0.1869
# Epoch 47/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0502 - mean_absolute_error: 0.1819 - val_loss: 0.0527 - val_mean_absolute_error: 0.1799
# Epoch 48/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0487 - mean_absolute_error: 0.1785 - val_loss: 0.0787 - val_mean_absolute_error: 0.2391
# Epoch 49/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0480 - mean_absolute_error: 0.1803 - val_loss: 0.0567 - val_mean_absolute_error: 0.1970
# Epoch 50/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0492 - mean_absolute_error: 0.1816 - val_loss: 0.0686 - val_mean_absolute_error: 0.2227
# Epoch 51/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0502 - mean_absolute_error: 0.1817 - val_loss: 0.0507 - val_mean_absolute_error: 0.1778
# Epoch 52/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0489 - mean_absolute_error: 0.1820 - val_loss: 0.0577 - val_mean_absolute_error: 0.1918
# Epoch 53/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0502 - mean_absolute_error: 0.1844 - val_loss: 0.0709 - val_mean_absolute_error: 0.2271
# Epoch 54/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0506 - mean_absolute_error: 0.1844 - val_loss: 0.0624 - val_mean_absolute_error: 0.1936
# Epoch 55/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0500 - mean_absolute_error: 0.1822 - val_loss: 0.0824 - val_mean_absolute_error: 0.2268
# Epoch 56/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0474 - mean_absolute_error: 0.1767 - val_loss: 0.0578 - val_mean_absolute_error: 0.2009
# Epoch 57/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0482 - mean_absolute_error: 0.1808 - val_loss: 0.0605 - val_mean_absolute_error: 0.2034
# Epoch 58/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0499 - mean_absolute_error: 0.1808 - val_loss: 0.0543 - val_mean_absolute_error: 0.1884
# Epoch 59/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0469 - mean_absolute_error: 0.1773 - val_loss: 0.0566 - val_mean_absolute_error: 0.1943
# Epoch 60/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0490 - mean_absolute_error: 0.1808 - val_loss: 0.0521 - val_mean_absolute_error: 0.1843
# Epoch 61/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0484 - mean_absolute_error: 0.1806 - val_loss: 0.0595 - val_mean_absolute_error: 0.1955
# Epoch 62/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0470 - mean_absolute_error: 0.1763 - val_loss: 0.0809 - val_mean_absolute_error: 0.2396
# Epoch 63/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0478 - mean_absolute_error: 0.1789 - val_loss: 0.0783 - val_mean_absolute_error: 0.2211
# Epoch 64/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0459 - mean_absolute_error: 0.1745 - val_loss: 0.0570 - val_mean_absolute_error: 0.1996
# Epoch 65/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0481 - mean_absolute_error: 0.1780 - val_loss: 0.0594 - val_mean_absolute_error: 0.1905
# Epoch 66/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0464 - mean_absolute_error: 0.1761 - val_loss: 0.0673 - val_mean_absolute_error: 0.2036
# Epoch 67/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0465 - mean_absolute_error: 0.1754 - val_loss: 0.1227 - val_mean_absolute_error: 0.3051
# Epoch 68/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0448 - mean_absolute_error: 0.1721 - val_loss: 0.0966 - val_mean_absolute_error: 0.2547
# Epoch 69/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0465 - mean_absolute_error: 0.1752 - val_loss: 0.0626 - val_mean_absolute_error: 0.1955
# Epoch 70/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0462 - mean_absolute_error: 0.1745 - val_loss: 0.0646 - val_mean_absolute_error: 0.1982
# Epoch 71/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0473 - mean_absolute_error: 0.1766 - val_loss: 0.0920 - val_mean_absolute_error: 0.2606
# Epoch 72/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0461 - mean_absolute_error: 0.1765 - val_loss: 0.0496 - val_mean_absolute_error: 0.1759
# Epoch 73/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0452 - mean_absolute_error: 0.1723 - val_loss: 0.0603 - val_mean_absolute_error: 0.1900
# Epoch 74/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0462 - mean_absolute_error: 0.1760 - val_loss: 0.0629 - val_mean_absolute_error: 0.1951
# Epoch 75/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0445 - mean_absolute_error: 0.1706 - val_loss: 0.0556 - val_mean_absolute_error: 0.1829
# Epoch 76/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0466 - mean_absolute_error: 0.1760 - val_loss: 0.0498 - val_mean_absolute_error: 0.1835
# Epoch 77/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0447 - mean_absolute_error: 0.1739 - val_loss: 0.0692 - val_mean_absolute_error: 0.2040
# Epoch 78/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0466 - mean_absolute_error: 0.1739 - val_loss: 0.0580 - val_mean_absolute_error: 0.2035
# Epoch 79/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0454 - mean_absolute_error: 0.1747 - val_loss: 0.0789 - val_mean_absolute_error: 0.2226
# Epoch 80/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0451 - mean_absolute_error: 0.1732 - val_loss: 0.0485 - val_mean_absolute_error: 0.1795
# Epoch 81/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0455 - mean_absolute_error: 0.1705 - val_loss: 0.0495 - val_mean_absolute_error: 0.1791
# Epoch 82/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0441 - mean_absolute_error: 0.1732 - val_loss: 0.0558 - val_mean_absolute_error: 0.1939
# Epoch 83/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0439 - mean_absolute_error: 0.1700 - val_loss: 0.0656 - val_mean_absolute_error: 0.1988
# Epoch 84/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0450 - mean_absolute_error: 0.1729 - val_loss: 0.0535 - val_mean_absolute_error: 0.1904
# Epoch 85/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0453 - mean_absolute_error: 0.1728 - val_loss: 0.0525 - val_mean_absolute_error: 0.1767
# Epoch 86/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0436 - mean_absolute_error: 0.1721 - val_loss: 0.0539 - val_mean_absolute_error: 0.1856
# Epoch 87/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0450 - mean_absolute_error: 0.1726 - val_loss: 0.0578 - val_mean_absolute_error: 0.1865
# Epoch 88/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0420 - mean_absolute_error: 0.1665 - val_loss: 0.0503 - val_mean_absolute_error: 0.1819
# Epoch 89/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0432 - mean_absolute_error: 0.1699 - val_loss: 0.0590 - val_mean_absolute_error: 0.1912
# Epoch 90/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0424 - mean_absolute_error: 0.1663 - val_loss: 0.0611 - val_mean_absolute_error: 0.2090
# Epoch 91/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0445 - mean_absolute_error: 0.1698 - val_loss: 0.0545 - val_mean_absolute_error: 0.1816
# Epoch 92/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0430 - mean_absolute_error: 0.1692 - val_loss: 0.0517 - val_mean_absolute_error: 0.1899
# Epoch 93/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0417 - mean_absolute_error: 0.1636 - val_loss: 0.0666 - val_mean_absolute_error: 0.2017
# Epoch 94/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0419 - mean_absolute_error: 0.1650 - val_loss: 0.0466 - val_mean_absolute_error: 0.1702
# Epoch 95/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0412 - mean_absolute_error: 0.1649 - val_loss: 0.0489 - val_mean_absolute_error: 0.1821
# Epoch 96/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0423 - mean_absolute_error: 0.1667 - val_loss: 0.0581 - val_mean_absolute_error: 0.1930
# Epoch 97/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0423 - mean_absolute_error: 0.1630 - val_loss: 0.0472 - val_mean_absolute_error: 0.1753
# Epoch 98/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0446 - mean_absolute_error: 0.1722 - val_loss: 0.0573 - val_mean_absolute_error: 0.1870
# Epoch 99/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0424 - mean_absolute_error: 0.1678 - val_loss: 0.0485 - val_mean_absolute_error: 0.1774
# Epoch 100/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0434 - mean_absolute_error: 0.1686 - val_loss: 0.0598 - val_mean_absolute_error: 0.2041
# Epoch 101/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0432 - mean_absolute_error: 0.1670 - val_loss: 0.0941 - val_mean_absolute_error: 0.2627
# Epoch 102/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0410 - mean_absolute_error: 0.1662 - val_loss: 0.0840 - val_mean_absolute_error: 0.2482
# Epoch 103/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0432 - mean_absolute_error: 0.1686 - val_loss: 0.0491 - val_mean_absolute_error: 0.1720
# Epoch 104/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0417 - mean_absolute_error: 0.1638 - val_loss: 0.0468 - val_mean_absolute_error: 0.1733
# Epoch 105/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0419 - mean_absolute_error: 0.1637 - val_loss: 0.0653 - val_mean_absolute_error: 0.2162
# Epoch 106/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0426 - mean_absolute_error: 0.1676 - val_loss: 0.0484 - val_mean_absolute_error: 0.1777
# Epoch 107/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0420 - mean_absolute_error: 0.1658 - val_loss: 0.0746 - val_mean_absolute_error: 0.2347
# Epoch 108/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0428 - mean_absolute_error: 0.1678 - val_loss: 0.0617 - val_mean_absolute_error: 0.1910
# Epoch 109/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0427 - mean_absolute_error: 0.1668 - val_loss: 0.0519 - val_mean_absolute_error: 0.1729
# Epoch 110/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0418 - mean_absolute_error: 0.1649 - val_loss: 0.0469 - val_mean_absolute_error: 0.1732
# Epoch 111/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0410 - mean_absolute_error: 0.1659 - val_loss: 0.0598 - val_mean_absolute_error: 0.1845
# Epoch 112/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0408 - mean_absolute_error: 0.1634 - val_loss: 0.0543 - val_mean_absolute_error: 0.1923
# Epoch 113/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0398 - mean_absolute_error: 0.1633 - val_loss: 0.0613 - val_mean_absolute_error: 0.1905
# Epoch 114/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0432 - mean_absolute_error: 0.1685 - val_loss: 0.0453 - val_mean_absolute_error: 0.1669
# Epoch 115/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0422 - mean_absolute_error: 0.1676 - val_loss: 0.0575 - val_mean_absolute_error: 0.1850
# Epoch 116/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0424 - mean_absolute_error: 0.1641 - val_loss: 0.0518 - val_mean_absolute_error: 0.1848
# Epoch 117/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0405 - mean_absolute_error: 0.1609 - val_loss: 0.0773 - val_mean_absolute_error: 0.2191
# Epoch 118/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0409 - mean_absolute_error: 0.1617 - val_loss: 0.0913 - val_mean_absolute_error: 0.2595
# Epoch 119/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0413 - mean_absolute_error: 0.1633 - val_loss: 0.0531 - val_mean_absolute_error: 0.1804
# Epoch 120/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0424 - mean_absolute_error: 0.1650 - val_loss: 0.0490 - val_mean_absolute_error: 0.1822
# Epoch 121/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0405 - mean_absolute_error: 0.1621 - val_loss: 0.0457 - val_mean_absolute_error: 0.1732
# Epoch 122/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0418 - mean_absolute_error: 0.1652 - val_loss: 0.0590 - val_mean_absolute_error: 0.1951
# Epoch 123/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0407 - mean_absolute_error: 0.1647 - val_loss: 0.0763 - val_mean_absolute_error: 0.2333
# Epoch 124/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0410 - mean_absolute_error: 0.1651 - val_loss: 0.0499 - val_mean_absolute_error: 0.1708
# Epoch 125/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0409 - mean_absolute_error: 0.1622 - val_loss: 0.0495 - val_mean_absolute_error: 0.1804
# Epoch 126/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0400 - mean_absolute_error: 0.1624 - val_loss: 0.0457 - val_mean_absolute_error: 0.1738
# Epoch 127/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0407 - mean_absolute_error: 0.1619 - val_loss: 0.0663 - val_mean_absolute_error: 0.2176
# Epoch 128/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0429 - mean_absolute_error: 0.1685 - val_loss: 0.0547 - val_mean_absolute_error: 0.1912
# Epoch 129/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0393 - mean_absolute_error: 0.1599 - val_loss: 0.0654 - val_mean_absolute_error: 0.1976
# Epoch 130/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0397 - mean_absolute_error: 0.1598 - val_loss: 0.0529 - val_mean_absolute_error: 0.1934
# Epoch 131/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0402 - mean_absolute_error: 0.1636 - val_loss: 0.0482 - val_mean_absolute_error: 0.1692
# Epoch 132/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0387 - mean_absolute_error: 0.1605 - val_loss: 0.0727 - val_mean_absolute_error: 0.2275
# Epoch 133/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0406 - mean_absolute_error: 0.1618 - val_loss: 0.0581 - val_mean_absolute_error: 0.1857
# Epoch 134/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0394 - mean_absolute_error: 0.1623 - val_loss: 0.0923 - val_mean_absolute_error: 0.2618
# Epoch 135/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0400 - mean_absolute_error: 0.1587 - val_loss: 0.0507 - val_mean_absolute_error: 0.1797
# Epoch 136/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0374 - mean_absolute_error: 0.1570 - val_loss: 0.0441 - val_mean_absolute_error: 0.1654
# Epoch 137/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0390 - mean_absolute_error: 0.1580 - val_loss: 0.0534 - val_mean_absolute_error: 0.1801
# Epoch 138/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0392 - mean_absolute_error: 0.1591 - val_loss: 0.0523 - val_mean_absolute_error: 0.1736
# Epoch 139/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0388 - mean_absolute_error: 0.1587 - val_loss: 0.0437 - val_mean_absolute_error: 0.1581
# Epoch 140/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0379 - mean_absolute_error: 0.1569 - val_loss: 0.0534 - val_mean_absolute_error: 0.1838
# Epoch 141/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0398 - mean_absolute_error: 0.1614 - val_loss: 0.0515 - val_mean_absolute_error: 0.1908
# Epoch 142/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0390 - mean_absolute_error: 0.1581 - val_loss: 0.0473 - val_mean_absolute_error: 0.1654
# Epoch 143/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0383 - mean_absolute_error: 0.1584 - val_loss: 0.0494 - val_mean_absolute_error: 0.1656
# Epoch 144/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0388 - mean_absolute_error: 0.1581 - val_loss: 0.0442 - val_mean_absolute_error: 0.1688
# Epoch 145/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0386 - mean_absolute_error: 0.1585 - val_loss: 0.0435 - val_mean_absolute_error: 0.1597
# Epoch 146/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0371 - mean_absolute_error: 0.1531 - val_loss: 0.0461 - val_mean_absolute_error: 0.1743
# Epoch 147/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0372 - mean_absolute_error: 0.1538 - val_loss: 0.0495 - val_mean_absolute_error: 0.1671
# Epoch 148/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0371 - mean_absolute_error: 0.1550 - val_loss: 0.0437 - val_mean_absolute_error: 0.1594
# Epoch 149/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0381 - mean_absolute_error: 0.1566 - val_loss: 0.0450 - val_mean_absolute_error: 0.1608
# Epoch 150/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0372 - mean_absolute_error: 0.1531 - val_loss: 0.0489 - val_mean_absolute_error: 0.1843
# Epoch 151/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0372 - mean_absolute_error: 0.1565 - val_loss: 0.0505 - val_mean_absolute_error: 0.1839
# Epoch 152/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0361 - mean_absolute_error: 0.1531 - val_loss: 0.0612 - val_mean_absolute_error: 0.2077
# Epoch 153/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0382 - mean_absolute_error: 0.1554 - val_loss: 0.0505 - val_mean_absolute_error: 0.1808
# Epoch 154/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0377 - mean_absolute_error: 0.1560 - val_loss: 0.0417 - val_mean_absolute_error: 0.1599
# Epoch 155/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0369 - mean_absolute_error: 0.1544 - val_loss: 0.0577 - val_mean_absolute_error: 0.1831
# Epoch 156/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0376 - mean_absolute_error: 0.1558 - val_loss: 0.0458 - val_mean_absolute_error: 0.1601
# Epoch 157/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0363 - mean_absolute_error: 0.1517 - val_loss: 0.0552 - val_mean_absolute_error: 0.1822
# Epoch 158/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0375 - mean_absolute_error: 0.1576 - val_loss: 0.0453 - val_mean_absolute_error: 0.1599
# Epoch 159/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0364 - mean_absolute_error: 0.1510 - val_loss: 0.0510 - val_mean_absolute_error: 0.1800
# Epoch 160/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0377 - mean_absolute_error: 0.1543 - val_loss: 0.0424 - val_mean_absolute_error: 0.1566
# Epoch 161/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0362 - mean_absolute_error: 0.1544 - val_loss: 0.0438 - val_mean_absolute_error: 0.1574
# Epoch 162/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0352 - mean_absolute_error: 0.1497 - val_loss: 0.0474 - val_mean_absolute_error: 0.1736
# Epoch 163/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0364 - mean_absolute_error: 0.1527 - val_loss: 0.0684 - val_mean_absolute_error: 0.1967
# Epoch 164/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0387 - mean_absolute_error: 0.1585 - val_loss: 0.0510 - val_mean_absolute_error: 0.1777
# Epoch 165/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0371 - mean_absolute_error: 0.1531 - val_loss: 0.0459 - val_mean_absolute_error: 0.1670
# Epoch 166/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0363 - mean_absolute_error: 0.1518 - val_loss: 0.0520 - val_mean_absolute_error: 0.1713
# Epoch 167/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0380 - mean_absolute_error: 0.1560 - val_loss: 0.0497 - val_mean_absolute_error: 0.1867
# Epoch 168/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0362 - mean_absolute_error: 0.1523 - val_loss: 0.0579 - val_mean_absolute_error: 0.2030
# Epoch 169/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0359 - mean_absolute_error: 0.1534 - val_loss: 0.0432 - val_mean_absolute_error: 0.1557
# Epoch 170/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0365 - mean_absolute_error: 0.1520 - val_loss: 0.0461 - val_mean_absolute_error: 0.1609
# Epoch 171/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0357 - mean_absolute_error: 0.1515 - val_loss: 0.0429 - val_mean_absolute_error: 0.1610
# Epoch 172/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0360 - mean_absolute_error: 0.1501 - val_loss: 0.0436 - val_mean_absolute_error: 0.1570
# Epoch 173/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0357 - mean_absolute_error: 0.1523 - val_loss: 0.0628 - val_mean_absolute_error: 0.1925
# Epoch 174/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0381 - mean_absolute_error: 0.1579 - val_loss: 0.0459 - val_mean_absolute_error: 0.1751
# Epoch 175/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0375 - mean_absolute_error: 0.1543 - val_loss: 0.0512 - val_mean_absolute_error: 0.1755
# Epoch 176/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0361 - mean_absolute_error: 0.1527 - val_loss: 0.0649 - val_mean_absolute_error: 0.1986
# Epoch 177/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0362 - mean_absolute_error: 0.1528 - val_loss: 0.0479 - val_mean_absolute_error: 0.1705
# Epoch 178/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0341 - mean_absolute_error: 0.1476 - val_loss: 0.0429 - val_mean_absolute_error: 0.1554
# Epoch 179/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0370 - mean_absolute_error: 0.1538 - val_loss: 0.0492 - val_mean_absolute_error: 0.1712
# Epoch 180/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0371 - mean_absolute_error: 0.1550 - val_loss: 0.0420 - val_mean_absolute_error: 0.1594
# Epoch 181/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0355 - mean_absolute_error: 0.1527 - val_loss: 0.0458 - val_mean_absolute_error: 0.1589
# Epoch 182/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0355 - mean_absolute_error: 0.1521 - val_loss: 0.0472 - val_mean_absolute_error: 0.1628
# Epoch 183/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0356 - mean_absolute_error: 0.1510 - val_loss: 0.0485 - val_mean_absolute_error: 0.1780
# Epoch 184/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0349 - mean_absolute_error: 0.1489 - val_loss: 0.0432 - val_mean_absolute_error: 0.1622
# Epoch 185/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0345 - mean_absolute_error: 0.1477 - val_loss: 0.0476 - val_mean_absolute_error: 0.1674
# Epoch 186/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0360 - mean_absolute_error: 0.1531 - val_loss: 0.0595 - val_mean_absolute_error: 0.1883
# Epoch 187/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0348 - mean_absolute_error: 0.1485 - val_loss: 0.0445 - val_mean_absolute_error: 0.1697
# Epoch 188/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0375 - mean_absolute_error: 0.1538 - val_loss: 0.0501 - val_mean_absolute_error: 0.1710
# Epoch 189/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0358 - mean_absolute_error: 0.1532 - val_loss: 0.0423 - val_mean_absolute_error: 0.1611
# Epoch 190/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0350 - mean_absolute_error: 0.1486 - val_loss: 0.0414 - val_mean_absolute_error: 0.1564
# Epoch 191/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0342 - mean_absolute_error: 0.1488 - val_loss: 0.0447 - val_mean_absolute_error: 0.1726
# Epoch 192/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0347 - mean_absolute_error: 0.1489 - val_loss: 0.0444 - val_mean_absolute_error: 0.1656
# Epoch 193/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0344 - mean_absolute_error: 0.1497 - val_loss: 0.0446 - val_mean_absolute_error: 0.1651
# Epoch 194/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0352 - mean_absolute_error: 0.1492 - val_loss: 0.0569 - val_mean_absolute_error: 0.1836
# Epoch 195/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0348 - mean_absolute_error: 0.1481 - val_loss: 0.0447 - val_mean_absolute_error: 0.1633
# Epoch 196/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0346 - mean_absolute_error: 0.1499 - val_loss: 0.0418 - val_mean_absolute_error: 0.1560
# Epoch 197/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0343 - mean_absolute_error: 0.1463 - val_loss: 0.0431 - val_mean_absolute_error: 0.1547
# Epoch 198/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0345 - mean_absolute_error: 0.1484 - val_loss: 0.0425 - val_mean_absolute_error: 0.1569
# Epoch 199/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0344 - mean_absolute_error: 0.1509 - val_loss: 0.0452 - val_mean_absolute_error: 0.1593
# Epoch 200/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0347 - mean_absolute_error: 0.1476 - val_loss: 0.0439 - val_mean_absolute_error: 0.1547
# Epoch 201/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0339 - mean_absolute_error: 0.1457 - val_loss: 0.0494 - val_mean_absolute_error: 0.1859
# Epoch 202/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0354 - mean_absolute_error: 0.1488 - val_loss: 0.0492 - val_mean_absolute_error: 0.1854
# Epoch 203/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0362 - mean_absolute_error: 0.1517 - val_loss: 0.0450 - val_mean_absolute_error: 0.1583
# Epoch 204/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0339 - mean_absolute_error: 0.1481 - val_loss: 0.0443 - val_mean_absolute_error: 0.1564
# Epoch 205/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0333 - mean_absolute_error: 0.1475 - val_loss: 0.0433 - val_mean_absolute_error: 0.1559
# Epoch 206/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0348 - mean_absolute_error: 0.1482 - val_loss: 0.0421 - val_mean_absolute_error: 0.1614
# Epoch 207/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0349 - mean_absolute_error: 0.1490 - val_loss: 0.0456 - val_mean_absolute_error: 0.1616
# Epoch 208/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0352 - mean_absolute_error: 0.1471 - val_loss: 0.0426 - val_mean_absolute_error: 0.1525
# Epoch 209/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0356 - mean_absolute_error: 0.1501 - val_loss: 0.0453 - val_mean_absolute_error: 0.1739
# Epoch 210/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0350 - mean_absolute_error: 0.1505 - val_loss: 0.0459 - val_mean_absolute_error: 0.1637
# Epoch 211/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0344 - mean_absolute_error: 0.1476 - val_loss: 0.0458 - val_mean_absolute_error: 0.1654
# Epoch 212/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0338 - mean_absolute_error: 0.1471 - val_loss: 0.0436 - val_mean_absolute_error: 0.1631
# Epoch 213/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0343 - mean_absolute_error: 0.1476 - val_loss: 0.0440 - val_mean_absolute_error: 0.1542
# Epoch 214/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0343 - mean_absolute_error: 0.1462 - val_loss: 0.0401 - val_mean_absolute_error: 0.1561
# Epoch 215/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0352 - mean_absolute_error: 0.1493 - val_loss: 0.0409 - val_mean_absolute_error: 0.1502
# Epoch 216/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0326 - mean_absolute_error: 0.1428 - val_loss: 0.0459 - val_mean_absolute_error: 0.1700
# Epoch 217/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0347 - mean_absolute_error: 0.1495 - val_loss: 0.0451 - val_mean_absolute_error: 0.1561
# Epoch 218/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0359 - mean_absolute_error: 0.1489 - val_loss: 0.0415 - val_mean_absolute_error: 0.1577
# Epoch 219/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0347 - mean_absolute_error: 0.1478 - val_loss: 0.0454 - val_mean_absolute_error: 0.1716
# Epoch 220/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0335 - mean_absolute_error: 0.1470 - val_loss: 0.0445 - val_mean_absolute_error: 0.1673
# Epoch 221/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0345 - mean_absolute_error: 0.1482 - val_loss: 0.0438 - val_mean_absolute_error: 0.1573
# Epoch 222/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0337 - mean_absolute_error: 0.1457 - val_loss: 0.0446 - val_mean_absolute_error: 0.1556
# Epoch 223/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0362 - mean_absolute_error: 0.1517 - val_loss: 0.0439 - val_mean_absolute_error: 0.1557
# Epoch 224/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0331 - mean_absolute_error: 0.1435 - val_loss: 0.0446 - val_mean_absolute_error: 0.1712
# Epoch 225/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0330 - mean_absolute_error: 0.1475 - val_loss: 0.0413 - val_mean_absolute_error: 0.1554
# Epoch 226/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0337 - mean_absolute_error: 0.1463 - val_loss: 0.0421 - val_mean_absolute_error: 0.1517
# Epoch 227/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0344 - mean_absolute_error: 0.1452 - val_loss: 0.0473 - val_mean_absolute_error: 0.1610
# Epoch 228/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0359 - mean_absolute_error: 0.1518 - val_loss: 0.0417 - val_mean_absolute_error: 0.1512
# Epoch 229/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0363 - mean_absolute_error: 0.1509 - val_loss: 0.0523 - val_mean_absolute_error: 0.1724
# Epoch 230/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0338 - mean_absolute_error: 0.1460 - val_loss: 0.0452 - val_mean_absolute_error: 0.1577
# Epoch 231/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0343 - mean_absolute_error: 0.1464 - val_loss: 0.0432 - val_mean_absolute_error: 0.1628
# Epoch 232/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0330 - mean_absolute_error: 0.1429 - val_loss: 0.0468 - val_mean_absolute_error: 0.1749
# Epoch 233/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0336 - mean_absolute_error: 0.1448 - val_loss: 0.0454 - val_mean_absolute_error: 0.1598
# Epoch 234/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0342 - mean_absolute_error: 0.1487 - val_loss: 0.0399 - val_mean_absolute_error: 0.1542
# Epoch 235/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0354 - mean_absolute_error: 0.1485 - val_loss: 0.0506 - val_mean_absolute_error: 0.1697
# Epoch 236/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0361 - mean_absolute_error: 0.1512 - val_loss: 0.0465 - val_mean_absolute_error: 0.1688
# Epoch 237/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0316 - mean_absolute_error: 0.1409 - val_loss: 0.0429 - val_mean_absolute_error: 0.1549
# Epoch 238/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0342 - mean_absolute_error: 0.1476 - val_loss: 0.0459 - val_mean_absolute_error: 0.1593
# Epoch 239/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0336 - mean_absolute_error: 0.1459 - val_loss: 0.0434 - val_mean_absolute_error: 0.1572
# Epoch 240/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0340 - mean_absolute_error: 0.1451 - val_loss: 0.0401 - val_mean_absolute_error: 0.1521
# Epoch 241/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0341 - mean_absolute_error: 0.1464 - val_loss: 0.0396 - val_mean_absolute_error: 0.1541
# Epoch 242/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0327 - mean_absolute_error: 0.1429 - val_loss: 0.0442 - val_mean_absolute_error: 0.1622
# Epoch 243/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0341 - mean_absolute_error: 0.1465 - val_loss: 0.0445 - val_mean_absolute_error: 0.1611
# Epoch 244/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0349 - mean_absolute_error: 0.1479 - val_loss: 0.0461 - val_mean_absolute_error: 0.1629
# Epoch 245/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0344 - mean_absolute_error: 0.1460 - val_loss: 0.0498 - val_mean_absolute_error: 0.1663
# Epoch 246/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0339 - mean_absolute_error: 0.1457 - val_loss: 0.0398 - val_mean_absolute_error: 0.1480
# Epoch 247/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0328 - mean_absolute_error: 0.1442 - val_loss: 0.0449 - val_mean_absolute_error: 0.1692
# Epoch 248/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0335 - mean_absolute_error: 0.1469 - val_loss: 0.0558 - val_mean_absolute_error: 0.1798
# Epoch 249/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0340 - mean_absolute_error: 0.1449 - val_loss: 0.0579 - val_mean_absolute_error: 0.1850
# Epoch 250/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0331 - mean_absolute_error: 0.1444 - val_loss: 0.0425 - val_mean_absolute_error: 0.1575
# Epoch 251/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0346 - mean_absolute_error: 0.1474 - val_loss: 0.0480 - val_mean_absolute_error: 0.1810
# Epoch 252/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0332 - mean_absolute_error: 0.1440 - val_loss: 0.0438 - val_mean_absolute_error: 0.1540
# Epoch 253/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0330 - mean_absolute_error: 0.1455 - val_loss: 0.0403 - val_mean_absolute_error: 0.1549
# Epoch 254/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0326 - mean_absolute_error: 0.1432 - val_loss: 0.0421 - val_mean_absolute_error: 0.1522
# Epoch 255/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0334 - mean_absolute_error: 0.1439 - val_loss: 0.0455 - val_mean_absolute_error: 0.1579
# Epoch 256/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0333 - mean_absolute_error: 0.1459 - val_loss: 0.0473 - val_mean_absolute_error: 0.1787
# Epoch 257/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0336 - mean_absolute_error: 0.1456 - val_loss: 0.0465 - val_mean_absolute_error: 0.1585
# Epoch 258/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0319 - mean_absolute_error: 0.1421 - val_loss: 0.0464 - val_mean_absolute_error: 0.1789
# Epoch 259/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0334 - mean_absolute_error: 0.1440 - val_loss: 0.0412 - val_mean_absolute_error: 0.1563
# Epoch 260/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0333 - mean_absolute_error: 0.1462 - val_loss: 0.0486 - val_mean_absolute_error: 0.1648
# Epoch 261/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0348 - mean_absolute_error: 0.1454 - val_loss: 0.0487 - val_mean_absolute_error: 0.1657
# Epoch 262/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0324 - mean_absolute_error: 0.1442 - val_loss: 0.0474 - val_mean_absolute_error: 0.1642
# Epoch 263/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0315 - mean_absolute_error: 0.1419 - val_loss: 0.0395 - val_mean_absolute_error: 0.1522
# Epoch 264/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0324 - mean_absolute_error: 0.1410 - val_loss: 0.0435 - val_mean_absolute_error: 0.1531
# Epoch 265/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0332 - mean_absolute_error: 0.1459 - val_loss: 0.0435 - val_mean_absolute_error: 0.1540
# Epoch 266/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0313 - mean_absolute_error: 0.1396 - val_loss: 0.0442 - val_mean_absolute_error: 0.1683
# Epoch 267/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0338 - mean_absolute_error: 0.1466 - val_loss: 0.0430 - val_mean_absolute_error: 0.1526
# Epoch 268/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0328 - mean_absolute_error: 0.1451 - val_loss: 0.0426 - val_mean_absolute_error: 0.1521
# Epoch 269/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0319 - mean_absolute_error: 0.1411 - val_loss: 0.0416 - val_mean_absolute_error: 0.1528
# Epoch 270/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0345 - mean_absolute_error: 0.1462 - val_loss: 0.0404 - val_mean_absolute_error: 0.1565
# Epoch 271/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0325 - mean_absolute_error: 0.1424 - val_loss: 0.0430 - val_mean_absolute_error: 0.1568
# Epoch 272/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0352 - mean_absolute_error: 0.1496 - val_loss: 0.0428 - val_mean_absolute_error: 0.1654
# Epoch 273/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0310 - mean_absolute_error: 0.1382 - val_loss: 0.0406 - val_mean_absolute_error: 0.1512
# Epoch 274/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0329 - mean_absolute_error: 0.1408 - val_loss: 0.0447 - val_mean_absolute_error: 0.1629
# Epoch 275/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0352 - mean_absolute_error: 0.1505 - val_loss: 0.0448 - val_mean_absolute_error: 0.1704
# Epoch 276/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0323 - mean_absolute_error: 0.1431 - val_loss: 0.0424 - val_mean_absolute_error: 0.1545
# Epoch 277/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0318 - mean_absolute_error: 0.1400 - val_loss: 0.0516 - val_mean_absolute_error: 0.1703
# Epoch 278/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0331 - mean_absolute_error: 0.1431 - val_loss: 0.0425 - val_mean_absolute_error: 0.1516
# Epoch 279/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0331 - mean_absolute_error: 0.1434 - val_loss: 0.0423 - val_mean_absolute_error: 0.1518
# Epoch 280/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0341 - mean_absolute_error: 0.1452 - val_loss: 0.0415 - val_mean_absolute_error: 0.1576
# Epoch 281/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0323 - mean_absolute_error: 0.1426 - val_loss: 0.0422 - val_mean_absolute_error: 0.1522
# Epoch 282/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0345 - mean_absolute_error: 0.1476 - val_loss: 0.0445 - val_mean_absolute_error: 0.1546
# Epoch 283/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0306 - mean_absolute_error: 0.1415 - val_loss: 0.0396 - val_mean_absolute_error: 0.1484
# Epoch 284/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0307 - mean_absolute_error: 0.1393 - val_loss: 0.0381 - val_mean_absolute_error: 0.1439
# Epoch 285/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0318 - mean_absolute_error: 0.1434 - val_loss: 0.0437 - val_mean_absolute_error: 0.1525
# Epoch 286/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0322 - mean_absolute_error: 0.1403 - val_loss: 0.0439 - val_mean_absolute_error: 0.1543
# Epoch 287/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0329 - mean_absolute_error: 0.1438 - val_loss: 0.0420 - val_mean_absolute_error: 0.1532
# Epoch 288/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0335 - mean_absolute_error: 0.1442 - val_loss: 0.0444 - val_mean_absolute_error: 0.1567
# Epoch 289/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0313 - mean_absolute_error: 0.1403 - val_loss: 0.0571 - val_mean_absolute_error: 0.1811
# Epoch 290/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0322 - mean_absolute_error: 0.1422 - val_loss: 0.0445 - val_mean_absolute_error: 0.1722
# Epoch 291/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0330 - mean_absolute_error: 0.1461 - val_loss: 0.0410 - val_mean_absolute_error: 0.1502
# Epoch 292/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0322 - mean_absolute_error: 0.1414 - val_loss: 0.0506 - val_mean_absolute_error: 0.1679
# Epoch 293/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0340 - mean_absolute_error: 0.1442 - val_loss: 0.0447 - val_mean_absolute_error: 0.1576
# Epoch 294/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0328 - mean_absolute_error: 0.1439 - val_loss: 0.0415 - val_mean_absolute_error: 0.1539
# Epoch 295/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0326 - mean_absolute_error: 0.1424 - val_loss: 0.0470 - val_mean_absolute_error: 0.1605
# Epoch 296/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0329 - mean_absolute_error: 0.1428 - val_loss: 0.0458 - val_mean_absolute_error: 0.1734
# Epoch 297/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0344 - mean_absolute_error: 0.1448 - val_loss: 0.0453 - val_mean_absolute_error: 0.1590
# Epoch 298/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0325 - mean_absolute_error: 0.1427 - val_loss: 0.0397 - val_mean_absolute_error: 0.1506
# Epoch 299/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0324 - mean_absolute_error: 0.1437 - val_loss: 0.0421 - val_mean_absolute_error: 0.1563
# Epoch 300/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0335 - mean_absolute_error: 0.1449 - val_loss: 0.0390 - val_mean_absolute_error: 0.1550
# Epoch 301/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0330 - mean_absolute_error: 0.1415 - val_loss: 0.0462 - val_mean_absolute_error: 0.1597
# Epoch 302/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0330 - mean_absolute_error: 0.1451 - val_loss: 0.0447 - val_mean_absolute_error: 0.1623
# Epoch 303/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0313 - mean_absolute_error: 0.1402 - val_loss: 0.0557 - val_mean_absolute_error: 0.1807
# Epoch 304/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0317 - mean_absolute_error: 0.1391 - val_loss: 0.0475 - val_mean_absolute_error: 0.1619
# Epoch 305/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0325 - mean_absolute_error: 0.1423 - val_loss: 0.0427 - val_mean_absolute_error: 0.1537
# Epoch 306/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0309 - mean_absolute_error: 0.1378 - val_loss: 0.0447 - val_mean_absolute_error: 0.1619
# Epoch 307/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0342 - mean_absolute_error: 0.1452 - val_loss: 0.0426 - val_mean_absolute_error: 0.1538
# Epoch 308/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0321 - mean_absolute_error: 0.1415 - val_loss: 0.0432 - val_mean_absolute_error: 0.1528
# Epoch 309/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0319 - mean_absolute_error: 0.1417 - val_loss: 0.0383 - val_mean_absolute_error: 0.1499
# Epoch 310/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0320 - mean_absolute_error: 0.1408 - val_loss: 0.0407 - val_mean_absolute_error: 0.1559
# Epoch 311/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0328 - mean_absolute_error: 0.1438 - val_loss: 0.0408 - val_mean_absolute_error: 0.1557
# Epoch 312/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0315 - mean_absolute_error: 0.1406 - val_loss: 0.0396 - val_mean_absolute_error: 0.1587
# Epoch 313/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0339 - mean_absolute_error: 0.1422 - val_loss: 0.0385 - val_mean_absolute_error: 0.1491
# Epoch 314/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0326 - mean_absolute_error: 0.1422 - val_loss: 0.0424 - val_mean_absolute_error: 0.1617
# Epoch 315/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0305 - mean_absolute_error: 0.1362 - val_loss: 0.0409 - val_mean_absolute_error: 0.1523
# Epoch 316/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0330 - mean_absolute_error: 0.1416 - val_loss: 0.0438 - val_mean_absolute_error: 0.1564
# Epoch 317/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0307 - mean_absolute_error: 0.1370 - val_loss: 0.0454 - val_mean_absolute_error: 0.1565
# Epoch 318/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0310 - mean_absolute_error: 0.1396 - val_loss: 0.0400 - val_mean_absolute_error: 0.1583
# Epoch 319/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0308 - mean_absolute_error: 0.1376 - val_loss: 0.0432 - val_mean_absolute_error: 0.1515
# Epoch 320/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0318 - mean_absolute_error: 0.1384 - val_loss: 0.0474 - val_mean_absolute_error: 0.1789
# Epoch 321/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0339 - mean_absolute_error: 0.1448 - val_loss: 0.0455 - val_mean_absolute_error: 0.1560
# Epoch 322/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0319 - mean_absolute_error: 0.1391 - val_loss: 0.0394 - val_mean_absolute_error: 0.1527
# Epoch 323/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0304 - mean_absolute_error: 0.1391 - val_loss: 0.0433 - val_mean_absolute_error: 0.1610
# Epoch 324/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0330 - mean_absolute_error: 0.1441 - val_loss: 0.0411 - val_mean_absolute_error: 0.1514
# Epoch 325/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0321 - mean_absolute_error: 0.1400 - val_loss: 0.0406 - val_mean_absolute_error: 0.1497
# Epoch 326/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0341 - mean_absolute_error: 0.1453 - val_loss: 0.0541 - val_mean_absolute_error: 0.1737
# Epoch 327/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0325 - mean_absolute_error: 0.1400 - val_loss: 0.0420 - val_mean_absolute_error: 0.1542
# Epoch 328/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0308 - mean_absolute_error: 0.1393 - val_loss: 0.0431 - val_mean_absolute_error: 0.1601
# Epoch 329/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0318 - mean_absolute_error: 0.1418 - val_loss: 0.0439 - val_mean_absolute_error: 0.1559
# Epoch 330/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0313 - mean_absolute_error: 0.1363 - val_loss: 0.0386 - val_mean_absolute_error: 0.1529
# Epoch 331/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0301 - mean_absolute_error: 0.1368 - val_loss: 0.0546 - val_mean_absolute_error: 0.1772
# Epoch 332/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0317 - mean_absolute_error: 0.1385 - val_loss: 0.0406 - val_mean_absolute_error: 0.1524
# Epoch 333/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0307 - mean_absolute_error: 0.1387 - val_loss: 0.0590 - val_mean_absolute_error: 0.1855
# Epoch 334/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0312 - mean_absolute_error: 0.1396 - val_loss: 0.0510 - val_mean_absolute_error: 0.1696
# Epoch 00334: early stopping

# %%
model = keras.models.load_model("best_model.h5")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test error", test_acc)
print("Test loss", test_loss)
# Out:
# 1/1 [==============================] - 0s 225ms/step - loss: 0.0405 - mean_absolute_error: 0.1437
# Test error 0.1437010020017624
# Test loss 0.040482569485902786

# %%
mua = np.zeros((x_train.shape[0],))
# mus = np.zeros((x_train.shape[0],))
d = np.zeros((x_train.shape[0],))
miu = np.zeros((x_train.shape[0],1))

miu = model.predict(x_train)
mua = miu[:,0]
# mus = miu[:,1]
d = x_train[:,0,0]

# %%
err = np.zeros((x_train.shape[0],))

err = y_train-mua
# err[:,1] = y_train[:,1]-mus

# print(mua[k],mus[k],d[k])
# print(y_train[k])

# %%
plt.plot(d,err[:,1])
plt.show()

# %%
# print(mua,mus,d)
# print(an2[i,1],an2[i,2],an2[i,0])
# plt.plot(abs(an1[:,1]-mua))
# plt.plot(abs(an1[:,2]-mus))
plt.hist(abs(y_train[:,0]-mua), bins=40,  facecolor="blue", edgecolor="black", alpha=0.7)
# plt.hist(abs(y_train[:,1]-mus), bins=40,  facecolor="green", edgecolor="black", alpha=0.7)
plt.show()

# %%
metric = "mean_absolute_error"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()

# %%
# 你可以用pca或者一些降维方法把特征搞一下
