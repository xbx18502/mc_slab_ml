# %%
# 不用PCA 而是 重新预处理输入量
import os  
import numpy as np
import struct
import matplotlib.pyplot as plt
import gc
import random
import math
from tensorflow import keras
import sklearn
# from scipy.interpolate import CubicSpline
from scipy.signal import find_peaks
from scipy.interpolate import interp1d

# %%
with open("C:\\Users\\Administrator\\source\\data\\dataset_test.bin", "rb") as file0:
    data1 = file0.read(4)
    NM1 = struct.unpack("i", data1)[0]
    sig2 = np.zeros((NM1,200),dtype = np.float32)
    an2 = np.zeros((NM1,4),dtype = np.float32)
    for i in range(NM1):
        for k in range(4):
            data1 = file0.read(4)
            an2[i,k] = struct.unpack("f", data1)[0]
        for k in range(200):
            data1 = file0.read(4)
            sig2[i,k] = struct.unpack("f", data1)[0]  
    # data1 = file0.read(len('end\0'))
    # end = struct.unpack("4s", data1)[0]

# %%
with open("C:\\Users\\Administrator\\source\\data\\dataset.bin", "rb") as file0:
    data1 = file0.read(4)
    NM1 = struct.unpack("i", data1)[0]
    sig1 = np.zeros((NM1,200),dtype = np.float32)
    an1 = np.zeros((NM1,4),dtype = np.float32)
    for i in range(NM1):
        for k in range(4):
            data1 = file0.read(4)
            an1[i,k] = struct.unpack("f", data1)[0]
        for k in range(200):
            data1 = file0.read(4)
            sig1[i,k] = struct.unpack("f", data1)[0]  
    # data1 = file0.read(len('end\0'))
    # end = struct.unpack("4s", data1)[0]

# %%
plt.axes(yscale = "log") 
for n in range(sig1.shape[0]):
    plt.plot(sig1[n])
plt.show()
print(NM1)
print(an2[-1])
# Out:
# 1262
# [1.24224685e-02 9.14926987e+01 1.54261023e+03 8.50000024e-01]

# %%
# def labeling(y,N):
#     ##############
#     a,b = y.shape
#     min0 = np.min(y,0)
#     max0 = np.max(y,0)
#     step = (max0-min0)/N
#     y2 = np.zeros((a,b,N))
    
#     # kernel = np.array([1]) 
#     # kernel = kernel/np.sum(kernel)
    
#     for i in range(a):
#         for j in range(b):
#             if(step[j]!=0):
#                 idx = (y[i,j]-min0[j])/step[j]-1
#                 y2[i,j,int(idx)] = 1
#             else:
#                 y2[i,j,0] = 1
#             # y2[i,j] = np.convolve(y2[i,j],kernel,mode='same')
            
#     return y2

# %%
xsig = sig1[0]
peaks, _ = find_peaks(xsig, height=0)
plt.plot(xsig)
plt.plot(peaks, xsig[peaks], "x")
plt.plot(np.zeros_like(xsig), "--", color="gray")
plt.show()

x = np.zeros((peaks.shape[0]+2,))
y = np.zeros((peaks.shape[0]+2,))
x[1:-1] = peaks
y[1:-1] = xsig[peaks]
x[-1] = sig1.shape[1]
plt.plot(x,y)
plt.show()

f2 = interp1d(x, y, kind='linear')
N = 200
xnew = np.linspace(0, N,num=N)
ynew = f2(xnew)

# plt.axes(yscale = "log") 
plt.plot(ynew)
plt.show()

# %%
def smooth_peak(xsig):
    peaks, _ = find_peaks(xsig, height=0)
    # plt.plot(xsig)
    # plt.plot(peaks, xsig[peaks], "x")
    # plt.plot(np.zeros_like(xsig), "--", color="gray")
    # plt.show()
    if(peaks.shape[0]!=0):
        x = np.zeros((peaks.shape[0]+3,))
        y = np.zeros((peaks.shape[0]+3,))
        x[1:-2] = peaks
        y[1:-2] = xsig[peaks]
        x[-1] = sig1.shape[1]
        y[-1] = 0
        x[-2] = peaks[-1]+5
        y[-2] = 0
        # plt.plot(x,y)
        # plt.show()

        f2 = interp1d(x, y, kind='linear')
        N = xsig.shape[0]
        xnew = np.linspace(0, N,num=N)
        ynew = f2(xnew)
    
    else:
        ynew = np.zeros((xsig.shape[0],))
    
    return ynew
#     # plt.axes(yscale = "log") 
#     plt.plot(ynew)
#     plt.show()

# %%
msig1 = np.zeros((sig1.shape[0],sig1.shape[1]))
for i in range(sig1.shape[0]):
    msig1[i] = smooth_peak(sig1[i])
    
msig2 = np.zeros((sig2.shape[0],sig2.shape[1]))
for i in range(sig2.shape[0]):
    msig2[i] = smooth_peak(sig2[i])

# %%
plt.axes(yscale = "log") 
for n in range(msig1.shape[0]):
    plt.plot(msig1[n])
plt.show()

# %%
print(sig1.shape)
print(an1.shape)
print(sig2.shape)
print(an2.shape)
# num_labels = 10
x_train = msig1
y_train = an1
x_test = msig2
y_test = an2

x_train = (np.log10((x_train+1e-6)/1000)+9)/9
x_test = (np.log10((x_test+1e-6)/1000)+9)/9
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))
d_train = np.reshape(y_train[:,0],(y_train[:,0].shape[0],1,1)) # add thickness of sample into input data
d_test = np.reshape(y_test[:,0],(y_test[:,0].shape[0],1,1))

x_train = np.concatenate((d_train,x_train),axis = 1) 
x_test = np.concatenate((d_test,x_test),axis = 1)
y_train[:,1] = y_train[:,1]/1e2
y_test[:,1] = y_test[:,1]/1e2
y_train[:,2] = y_train[:,2]/200e2
y_test[:,2] = y_test[:,2]/200e2
y_train = y_train[:,2:3] # determine the nn to output mua/mus or mua+mus
y_test = y_test[:,2:3]
# y_train = labeling(y_train,num_labels)[:,1,:] # select to predict what : 0:thickness 1:mua 2: mus
# y_test = labeling(y_test,num_labels)[:,1,:]
print('x_train.shape = '+str(x_train.shape)) 
print('y_train.shape = '+str(y_train.shape))
# Out:
# (1262, 200)
# (1262, 4)
# (30, 200)
# (30, 4)
# x_train.shape = (1262, 201, 1)
# y_train.shape = (1262, 1)

# %%
for n in range(x_train.shape[0]):
    plt.plot(x_train[n,1:])
plt.show()

# %%
# num_classes = y_train.shape[1]
########################################
# input_shape = (1,5,1)
# x = np.arange(np.prod(input_shape)).reshape(input_shape)      # test cropping#
# print(x)
# y = keras.layers.Cropping1D(cropping=(0,4))(x)
# z = keras.layers.Cropping1D(cropping=(1,0))(x)
# print(y)
# print(z)

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)
    
    d_1 = keras.layers.Cropping1D(cropping=(0,200))(input_layer)
    sig = keras.layers.Cropping1D(cropping=(1,0))(input_layer)
    
    conv1 = keras.layers.Conv1D(filters=16, kernel_size=3, padding="same")(sig)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=16, kernel_size=3, padding="same")(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=16, kernel_size=3, padding="same")(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)
    
    gap = keras.layers.Dense(16, activation='relu')(gap)
    gap = keras.layers.BatchNormalization()(gap)
    gap = keras.layers.Dropout(0.5)(gap)
    gap = keras.layers.Dense(16, activation='relu')(gap)
    
    
    d_1 = keras.layers.Dense(8, activation='relu')(d_1)
    d_1 = keras.layers.Dense(8, activation='relu')(d_1)
    d_1 = keras.layers.Reshape((8,))(d_1)
    
    
    
    merged = keras.layers.Concatenate()([d_1, gap])
    merged = keras.layers.Dense(4, activation='relu')(merged)
    
    output_layer = keras.layers.Dense(1, activation="linear")(merged)
#######################################################################
#     d_1 = keras.layers.Dense(16, activation='relu')(d_1)
#     # d_1 = keras.layers.Dense(10, activation='relu')(d_1)
#     d_1 = keras.layers.Reshape((16,))(d_1)
    
#     d_1 = keras.layers.BatchNormalization()(d_1)
#     gap = keras.layers.Dense(8, activation='relu')(gap)
#     gap = keras.layers.BatchNormalization()(gap)
    
#     merged = keras.layers.Concatenate()([d_1, gap])
#     merged = keras.layers.Dense(8, activation='relu')(merged)
    
#     output_layer = keras.layers.Dense(2, activation="linear")(merged)
##########################################################################    
    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])
keras.utils.plot_model(model, show_shapes=True)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %%
epochs = 500
batch_size = 32
#####################################################
index = [i for i in range(x_train.shape[0])]  
np.random.shuffle(index) 
x_train = x_train[index]
y_train = y_train[index]
####################################################
callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    # loss="mean_squared_error",
    loss="mean_absolute_error",
    metrics=["MeanAbsoluteError"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.4,
    verbose=1,
)
# Out:
# Epoch 1/500
# 24/24 [==============================] - 2s 31ms/step - loss: 0.7499 - mean_absolute_error: 0.7499 - val_loss: 0.4557 - val_mean_absolute_error: 0.4557
# Epoch 2/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.4641 - mean_absolute_error: 0.4641 - val_loss: 0.3922 - val_mean_absolute_error: 0.3922
# Epoch 3/500
# 24/24 [==============================] - 1s 21ms/step - loss: 0.3415 - mean_absolute_error: 0.3415 - val_loss: 0.3349 - val_mean_absolute_error: 0.3349
# Epoch 4/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.2846 - mean_absolute_error: 0.2846 - val_loss: 0.2914 - val_mean_absolute_error: 0.2914
# Epoch 5/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.2599 - mean_absolute_error: 0.2599 - val_loss: 0.2661 - val_mean_absolute_error: 0.2661
# Epoch 6/500
# 24/24 [==============================] - 0s 21ms/step - loss: 0.2457 - mean_absolute_error: 0.2457 - val_loss: 0.2574 - val_mean_absolute_error: 0.2574
# Epoch 7/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.2356 - mean_absolute_error: 0.2356 - val_loss: 0.2477 - val_mean_absolute_error: 0.2477
# Epoch 8/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.2206 - mean_absolute_error: 0.2206 - val_loss: 0.2405 - val_mean_absolute_error: 0.2405
# Epoch 9/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.2139 - mean_absolute_error: 0.2139 - val_loss: 0.2410 - val_mean_absolute_error: 0.2410
# Epoch 10/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.2155 - mean_absolute_error: 0.2155 - val_loss: 0.2464 - val_mean_absolute_error: 0.2464
# Epoch 11/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.2034 - mean_absolute_error: 0.2034 - val_loss: 0.2443 - val_mean_absolute_error: 0.2443
# Epoch 12/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.2078 - mean_absolute_error: 0.2078 - val_loss: 0.2527 - val_mean_absolute_error: 0.2527
# Epoch 13/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.2141 - mean_absolute_error: 0.2141 - val_loss: 0.2700 - val_mean_absolute_error: 0.2700
# Epoch 14/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.2058 - mean_absolute_error: 0.2058 - val_loss: 0.2959 - val_mean_absolute_error: 0.2959
# Epoch 15/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.2028 - mean_absolute_error: 0.2028 - val_loss: 0.3253 - val_mean_absolute_error: 0.3253
# Epoch 16/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1965 - mean_absolute_error: 0.1965 - val_loss: 0.3170 - val_mean_absolute_error: 0.3170
# Epoch 17/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1978 - mean_absolute_error: 0.1978 - val_loss: 0.2905 - val_mean_absolute_error: 0.2905
# Epoch 18/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1958 - mean_absolute_error: 0.1958 - val_loss: 0.3382 - val_mean_absolute_error: 0.3382
# Epoch 19/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1897 - mean_absolute_error: 0.1897 - val_loss: 0.3899 - val_mean_absolute_error: 0.3899
# Epoch 20/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1924 - mean_absolute_error: 0.1924 - val_loss: 0.4497 - val_mean_absolute_error: 0.4497
# Epoch 21/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1941 - mean_absolute_error: 0.1941 - val_loss: 0.5911 - val_mean_absolute_error: 0.5911
# Epoch 22/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1905 - mean_absolute_error: 0.1905 - val_loss: 0.6910 - val_mean_absolute_error: 0.6910
# Epoch 23/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.2002 - mean_absolute_error: 0.2002 - val_loss: 0.6373 - val_mean_absolute_error: 0.6373
# Epoch 24/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1916 - mean_absolute_error: 0.1916 - val_loss: 0.4161 - val_mean_absolute_error: 0.4161
# Epoch 25/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1898 - mean_absolute_error: 0.1898 - val_loss: 0.2873 - val_mean_absolute_error: 0.2873
# Epoch 26/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1860 - mean_absolute_error: 0.1860 - val_loss: 0.2922 - val_mean_absolute_error: 0.2922
# Epoch 27/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1861 - mean_absolute_error: 0.1861 - val_loss: 0.6352 - val_mean_absolute_error: 0.6352
# Epoch 28/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.1845 - mean_absolute_error: 0.1845 - val_loss: 0.7720 - val_mean_absolute_error: 0.7720
# Epoch 29/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1880 - mean_absolute_error: 0.1880 - val_loss: 0.6118 - val_mean_absolute_error: 0.6118
# Epoch 30/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1847 - mean_absolute_error: 0.1847 - val_loss: 0.6992 - val_mean_absolute_error: 0.6992
# Epoch 31/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1787 - mean_absolute_error: 0.1787 - val_loss: 0.7069 - val_mean_absolute_error: 0.7069
# Epoch 32/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1853 - mean_absolute_error: 0.1853 - val_loss: 0.5705 - val_mean_absolute_error: 0.5705
# Epoch 33/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1864 - mean_absolute_error: 0.1864 - val_loss: 0.5448 - val_mean_absolute_error: 0.5448
# Epoch 34/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1807 - mean_absolute_error: 0.1807 - val_loss: 0.4465 - val_mean_absolute_error: 0.4465
# Epoch 35/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1824 - mean_absolute_error: 0.1824 - val_loss: 0.2808 - val_mean_absolute_error: 0.2808
# Epoch 36/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1847 - mean_absolute_error: 0.1847 - val_loss: 0.2114 - val_mean_absolute_error: 0.2114
# Epoch 37/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1807 - mean_absolute_error: 0.1807 - val_loss: 0.2262 - val_mean_absolute_error: 0.2262
# Epoch 38/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1858 - mean_absolute_error: 0.1858 - val_loss: 0.1869 - val_mean_absolute_error: 0.1869
# Epoch 39/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1825 - mean_absolute_error: 0.1825 - val_loss: 0.1882 - val_mean_absolute_error: 0.1882
# Epoch 40/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1891 - mean_absolute_error: 0.1891 - val_loss: 0.1824 - val_mean_absolute_error: 0.1824
# Epoch 41/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1797 - mean_absolute_error: 0.1797 - val_loss: 0.1883 - val_mean_absolute_error: 0.1883
# Epoch 42/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1803 - mean_absolute_error: 0.1803 - val_loss: 0.1992 - val_mean_absolute_error: 0.1992
# Epoch 43/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1826 - mean_absolute_error: 0.1826 - val_loss: 0.1882 - val_mean_absolute_error: 0.1882
# Epoch 44/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1817 - mean_absolute_error: 0.1817 - val_loss: 0.2041 - val_mean_absolute_error: 0.2041
# Epoch 45/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1812 - mean_absolute_error: 0.1812 - val_loss: 0.1880 - val_mean_absolute_error: 0.1880
# Epoch 46/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1859 - mean_absolute_error: 0.1859 - val_loss: 0.1917 - val_mean_absolute_error: 0.1917
# Epoch 47/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1844 - mean_absolute_error: 0.1844 - val_loss: 0.1919 - val_mean_absolute_error: 0.1919
# Epoch 48/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1821 - mean_absolute_error: 0.1821 - val_loss: 0.2994 - val_mean_absolute_error: 0.2994
# Epoch 49/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1766 - mean_absolute_error: 0.1766 - val_loss: 0.3370 - val_mean_absolute_error: 0.3370
# Epoch 50/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1765 - mean_absolute_error: 0.1765 - val_loss: 0.2620 - val_mean_absolute_error: 0.2620
# Epoch 51/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1834 - mean_absolute_error: 0.1834 - val_loss: 0.2071 - val_mean_absolute_error: 0.2071
# Epoch 52/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1790 - mean_absolute_error: 0.1790 - val_loss: 0.2091 - val_mean_absolute_error: 0.2091
# Epoch 53/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1769 - mean_absolute_error: 0.1769 - val_loss: 0.2175 - val_mean_absolute_error: 0.2175
# Epoch 54/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1794 - mean_absolute_error: 0.1794 - val_loss: 0.2287 - val_mean_absolute_error: 0.2287
# Epoch 55/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1800 - mean_absolute_error: 0.1800 - val_loss: 0.2094 - val_mean_absolute_error: 0.2094
# Epoch 56/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1837 - mean_absolute_error: 0.1837 - val_loss: 0.2008 - val_mean_absolute_error: 0.2008
# Epoch 57/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1762 - mean_absolute_error: 0.1762 - val_loss: 0.2206 - val_mean_absolute_error: 0.2206
# Epoch 58/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1799 - mean_absolute_error: 0.1799 - val_loss: 0.2412 - val_mean_absolute_error: 0.2412
# Epoch 59/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1799 - mean_absolute_error: 0.1799 - val_loss: 0.1834 - val_mean_absolute_error: 0.1834
# Epoch 60/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1759 - mean_absolute_error: 0.1759 - val_loss: 0.2036 - val_mean_absolute_error: 0.2036
# Epoch 61/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1771 - mean_absolute_error: 0.1771 - val_loss: 0.1805 - val_mean_absolute_error: 0.1805
# Epoch 62/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1742 - mean_absolute_error: 0.1742 - val_loss: 0.1894 - val_mean_absolute_error: 0.1894
# Epoch 63/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1822 - mean_absolute_error: 0.1822 - val_loss: 0.1827 - val_mean_absolute_error: 0.1827
# Epoch 64/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1760 - mean_absolute_error: 0.1760 - val_loss: 0.1793 - val_mean_absolute_error: 0.1793
# Epoch 65/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1811 - mean_absolute_error: 0.1811 - val_loss: 0.1903 - val_mean_absolute_error: 0.1903
# Epoch 66/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1780 - mean_absolute_error: 0.1780 - val_loss: 0.2007 - val_mean_absolute_error: 0.2007
# Epoch 67/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1756 - mean_absolute_error: 0.1756 - val_loss: 0.1888 - val_mean_absolute_error: 0.1888
# Epoch 68/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1790 - mean_absolute_error: 0.1790 - val_loss: 0.1781 - val_mean_absolute_error: 0.1781
# Epoch 69/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1795 - mean_absolute_error: 0.1795 - val_loss: 0.1793 - val_mean_absolute_error: 0.1793
# Epoch 70/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1773 - mean_absolute_error: 0.1773 - val_loss: 0.1810 - val_mean_absolute_error: 0.1810
# Epoch 71/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1730 - mean_absolute_error: 0.1730 - val_loss: 0.1789 - val_mean_absolute_error: 0.1789
# Epoch 72/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1759 - mean_absolute_error: 0.1759 - val_loss: 0.1822 - val_mean_absolute_error: 0.1822
# Epoch 73/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1779 - mean_absolute_error: 0.1779 - val_loss: 0.1799 - val_mean_absolute_error: 0.1799
# Epoch 74/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1741 - mean_absolute_error: 0.1741 - val_loss: 0.1803 - val_mean_absolute_error: 0.1803
# Epoch 75/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1741 - mean_absolute_error: 0.1741 - val_loss: 0.1759 - val_mean_absolute_error: 0.1759
# Epoch 76/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1730 - mean_absolute_error: 0.1730 - val_loss: 0.1748 - val_mean_absolute_error: 0.1748
# Epoch 77/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1723 - mean_absolute_error: 0.1723 - val_loss: 0.1797 - val_mean_absolute_error: 0.1797
# Epoch 78/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1764 - mean_absolute_error: 0.1764 - val_loss: 0.1783 - val_mean_absolute_error: 0.1783
# Epoch 79/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1815 - mean_absolute_error: 0.1815 - val_loss: 0.1793 - val_mean_absolute_error: 0.1793
# Epoch 80/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1759 - mean_absolute_error: 0.1759 - val_loss: 0.1771 - val_mean_absolute_error: 0.1771
# Epoch 81/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1745 - mean_absolute_error: 0.1745 - val_loss: 0.1772 - val_mean_absolute_error: 0.1772
# Epoch 82/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1751 - mean_absolute_error: 0.1751 - val_loss: 0.1878 - val_mean_absolute_error: 0.1878
# Epoch 83/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1757 - mean_absolute_error: 0.1757 - val_loss: 0.1860 - val_mean_absolute_error: 0.1860
# Epoch 84/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1751 - mean_absolute_error: 0.1751 - val_loss: 0.1841 - val_mean_absolute_error: 0.1841
# Epoch 85/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1755 - mean_absolute_error: 0.1755 - val_loss: 0.1807 - val_mean_absolute_error: 0.1807
# Epoch 86/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1793 - mean_absolute_error: 0.1793 - val_loss: 0.1803 - val_mean_absolute_error: 0.1803
# Epoch 87/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1750 - mean_absolute_error: 0.1750 - val_loss: 0.1769 - val_mean_absolute_error: 0.1769
# Epoch 88/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1756 - mean_absolute_error: 0.1756 - val_loss: 0.1751 - val_mean_absolute_error: 0.1751
# Epoch 89/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1725 - mean_absolute_error: 0.1725 - val_loss: 0.1796 - val_mean_absolute_error: 0.1796
# Epoch 90/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1715 - mean_absolute_error: 0.1715 - val_loss: 0.1784 - val_mean_absolute_error: 0.1784
# Epoch 91/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1747 - mean_absolute_error: 0.1747 - val_loss: 0.1806 - val_mean_absolute_error: 0.1806
# Epoch 92/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1731 - mean_absolute_error: 0.1731 - val_loss: 0.1789 - val_mean_absolute_error: 0.1789
# Epoch 93/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1693 - mean_absolute_error: 0.1693 - val_loss: 0.1776 - val_mean_absolute_error: 0.1776
# Epoch 94/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1647 - mean_absolute_error: 0.1647 - val_loss: 0.1787 - val_mean_absolute_error: 0.1787
# Epoch 95/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1761 - mean_absolute_error: 0.1761 - val_loss: 0.1792 - val_mean_absolute_error: 0.1792
# Epoch 96/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1719 - mean_absolute_error: 0.1719 - val_loss: 0.1756 - val_mean_absolute_error: 0.1756
# Epoch 97/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1694 - mean_absolute_error: 0.1694 - val_loss: 0.1752 - val_mean_absolute_error: 0.1752
# Epoch 98/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1710 - mean_absolute_error: 0.1710 - val_loss: 0.1737 - val_mean_absolute_error: 0.1737
# Epoch 99/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1772 - mean_absolute_error: 0.1772 - val_loss: 0.1744 - val_mean_absolute_error: 0.1744
# Epoch 100/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1721 - mean_absolute_error: 0.1721 - val_loss: 0.1910 - val_mean_absolute_error: 0.1910
# Epoch 101/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1734 - mean_absolute_error: 0.1734 - val_loss: 0.1756 - val_mean_absolute_error: 0.1756
# Epoch 102/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1744 - mean_absolute_error: 0.1744 - val_loss: 0.1752 - val_mean_absolute_error: 0.1752
# Epoch 103/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1769 - mean_absolute_error: 0.1769 - val_loss: 0.1863 - val_mean_absolute_error: 0.1863
# Epoch 104/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1735 - mean_absolute_error: 0.1735 - val_loss: 0.1813 - val_mean_absolute_error: 0.1813
# Epoch 105/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1693 - mean_absolute_error: 0.1693 - val_loss: 0.1778 - val_mean_absolute_error: 0.1778
# Epoch 106/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1699 - mean_absolute_error: 0.1699 - val_loss: 0.1813 - val_mean_absolute_error: 0.1813
# Epoch 107/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1726 - mean_absolute_error: 0.1726 - val_loss: 0.2100 - val_mean_absolute_error: 0.2100
# Epoch 108/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1721 - mean_absolute_error: 0.1721 - val_loss: 0.2190 - val_mean_absolute_error: 0.2190
# Epoch 109/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1746 - mean_absolute_error: 0.1746 - val_loss: 0.1800 - val_mean_absolute_error: 0.1800
# Epoch 110/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1707 - mean_absolute_error: 0.1707 - val_loss: 0.1749 - val_mean_absolute_error: 0.1749
# Epoch 111/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1715 - mean_absolute_error: 0.1715 - val_loss: 0.1742 - val_mean_absolute_error: 0.1742
# Epoch 112/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1736 - mean_absolute_error: 0.1736 - val_loss: 0.1757 - val_mean_absolute_error: 0.1757
# Epoch 113/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1733 - mean_absolute_error: 0.1733 - val_loss: 0.1833 - val_mean_absolute_error: 0.1833
# Epoch 114/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1698 - mean_absolute_error: 0.1698 - val_loss: 0.1766 - val_mean_absolute_error: 0.1766
# Epoch 115/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1668 - mean_absolute_error: 0.1668 - val_loss: 0.1790 - val_mean_absolute_error: 0.1790
# Epoch 116/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1709 - mean_absolute_error: 0.1709 - val_loss: 0.1797 - val_mean_absolute_error: 0.1797
# Epoch 117/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1790 - mean_absolute_error: 0.1790 - val_loss: 0.1758 - val_mean_absolute_error: 0.1758
# Epoch 118/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1733 - mean_absolute_error: 0.1733 - val_loss: 0.1768 - val_mean_absolute_error: 0.1768
# Epoch 119/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1666 - mean_absolute_error: 0.1666 - val_loss: 0.1784 - val_mean_absolute_error: 0.1784
# Epoch 120/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1695 - mean_absolute_error: 0.1695 - val_loss: 0.1857 - val_mean_absolute_error: 0.1857
# Epoch 121/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1724 - mean_absolute_error: 0.1724 - val_loss: 0.1815 - val_mean_absolute_error: 0.1815
# Epoch 122/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1681 - mean_absolute_error: 0.1681 - val_loss: 0.1910 - val_mean_absolute_error: 0.1910
# Epoch 123/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1678 - mean_absolute_error: 0.1678 - val_loss: 0.2018 - val_mean_absolute_error: 0.2018
# Epoch 124/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1708 - mean_absolute_error: 0.1708 - val_loss: 0.1925 - val_mean_absolute_error: 0.1925
# Epoch 125/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1658 - mean_absolute_error: 0.1658 - val_loss: 0.1760 - val_mean_absolute_error: 0.1760
# Epoch 126/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1760 - mean_absolute_error: 0.1760 - val_loss: 0.1769 - val_mean_absolute_error: 0.1769
# Epoch 127/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1649 - mean_absolute_error: 0.1649 - val_loss: 0.1801 - val_mean_absolute_error: 0.1801
# Epoch 128/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1753 - mean_absolute_error: 0.1753 - val_loss: 0.1816 - val_mean_absolute_error: 0.1816
# Epoch 129/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1709 - mean_absolute_error: 0.1709 - val_loss: 0.1798 - val_mean_absolute_error: 0.1798
# Epoch 130/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1723 - mean_absolute_error: 0.1723 - val_loss: 0.1830 - val_mean_absolute_error: 0.1830
# Epoch 131/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1750 - mean_absolute_error: 0.1750 - val_loss: 0.1774 - val_mean_absolute_error: 0.1774
# Epoch 132/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1707 - mean_absolute_error: 0.1707 - val_loss: 0.1747 - val_mean_absolute_error: 0.1747
# Epoch 133/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1696 - mean_absolute_error: 0.1696 - val_loss: 0.1755 - val_mean_absolute_error: 0.1755
# Epoch 134/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1739 - mean_absolute_error: 0.1739 - val_loss: 0.1720 - val_mean_absolute_error: 0.1720
# Epoch 135/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1688 - mean_absolute_error: 0.1688 - val_loss: 0.1762 - val_mean_absolute_error: 0.1762
# Epoch 136/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1725 - mean_absolute_error: 0.1725 - val_loss: 0.1802 - val_mean_absolute_error: 0.1802
# Epoch 137/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1638 - mean_absolute_error: 0.1638 - val_loss: 0.1750 - val_mean_absolute_error: 0.1750
# Epoch 138/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1701 - mean_absolute_error: 0.1701 - val_loss: 0.1759 - val_mean_absolute_error: 0.1759
# Epoch 139/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1656 - mean_absolute_error: 0.1656 - val_loss: 0.1850 - val_mean_absolute_error: 0.1850
# Epoch 140/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1708 - mean_absolute_error: 0.1708 - val_loss: 0.1790 - val_mean_absolute_error: 0.1790
# Epoch 141/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1704 - mean_absolute_error: 0.1704 - val_loss: 0.1773 - val_mean_absolute_error: 0.1773
# Epoch 142/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1703 - mean_absolute_error: 0.1703 - val_loss: 0.1806 - val_mean_absolute_error: 0.1806
# Epoch 143/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1701 - mean_absolute_error: 0.1701 - val_loss: 0.1734 - val_mean_absolute_error: 0.1734
# Epoch 144/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1716 - mean_absolute_error: 0.1716 - val_loss: 0.1769 - val_mean_absolute_error: 0.1769
# Epoch 145/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1740 - mean_absolute_error: 0.1740 - val_loss: 0.1768 - val_mean_absolute_error: 0.1768
# Epoch 146/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1734 - mean_absolute_error: 0.1734 - val_loss: 0.1727 - val_mean_absolute_error: 0.1727
# Epoch 147/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1737 - mean_absolute_error: 0.1737 - val_loss: 0.1748 - val_mean_absolute_error: 0.1748
# Epoch 148/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1670 - mean_absolute_error: 0.1670 - val_loss: 0.1757 - val_mean_absolute_error: 0.1757
# Epoch 149/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1715 - mean_absolute_error: 0.1715 - val_loss: 0.1862 - val_mean_absolute_error: 0.1862
# Epoch 150/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1687 - mean_absolute_error: 0.1687 - val_loss: 0.1787 - val_mean_absolute_error: 0.1787
# Epoch 151/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1707 - mean_absolute_error: 0.1707 - val_loss: 0.1795 - val_mean_absolute_error: 0.1795
# Epoch 152/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1705 - mean_absolute_error: 0.1705 - val_loss: 0.1752 - val_mean_absolute_error: 0.1752
# Epoch 153/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1657 - mean_absolute_error: 0.1657 - val_loss: 0.1859 - val_mean_absolute_error: 0.1859
# Epoch 154/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1720 - mean_absolute_error: 0.1720 - val_loss: 0.1810 - val_mean_absolute_error: 0.1810
# Epoch 155/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1714 - mean_absolute_error: 0.1714 - val_loss: 0.1713 - val_mean_absolute_error: 0.1713
# Epoch 156/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1680 - mean_absolute_error: 0.1680 - val_loss: 0.1724 - val_mean_absolute_error: 0.1724
# Epoch 157/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1708 - mean_absolute_error: 0.1708 - val_loss: 0.1823 - val_mean_absolute_error: 0.1823
# Epoch 158/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1677 - mean_absolute_error: 0.1677 - val_loss: 0.1749 - val_mean_absolute_error: 0.1749
# Epoch 159/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1710 - mean_absolute_error: 0.1710 - val_loss: 0.1700 - val_mean_absolute_error: 0.1700
# Epoch 160/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1699 - mean_absolute_error: 0.1699 - val_loss: 0.1813 - val_mean_absolute_error: 0.1813
# Epoch 161/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1736 - mean_absolute_error: 0.1736 - val_loss: 0.1764 - val_mean_absolute_error: 0.1764
# Epoch 162/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1663 - mean_absolute_error: 0.1663 - val_loss: 0.1763 - val_mean_absolute_error: 0.1763
# Epoch 163/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1694 - mean_absolute_error: 0.1694 - val_loss: 0.1829 - val_mean_absolute_error: 0.1829
# Epoch 164/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1727 - mean_absolute_error: 0.1727 - val_loss: 0.1910 - val_mean_absolute_error: 0.1910
# Epoch 165/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1667 - mean_absolute_error: 0.1667 - val_loss: 0.1896 - val_mean_absolute_error: 0.1896
# Epoch 166/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1624 - mean_absolute_error: 0.1624 - val_loss: 0.1816 - val_mean_absolute_error: 0.1816
# Epoch 167/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1717 - mean_absolute_error: 0.1717 - val_loss: 0.1741 - val_mean_absolute_error: 0.1741
# Epoch 168/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1658 - mean_absolute_error: 0.1658 - val_loss: 0.1778 - val_mean_absolute_error: 0.1778
# Epoch 169/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1713 - mean_absolute_error: 0.1713 - val_loss: 0.1699 - val_mean_absolute_error: 0.1699
# Epoch 170/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1709 - mean_absolute_error: 0.1709 - val_loss: 0.1792 - val_mean_absolute_error: 0.1792
# Epoch 171/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1729 - mean_absolute_error: 0.1729 - val_loss: 0.1897 - val_mean_absolute_error: 0.1897
# Epoch 172/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1662 - mean_absolute_error: 0.1662 - val_loss: 0.1712 - val_mean_absolute_error: 0.1712
# Epoch 173/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1687 - mean_absolute_error: 0.1687 - val_loss: 0.1703 - val_mean_absolute_error: 0.1703
# Epoch 174/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1708 - mean_absolute_error: 0.1708 - val_loss: 0.1852 - val_mean_absolute_error: 0.1852
# Epoch 175/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1671 - mean_absolute_error: 0.1671 - val_loss: 0.1942 - val_mean_absolute_error: 0.1942
# Epoch 176/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1640 - mean_absolute_error: 0.1640 - val_loss: 0.1755 - val_mean_absolute_error: 0.1755
# Epoch 177/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.1682 - mean_absolute_error: 0.1682 - val_loss: 0.1730 - val_mean_absolute_error: 0.1730
# Epoch 178/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1729 - mean_absolute_error: 0.1729 - val_loss: 0.1700 - val_mean_absolute_error: 0.1700
# Epoch 179/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1674 - mean_absolute_error: 0.1674 - val_loss: 0.1709 - val_mean_absolute_error: 0.1709
# Epoch 180/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1689 - mean_absolute_error: 0.1689 - val_loss: 0.1699 - val_mean_absolute_error: 0.1699
# Epoch 181/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1709 - mean_absolute_error: 0.1709 - val_loss: 0.1767 - val_mean_absolute_error: 0.1767
# Epoch 182/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1692 - mean_absolute_error: 0.1692 - val_loss: 0.1853 - val_mean_absolute_error: 0.1853
# Epoch 183/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1685 - mean_absolute_error: 0.1685 - val_loss: 0.1841 - val_mean_absolute_error: 0.1841
# Epoch 184/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1738 - mean_absolute_error: 0.1738 - val_loss: 0.1742 - val_mean_absolute_error: 0.1742
# Epoch 185/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1675 - mean_absolute_error: 0.1675 - val_loss: 0.1684 - val_mean_absolute_error: 0.1684
# Epoch 186/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1679 - mean_absolute_error: 0.1679 - val_loss: 0.1701 - val_mean_absolute_error: 0.1701
# Epoch 187/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1669 - mean_absolute_error: 0.1669 - val_loss: 0.1680 - val_mean_absolute_error: 0.1680
# Epoch 188/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1684 - mean_absolute_error: 0.1684 - val_loss: 0.1715 - val_mean_absolute_error: 0.1715
# Epoch 189/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1668 - mean_absolute_error: 0.1668 - val_loss: 0.1725 - val_mean_absolute_error: 0.1725
# Epoch 190/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1672 - mean_absolute_error: 0.1672 - val_loss: 0.1716 - val_mean_absolute_error: 0.1716
# Epoch 191/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1698 - mean_absolute_error: 0.1698 - val_loss: 0.1736 - val_mean_absolute_error: 0.1736
# Epoch 192/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1667 - mean_absolute_error: 0.1667 - val_loss: 0.1710 - val_mean_absolute_error: 0.1710
# Epoch 193/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1698 - mean_absolute_error: 0.1698 - val_loss: 0.1673 - val_mean_absolute_error: 0.1673
# Epoch 194/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1673 - mean_absolute_error: 0.1673 - val_loss: 0.1694 - val_mean_absolute_error: 0.1694
# Epoch 195/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1712 - mean_absolute_error: 0.1712 - val_loss: 0.1827 - val_mean_absolute_error: 0.1827
# Epoch 196/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1685 - mean_absolute_error: 0.1685 - val_loss: 0.1742 - val_mean_absolute_error: 0.1742
# Epoch 197/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1621 - mean_absolute_error: 0.1621 - val_loss: 0.1726 - val_mean_absolute_error: 0.1726
# Epoch 198/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1717 - mean_absolute_error: 0.1717 - val_loss: 0.1817 - val_mean_absolute_error: 0.1817
# Epoch 199/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1660 - mean_absolute_error: 0.1660 - val_loss: 0.1697 - val_mean_absolute_error: 0.1697
# Epoch 200/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1692 - mean_absolute_error: 0.1692 - val_loss: 0.1707 - val_mean_absolute_error: 0.1707
# Epoch 201/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1708 - mean_absolute_error: 0.1708 - val_loss: 0.1742 - val_mean_absolute_error: 0.1742
# Epoch 202/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1653 - mean_absolute_error: 0.1653 - val_loss: 0.1772 - val_mean_absolute_error: 0.1772
# Epoch 203/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1694 - mean_absolute_error: 0.1694 - val_loss: 0.1696 - val_mean_absolute_error: 0.1696
# Epoch 204/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1692 - mean_absolute_error: 0.1692 - val_loss: 0.1818 - val_mean_absolute_error: 0.1818
# Epoch 205/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1670 - mean_absolute_error: 0.1670 - val_loss: 0.1936 - val_mean_absolute_error: 0.1936
# Epoch 206/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1731 - mean_absolute_error: 0.1731 - val_loss: 0.1933 - val_mean_absolute_error: 0.1933
# Epoch 207/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1676 - mean_absolute_error: 0.1676 - val_loss: 0.1794 - val_mean_absolute_error: 0.1794
# Epoch 208/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1656 - mean_absolute_error: 0.1656 - val_loss: 0.1723 - val_mean_absolute_error: 0.1723
# Epoch 209/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1622 - mean_absolute_error: 0.1622 - val_loss: 0.1741 - val_mean_absolute_error: 0.1741
# Epoch 210/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1661 - mean_absolute_error: 0.1661 - val_loss: 0.1780 - val_mean_absolute_error: 0.1780
# Epoch 211/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1685 - mean_absolute_error: 0.1685 - val_loss: 0.1843 - val_mean_absolute_error: 0.1843
# Epoch 212/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1630 - mean_absolute_error: 0.1630 - val_loss: 0.1770 - val_mean_absolute_error: 0.1770
# Epoch 213/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1654 - mean_absolute_error: 0.1654 - val_loss: 0.1745 - val_mean_absolute_error: 0.1745
# Epoch 214/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1652 - mean_absolute_error: 0.1652 - val_loss: 0.1697 - val_mean_absolute_error: 0.1697
# Epoch 215/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1659 - mean_absolute_error: 0.1659 - val_loss: 0.1895 - val_mean_absolute_error: 0.1895
# Epoch 216/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1690 - mean_absolute_error: 0.1690 - val_loss: 0.1714 - val_mean_absolute_error: 0.1714
# Epoch 217/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1651 - mean_absolute_error: 0.1651 - val_loss: 0.1702 - val_mean_absolute_error: 0.1702
# Epoch 218/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1640 - mean_absolute_error: 0.1640 - val_loss: 0.1674 - val_mean_absolute_error: 0.1674
# Epoch 219/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1669 - mean_absolute_error: 0.1669 - val_loss: 0.1923 - val_mean_absolute_error: 0.1923
# Epoch 220/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1667 - mean_absolute_error: 0.1667 - val_loss: 0.1775 - val_mean_absolute_error: 0.1775
# Epoch 221/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1669 - mean_absolute_error: 0.1669 - val_loss: 0.1740 - val_mean_absolute_error: 0.1740
# Epoch 222/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1662 - mean_absolute_error: 0.1662 - val_loss: 0.1805 - val_mean_absolute_error: 0.1805
# Epoch 223/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1702 - mean_absolute_error: 0.1702 - val_loss: 0.1712 - val_mean_absolute_error: 0.1712
# Epoch 224/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1730 - mean_absolute_error: 0.1730 - val_loss: 0.1797 - val_mean_absolute_error: 0.1797
# Epoch 225/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1719 - mean_absolute_error: 0.1719 - val_loss: 0.1776 - val_mean_absolute_error: 0.1776
# Epoch 226/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1661 - mean_absolute_error: 0.1661 - val_loss: 0.1825 - val_mean_absolute_error: 0.1825
# Epoch 227/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1689 - mean_absolute_error: 0.1689 - val_loss: 0.1745 - val_mean_absolute_error: 0.1745
# Epoch 228/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1635 - mean_absolute_error: 0.1635 - val_loss: 0.1688 - val_mean_absolute_error: 0.1688
# Epoch 229/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1688 - mean_absolute_error: 0.1688 - val_loss: 0.1768 - val_mean_absolute_error: 0.1768
# Epoch 230/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1700 - mean_absolute_error: 0.1700 - val_loss: 0.1688 - val_mean_absolute_error: 0.1688
# Epoch 231/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1651 - mean_absolute_error: 0.1651 - val_loss: 0.1786 - val_mean_absolute_error: 0.1786
# Epoch 232/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1680 - mean_absolute_error: 0.1680 - val_loss: 0.1816 - val_mean_absolute_error: 0.1816
# Epoch 233/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1701 - mean_absolute_error: 0.1701 - val_loss: 0.1735 - val_mean_absolute_error: 0.1735
# Epoch 234/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1677 - mean_absolute_error: 0.1677 - val_loss: 0.1719 - val_mean_absolute_error: 0.1719
# Epoch 235/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1621 - mean_absolute_error: 0.1621 - val_loss: 0.1752 - val_mean_absolute_error: 0.1752
# Epoch 236/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1695 - mean_absolute_error: 0.1695 - val_loss: 0.1707 - val_mean_absolute_error: 0.1707
# Epoch 237/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1723 - mean_absolute_error: 0.1723 - val_loss: 0.1726 - val_mean_absolute_error: 0.1726
# Epoch 238/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1667 - mean_absolute_error: 0.1667 - val_loss: 0.1761 - val_mean_absolute_error: 0.1761
# Epoch 239/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1646 - mean_absolute_error: 0.1646 - val_loss: 0.1690 - val_mean_absolute_error: 0.1690
# Epoch 240/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1644 - mean_absolute_error: 0.1644 - val_loss: 0.1777 - val_mean_absolute_error: 0.1777
# Epoch 241/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1683 - mean_absolute_error: 0.1683 - val_loss: 0.1886 - val_mean_absolute_error: 0.1886
# Epoch 242/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.1647 - mean_absolute_error: 0.1647 - val_loss: 0.1916 - val_mean_absolute_error: 0.1916
# Epoch 243/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1689 - mean_absolute_error: 0.1689 - val_loss: 0.1818 - val_mean_absolute_error: 0.1818
# Epoch 00243: early stopping

# %%
model = keras.models.load_model("best_model.h5")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test error", test_acc)
print("Test loss", test_loss)
# Out:
# 1/1 [==============================] - 1s 664ms/step - loss: 0.1642 - mean_absolute_error: 0.1642
# Test error 0.16419276595115662
# Test loss 0.16419276595115662

# %%
mua = np.zeros((x_train.shape[0],))
# mus = np.zeros((x_train.shape[0],))
d = np.zeros((x_train.shape[0],))
miu = np.zeros((x_train.shape[0],1))

miu = model.predict(x_train)
mus = miu[:,0]
# mus = miu[:,1]
d = x_train[:,0,0]

# %%
err = np.zeros((x_train.shape[0],))

err = y_train[:,0]-mus
# err[:,1] = y_train[:,1]-mus

# print(mua[k],mus[k],d[k])
# print(y_train[k])

# %%
k=np.random.randint(0,x_train.shape[0],1)[0]
print(mus[k],d[k])
print(y_train[k])
# Out:
# 0.12993647 0.00419602170586586
# [0.05860963]

# %%
plt.plot(d,err)
plt.show()

# %%
# print(mua,mus,d)
# print(an2[i,1],an2[i,2],an2[i,0])
# plt.plot(abs(an1[:,1]-mua))
# plt.plot(abs(an1[:,2]-mus))
plt.hist(abs(err), bins=40,  facecolor="blue", edgecolor="black", alpha=0.7)
# plt.hist(abs(y_train[:,1]-mus), bins=40,  facecolor="green", edgecolor="black", alpha=0.7)
plt.show()

# %%
metric = "mean_absolute_error"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()

# %%
# 你可以用pca或者一些降维方法把特征搞一下
