# %%
# 不用PCA 而是 重新预处理输入量
import os  
import numpy as np
import struct
import matplotlib.pyplot as plt
import gc
import random
import math
from tensorflow import keras
import sklearn
# from scipy.interpolate import CubicSpline
from scipy.signal import find_peaks
from scipy.interpolate import interp1d

# %%
with open("C:\\Users\\Administrator\\source\\data\\dataset_test.bin", "rb") as file0:
    data1 = file0.read(4)
    NM1 = struct.unpack("i", data1)[0]
    sig2 = np.zeros((NM1,200),dtype = np.float32)
    an2 = np.zeros((NM1,4),dtype = np.float32)
    for i in range(NM1):
        for k in range(4):
            data1 = file0.read(4)
            an2[i,k] = struct.unpack("f", data1)[0]
        for k in range(200):
            data1 = file0.read(4)
            sig2[i,k] = struct.unpack("f", data1)[0]  
    # data1 = file0.read(len('end\0'))
    # end = struct.unpack("4s", data1)[0]

# %%
with open("C:\\Users\\Administrator\\source\\data\\dataset.bin", "rb") as file0:
    data1 = file0.read(4)
    NM1 = struct.unpack("i", data1)[0]
    sig1 = np.zeros((NM1,200),dtype = np.float32)
    an1 = np.zeros((NM1,4),dtype = np.float32)
    for i in range(NM1):
        for k in range(4):
            data1 = file0.read(4)
            an1[i,k] = struct.unpack("f", data1)[0]
        for k in range(200):
            data1 = file0.read(4)
            sig1[i,k] = struct.unpack("f", data1)[0]  
    # data1 = file0.read(len('end\0'))
    # end = struct.unpack("4s", data1)[0]

# %%
plt.axes(yscale = "log") 
for n in range(sig1.shape[0]):
    plt.plot(sig1[n])
plt.show()
print(NM1)
print(an2[-1])
# Out:
# 1262
# [1.24224685e-02 9.14926987e+01 1.54261023e+03 8.50000024e-01]

# %%
# def labeling(y,N):
#     ##############
#     a,b = y.shape
#     min0 = np.min(y,0)
#     max0 = np.max(y,0)
#     step = (max0-min0)/N
#     y2 = np.zeros((a,b,N))
    
#     # kernel = np.array([1]) 
#     # kernel = kernel/np.sum(kernel)
    
#     for i in range(a):
#         for j in range(b):
#             if(step[j]!=0):
#                 idx = (y[i,j]-min0[j])/step[j]-1
#                 y2[i,j,int(idx)] = 1
#             else:
#                 y2[i,j,0] = 1
#             # y2[i,j] = np.convolve(y2[i,j],kernel,mode='same')
            
#     return y2

# %%
xsig = sig1[0]
peaks, _ = find_peaks(xsig, height=0)
plt.plot(xsig)
plt.plot(peaks, xsig[peaks], "x")
plt.plot(np.zeros_like(xsig), "--", color="gray")
plt.show()

x = np.zeros((peaks.shape[0]+2,))
y = np.zeros((peaks.shape[0]+2,))
x[1:-1] = peaks
y[1:-1] = xsig[peaks]
x[-1] = sig1.shape[1]
plt.plot(x,y)
plt.show()

f2 = interp1d(x, y, kind='linear')
N = 200
xnew = np.linspace(0, N,num=N)
ynew = f2(xnew)

# plt.axes(yscale = "log") 
plt.plot(ynew)
plt.show()

# %%
def smooth_peak(xsig):
    peaks, _ = find_peaks(xsig, height=0)
    # plt.plot(xsig)
    # plt.plot(peaks, xsig[peaks], "x")
    # plt.plot(np.zeros_like(xsig), "--", color="gray")
    # plt.show()
    if(peaks.shape[0]!=0):
        x = np.zeros((peaks.shape[0]+3,))
        y = np.zeros((peaks.shape[0]+3,))
        x[1:-2] = peaks
        y[1:-2] = xsig[peaks]
        x[-1] = sig1.shape[1]
        y[-1] = 0
        x[-2] = peaks[-1]+5
        y[-2] = 0
        # plt.plot(x,y)
        # plt.show()

        f2 = interp1d(x, y, kind='linear')
        N = xsig.shape[0]
        xnew = np.linspace(0, N,num=N)
        ynew = f2(xnew)
    
    else:
        ynew = np.zeros((xsig.shape[0],))
    
    return ynew
#     # plt.axes(yscale = "log") 
#     plt.plot(ynew)
#     plt.show()

# %%
msig1 = np.zeros((sig1.shape[0],sig1.shape[1]))
for i in range(sig1.shape[0]):
    msig1[i] = smooth_peak(sig1[i])
    
msig2 = np.zeros((sig2.shape[0],sig2.shape[1]))
for i in range(sig2.shape[0]):
    msig2[i] = smooth_peak(sig2[i])

# %%
plt.axes(yscale = "log") 
for n in range(msig1.shape[0]):
    plt.plot(msig1[n])
plt.show()

# %%
print(sig1.shape)
print(an1.shape)
print(sig2.shape)
print(an2.shape)
# num_labels = 10
x_train = msig1
y_train = an1
x_test = msig2
y_test = an2

x_train = np.log10((x_train+1e-6)/1000)+11
x_test = np.log10((x_test+1e-6)/1000)+11
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))
d_train = np.reshape(y_train[:,0],(y_train[:,0].shape[0],1,1)) # add thickness of sample into input data
d_test = np.reshape(y_test[:,0],(y_test[:,0].shape[0],1,1))

x_train = np.concatenate((d_train,x_train),axis = 1) 
x_test = np.concatenate((d_test,x_test),axis = 1)
y_train[:,1] = y_train[:,1]/1e2
y_test[:,1] = y_test[:,1]/1e2
y_train[:,2] = y_train[:,2]/200e2
y_test[:,2] = y_test[:,2]/200e2
y_train = y_train[:,1:2] # determine the nn to output mua/mus or mua+mus
y_test = y_test[:,1:2]
# y_train = labeling(y_train,num_labels)[:,1,:] # select to predict what : 0:thickness 1:mua 2: mus
# y_test = labeling(y_test,num_labels)[:,1,:]
print('x_train.shape = '+str(x_train.shape)) 
print('y_train.shape = '+str(y_train.shape))
# Out:
# (1262, 200)
# (1262, 4)
# (30, 200)
# (30, 4)
# x_train.shape = (1262, 201, 1)
# y_train.shape = (1262, 1)

# %%
for n in range(x_train.shape[0]):
    plt.plot(x_train[n,1:])
plt.show()

# %%
# num_classes = y_train.shape[1]
########################################
# input_shape = (1,5,1)
# x = np.arange(np.prod(input_shape)).reshape(input_shape)      # test cropping#
# print(x)
# y = keras.layers.Cropping1D(cropping=(0,4))(x)
# z = keras.layers.Cropping1D(cropping=(1,0))(x)
# print(y)
# print(z)

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)
    
    d_1 = keras.layers.Cropping1D(cropping=(0,200))(input_layer)
    sig = keras.layers.Cropping1D(cropping=(1,0))(input_layer)
    
    conv1 = keras.layers.Conv1D(filters=16, kernel_size=3, padding="same")(sig)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=16, kernel_size=3, padding="same")(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=16, kernel_size=3, padding="same")(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)
    
    gap = keras.layers.Dense(16, activation='relu')(gap)
    gap = keras.layers.BatchNormalization()(gap)
    gap = keras.layers.Dropout(0.5)(gap)
    gap = keras.layers.Dense(16, activation='relu')(gap)
    
    
    d_1 = keras.layers.Dense(16, activation='relu')(d_1)
    d_1 = keras.layers.Dense(16, activation='relu')(d_1)
    d_1 = keras.layers.Reshape((16,))(d_1)
    
    
    
    merged = keras.layers.Concatenate()([d_1, gap])
    merged = keras.layers.Dense(8, activation='relu')(merged)
    
    output_layer = keras.layers.Dense(1, activation="linear")(merged)
#######################################################################
#     d_1 = keras.layers.Dense(16, activation='relu')(d_1)
#     # d_1 = keras.layers.Dense(10, activation='relu')(d_1)
#     d_1 = keras.layers.Reshape((16,))(d_1)
    
#     d_1 = keras.layers.BatchNormalization()(d_1)
#     gap = keras.layers.Dense(8, activation='relu')(gap)
#     gap = keras.layers.BatchNormalization()(gap)
    
#     merged = keras.layers.Concatenate()([d_1, gap])
#     merged = keras.layers.Dense(8, activation='relu')(merged)
    
#     output_layer = keras.layers.Dense(2, activation="linear")(merged)
##########################################################################    
    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])
keras.utils.plot_model(model, show_shapes=True)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %%
epochs = 500
batch_size = 32
#####################################################
index = [i for i in range(x_train.shape[0])]  
np.random.shuffle(index) 
x_train = x_train[index]
y_train = y_train[index]
####################################################
callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="mean_squared_error",
    metrics=["MeanAbsoluteError"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.4,
    verbose=1,
)
# Out:
# Epoch 1/500
# 24/24 [==============================] - 4s 41ms/step - loss: 0.2179 - mean_absolute_error: 0.3886 - val_loss: 0.2215 - val_mean_absolute_error: 0.3936
# Epoch 2/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1126 - mean_absolute_error: 0.2582 - val_loss: 0.1249 - val_mean_absolute_error: 0.2876
# Epoch 3/500
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0744 - mean_absolute_error: 0.2129 - val_loss: 0.0820 - val_mean_absolute_error: 0.2388
# Epoch 4/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0576 - mean_absolute_error: 0.1835 - val_loss: 0.0725 - val_mean_absolute_error: 0.2275
# Epoch 5/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0576 - mean_absolute_error: 0.1876 - val_loss: 0.0759 - val_mean_absolute_error: 0.2348
# Epoch 6/500
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0487 - mean_absolute_error: 0.1722 - val_loss: 0.0882 - val_mean_absolute_error: 0.2522
# Epoch 7/500
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0501 - mean_absolute_error: 0.1742 - val_loss: 0.0902 - val_mean_absolute_error: 0.2532
# Epoch 8/500
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0479 - mean_absolute_error: 0.1711 - val_loss: 0.1253 - val_mean_absolute_error: 0.2957
# Epoch 9/500
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0463 - mean_absolute_error: 0.1681 - val_loss: 0.1407 - val_mean_absolute_error: 0.3124
# Epoch 10/500
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0442 - mean_absolute_error: 0.1653 - val_loss: 0.0903 - val_mean_absolute_error: 0.2568
# Epoch 11/500
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0437 - mean_absolute_error: 0.1623 - val_loss: 0.1077 - val_mean_absolute_error: 0.2781
# Epoch 12/500
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0388 - mean_absolute_error: 0.1497 - val_loss: 0.1307 - val_mean_absolute_error: 0.3019
# Epoch 13/500
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0383 - mean_absolute_error: 0.1519 - val_loss: 0.1373 - val_mean_absolute_error: 0.3081
# Epoch 14/500
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0355 - mean_absolute_error: 0.1466 - val_loss: 0.1392 - val_mean_absolute_error: 0.3118
# Epoch 15/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0375 - mean_absolute_error: 0.1480 - val_loss: 0.0580 - val_mean_absolute_error: 0.1951
# Epoch 16/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0353 - mean_absolute_error: 0.1419 - val_loss: 0.0601 - val_mean_absolute_error: 0.1999
# Epoch 17/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0332 - mean_absolute_error: 0.1406 - val_loss: 0.0764 - val_mean_absolute_error: 0.2386
# Epoch 18/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0391 - mean_absolute_error: 0.1494 - val_loss: 0.0388 - val_mean_absolute_error: 0.1568
# Epoch 19/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0331 - mean_absolute_error: 0.1391 - val_loss: 0.0335 - val_mean_absolute_error: 0.1453
# Epoch 20/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0302 - mean_absolute_error: 0.1349 - val_loss: 0.0475 - val_mean_absolute_error: 0.1688
# Epoch 21/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0309 - mean_absolute_error: 0.1310 - val_loss: 0.0431 - val_mean_absolute_error: 0.1503
# Epoch 22/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0313 - mean_absolute_error: 0.1343 - val_loss: 0.0398 - val_mean_absolute_error: 0.1646
# Epoch 23/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0310 - mean_absolute_error: 0.1336 - val_loss: 0.0578 - val_mean_absolute_error: 0.1977
# Epoch 24/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0311 - mean_absolute_error: 0.1352 - val_loss: 0.0600 - val_mean_absolute_error: 0.2063
# Epoch 25/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0289 - mean_absolute_error: 0.1305 - val_loss: 0.0293 - val_mean_absolute_error: 0.1327
# Epoch 26/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0291 - mean_absolute_error: 0.1267 - val_loss: 0.0339 - val_mean_absolute_error: 0.1403
# Epoch 27/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0297 - mean_absolute_error: 0.1292 - val_loss: 0.0283 - val_mean_absolute_error: 0.1286
# Epoch 28/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0303 - mean_absolute_error: 0.1306 - val_loss: 0.0192 - val_mean_absolute_error: 0.0992
# Epoch 29/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0303 - mean_absolute_error: 0.1322 - val_loss: 0.0277 - val_mean_absolute_error: 0.1189
# Epoch 30/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0296 - mean_absolute_error: 0.1291 - val_loss: 0.0282 - val_mean_absolute_error: 0.1274
# Epoch 31/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0269 - mean_absolute_error: 0.1242 - val_loss: 0.0217 - val_mean_absolute_error: 0.1084
# Epoch 32/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0255 - mean_absolute_error: 0.1221 - val_loss: 0.0394 - val_mean_absolute_error: 0.1717
# Epoch 33/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0273 - mean_absolute_error: 0.1254 - val_loss: 0.0227 - val_mean_absolute_error: 0.1085
# Epoch 34/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0260 - mean_absolute_error: 0.1211 - val_loss: 0.0303 - val_mean_absolute_error: 0.1415
# Epoch 35/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0247 - mean_absolute_error: 0.1182 - val_loss: 0.0479 - val_mean_absolute_error: 0.1865
# Epoch 36/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0248 - mean_absolute_error: 0.1169 - val_loss: 0.0280 - val_mean_absolute_error: 0.1273
# Epoch 37/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0268 - mean_absolute_error: 0.1242 - val_loss: 0.0343 - val_mean_absolute_error: 0.1375
# Epoch 38/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0282 - mean_absolute_error: 0.1239 - val_loss: 0.0872 - val_mean_absolute_error: 0.2567
# Epoch 39/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0284 - mean_absolute_error: 0.1281 - val_loss: 0.0270 - val_mean_absolute_error: 0.1195
# Epoch 40/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0283 - mean_absolute_error: 0.1265 - val_loss: 0.0482 - val_mean_absolute_error: 0.1749
# Epoch 41/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0291 - mean_absolute_error: 0.1273 - val_loss: 0.0337 - val_mean_absolute_error: 0.1548
# Epoch 42/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0269 - mean_absolute_error: 0.1213 - val_loss: 0.0563 - val_mean_absolute_error: 0.1769
# Epoch 43/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0272 - mean_absolute_error: 0.1219 - val_loss: 0.0351 - val_mean_absolute_error: 0.1584
# Epoch 44/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0246 - mean_absolute_error: 0.1149 - val_loss: 0.0651 - val_mean_absolute_error: 0.2075
# Epoch 45/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0254 - mean_absolute_error: 0.1182 - val_loss: 0.1218 - val_mean_absolute_error: 0.2988
# Epoch 46/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0289 - mean_absolute_error: 0.1304 - val_loss: 0.0439 - val_mean_absolute_error: 0.1548
# Epoch 47/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0258 - mean_absolute_error: 0.1209 - val_loss: 0.0779 - val_mean_absolute_error: 0.2420
# Epoch 48/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0286 - mean_absolute_error: 0.1243 - val_loss: 0.0806 - val_mean_absolute_error: 0.2126
# Epoch 49/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0278 - mean_absolute_error: 0.1235 - val_loss: 0.0660 - val_mean_absolute_error: 0.2246
# Epoch 50/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0255 - mean_absolute_error: 0.1182 - val_loss: 0.0223 - val_mean_absolute_error: 0.1168
# Epoch 51/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0250 - mean_absolute_error: 0.1195 - val_loss: 0.0318 - val_mean_absolute_error: 0.1496
# Epoch 52/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0247 - mean_absolute_error: 0.1155 - val_loss: 0.0192 - val_mean_absolute_error: 0.0986
# Epoch 53/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0247 - mean_absolute_error: 0.1201 - val_loss: 0.0851 - val_mean_absolute_error: 0.2620
# Epoch 54/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0233 - mean_absolute_error: 0.1111 - val_loss: 0.0182 - val_mean_absolute_error: 0.0998
# Epoch 55/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0244 - mean_absolute_error: 0.1165 - val_loss: 0.0742 - val_mean_absolute_error: 0.2336
# Epoch 56/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0238 - mean_absolute_error: 0.1135 - val_loss: 0.0882 - val_mean_absolute_error: 0.2698
# Epoch 57/500
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0210 - mean_absolute_error: 0.1068 - val_loss: 0.0219 - val_mean_absolute_error: 0.1139
# Epoch 58/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0238 - mean_absolute_error: 0.1139 - val_loss: 0.0421 - val_mean_absolute_error: 0.1768
# Epoch 59/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0234 - mean_absolute_error: 0.1106 - val_loss: 0.0221 - val_mean_absolute_error: 0.1057
# Epoch 60/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0258 - mean_absolute_error: 0.1209 - val_loss: 0.0899 - val_mean_absolute_error: 0.2592
# Epoch 61/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0240 - mean_absolute_error: 0.1119 - val_loss: 0.0780 - val_mean_absolute_error: 0.2421
# Epoch 62/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0218 - mean_absolute_error: 0.1076 - val_loss: 0.0429 - val_mean_absolute_error: 0.1750
# Epoch 63/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0240 - mean_absolute_error: 0.1125 - val_loss: 0.0215 - val_mean_absolute_error: 0.1112
# Epoch 64/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0233 - mean_absolute_error: 0.1149 - val_loss: 0.0319 - val_mean_absolute_error: 0.1382
# Epoch 65/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0241 - mean_absolute_error: 0.1121 - val_loss: 0.0231 - val_mean_absolute_error: 0.1200
# Epoch 66/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0217 - mean_absolute_error: 0.1070 - val_loss: 0.0179 - val_mean_absolute_error: 0.0893
# Epoch 67/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0240 - mean_absolute_error: 0.1136 - val_loss: 0.0152 - val_mean_absolute_error: 0.0850
# Epoch 68/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0228 - mean_absolute_error: 0.1115 - val_loss: 0.0400 - val_mean_absolute_error: 0.1559
# Epoch 69/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0239 - mean_absolute_error: 0.1109 - val_loss: 0.0178 - val_mean_absolute_error: 0.0955
# Epoch 70/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0239 - mean_absolute_error: 0.1092 - val_loss: 0.0483 - val_mean_absolute_error: 0.1925
# Epoch 71/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0244 - mean_absolute_error: 0.1144 - val_loss: 0.0242 - val_mean_absolute_error: 0.1308
# Epoch 72/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0226 - mean_absolute_error: 0.1118 - val_loss: 0.0512 - val_mean_absolute_error: 0.1928
# Epoch 73/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0203 - mean_absolute_error: 0.1037 - val_loss: 0.0802 - val_mean_absolute_error: 0.2485
# Epoch 74/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0226 - mean_absolute_error: 0.1096 - val_loss: 0.0244 - val_mean_absolute_error: 0.1146
# Epoch 75/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0213 - mean_absolute_error: 0.1055 - val_loss: 0.0521 - val_mean_absolute_error: 0.1919
# Epoch 76/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0229 - mean_absolute_error: 0.1081 - val_loss: 0.0553 - val_mean_absolute_error: 0.1791
# Epoch 77/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0216 - mean_absolute_error: 0.1077 - val_loss: 0.1396 - val_mean_absolute_error: 0.3245
# Epoch 78/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0228 - mean_absolute_error: 0.1133 - val_loss: 0.0635 - val_mean_absolute_error: 0.1858
# Epoch 79/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0223 - mean_absolute_error: 0.1110 - val_loss: 0.0558 - val_mean_absolute_error: 0.1743
# Epoch 80/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0234 - mean_absolute_error: 0.1100 - val_loss: 0.0226 - val_mean_absolute_error: 0.1083
# Epoch 81/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0280 - mean_absolute_error: 0.1234 - val_loss: 0.0968 - val_mean_absolute_error: 0.2630
# Epoch 82/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0227 - mean_absolute_error: 0.1090 - val_loss: 0.0243 - val_mean_absolute_error: 0.1175
# Epoch 83/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0224 - mean_absolute_error: 0.1089 - val_loss: 0.0205 - val_mean_absolute_error: 0.1033
# Epoch 84/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0230 - mean_absolute_error: 0.1132 - val_loss: 0.1522 - val_mean_absolute_error: 0.3461
# Epoch 85/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0232 - mean_absolute_error: 0.1127 - val_loss: 0.1413 - val_mean_absolute_error: 0.3330
# Epoch 86/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0230 - mean_absolute_error: 0.1100 - val_loss: 0.0710 - val_mean_absolute_error: 0.1973
# Epoch 87/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0226 - mean_absolute_error: 0.1073 - val_loss: 0.0181 - val_mean_absolute_error: 0.0983
# Epoch 88/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0232 - mean_absolute_error: 0.1111 - val_loss: 0.0177 - val_mean_absolute_error: 0.0924
# Epoch 89/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0216 - mean_absolute_error: 0.1077 - val_loss: 0.0632 - val_mean_absolute_error: 0.2168
# Epoch 90/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0209 - mean_absolute_error: 0.1039 - val_loss: 0.0280 - val_mean_absolute_error: 0.1412
# Epoch 91/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0204 - mean_absolute_error: 0.1051 - val_loss: 0.0289 - val_mean_absolute_error: 0.1347
# Epoch 92/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0226 - mean_absolute_error: 0.1105 - val_loss: 0.0229 - val_mean_absolute_error: 0.1213
# Epoch 93/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0214 - mean_absolute_error: 0.1051 - val_loss: 0.0290 - val_mean_absolute_error: 0.1210
# Epoch 94/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0214 - mean_absolute_error: 0.1057 - val_loss: 0.0176 - val_mean_absolute_error: 0.0960
# Epoch 95/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0213 - mean_absolute_error: 0.1053 - val_loss: 0.0254 - val_mean_absolute_error: 0.1239
# Epoch 96/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0219 - mean_absolute_error: 0.1052 - val_loss: 0.0554 - val_mean_absolute_error: 0.2045
# Epoch 97/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0239 - mean_absolute_error: 0.1126 - val_loss: 0.0151 - val_mean_absolute_error: 0.0819
# Epoch 98/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0210 - mean_absolute_error: 0.1040 - val_loss: 0.0145 - val_mean_absolute_error: 0.0826
# Epoch 99/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0191 - mean_absolute_error: 0.1012 - val_loss: 0.0259 - val_mean_absolute_error: 0.1179
# Epoch 100/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0202 - mean_absolute_error: 0.1021 - val_loss: 0.0310 - val_mean_absolute_error: 0.1334
# Epoch 101/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0231 - mean_absolute_error: 0.1086 - val_loss: 0.0698 - val_mean_absolute_error: 0.2204
# Epoch 102/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0221 - mean_absolute_error: 0.1049 - val_loss: 0.0420 - val_mean_absolute_error: 0.1574
# Epoch 103/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0254 - mean_absolute_error: 0.1151 - val_loss: 0.0586 - val_mean_absolute_error: 0.2029
# Epoch 104/500
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0209 - mean_absolute_error: 0.1044 - val_loss: 0.0204 - val_mean_absolute_error: 0.1147
# Epoch 105/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0222 - mean_absolute_error: 0.1102 - val_loss: 0.0253 - val_mean_absolute_error: 0.1040
# Epoch 106/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0202 - mean_absolute_error: 0.1020 - val_loss: 0.0762 - val_mean_absolute_error: 0.2307
# Epoch 107/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0194 - mean_absolute_error: 0.1013 - val_loss: 0.0202 - val_mean_absolute_error: 0.0943
# Epoch 108/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0220 - mean_absolute_error: 0.1064 - val_loss: 0.0251 - val_mean_absolute_error: 0.1301
# Epoch 109/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0218 - mean_absolute_error: 0.1102 - val_loss: 0.0475 - val_mean_absolute_error: 0.1732
# Epoch 110/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0226 - mean_absolute_error: 0.1099 - val_loss: 0.0673 - val_mean_absolute_error: 0.2120
# Epoch 111/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0233 - mean_absolute_error: 0.1105 - val_loss: 0.0215 - val_mean_absolute_error: 0.1048
# Epoch 112/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0231 - mean_absolute_error: 0.1114 - val_loss: 0.0378 - val_mean_absolute_error: 0.1595
# Epoch 113/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0226 - mean_absolute_error: 0.1090 - val_loss: 0.0241 - val_mean_absolute_error: 0.1179
# Epoch 114/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0218 - mean_absolute_error: 0.1049 - val_loss: 0.0457 - val_mean_absolute_error: 0.1694
# Epoch 115/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0204 - mean_absolute_error: 0.1024 - val_loss: 0.0251 - val_mean_absolute_error: 0.1228
# Epoch 116/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0209 - mean_absolute_error: 0.1054 - val_loss: 0.0206 - val_mean_absolute_error: 0.1035
# Epoch 117/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0208 - mean_absolute_error: 0.1058 - val_loss: 0.0173 - val_mean_absolute_error: 0.0903
# Epoch 118/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0190 - mean_absolute_error: 0.0997 - val_loss: 0.0164 - val_mean_absolute_error: 0.0922
# Epoch 119/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0212 - mean_absolute_error: 0.1076 - val_loss: 0.0167 - val_mean_absolute_error: 0.0939
# Epoch 120/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0221 - mean_absolute_error: 0.1067 - val_loss: 0.0151 - val_mean_absolute_error: 0.0860
# Epoch 121/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0195 - mean_absolute_error: 0.1002 - val_loss: 0.0406 - val_mean_absolute_error: 0.1751
# Epoch 122/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0190 - mean_absolute_error: 0.0974 - val_loss: 0.0142 - val_mean_absolute_error: 0.0774
# Epoch 123/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0200 - mean_absolute_error: 0.1009 - val_loss: 0.0157 - val_mean_absolute_error: 0.0909
# Epoch 124/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0213 - mean_absolute_error: 0.1049 - val_loss: 0.0270 - val_mean_absolute_error: 0.1324
# Epoch 125/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0204 - mean_absolute_error: 0.1014 - val_loss: 0.0165 - val_mean_absolute_error: 0.0875
# Epoch 126/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0200 - mean_absolute_error: 0.1008 - val_loss: 0.0158 - val_mean_absolute_error: 0.0901
# Epoch 127/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0203 - mean_absolute_error: 0.1022 - val_loss: 0.0156 - val_mean_absolute_error: 0.0895
# Epoch 128/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0199 - mean_absolute_error: 0.1036 - val_loss: 0.0193 - val_mean_absolute_error: 0.1043
# Epoch 129/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0198 - mean_absolute_error: 0.1015 - val_loss: 0.0228 - val_mean_absolute_error: 0.1129
# Epoch 130/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0198 - mean_absolute_error: 0.0987 - val_loss: 0.0146 - val_mean_absolute_error: 0.0826
# Epoch 131/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0205 - mean_absolute_error: 0.1043 - val_loss: 0.0158 - val_mean_absolute_error: 0.0828
# Epoch 132/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0212 - mean_absolute_error: 0.1036 - val_loss: 0.0157 - val_mean_absolute_error: 0.0871
# Epoch 133/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0204 - mean_absolute_error: 0.1038 - val_loss: 0.0255 - val_mean_absolute_error: 0.1233
# Epoch 134/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0210 - mean_absolute_error: 0.1072 - val_loss: 0.0172 - val_mean_absolute_error: 0.0957
# Epoch 135/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0220 - mean_absolute_error: 0.1061 - val_loss: 0.0140 - val_mean_absolute_error: 0.0779
# Epoch 136/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0225 - mean_absolute_error: 0.1080 - val_loss: 0.0153 - val_mean_absolute_error: 0.0829
# Epoch 137/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0214 - mean_absolute_error: 0.1032 - val_loss: 0.0151 - val_mean_absolute_error: 0.0834
# Epoch 138/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0215 - mean_absolute_error: 0.1080 - val_loss: 0.0187 - val_mean_absolute_error: 0.1028
# Epoch 139/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0182 - mean_absolute_error: 0.0979 - val_loss: 0.0166 - val_mean_absolute_error: 0.0930
# Epoch 140/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0203 - mean_absolute_error: 0.1018 - val_loss: 0.0505 - val_mean_absolute_error: 0.1907
# Epoch 141/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0199 - mean_absolute_error: 0.1016 - val_loss: 0.0155 - val_mean_absolute_error: 0.0892
# Epoch 142/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0191 - mean_absolute_error: 0.0988 - val_loss: 0.0165 - val_mean_absolute_error: 0.0931
# Epoch 143/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0214 - mean_absolute_error: 0.1054 - val_loss: 0.0183 - val_mean_absolute_error: 0.0976
# Epoch 144/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0223 - mean_absolute_error: 0.1077 - val_loss: 0.0605 - val_mean_absolute_error: 0.2120
# Epoch 145/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0203 - mean_absolute_error: 0.1049 - val_loss: 0.0226 - val_mean_absolute_error: 0.0991
# Epoch 146/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0210 - mean_absolute_error: 0.1056 - val_loss: 0.0205 - val_mean_absolute_error: 0.0993
# Epoch 147/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0206 - mean_absolute_error: 0.1032 - val_loss: 0.0219 - val_mean_absolute_error: 0.1114
# Epoch 148/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0188 - mean_absolute_error: 0.1002 - val_loss: 0.0236 - val_mean_absolute_error: 0.1148
# Epoch 149/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0211 - mean_absolute_error: 0.1069 - val_loss: 0.0184 - val_mean_absolute_error: 0.0993
# Epoch 150/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0200 - mean_absolute_error: 0.1006 - val_loss: 0.0403 - val_mean_absolute_error: 0.1600
# Epoch 151/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0207 - mean_absolute_error: 0.1057 - val_loss: 0.0259 - val_mean_absolute_error: 0.1242
# Epoch 152/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0180 - mean_absolute_error: 0.0981 - val_loss: 0.0308 - val_mean_absolute_error: 0.1387
# Epoch 153/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0195 - mean_absolute_error: 0.1018 - val_loss: 0.0157 - val_mean_absolute_error: 0.0915
# Epoch 154/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0208 - mean_absolute_error: 0.1017 - val_loss: 0.0154 - val_mean_absolute_error: 0.0896
# Epoch 155/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0186 - mean_absolute_error: 0.0976 - val_loss: 0.0166 - val_mean_absolute_error: 0.0951
# Epoch 156/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0201 - mean_absolute_error: 0.1021 - val_loss: 0.0214 - val_mean_absolute_error: 0.1048
# Epoch 157/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0210 - mean_absolute_error: 0.1034 - val_loss: 0.0151 - val_mean_absolute_error: 0.0835
# Epoch 158/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0202 - mean_absolute_error: 0.1018 - val_loss: 0.0160 - val_mean_absolute_error: 0.0897
# Epoch 159/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0200 - mean_absolute_error: 0.1010 - val_loss: 0.0324 - val_mean_absolute_error: 0.1401
# Epoch 160/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0213 - mean_absolute_error: 0.1066 - val_loss: 0.0233 - val_mean_absolute_error: 0.1120
# Epoch 161/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0193 - mean_absolute_error: 0.0999 - val_loss: 0.0348 - val_mean_absolute_error: 0.1537
# Epoch 162/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0203 - mean_absolute_error: 0.1024 - val_loss: 0.0465 - val_mean_absolute_error: 0.1746
# Epoch 163/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0238 - mean_absolute_error: 0.1099 - val_loss: 0.0145 - val_mean_absolute_error: 0.0826
# Epoch 164/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0202 - mean_absolute_error: 0.1035 - val_loss: 0.0155 - val_mean_absolute_error: 0.0813
# Epoch 165/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0196 - mean_absolute_error: 0.1001 - val_loss: 0.0199 - val_mean_absolute_error: 0.1054
# Epoch 166/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0182 - mean_absolute_error: 0.0966 - val_loss: 0.0158 - val_mean_absolute_error: 0.0889
# Epoch 167/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0193 - mean_absolute_error: 0.0998 - val_loss: 0.0174 - val_mean_absolute_error: 0.0985
# Epoch 168/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0197 - mean_absolute_error: 0.1012 - val_loss: 0.0135 - val_mean_absolute_error: 0.0772
# Epoch 169/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0187 - mean_absolute_error: 0.0978 - val_loss: 0.0145 - val_mean_absolute_error: 0.0822
# Epoch 170/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0191 - mean_absolute_error: 0.0992 - val_loss: 0.0201 - val_mean_absolute_error: 0.1120
# Epoch 171/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0201 - mean_absolute_error: 0.1011 - val_loss: 0.0175 - val_mean_absolute_error: 0.0968
# Epoch 172/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0201 - mean_absolute_error: 0.1007 - val_loss: 0.0361 - val_mean_absolute_error: 0.1561
# Epoch 173/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0191 - mean_absolute_error: 0.0993 - val_loss: 0.0163 - val_mean_absolute_error: 0.0913
# Epoch 174/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0189 - mean_absolute_error: 0.0993 - val_loss: 0.0160 - val_mean_absolute_error: 0.0915
# Epoch 175/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0183 - mean_absolute_error: 0.0975 - val_loss: 0.0182 - val_mean_absolute_error: 0.0998
# Epoch 176/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0195 - mean_absolute_error: 0.0986 - val_loss: 0.0188 - val_mean_absolute_error: 0.1021
# Epoch 177/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0189 - mean_absolute_error: 0.0992 - val_loss: 0.0153 - val_mean_absolute_error: 0.0852
# Epoch 178/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0192 - mean_absolute_error: 0.0993 - val_loss: 0.0255 - val_mean_absolute_error: 0.1298
# Epoch 179/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0194 - mean_absolute_error: 0.0990 - val_loss: 0.0132 - val_mean_absolute_error: 0.0759
# Epoch 180/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0185 - mean_absolute_error: 0.0992 - val_loss: 0.0194 - val_mean_absolute_error: 0.1018
# Epoch 181/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0207 - mean_absolute_error: 0.1035 - val_loss: 0.0167 - val_mean_absolute_error: 0.0970
# Epoch 182/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0185 - mean_absolute_error: 0.0983 - val_loss: 0.0294 - val_mean_absolute_error: 0.1390
# Epoch 183/500
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0204 - mean_absolute_error: 0.1021 - val_loss: 0.0191 - val_mean_absolute_error: 0.1053
# Epoch 184/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0183 - mean_absolute_error: 0.0959 - val_loss: 0.0203 - val_mean_absolute_error: 0.0964
# Epoch 185/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0196 - mean_absolute_error: 0.1034 - val_loss: 0.0178 - val_mean_absolute_error: 0.0901
# Epoch 186/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0205 - mean_absolute_error: 0.1061 - val_loss: 0.0295 - val_mean_absolute_error: 0.1228
# Epoch 187/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0185 - mean_absolute_error: 0.0978 - val_loss: 0.0556 - val_mean_absolute_error: 0.1945
# Epoch 188/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0196 - mean_absolute_error: 0.1017 - val_loss: 0.0572 - val_mean_absolute_error: 0.2037
# Epoch 189/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0196 - mean_absolute_error: 0.0973 - val_loss: 0.0233 - val_mean_absolute_error: 0.1172
# Epoch 190/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0186 - mean_absolute_error: 0.0970 - val_loss: 0.0154 - val_mean_absolute_error: 0.0822
# Epoch 191/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0191 - mean_absolute_error: 0.1002 - val_loss: 0.0172 - val_mean_absolute_error: 0.0963
# Epoch 192/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0196 - mean_absolute_error: 0.1008 - val_loss: 0.0166 - val_mean_absolute_error: 0.0901
# Epoch 193/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0223 - mean_absolute_error: 0.1072 - val_loss: 0.0348 - val_mean_absolute_error: 0.1564
# Epoch 194/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0188 - mean_absolute_error: 0.0993 - val_loss: 0.0222 - val_mean_absolute_error: 0.1207
# Epoch 195/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0180 - mean_absolute_error: 0.0933 - val_loss: 0.0151 - val_mean_absolute_error: 0.0852
# Epoch 196/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0182 - mean_absolute_error: 0.0973 - val_loss: 0.0143 - val_mean_absolute_error: 0.0803
# Epoch 197/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0183 - mean_absolute_error: 0.0964 - val_loss: 0.0210 - val_mean_absolute_error: 0.1079
# Epoch 198/500
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0218 - mean_absolute_error: 0.1063 - val_loss: 0.0149 - val_mean_absolute_error: 0.0850
# Epoch 199/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0202 - mean_absolute_error: 0.1006 - val_loss: 0.0147 - val_mean_absolute_error: 0.0825
# Epoch 200/500
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0179 - mean_absolute_error: 0.0966 - val_loss: 0.0149 - val_mean_absolute_error: 0.0786
# Epoch 201/500
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0226 - mean_absolute_error: 0.1091 - val_loss: 0.0224 - val_mean_absolute_error: 0.1129
# Epoch 202/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0190 - mean_absolute_error: 0.0969 - val_loss: 0.0169 - val_mean_absolute_error: 0.0939
# Epoch 203/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0197 - mean_absolute_error: 0.0972 - val_loss: 0.0164 - val_mean_absolute_error: 0.0852
# Epoch 204/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0191 - mean_absolute_error: 0.1012 - val_loss: 0.0288 - val_mean_absolute_error: 0.1383
# Epoch 205/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0191 - mean_absolute_error: 0.0971 - val_loss: 0.0368 - val_mean_absolute_error: 0.1630
# Epoch 206/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0184 - mean_absolute_error: 0.0986 - val_loss: 0.0152 - val_mean_absolute_error: 0.0797
# Epoch 207/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0194 - mean_absolute_error: 0.1010 - val_loss: 0.0146 - val_mean_absolute_error: 0.0779
# Epoch 208/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0202 - mean_absolute_error: 0.1025 - val_loss: 0.0157 - val_mean_absolute_error: 0.0812
# Epoch 209/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0208 - mean_absolute_error: 0.1032 - val_loss: 0.0160 - val_mean_absolute_error: 0.0876
# Epoch 210/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0209 - mean_absolute_error: 0.1019 - val_loss: 0.0163 - val_mean_absolute_error: 0.0869
# Epoch 211/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0191 - mean_absolute_error: 0.1007 - val_loss: 0.0277 - val_mean_absolute_error: 0.1375
# Epoch 212/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0193 - mean_absolute_error: 0.0993 - val_loss: 0.0148 - val_mean_absolute_error: 0.0849
# Epoch 213/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0199 - mean_absolute_error: 0.1009 - val_loss: 0.0226 - val_mean_absolute_error: 0.1226
# Epoch 214/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0209 - mean_absolute_error: 0.1050 - val_loss: 0.0154 - val_mean_absolute_error: 0.0835
# Epoch 215/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0192 - mean_absolute_error: 0.1002 - val_loss: 0.0179 - val_mean_absolute_error: 0.0963
# Epoch 216/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0191 - mean_absolute_error: 0.0974 - val_loss: 0.0139 - val_mean_absolute_error: 0.0777
# Epoch 217/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0209 - mean_absolute_error: 0.1038 - val_loss: 0.0180 - val_mean_absolute_error: 0.0988
# Epoch 218/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0201 - mean_absolute_error: 0.1019 - val_loss: 0.0141 - val_mean_absolute_error: 0.0789
# Epoch 219/500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0183 - mean_absolute_error: 0.0965 - val_loss: 0.0135 - val_mean_absolute_error: 0.0774
# Epoch 220/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0184 - mean_absolute_error: 0.0978 - val_loss: 0.0257 - val_mean_absolute_error: 0.1212
# Epoch 221/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0187 - mean_absolute_error: 0.0949 - val_loss: 0.0225 - val_mean_absolute_error: 0.1093
# Epoch 222/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0187 - mean_absolute_error: 0.0980 - val_loss: 0.0149 - val_mean_absolute_error: 0.0845
# Epoch 223/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0186 - mean_absolute_error: 0.0980 - val_loss: 0.0228 - val_mean_absolute_error: 0.1192
# Epoch 224/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0181 - mean_absolute_error: 0.0969 - val_loss: 0.0151 - val_mean_absolute_error: 0.0862
# Epoch 225/500
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0200 - mean_absolute_error: 0.1041 - val_loss: 0.0455 - val_mean_absolute_error: 0.1729
# Epoch 226/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0200 - mean_absolute_error: 0.1008 - val_loss: 0.0189 - val_mean_absolute_error: 0.1004
# Epoch 227/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0183 - mean_absolute_error: 0.0948 - val_loss: 0.0198 - val_mean_absolute_error: 0.1067
# Epoch 228/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0199 - mean_absolute_error: 0.1018 - val_loss: 0.0135 - val_mean_absolute_error: 0.0772
# Epoch 229/500
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0195 - mean_absolute_error: 0.1004 - val_loss: 0.0133 - val_mean_absolute_error: 0.0740
# Epoch 00229: early stopping

# %%
model = keras.models.load_model("best_model.h5")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test error", test_acc)
print("Test loss", test_loss)
# Out:
# 1/1 [==============================] - 0s 465ms/step - loss: 0.0184 - mean_absolute_error: 0.1045
# Test error 0.1045384407043457
# Test loss 0.018382135778665543

# %%
mua = np.zeros((x_train.shape[0],))
# mus = np.zeros((x_train.shape[0],))
d = np.zeros((x_train.shape[0],))
miu = np.zeros((x_train.shape[0],1))

miu = model.predict(x_train)
mua = miu[:,0]
# mus = miu[:,1]
d = x_train[:,0,0]

# %%
err = np.zeros((x_train.shape[0],))

err = y_train-mua
# err[:,1] = y_train[:,1]-mus

# print(mua[k],mus[k],d[k])
# print(y_train[k])

# %%
plt.plot(d,err[:,1])
plt.show()

# %%
# print(mua,mus,d)
# print(an2[i,1],an2[i,2],an2[i,0])
# plt.plot(abs(an1[:,1]-mua))
# plt.plot(abs(an1[:,2]-mus))
plt.hist(abs(y_train[:,0]-mua), bins=40,  facecolor="blue", edgecolor="black", alpha=0.7)
# plt.hist(abs(y_train[:,1]-mus), bins=40,  facecolor="green", edgecolor="black", alpha=0.7)
plt.show()

# %%
metric = "mean_absolute_error"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()

# %%
# 你可以用pca或者一些降维方法把特征搞一下
