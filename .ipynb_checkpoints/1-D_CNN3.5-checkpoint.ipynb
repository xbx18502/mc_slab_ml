# %%
# 同时计算mua和mus,只输入波峰信息
import os  
import numpy as np
import struct
import matplotlib.pyplot as plt
import gc
import random
import math
from tensorflow import keras
import sklearn
# from scipy.interpolate import CubicSpline
from scipy.signal import find_peaks
from scipy.interpolate import interp1d

# %%
with open("C:\\Users\\Administrator\\source\\data\\dataset_test.bin", "rb") as file0:
    data1 = file0.read(4)
    NM1 = struct.unpack("i", data1)[0]
    sig2 = np.zeros((NM1,200),dtype = np.float32)
    an2 = np.zeros((NM1,4),dtype = np.float32)
    for i in range(NM1):
        for k in range(4):
            data1 = file0.read(4)
            an2[i,k] = struct.unpack("f", data1)[0]
        for k in range(200):
            data1 = file0.read(4)
            sig2[i,k] = struct.unpack("f", data1)[0]  
    # data1 = file0.read(len('end\0'))
    # end = struct.unpack("4s", data1)[0]

# %%
with open("C:\\Users\\Administrator\\source\\data\\dataset.bin", "rb") as file0:
    data1 = file0.read(4)
    NM1 = struct.unpack("i", data1)[0]
    sig1 = np.zeros((NM1,200),dtype = np.float32)
    an1 = np.zeros((NM1,4),dtype = np.float32)
    for i in range(NM1):
        for k in range(4):
            data1 = file0.read(4)
            an1[i,k] = struct.unpack("f", data1)[0]
        for k in range(200):
            data1 = file0.read(4)
            sig1[i,k] = struct.unpack("f", data1)[0]  
    # data1 = file0.read(len('end\0'))
    # end = struct.unpack("4s", data1)[0]

# %%
plt.axes(yscale = "log") 
for n in range(sig1.shape[0]):
    plt.plot(sig1[n])
plt.show()
print(NM1)
print(an2[-1])
# Out:
# 1262
# [1.24224685e-02 9.14926987e+01 1.54261023e+03 8.50000024e-01]

# %%
# def labeling(y,N):
#     ##############
#     a,b = y.shape
#     min0 = np.min(y,0)
#     max0 = np.max(y,0)
#     step = (max0-min0)/N
#     y2 = np.zeros((a,b,N))
    
#     # kernel = np.array([1]) 
#     # kernel = kernel/np.sum(kernel)
    
#     for i in range(a):
#         for j in range(b):
#             if(step[j]!=0):
#                 idx = (y[i,j]-min0[j])/step[j]-1
#                 y2[i,j,int(idx)] = 1
#             else:
#                 y2[i,j,0] = 1
#             # y2[i,j] = np.convolve(y2[i,j],kernel,mode='same')
            
#     return y2

# %%
xsig = sig1[0]
peaks, _ = find_peaks(xsig, height=0)
plt.plot(xsig)
plt.plot(peaks, xsig[peaks], "x")
plt.plot(np.zeros_like(xsig), "--", color="gray")
plt.show()

x = np.zeros((peaks.shape[0]+2,))
y = np.zeros((peaks.shape[0]+2,))
x[1:-1] = peaks
y[1:-1] = xsig[peaks]
x[-1] = sig1.shape[1]
plt.plot(x,y)
plt.show()

f2 = interp1d(x, y, kind='linear')
N = 200
xnew = np.linspace(0, N,num=N)
ynew = f2(xnew)

# plt.axes(yscale = "log") 
plt.plot(ynew)
plt.show()

# %%
def smooth_peak(xsig):
    peaks, _ = find_peaks(xsig, height=0)
    # plt.plot(xsig)
    # plt.plot(peaks, xsig[peaks], "x")
    # plt.plot(np.zeros_like(xsig), "--", color="gray")
    # plt.show()
    if(peaks.shape[0]!=0):
        x = np.zeros((peaks.shape[0]+3,))
        y = np.zeros((peaks.shape[0]+3,))
        x[1:-2] = peaks
        y[1:-2] = xsig[peaks]
        x[-1] = sig1.shape[1]
        y[-1] = 0
        x[-2] = peaks[-1]+5
        y[-2] = 0
        # plt.plot(x,y)
        # plt.show()

        f2 = interp1d(x, y, kind='linear')
        N = xsig.shape[0]
        xnew = np.linspace(0, N,num=N)
        ynew = f2(xnew)
    
    else:
        ynew = np.zeros((xsig.shape[0],))

    return ynew
#     # plt.axes(yscale = "log") 
#     plt.plot(ynew)
#     plt.show()

# %%
msig1 = np.zeros((sig1.shape[0],sig1.shape[1]))
an3 = np.zeros((an1.shape))
i_invalid = 0
flag = 0
for i in range(sig1.shape[0]):
    ynew = smooth_peak(sig1[i])
    if(np.all(ynew == 0)):
        i_invalid = i_invalid+1
    else:
        msig1[flag] = ynew
        an3[flag] = an1[i]
        flag = flag+1
msig1 = msig1[0:msig1.shape[0]-i_invalid,:]  
an3 = an3[0:an3.shape[0]-i_invalid,:]

i_invalid = 0
flag = 0
msig2 = np.zeros((sig2.shape[0],sig2.shape[1]))
an4 = np.zeros((an2.shape))
for i in range(sig2.shape[0]):
    ynew = smooth_peak(sig2[i])
    if(np.all(ynew == 0)):
        i_invalid = i_invalid+1
    
    else:
        msig2[flag] = ynew
        an4[flag] = an2[i]
        flag = flag+1
msig2 = msig2[0:msig2.shape[0]-i_invalid,:] 
an4 = an4[0:an4.shape[0]-i_invalid,:]

# %%
plt.axes(yscale = "log") 
for n in range(msig1.shape[0]): #msig1.shape[0]
    plt.plot(msig1[n])
plt.show()

# %%
# x_train = msig1
y_train = an3
# x_test = msig2
y_test = an4

x_train = np.zeros((msig1.shape[0],3))
x_test = np.zeros((msig2.shape[0],3))

x_train[:,0] = np.argmax(msig1,1)/200*3
x_train[:,1] = np.diagonal(msig1[:,np.argmax(msig1,1)])/1000 # t of peak, height of peak, thickness(d)
x_train[:,2] = an3[:,0]/20e-3 
# x_train = np.log10(x_train)+7

x_test[:,0] = np.argmax(msig2,1)/200*3
x_test[:,1] = np.diagonal(msig2[:,np.argmax(msig2,1)])/1000 
x_test[:,2] = an4[:,0]/20e-3
# x_test = np.log10(x_test)+7

x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))
# d_train = np.reshape(y_train[:,0],(y_train[:,0].shape[0],1,1)) # add thickness of sample into input data
# d_test = np.reshape(y_test[:,0],(y_test[:,0].shape[0],1,1))

# x_train = np.concatenate((d_train,x_train),axis = 1) 
# x_test = np.concatenate((d_test,x_test),axis = 1)
y_train[:,1] = y_train[:,1]/1e2
y_test[:,1] = y_test[:,1]/1e2
y_train[:,2] = y_train[:,2]/200e2
y_test[:,2] = y_test[:,2]/200e2
y_train = y_train[:,1:3]
y_test = y_test[:,1:3]
# y_train = labeling(y_train,num_labels)[:,1,:] # select to predict what : 0:thickness 1:mua 2: mus
# y_test = labeling(y_test,num_labels)[:,1,:]
print('x_train.shape = '+str(x_train.shape)) 
print('y_train.shape = '+str(y_train.shape))
# Out:
# x_train.shape = (1258, 3, 1)
# y_train.shape = (1258, 2)

# %%
for n in range(x_train.shape[0]):  #x_train.shape[0]
    plt.plot(x_train[n,:])
plt.show()

# %%
# num_classes = y_train.shape[1]
########################################
# input_shape = (1,5,1)
# x = np.arange(np.prod(input_shape)).reshape(input_shape)      # test cropping#
# print(x)
# y = keras.layers.Cropping1D(cropping=(0,4))(x)
# z = keras.layers.Cropping1D(cropping=(1,0))(x)
# print(y)
# print(z)

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)
    
#     d_1 = keras.layers.Cropping1D(cropping=(0,2))(input_layer)
#     sig = keras.layers.Cropping1D(cropping=(1,0))(input_layer)
    
#     conv1 = keras.layers.Conv1D(filters=16, kernel_size=3, padding="same")(sig)
#     conv1 = keras.layers.BatchNormalization()(conv1)
#     conv1 = keras.layers.ReLU()(conv1)

#     conv2 = keras.layers.Conv1D(filters=16, kernel_size=3, padding="same")(conv1)
#     conv2 = keras.layers.BatchNormalization()(conv2)
#     conv2 = keras.layers.ReLU()(conv2)

#     conv3 = keras.layers.Conv1D(filters=16, kernel_size=3, padding="same")(conv2)
#     conv3 = keras.layers.BatchNormalization()(conv3)
#     conv3 = keras.layers.ReLU()(conv3)

    # gap = keras.layers.GlobalAveragePooling1D()(conv3)
    gap = keras.layers.Reshape((input_shape[0],))(input_layer)
    
    gap = keras.layers.Dense(8, activation='relu')(gap)
    gap = keras.layers.BatchNormalization()(gap)
    # gap = keras.layers.Dropout(0.5)(gap)
    gap = keras.layers.Dense(8, activation='relu')(gap)
    gap = keras.layers.BatchNormalization()(gap)
    # gap = keras.layers.Dropout(0.5)(gap)
    
    # d_1 = keras.layers.Dense(16, activation='relu')(d_1)
    # d_1 = keras.layers.Dense(16, activation='relu')(d_1)
    # gap = keras.layers.Reshape((16,))(gap)
    
    
    
    # merged = keras.layers.Concatenate()([d_1, gap])
    # merged = keras.layers.Dense(8, activation='relu')(merged)
    
    output_layer = keras.layers.Dense(2, activation="linear")(gap)  
    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])
keras.utils.plot_model(model, show_shapes=True)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %%
epochs = 500
batch_size = 32
#####################################################
index = [i for i in range(x_train.shape[0])]  
np.random.shuffle(index) 
x_train = x_train[index]
y_train = y_train[index]
####################################################
callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model3.5.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    # loss="mean_squared_error",
    loss="mean_absolute_error",
    metrics=["MeanAbsoluteError"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.4,
    verbose=1,
)
# Out:
# Epoch 1/500
# 24/24 [==============================] - 1s 15ms/step - loss: 0.6994 - mean_absolute_error: 0.6994 - val_loss: 0.4538 - val_mean_absolute_error: 0.4538
# Epoch 2/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.5145 - mean_absolute_error: 0.5145 - val_loss: 0.4138 - val_mean_absolute_error: 0.4138
# Epoch 3/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.4273 - mean_absolute_error: 0.4273 - val_loss: 0.3811 - val_mean_absolute_error: 0.3811
# Epoch 4/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.3597 - mean_absolute_error: 0.3597 - val_loss: 0.3547 - val_mean_absolute_error: 0.3547
# Epoch 5/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.3018 - mean_absolute_error: 0.3018 - val_loss: 0.3333 - val_mean_absolute_error: 0.3333
# Epoch 6/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.2624 - mean_absolute_error: 0.2624 - val_loss: 0.3143 - val_mean_absolute_error: 0.3143
# Epoch 7/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.2473 - mean_absolute_error: 0.2473 - val_loss: 0.3022 - val_mean_absolute_error: 0.3022
# Epoch 8/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.2261 - mean_absolute_error: 0.2261 - val_loss: 0.2966 - val_mean_absolute_error: 0.2966
# Epoch 9/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.2213 - mean_absolute_error: 0.2213 - val_loss: 0.2976 - val_mean_absolute_error: 0.2976
# Epoch 10/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.2058 - mean_absolute_error: 0.2058 - val_loss: 0.2911 - val_mean_absolute_error: 0.2911
# Epoch 11/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.2148 - mean_absolute_error: 0.2148 - val_loss: 0.2903 - val_mean_absolute_error: 0.2903
# Epoch 12/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.2053 - mean_absolute_error: 0.2053 - val_loss: 0.2822 - val_mean_absolute_error: 0.2822
# Epoch 13/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.2155 - mean_absolute_error: 0.2155 - val_loss: 0.2847 - val_mean_absolute_error: 0.2847
# Epoch 14/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.2058 - mean_absolute_error: 0.2058 - val_loss: 0.2773 - val_mean_absolute_error: 0.2773
# Epoch 15/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1937 - mean_absolute_error: 0.1937 - val_loss: 0.2704 - val_mean_absolute_error: 0.2704
# Epoch 16/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.2077 - mean_absolute_error: 0.2077 - val_loss: 0.2648 - val_mean_absolute_error: 0.2648
# Epoch 17/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1967 - mean_absolute_error: 0.1967 - val_loss: 0.2521 - val_mean_absolute_error: 0.2521
# Epoch 18/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1973 - mean_absolute_error: 0.1973 - val_loss: 0.2398 - val_mean_absolute_error: 0.2398
# Epoch 19/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1938 - mean_absolute_error: 0.1938 - val_loss: 0.2337 - val_mean_absolute_error: 0.2337
# Epoch 20/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1924 - mean_absolute_error: 0.1924 - val_loss: 0.2171 - val_mean_absolute_error: 0.2171
# Epoch 21/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1913 - mean_absolute_error: 0.1913 - val_loss: 0.2147 - val_mean_absolute_error: 0.2147
# Epoch 22/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1899 - mean_absolute_error: 0.1899 - val_loss: 0.2065 - val_mean_absolute_error: 0.2065
# Epoch 23/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1974 - mean_absolute_error: 0.1974 - val_loss: 0.1985 - val_mean_absolute_error: 0.1985
# Epoch 24/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1906 - mean_absolute_error: 0.1906 - val_loss: 0.1917 - val_mean_absolute_error: 0.1917
# Epoch 25/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1873 - mean_absolute_error: 0.1873 - val_loss: 0.1879 - val_mean_absolute_error: 0.1879
# Epoch 26/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1833 - mean_absolute_error: 0.1833 - val_loss: 0.1861 - val_mean_absolute_error: 0.1861
# Epoch 27/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1867 - mean_absolute_error: 0.1867 - val_loss: 0.1833 - val_mean_absolute_error: 0.1833
# Epoch 28/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1936 - mean_absolute_error: 0.1936 - val_loss: 0.1912 - val_mean_absolute_error: 0.1912
# Epoch 29/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1858 - mean_absolute_error: 0.1858 - val_loss: 0.1855 - val_mean_absolute_error: 0.1855
# Epoch 30/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1902 - mean_absolute_error: 0.1902 - val_loss: 0.1920 - val_mean_absolute_error: 0.1920
# Epoch 31/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1878 - mean_absolute_error: 0.1878 - val_loss: 0.1799 - val_mean_absolute_error: 0.1799
# Epoch 32/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1816 - mean_absolute_error: 0.1816 - val_loss: 0.1879 - val_mean_absolute_error: 0.1879
# Epoch 33/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1812 - mean_absolute_error: 0.1812 - val_loss: 0.1907 - val_mean_absolute_error: 0.1907
# Epoch 34/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1832 - mean_absolute_error: 0.1832 - val_loss: 0.1807 - val_mean_absolute_error: 0.1807
# Epoch 35/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1832 - mean_absolute_error: 0.1832 - val_loss: 0.1897 - val_mean_absolute_error: 0.1897
# Epoch 36/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1852 - mean_absolute_error: 0.1852 - val_loss: 0.1870 - val_mean_absolute_error: 0.1870
# Epoch 37/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1877 - mean_absolute_error: 0.1877 - val_loss: 0.1750 - val_mean_absolute_error: 0.1750
# Epoch 38/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1823 - mean_absolute_error: 0.1823 - val_loss: 0.1839 - val_mean_absolute_error: 0.1839
# Epoch 39/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1823 - mean_absolute_error: 0.1823 - val_loss: 0.2034 - val_mean_absolute_error: 0.2034
# Epoch 40/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1782 - mean_absolute_error: 0.1782 - val_loss: 0.1945 - val_mean_absolute_error: 0.1945
# Epoch 41/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1807 - mean_absolute_error: 0.1807 - val_loss: 0.2083 - val_mean_absolute_error: 0.2083
# Epoch 42/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1777 - mean_absolute_error: 0.1777 - val_loss: 0.1856 - val_mean_absolute_error: 0.1856
# Epoch 43/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1840 - mean_absolute_error: 0.1840 - val_loss: 0.1721 - val_mean_absolute_error: 0.1721
# Epoch 44/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1770 - mean_absolute_error: 0.1770 - val_loss: 0.1779 - val_mean_absolute_error: 0.1779
# Epoch 45/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1772 - mean_absolute_error: 0.1772 - val_loss: 0.1867 - val_mean_absolute_error: 0.1867
# Epoch 46/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1782 - mean_absolute_error: 0.1782 - val_loss: 0.1889 - val_mean_absolute_error: 0.1889
# Epoch 47/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1792 - mean_absolute_error: 0.1792 - val_loss: 0.1911 - val_mean_absolute_error: 0.1911
# Epoch 48/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1775 - mean_absolute_error: 0.1775 - val_loss: 0.1842 - val_mean_absolute_error: 0.1842
# Epoch 49/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1785 - mean_absolute_error: 0.1785 - val_loss: 0.1799 - val_mean_absolute_error: 0.1799
# Epoch 50/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1760 - mean_absolute_error: 0.1760 - val_loss: 0.1735 - val_mean_absolute_error: 0.1735
# Epoch 51/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1743 - mean_absolute_error: 0.1743 - val_loss: 0.1781 - val_mean_absolute_error: 0.1781
# Epoch 52/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1764 - mean_absolute_error: 0.1764 - val_loss: 0.1769 - val_mean_absolute_error: 0.1769
# Epoch 53/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1750 - mean_absolute_error: 0.1750 - val_loss: 0.1733 - val_mean_absolute_error: 0.1733
# Epoch 54/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1775 - mean_absolute_error: 0.1775 - val_loss: 0.1812 - val_mean_absolute_error: 0.1812
# Epoch 55/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1768 - mean_absolute_error: 0.1768 - val_loss: 0.1773 - val_mean_absolute_error: 0.1773
# Epoch 56/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1742 - mean_absolute_error: 0.1742 - val_loss: 0.1704 - val_mean_absolute_error: 0.1704
# Epoch 57/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1742 - mean_absolute_error: 0.1742 - val_loss: 0.1762 - val_mean_absolute_error: 0.1762
# Epoch 58/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1751 - mean_absolute_error: 0.1751 - val_loss: 0.1755 - val_mean_absolute_error: 0.1755
# Epoch 59/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1779 - mean_absolute_error: 0.1779 - val_loss: 0.1734 - val_mean_absolute_error: 0.1734
# Epoch 60/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1770 - mean_absolute_error: 0.1770 - val_loss: 0.1720 - val_mean_absolute_error: 0.1720
# Epoch 61/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1735 - mean_absolute_error: 0.1735 - val_loss: 0.1759 - val_mean_absolute_error: 0.1759
# Epoch 62/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1781 - mean_absolute_error: 0.1781 - val_loss: 0.1752 - val_mean_absolute_error: 0.1752
# Epoch 63/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1731 - mean_absolute_error: 0.1731 - val_loss: 0.1749 - val_mean_absolute_error: 0.1749
# Epoch 64/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1731 - mean_absolute_error: 0.1731 - val_loss: 0.1853 - val_mean_absolute_error: 0.1853
# Epoch 65/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1740 - mean_absolute_error: 0.1740 - val_loss: 0.1865 - val_mean_absolute_error: 0.1865
# Epoch 66/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1816 - mean_absolute_error: 0.1816 - val_loss: 0.1814 - val_mean_absolute_error: 0.1814
# Epoch 67/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1771 - mean_absolute_error: 0.1771 - val_loss: 0.1736 - val_mean_absolute_error: 0.1736
# Epoch 68/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1761 - mean_absolute_error: 0.1761 - val_loss: 0.1809 - val_mean_absolute_error: 0.1809
# Epoch 69/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1706 - mean_absolute_error: 0.1706 - val_loss: 0.1826 - val_mean_absolute_error: 0.1826
# Epoch 70/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1737 - mean_absolute_error: 0.1737 - val_loss: 0.1766 - val_mean_absolute_error: 0.1766
# Epoch 71/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1737 - mean_absolute_error: 0.1737 - val_loss: 0.1749 - val_mean_absolute_error: 0.1749
# Epoch 72/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1745 - mean_absolute_error: 0.1745 - val_loss: 0.1852 - val_mean_absolute_error: 0.1852
# Epoch 73/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1746 - mean_absolute_error: 0.1746 - val_loss: 0.1746 - val_mean_absolute_error: 0.1746
# Epoch 74/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1760 - mean_absolute_error: 0.1760 - val_loss: 0.1766 - val_mean_absolute_error: 0.1766
# Epoch 75/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1759 - mean_absolute_error: 0.1759 - val_loss: 0.1748 - val_mean_absolute_error: 0.1748
# Epoch 76/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1759 - mean_absolute_error: 0.1759 - val_loss: 0.1708 - val_mean_absolute_error: 0.1708
# Epoch 77/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1721 - mean_absolute_error: 0.1721 - val_loss: 0.1721 - val_mean_absolute_error: 0.1721
# Epoch 78/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1687 - mean_absolute_error: 0.1687 - val_loss: 0.1694 - val_mean_absolute_error: 0.1694
# Epoch 79/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1724 - mean_absolute_error: 0.1724 - val_loss: 0.1698 - val_mean_absolute_error: 0.1698
# Epoch 80/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1718 - mean_absolute_error: 0.1718 - val_loss: 0.1696 - val_mean_absolute_error: 0.1696
# Epoch 81/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1691 - mean_absolute_error: 0.1691 - val_loss: 0.1689 - val_mean_absolute_error: 0.1689
# Epoch 82/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1711 - mean_absolute_error: 0.1711 - val_loss: 0.1692 - val_mean_absolute_error: 0.1692
# Epoch 83/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1740 - mean_absolute_error: 0.1740 - val_loss: 0.1684 - val_mean_absolute_error: 0.1684
# Epoch 84/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1737 - mean_absolute_error: 0.1737 - val_loss: 0.1754 - val_mean_absolute_error: 0.1754
# Epoch 85/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1742 - mean_absolute_error: 0.1742 - val_loss: 0.1714 - val_mean_absolute_error: 0.1714
# Epoch 86/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1718 - mean_absolute_error: 0.1718 - val_loss: 0.1687 - val_mean_absolute_error: 0.1687
# Epoch 87/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1729 - mean_absolute_error: 0.1729 - val_loss: 0.1684 - val_mean_absolute_error: 0.1684
# Epoch 88/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1705 - mean_absolute_error: 0.1705 - val_loss: 0.1687 - val_mean_absolute_error: 0.1687
# Epoch 89/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1762 - mean_absolute_error: 0.1762 - val_loss: 0.1702 - val_mean_absolute_error: 0.1702
# Epoch 90/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1730 - mean_absolute_error: 0.1730 - val_loss: 0.1699 - val_mean_absolute_error: 0.1699
# Epoch 91/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1716 - mean_absolute_error: 0.1716 - val_loss: 0.1688 - val_mean_absolute_error: 0.1688
# Epoch 92/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1714 - mean_absolute_error: 0.1714 - val_loss: 0.1695 - val_mean_absolute_error: 0.1695
# Epoch 93/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1690 - mean_absolute_error: 0.1690 - val_loss: 0.1685 - val_mean_absolute_error: 0.1685
# Epoch 94/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1733 - mean_absolute_error: 0.1733 - val_loss: 0.1720 - val_mean_absolute_error: 0.1720
# Epoch 95/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1698 - mean_absolute_error: 0.1698 - val_loss: 0.1711 - val_mean_absolute_error: 0.1711
# Epoch 96/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1730 - mean_absolute_error: 0.1730 - val_loss: 0.1715 - val_mean_absolute_error: 0.1715
# Epoch 97/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1726 - mean_absolute_error: 0.1726 - val_loss: 0.1676 - val_mean_absolute_error: 0.1676
# Epoch 98/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1721 - mean_absolute_error: 0.1721 - val_loss: 0.1689 - val_mean_absolute_error: 0.1689
# Epoch 99/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1705 - mean_absolute_error: 0.1705 - val_loss: 0.1679 - val_mean_absolute_error: 0.1679
# Epoch 100/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1682 - mean_absolute_error: 0.1682 - val_loss: 0.1681 - val_mean_absolute_error: 0.1681
# Epoch 101/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1707 - mean_absolute_error: 0.1707 - val_loss: 0.1674 - val_mean_absolute_error: 0.1674
# Epoch 102/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1703 - mean_absolute_error: 0.1703 - val_loss: 0.1687 - val_mean_absolute_error: 0.1687
# Epoch 103/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1733 - mean_absolute_error: 0.1733 - val_loss: 0.1718 - val_mean_absolute_error: 0.1718
# Epoch 104/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1701 - mean_absolute_error: 0.1701 - val_loss: 0.1749 - val_mean_absolute_error: 0.1749
# Epoch 105/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1756 - mean_absolute_error: 0.1756 - val_loss: 0.1725 - val_mean_absolute_error: 0.1725
# Epoch 106/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1726 - mean_absolute_error: 0.1726 - val_loss: 0.1718 - val_mean_absolute_error: 0.1718
# Epoch 107/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1717 - mean_absolute_error: 0.1717 - val_loss: 0.1721 - val_mean_absolute_error: 0.1721
# Epoch 108/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1675 - mean_absolute_error: 0.1675 - val_loss: 0.1683 - val_mean_absolute_error: 0.1683
# Epoch 109/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1675 - mean_absolute_error: 0.1675 - val_loss: 0.1681 - val_mean_absolute_error: 0.1681
# Epoch 110/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1677 - mean_absolute_error: 0.1677 - val_loss: 0.1678 - val_mean_absolute_error: 0.1678
# Epoch 111/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1736 - mean_absolute_error: 0.1736 - val_loss: 0.1699 - val_mean_absolute_error: 0.1699
# Epoch 112/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1736 - mean_absolute_error: 0.1736 - val_loss: 0.1681 - val_mean_absolute_error: 0.1681
# Epoch 113/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1710 - mean_absolute_error: 0.1710 - val_loss: 0.1681 - val_mean_absolute_error: 0.1681
# Epoch 114/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1685 - mean_absolute_error: 0.1685 - val_loss: 0.1673 - val_mean_absolute_error: 0.1673
# Epoch 115/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1689 - mean_absolute_error: 0.1689 - val_loss: 0.1674 - val_mean_absolute_error: 0.1674
# Epoch 116/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1702 - mean_absolute_error: 0.1702 - val_loss: 0.1679 - val_mean_absolute_error: 0.1679
# Epoch 117/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1687 - mean_absolute_error: 0.1687 - val_loss: 0.1695 - val_mean_absolute_error: 0.1695
# Epoch 118/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1727 - mean_absolute_error: 0.1727 - val_loss: 0.1699 - val_mean_absolute_error: 0.1699
# Epoch 119/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1730 - mean_absolute_error: 0.1730 - val_loss: 0.1671 - val_mean_absolute_error: 0.1671
# Epoch 120/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1724 - mean_absolute_error: 0.1724 - val_loss: 0.1677 - val_mean_absolute_error: 0.1677
# Epoch 121/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1722 - mean_absolute_error: 0.1722 - val_loss: 0.1668 - val_mean_absolute_error: 0.1668
# Epoch 122/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1699 - mean_absolute_error: 0.1699 - val_loss: 0.1699 - val_mean_absolute_error: 0.1699
# Epoch 123/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1730 - mean_absolute_error: 0.1730 - val_loss: 0.1696 - val_mean_absolute_error: 0.1696
# Epoch 124/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1700 - mean_absolute_error: 0.1700 - val_loss: 0.1683 - val_mean_absolute_error: 0.1683
# Epoch 125/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1680 - mean_absolute_error: 0.1680 - val_loss: 0.1663 - val_mean_absolute_error: 0.1663
# Epoch 126/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1690 - mean_absolute_error: 0.1690 - val_loss: 0.1700 - val_mean_absolute_error: 0.1700
# Epoch 127/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1687 - mean_absolute_error: 0.1687 - val_loss: 0.1697 - val_mean_absolute_error: 0.1697
# Epoch 128/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1747 - mean_absolute_error: 0.1747 - val_loss: 0.1691 - val_mean_absolute_error: 0.1691
# Epoch 129/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1704 - mean_absolute_error: 0.1704 - val_loss: 0.1709 - val_mean_absolute_error: 0.1709
# Epoch 130/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1671 - mean_absolute_error: 0.1671 - val_loss: 0.1722 - val_mean_absolute_error: 0.1722
# Epoch 131/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1696 - mean_absolute_error: 0.1696 - val_loss: 0.1679 - val_mean_absolute_error: 0.1679
# Epoch 132/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1716 - mean_absolute_error: 0.1716 - val_loss: 0.1670 - val_mean_absolute_error: 0.1670
# Epoch 133/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1683 - mean_absolute_error: 0.1683 - val_loss: 0.1690 - val_mean_absolute_error: 0.1690
# Epoch 134/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1654 - mean_absolute_error: 0.1654 - val_loss: 0.1685 - val_mean_absolute_error: 0.1685
# Epoch 135/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1700 - mean_absolute_error: 0.1700 - val_loss: 0.1673 - val_mean_absolute_error: 0.1673
# Epoch 136/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1711 - mean_absolute_error: 0.1711 - val_loss: 0.1674 - val_mean_absolute_error: 0.1674
# Epoch 137/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1715 - mean_absolute_error: 0.1715 - val_loss: 0.1665 - val_mean_absolute_error: 0.1665
# Epoch 138/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1731 - mean_absolute_error: 0.1731 - val_loss: 0.1660 - val_mean_absolute_error: 0.1660
# Epoch 139/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1666 - mean_absolute_error: 0.1666 - val_loss: 0.1683 - val_mean_absolute_error: 0.1683
# Epoch 140/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1686 - mean_absolute_error: 0.1686 - val_loss: 0.1694 - val_mean_absolute_error: 0.1694
# Epoch 141/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1698 - mean_absolute_error: 0.1698 - val_loss: 0.1684 - val_mean_absolute_error: 0.1684
# Epoch 142/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1681 - mean_absolute_error: 0.1681 - val_loss: 0.1673 - val_mean_absolute_error: 0.1673
# Epoch 143/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1686 - mean_absolute_error: 0.1686 - val_loss: 0.1667 - val_mean_absolute_error: 0.1667
# Epoch 144/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1685 - mean_absolute_error: 0.1685 - val_loss: 0.1682 - val_mean_absolute_error: 0.1682
# Epoch 145/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1709 - mean_absolute_error: 0.1709 - val_loss: 0.1674 - val_mean_absolute_error: 0.1674
# Epoch 146/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1665 - mean_absolute_error: 0.1665 - val_loss: 0.1665 - val_mean_absolute_error: 0.1665
# Epoch 147/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1685 - mean_absolute_error: 0.1685 - val_loss: 0.1658 - val_mean_absolute_error: 0.1658
# Epoch 148/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1692 - mean_absolute_error: 0.1692 - val_loss: 0.1665 - val_mean_absolute_error: 0.1665
# Epoch 149/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1700 - mean_absolute_error: 0.1700 - val_loss: 0.1675 - val_mean_absolute_error: 0.1675
# Epoch 150/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1711 - mean_absolute_error: 0.1711 - val_loss: 0.1673 - val_mean_absolute_error: 0.1673
# Epoch 151/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1673 - mean_absolute_error: 0.1673 - val_loss: 0.1671 - val_mean_absolute_error: 0.1671
# Epoch 152/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1692 - mean_absolute_error: 0.1692 - val_loss: 0.1662 - val_mean_absolute_error: 0.1662
# Epoch 153/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1706 - mean_absolute_error: 0.1706 - val_loss: 0.1681 - val_mean_absolute_error: 0.1681
# Epoch 154/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1685 - mean_absolute_error: 0.1685 - val_loss: 0.1662 - val_mean_absolute_error: 0.1662
# Epoch 155/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1708 - mean_absolute_error: 0.1708 - val_loss: 0.1661 - val_mean_absolute_error: 0.1661
# Epoch 156/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1708 - mean_absolute_error: 0.1708 - val_loss: 0.1659 - val_mean_absolute_error: 0.1659
# Epoch 157/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1668 - mean_absolute_error: 0.1668 - val_loss: 0.1674 - val_mean_absolute_error: 0.1674
# Epoch 158/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1663 - mean_absolute_error: 0.1663 - val_loss: 0.1661 - val_mean_absolute_error: 0.1661
# Epoch 159/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1688 - mean_absolute_error: 0.1688 - val_loss: 0.1683 - val_mean_absolute_error: 0.1683
# Epoch 160/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1736 - mean_absolute_error: 0.1736 - val_loss: 0.1679 - val_mean_absolute_error: 0.1679
# Epoch 161/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1671 - mean_absolute_error: 0.1671 - val_loss: 0.1686 - val_mean_absolute_error: 0.1686
# Epoch 162/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1663 - mean_absolute_error: 0.1663 - val_loss: 0.1692 - val_mean_absolute_error: 0.1692
# Epoch 163/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1685 - mean_absolute_error: 0.1685 - val_loss: 0.1677 - val_mean_absolute_error: 0.1677
# Epoch 164/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1659 - mean_absolute_error: 0.1659 - val_loss: 0.1675 - val_mean_absolute_error: 0.1675
# Epoch 165/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1707 - mean_absolute_error: 0.1707 - val_loss: 0.1678 - val_mean_absolute_error: 0.1678
# Epoch 166/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1658 - mean_absolute_error: 0.1658 - val_loss: 0.1667 - val_mean_absolute_error: 0.1667
# Epoch 167/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1693 - mean_absolute_error: 0.1693 - val_loss: 0.1687 - val_mean_absolute_error: 0.1687
# Epoch 168/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1678 - mean_absolute_error: 0.1678 - val_loss: 0.1663 - val_mean_absolute_error: 0.1663
# Epoch 169/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1669 - mean_absolute_error: 0.1669 - val_loss: 0.1661 - val_mean_absolute_error: 0.1661
# Epoch 170/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1683 - mean_absolute_error: 0.1683 - val_loss: 0.1652 - val_mean_absolute_error: 0.1652
# Epoch 171/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1660 - mean_absolute_error: 0.1660 - val_loss: 0.1656 - val_mean_absolute_error: 0.1656
# Epoch 172/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1700 - mean_absolute_error: 0.1700 - val_loss: 0.1650 - val_mean_absolute_error: 0.1650
# Epoch 173/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1661 - mean_absolute_error: 0.1661 - val_loss: 0.1655 - val_mean_absolute_error: 0.1655
# Epoch 174/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1670 - mean_absolute_error: 0.1670 - val_loss: 0.1667 - val_mean_absolute_error: 0.1667
# Epoch 175/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1660 - mean_absolute_error: 0.1660 - val_loss: 0.1661 - val_mean_absolute_error: 0.1661
# Epoch 176/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1674 - mean_absolute_error: 0.1674 - val_loss: 0.1656 - val_mean_absolute_error: 0.1656
# Epoch 177/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1669 - mean_absolute_error: 0.1669 - val_loss: 0.1650 - val_mean_absolute_error: 0.1650
# Epoch 178/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1701 - mean_absolute_error: 0.1701 - val_loss: 0.1670 - val_mean_absolute_error: 0.1670
# Epoch 179/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1677 - mean_absolute_error: 0.1677 - val_loss: 0.1657 - val_mean_absolute_error: 0.1657
# Epoch 180/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1661 - mean_absolute_error: 0.1661 - val_loss: 0.1644 - val_mean_absolute_error: 0.1644
# Epoch 181/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1680 - mean_absolute_error: 0.1680 - val_loss: 0.1650 - val_mean_absolute_error: 0.1650
# Epoch 182/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1694 - mean_absolute_error: 0.1694 - val_loss: 0.1663 - val_mean_absolute_error: 0.1663
# Epoch 183/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1659 - mean_absolute_error: 0.1659 - val_loss: 0.1668 - val_mean_absolute_error: 0.1668
# Epoch 184/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1643 - mean_absolute_error: 0.1643 - val_loss: 0.1656 - val_mean_absolute_error: 0.1656
# Epoch 185/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1682 - mean_absolute_error: 0.1682 - val_loss: 0.1660 - val_mean_absolute_error: 0.1660
# Epoch 186/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1682 - mean_absolute_error: 0.1682 - val_loss: 0.1670 - val_mean_absolute_error: 0.1670
# Epoch 187/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1659 - mean_absolute_error: 0.1659 - val_loss: 0.1663 - val_mean_absolute_error: 0.1663
# Epoch 188/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1660 - mean_absolute_error: 0.1660 - val_loss: 0.1664 - val_mean_absolute_error: 0.1664
# Epoch 189/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1649 - mean_absolute_error: 0.1649 - val_loss: 0.1649 - val_mean_absolute_error: 0.1649
# Epoch 190/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1679 - mean_absolute_error: 0.1679 - val_loss: 0.1644 - val_mean_absolute_error: 0.1644
# Epoch 191/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1632 - mean_absolute_error: 0.1632 - val_loss: 0.1643 - val_mean_absolute_error: 0.1643
# Epoch 192/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1708 - mean_absolute_error: 0.1708 - val_loss: 0.1651 - val_mean_absolute_error: 0.1651
# Epoch 193/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1672 - mean_absolute_error: 0.1672 - val_loss: 0.1651 - val_mean_absolute_error: 0.1651
# Epoch 194/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1663 - mean_absolute_error: 0.1663 - val_loss: 0.1657 - val_mean_absolute_error: 0.1657
# Epoch 195/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1628 - mean_absolute_error: 0.1628 - val_loss: 0.1647 - val_mean_absolute_error: 0.1647
# Epoch 196/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1652 - mean_absolute_error: 0.1652 - val_loss: 0.1654 - val_mean_absolute_error: 0.1654
# Epoch 197/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1679 - mean_absolute_error: 0.1679 - val_loss: 0.1657 - val_mean_absolute_error: 0.1657
# Epoch 198/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1687 - mean_absolute_error: 0.1687 - val_loss: 0.1657 - val_mean_absolute_error: 0.1657
# Epoch 199/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1651 - mean_absolute_error: 0.1651 - val_loss: 0.1653 - val_mean_absolute_error: 0.1653
# Epoch 200/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1668 - mean_absolute_error: 0.1668 - val_loss: 0.1663 - val_mean_absolute_error: 0.1663
# Epoch 201/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1687 - mean_absolute_error: 0.1687 - val_loss: 0.1656 - val_mean_absolute_error: 0.1656
# Epoch 202/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1677 - mean_absolute_error: 0.1677 - val_loss: 0.1652 - val_mean_absolute_error: 0.1652
# Epoch 203/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1623 - mean_absolute_error: 0.1623 - val_loss: 0.1649 - val_mean_absolute_error: 0.1649
# Epoch 204/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1673 - mean_absolute_error: 0.1673 - val_loss: 0.1651 - val_mean_absolute_error: 0.1651
# Epoch 205/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1698 - mean_absolute_error: 0.1698 - val_loss: 0.1653 - val_mean_absolute_error: 0.1653
# Epoch 206/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1658 - mean_absolute_error: 0.1658 - val_loss: 0.1648 - val_mean_absolute_error: 0.1648
# Epoch 207/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1679 - mean_absolute_error: 0.1679 - val_loss: 0.1648 - val_mean_absolute_error: 0.1648
# Epoch 208/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1647 - mean_absolute_error: 0.1647 - val_loss: 0.1654 - val_mean_absolute_error: 0.1654
# Epoch 209/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1687 - mean_absolute_error: 0.1687 - val_loss: 0.1650 - val_mean_absolute_error: 0.1650
# Epoch 210/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1668 - mean_absolute_error: 0.1668 - val_loss: 0.1651 - val_mean_absolute_error: 0.1651
# Epoch 211/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1662 - mean_absolute_error: 0.1662 - val_loss: 0.1656 - val_mean_absolute_error: 0.1656
# Epoch 212/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1660 - mean_absolute_error: 0.1660 - val_loss: 0.1654 - val_mean_absolute_error: 0.1654
# Epoch 213/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1656 - mean_absolute_error: 0.1656 - val_loss: 0.1648 - val_mean_absolute_error: 0.1648
# Epoch 214/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1682 - mean_absolute_error: 0.1682 - val_loss: 0.1649 - val_mean_absolute_error: 0.1649
# Epoch 215/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1692 - mean_absolute_error: 0.1692 - val_loss: 0.1648 - val_mean_absolute_error: 0.1648
# Epoch 216/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1669 - mean_absolute_error: 0.1669 - val_loss: 0.1654 - val_mean_absolute_error: 0.1654
# Epoch 217/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1683 - mean_absolute_error: 0.1683 - val_loss: 0.1654 - val_mean_absolute_error: 0.1654
# Epoch 218/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1657 - mean_absolute_error: 0.1657 - val_loss: 0.1655 - val_mean_absolute_error: 0.1655
# Epoch 219/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1649 - mean_absolute_error: 0.1649 - val_loss: 0.1651 - val_mean_absolute_error: 0.1651
# Epoch 220/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1680 - mean_absolute_error: 0.1680 - val_loss: 0.1654 - val_mean_absolute_error: 0.1654
# Epoch 221/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1683 - mean_absolute_error: 0.1683 - val_loss: 0.1658 - val_mean_absolute_error: 0.1658
# Epoch 222/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1630 - mean_absolute_error: 0.1630 - val_loss: 0.1654 - val_mean_absolute_error: 0.1654
# Epoch 223/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1674 - mean_absolute_error: 0.1674 - val_loss: 0.1659 - val_mean_absolute_error: 0.1659
# Epoch 224/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1634 - mean_absolute_error: 0.1634 - val_loss: 0.1657 - val_mean_absolute_error: 0.1657
# Epoch 225/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1695 - mean_absolute_error: 0.1695 - val_loss: 0.1652 - val_mean_absolute_error: 0.1652
# Epoch 226/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1657 - mean_absolute_error: 0.1657 - val_loss: 0.1655 - val_mean_absolute_error: 0.1655
# Epoch 227/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1664 - mean_absolute_error: 0.1664 - val_loss: 0.1655 - val_mean_absolute_error: 0.1655
# Epoch 228/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1634 - mean_absolute_error: 0.1634 - val_loss: 0.1654 - val_mean_absolute_error: 0.1654
# Epoch 229/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1669 - mean_absolute_error: 0.1669 - val_loss: 0.1651 - val_mean_absolute_error: 0.1651
# Epoch 230/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1683 - mean_absolute_error: 0.1683 - val_loss: 0.1648 - val_mean_absolute_error: 0.1648
# Epoch 231/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1661 - mean_absolute_error: 0.1661 - val_loss: 0.1645 - val_mean_absolute_error: 0.1645
# Epoch 232/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1662 - mean_absolute_error: 0.1662 - val_loss: 0.1647 - val_mean_absolute_error: 0.1647
# Epoch 233/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1661 - mean_absolute_error: 0.1661 - val_loss: 0.1644 - val_mean_absolute_error: 0.1644
# Epoch 234/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1683 - mean_absolute_error: 0.1683 - val_loss: 0.1646 - val_mean_absolute_error: 0.1646
# Epoch 235/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1653 - mean_absolute_error: 0.1653 - val_loss: 0.1649 - val_mean_absolute_error: 0.1649
# Epoch 236/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1652 - mean_absolute_error: 0.1652 - val_loss: 0.1652 - val_mean_absolute_error: 0.1652
# Epoch 237/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1652 - mean_absolute_error: 0.1652 - val_loss: 0.1654 - val_mean_absolute_error: 0.1654
# Epoch 238/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1680 - mean_absolute_error: 0.1680 - val_loss: 0.1656 - val_mean_absolute_error: 0.1656
# Epoch 239/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1679 - mean_absolute_error: 0.1679 - val_loss: 0.1645 - val_mean_absolute_error: 0.1645
# Epoch 240/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1644 - mean_absolute_error: 0.1644 - val_loss: 0.1641 - val_mean_absolute_error: 0.1641
# Epoch 241/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1673 - mean_absolute_error: 0.1673 - val_loss: 0.1644 - val_mean_absolute_error: 0.1644
# Epoch 242/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1650 - mean_absolute_error: 0.1650 - val_loss: 0.1645 - val_mean_absolute_error: 0.1645
# Epoch 243/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1690 - mean_absolute_error: 0.1690 - val_loss: 0.1645 - val_mean_absolute_error: 0.1645
# Epoch 244/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1645 - mean_absolute_error: 0.1645 - val_loss: 0.1649 - val_mean_absolute_error: 0.1649
# Epoch 245/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1654 - mean_absolute_error: 0.1654 - val_loss: 0.1654 - val_mean_absolute_error: 0.1654
# Epoch 246/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1664 - mean_absolute_error: 0.1664 - val_loss: 0.1650 - val_mean_absolute_error: 0.1650
# Epoch 247/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1618 - mean_absolute_error: 0.1618 - val_loss: 0.1643 - val_mean_absolute_error: 0.1643
# Epoch 248/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1641 - mean_absolute_error: 0.1641 - val_loss: 0.1648 - val_mean_absolute_error: 0.1648
# Epoch 249/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1659 - mean_absolute_error: 0.1659 - val_loss: 0.1653 - val_mean_absolute_error: 0.1653
# Epoch 250/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1662 - mean_absolute_error: 0.1662 - val_loss: 0.1649 - val_mean_absolute_error: 0.1649
# Epoch 251/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1677 - mean_absolute_error: 0.1677 - val_loss: 0.1651 - val_mean_absolute_error: 0.1651
# Epoch 252/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1673 - mean_absolute_error: 0.1673 - val_loss: 0.1652 - val_mean_absolute_error: 0.1652
# Epoch 253/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1666 - mean_absolute_error: 0.1666 - val_loss: 0.1649 - val_mean_absolute_error: 0.1649
# Epoch 254/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1643 - mean_absolute_error: 0.1643 - val_loss: 0.1648 - val_mean_absolute_error: 0.1648
# Epoch 255/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1638 - mean_absolute_error: 0.1638 - val_loss: 0.1646 - val_mean_absolute_error: 0.1646
# Epoch 256/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1643 - mean_absolute_error: 0.1643 - val_loss: 0.1646 - val_mean_absolute_error: 0.1646
# Epoch 257/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1671 - mean_absolute_error: 0.1671 - val_loss: 0.1646 - val_mean_absolute_error: 0.1646
# Epoch 258/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1666 - mean_absolute_error: 0.1666 - val_loss: 0.1646 - val_mean_absolute_error: 0.1646
# Epoch 259/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1640 - mean_absolute_error: 0.1640 - val_loss: 0.1643 - val_mean_absolute_error: 0.1643
# Epoch 260/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1686 - mean_absolute_error: 0.1686 - val_loss: 0.1643 - val_mean_absolute_error: 0.1643
# Epoch 261/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1632 - mean_absolute_error: 0.1632 - val_loss: 0.1645 - val_mean_absolute_error: 0.1645
# Epoch 262/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1655 - mean_absolute_error: 0.1655 - val_loss: 0.1649 - val_mean_absolute_error: 0.1649
# Epoch 263/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1647 - mean_absolute_error: 0.1647 - val_loss: 0.1649 - val_mean_absolute_error: 0.1649
# Epoch 264/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1675 - mean_absolute_error: 0.1675 - val_loss: 0.1650 - val_mean_absolute_error: 0.1650
# Epoch 265/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1671 - mean_absolute_error: 0.1671 - val_loss: 0.1651 - val_mean_absolute_error: 0.1651
# Epoch 266/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1652 - mean_absolute_error: 0.1652 - val_loss: 0.1647 - val_mean_absolute_error: 0.1647
# Epoch 267/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1660 - mean_absolute_error: 0.1660 - val_loss: 0.1650 - val_mean_absolute_error: 0.1650
# Epoch 268/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1662 - mean_absolute_error: 0.1662 - val_loss: 0.1648 - val_mean_absolute_error: 0.1648
# Epoch 269/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1648 - mean_absolute_error: 0.1648 - val_loss: 0.1648 - val_mean_absolute_error: 0.1648
# Epoch 270/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1675 - mean_absolute_error: 0.1675 - val_loss: 0.1646 - val_mean_absolute_error: 0.1646
# Epoch 271/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1647 - mean_absolute_error: 0.1647 - val_loss: 0.1651 - val_mean_absolute_error: 0.1651
# Epoch 272/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1656 - mean_absolute_error: 0.1656 - val_loss: 0.1651 - val_mean_absolute_error: 0.1651
# Epoch 273/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1695 - mean_absolute_error: 0.1695 - val_loss: 0.1652 - val_mean_absolute_error: 0.1652
# Epoch 274/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1651 - mean_absolute_error: 0.1651 - val_loss: 0.1645 - val_mean_absolute_error: 0.1645
# Epoch 275/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1646 - mean_absolute_error: 0.1646 - val_loss: 0.1647 - val_mean_absolute_error: 0.1647
# Epoch 276/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1635 - mean_absolute_error: 0.1635 - val_loss: 0.1649 - val_mean_absolute_error: 0.1649
# Epoch 277/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1684 - mean_absolute_error: 0.1684 - val_loss: 0.1645 - val_mean_absolute_error: 0.1645
# Epoch 278/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1710 - mean_absolute_error: 0.1710 - val_loss: 0.1644 - val_mean_absolute_error: 0.1644
# Epoch 279/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1683 - mean_absolute_error: 0.1683 - val_loss: 0.1652 - val_mean_absolute_error: 0.1652
# Epoch 280/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1634 - mean_absolute_error: 0.1634 - val_loss: 0.1645 - val_mean_absolute_error: 0.1645
# Epoch 281/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1631 - mean_absolute_error: 0.1631 - val_loss: 0.1644 - val_mean_absolute_error: 0.1644
# Epoch 282/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1655 - mean_absolute_error: 0.1655 - val_loss: 0.1643 - val_mean_absolute_error: 0.1643
# Epoch 283/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1672 - mean_absolute_error: 0.1672 - val_loss: 0.1641 - val_mean_absolute_error: 0.1641
# Epoch 284/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1684 - mean_absolute_error: 0.1684 - val_loss: 0.1636 - val_mean_absolute_error: 0.1636
# Epoch 285/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1636 - mean_absolute_error: 0.1636 - val_loss: 0.1640 - val_mean_absolute_error: 0.1640
# Epoch 286/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1664 - mean_absolute_error: 0.1664 - val_loss: 0.1643 - val_mean_absolute_error: 0.1643
# Epoch 287/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1645 - mean_absolute_error: 0.1645 - val_loss: 0.1641 - val_mean_absolute_error: 0.1641
# Epoch 288/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1677 - mean_absolute_error: 0.1677 - val_loss: 0.1642 - val_mean_absolute_error: 0.1642
# Epoch 289/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1647 - mean_absolute_error: 0.1647 - val_loss: 0.1647 - val_mean_absolute_error: 0.1647
# Epoch 290/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1681 - mean_absolute_error: 0.1681 - val_loss: 0.1645 - val_mean_absolute_error: 0.1645
# Epoch 291/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1651 - mean_absolute_error: 0.1651 - val_loss: 0.1652 - val_mean_absolute_error: 0.1652
# Epoch 292/500
# ...
# Epoch 316/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1629 - mean_absolute_error: 0.1629 - val_loss: 0.1640 - val_mean_absolute_error: 0.1640
# Epoch 317/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1624 - mean_absolute_error: 0.1624 - val_loss: 0.1638 - val_mean_absolute_error: 0.1638
# Epoch 318/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1673 - mean_absolute_error: 0.1673 - val_loss: 0.1633 - val_mean_absolute_error: 0.1633
# Epoch 319/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1683 - mean_absolute_error: 0.1683 - val_loss: 0.1638 - val_mean_absolute_error: 0.1638
# Epoch 320/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1667 - mean_absolute_error: 0.1667 - val_loss: 0.1646 - val_mean_absolute_error: 0.1646
# Epoch 321/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1660 - mean_absolute_error: 0.1660 - val_loss: 0.1645 - val_mean_absolute_error: 0.1645
# Epoch 322/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1648 - mean_absolute_error: 0.1648 - val_loss: 0.1641 - val_mean_absolute_error: 0.1641
# Epoch 323/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1660 - mean_absolute_error: 0.1660 - val_loss: 0.1640 - val_mean_absolute_error: 0.1640
# Epoch 324/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1645 - mean_absolute_error: 0.1645 - val_loss: 0.1641 - val_mean_absolute_error: 0.1641
# Epoch 325/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1635 - mean_absolute_error: 0.1635 - val_loss: 0.1643 - val_mean_absolute_error: 0.1643
# Epoch 326/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1655 - mean_absolute_error: 0.1655 - val_loss: 0.1644 - val_mean_absolute_error: 0.1644
# Epoch 327/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1673 - mean_absolute_error: 0.1673 - val_loss: 0.1643 - val_mean_absolute_error: 0.1643
# Epoch 328/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1612 - mean_absolute_error: 0.1612 - val_loss: 0.1642 - val_mean_absolute_error: 0.1642
# Epoch 329/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1649 - mean_absolute_error: 0.1649 - val_loss: 0.1638 - val_mean_absolute_error: 0.1638
# Epoch 330/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1659 - mean_absolute_error: 0.1659 - val_loss: 0.1639 - val_mean_absolute_error: 0.1639
# Epoch 331/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1660 - mean_absolute_error: 0.1660 - val_loss: 0.1641 - val_mean_absolute_error: 0.1641
# Epoch 332/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1646 - mean_absolute_error: 0.1646 - val_loss: 0.1642 - val_mean_absolute_error: 0.1642
# Epoch 333/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1643 - mean_absolute_error: 0.1643 - val_loss: 0.1643 - val_mean_absolute_error: 0.1643
# Epoch 334/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1681 - mean_absolute_error: 0.1681 - val_loss: 0.1641 - val_mean_absolute_error: 0.1641
# Epoch 335/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1648 - mean_absolute_error: 0.1648 - val_loss: 0.1650 - val_mean_absolute_error: 0.1650
# Epoch 336/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1652 - mean_absolute_error: 0.1652 - val_loss: 0.1643 - val_mean_absolute_error: 0.1643
# Epoch 337/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1658 - mean_absolute_error: 0.1658 - val_loss: 0.1643 - val_mean_absolute_error: 0.1643
# Epoch 338/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1643 - mean_absolute_error: 0.1643 - val_loss: 0.1638 - val_mean_absolute_error: 0.1638
# Epoch 339/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1629 - mean_absolute_error: 0.1629 - val_loss: 0.1642 - val_mean_absolute_error: 0.1642
# Epoch 340/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1681 - mean_absolute_error: 0.1681 - val_loss: 0.1643 - val_mean_absolute_error: 0.1643
# Epoch 341/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1617 - mean_absolute_error: 0.1617 - val_loss: 0.1650 - val_mean_absolute_error: 0.1650
# Epoch 342/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1650 - mean_absolute_error: 0.1650 - val_loss: 0.1640 - val_mean_absolute_error: 0.1640
# Epoch 343/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1648 - mean_absolute_error: 0.1648 - val_loss: 0.1637 - val_mean_absolute_error: 0.1637
# Epoch 344/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1639 - mean_absolute_error: 0.1639 - val_loss: 0.1635 - val_mean_absolute_error: 0.1635
# Epoch 345/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1640 - mean_absolute_error: 0.1640 - val_loss: 0.1636 - val_mean_absolute_error: 0.1636
# Epoch 346/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1645 - mean_absolute_error: 0.1645 - val_loss: 0.1636 - val_mean_absolute_error: 0.1636
# Epoch 347/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1686 - mean_absolute_error: 0.1686 - val_loss: 0.1635 - val_mean_absolute_error: 0.1635
# Epoch 348/500
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1628 - mean_absolute_error: 0.1628 - val_loss: 0.1641 - val_mean_absolute_error: 0.1641
# Epoch 349/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1637 - mean_absolute_error: 0.1637 - val_loss: 0.1643 - val_mean_absolute_error: 0.1643
# Epoch 350/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1643 - mean_absolute_error: 0.1643 - val_loss: 0.1642 - val_mean_absolute_error: 0.1642
# Epoch 351/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1625 - mean_absolute_error: 0.1625 - val_loss: 0.1641 - val_mean_absolute_error: 0.1641
# Epoch 352/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1653 - mean_absolute_error: 0.1653 - val_loss: 0.1642 - val_mean_absolute_error: 0.1642
# Epoch 353/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1649 - mean_absolute_error: 0.1649 - val_loss: 0.1645 - val_mean_absolute_error: 0.1645
# Epoch 354/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1635 - mean_absolute_error: 0.1635 - val_loss: 0.1644 - val_mean_absolute_error: 0.1644
# Epoch 355/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1659 - mean_absolute_error: 0.1659 - val_loss: 0.1637 - val_mean_absolute_error: 0.1637
# Epoch 356/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1618 - mean_absolute_error: 0.1618 - val_loss: 0.1642 - val_mean_absolute_error: 0.1642
# Epoch 357/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1632 - mean_absolute_error: 0.1632 - val_loss: 0.1648 - val_mean_absolute_error: 0.1648
# Epoch 358/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1656 - mean_absolute_error: 0.1656 - val_loss: 0.1642 - val_mean_absolute_error: 0.1642
# Epoch 359/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1639 - mean_absolute_error: 0.1639 - val_loss: 0.1634 - val_mean_absolute_error: 0.1634
# Epoch 360/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1629 - mean_absolute_error: 0.1629 - val_loss: 0.1633 - val_mean_absolute_error: 0.1633
# Epoch 361/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1648 - mean_absolute_error: 0.1648 - val_loss: 0.1631 - val_mean_absolute_error: 0.1631
# Epoch 362/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1687 - mean_absolute_error: 0.1687 - val_loss: 0.1634 - val_mean_absolute_error: 0.1634
# Epoch 363/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1635 - mean_absolute_error: 0.1635 - val_loss: 0.1633 - val_mean_absolute_error: 0.1633
# Epoch 364/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1684 - mean_absolute_error: 0.1684 - val_loss: 0.1638 - val_mean_absolute_error: 0.1638
# Epoch 365/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1649 - mean_absolute_error: 0.1649 - val_loss: 0.1639 - val_mean_absolute_error: 0.1639
# Epoch 366/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1643 - mean_absolute_error: 0.1643 - val_loss: 0.1640 - val_mean_absolute_error: 0.1640
# Epoch 367/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1626 - mean_absolute_error: 0.1626 - val_loss: 0.1643 - val_mean_absolute_error: 0.1643
# Epoch 368/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1643 - mean_absolute_error: 0.1643 - val_loss: 0.1647 - val_mean_absolute_error: 0.1647
# Epoch 369/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1654 - mean_absolute_error: 0.1654 - val_loss: 0.1649 - val_mean_absolute_error: 0.1649
# Epoch 370/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1641 - mean_absolute_error: 0.1641 - val_loss: 0.1647 - val_mean_absolute_error: 0.1647
# Epoch 371/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1667 - mean_absolute_error: 0.1667 - val_loss: 0.1642 - val_mean_absolute_error: 0.1642
# Epoch 372/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1660 - mean_absolute_error: 0.1660 - val_loss: 0.1640 - val_mean_absolute_error: 0.1640
# Epoch 373/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1659 - mean_absolute_error: 0.1659 - val_loss: 0.1639 - val_mean_absolute_error: 0.1639
# Epoch 374/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1663 - mean_absolute_error: 0.1663 - val_loss: 0.1640 - val_mean_absolute_error: 0.1640
# Epoch 375/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1654 - mean_absolute_error: 0.1654 - val_loss: 0.1646 - val_mean_absolute_error: 0.1646
# Epoch 376/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1631 - mean_absolute_error: 0.1631 - val_loss: 0.1642 - val_mean_absolute_error: 0.1642
# Epoch 377/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1630 - mean_absolute_error: 0.1630 - val_loss: 0.1642 - val_mean_absolute_error: 0.1642
# Epoch 378/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1634 - mean_absolute_error: 0.1634 - val_loss: 0.1643 - val_mean_absolute_error: 0.1643
# Epoch 379/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1661 - mean_absolute_error: 0.1661 - val_loss: 0.1642 - val_mean_absolute_error: 0.1642
# Epoch 380/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1638 - mean_absolute_error: 0.1638 - val_loss: 0.1645 - val_mean_absolute_error: 0.1645
# Epoch 381/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1656 - mean_absolute_error: 0.1656 - val_loss: 0.1641 - val_mean_absolute_error: 0.1641
# Epoch 382/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1656 - mean_absolute_error: 0.1656 - val_loss: 0.1637 - val_mean_absolute_error: 0.1637
# Epoch 383/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1654 - mean_absolute_error: 0.1654 - val_loss: 0.1637 - val_mean_absolute_error: 0.1637
# Epoch 384/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1639 - mean_absolute_error: 0.1639 - val_loss: 0.1635 - val_mean_absolute_error: 0.1635
# Epoch 385/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1677 - mean_absolute_error: 0.1677 - val_loss: 0.1637 - val_mean_absolute_error: 0.1637
# Epoch 386/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1644 - mean_absolute_error: 0.1644 - val_loss: 0.1642 - val_mean_absolute_error: 0.1642
# Epoch 387/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1675 - mean_absolute_error: 0.1675 - val_loss: 0.1640 - val_mean_absolute_error: 0.1640
# Epoch 388/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1654 - mean_absolute_error: 0.1654 - val_loss: 0.1641 - val_mean_absolute_error: 0.1641
# Epoch 389/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1619 - mean_absolute_error: 0.1619 - val_loss: 0.1640 - val_mean_absolute_error: 0.1640
# Epoch 390/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1644 - mean_absolute_error: 0.1644 - val_loss: 0.1639 - val_mean_absolute_error: 0.1639
# Epoch 391/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1680 - mean_absolute_error: 0.1680 - val_loss: 0.1641 - val_mean_absolute_error: 0.1641
# Epoch 392/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1638 - mean_absolute_error: 0.1638 - val_loss: 0.1637 - val_mean_absolute_error: 0.1637
# Epoch 393/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1628 - mean_absolute_error: 0.1628 - val_loss: 0.1637 - val_mean_absolute_error: 0.1637
# Epoch 394/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1642 - mean_absolute_error: 0.1642 - val_loss: 0.1637 - val_mean_absolute_error: 0.1637
# Epoch 395/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1650 - mean_absolute_error: 0.1650 - val_loss: 0.1633 - val_mean_absolute_error: 0.1633
# Epoch 396/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1681 - mean_absolute_error: 0.1681 - val_loss: 0.1635 - val_mean_absolute_error: 0.1635
# Epoch 397/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1635 - mean_absolute_error: 0.1635 - val_loss: 0.1638 - val_mean_absolute_error: 0.1638
# Epoch 398/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1621 - mean_absolute_error: 0.1621 - val_loss: 0.1637 - val_mean_absolute_error: 0.1637
# Epoch 399/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1661 - mean_absolute_error: 0.1661 - val_loss: 0.1641 - val_mean_absolute_error: 0.1641
# Epoch 400/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1619 - mean_absolute_error: 0.1619 - val_loss: 0.1643 - val_mean_absolute_error: 0.1643
# Epoch 401/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1627 - mean_absolute_error: 0.1627 - val_loss: 0.1638 - val_mean_absolute_error: 0.1638
# Epoch 402/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1672 - mean_absolute_error: 0.1672 - val_loss: 0.1642 - val_mean_absolute_error: 0.1642
# Epoch 403/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1655 - mean_absolute_error: 0.1655 - val_loss: 0.1640 - val_mean_absolute_error: 0.1640
# Epoch 404/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1643 - mean_absolute_error: 0.1643 - val_loss: 0.1638 - val_mean_absolute_error: 0.1638
# Epoch 405/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1630 - mean_absolute_error: 0.1630 - val_loss: 0.1636 - val_mean_absolute_error: 0.1636
# Epoch 406/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1670 - mean_absolute_error: 0.1670 - val_loss: 0.1641 - val_mean_absolute_error: 0.1641
# Epoch 407/500
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1628 - mean_absolute_error: 0.1628 - val_loss: 0.1639 - val_mean_absolute_error: 0.1639
# Epoch 408/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1654 - mean_absolute_error: 0.1654 - val_loss: 0.1633 - val_mean_absolute_error: 0.1633
# Epoch 409/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1640 - mean_absolute_error: 0.1640 - val_loss: 0.1635 - val_mean_absolute_error: 0.1635
# Epoch 410/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1625 - mean_absolute_error: 0.1625 - val_loss: 0.1642 - val_mean_absolute_error: 0.1642
# Epoch 411/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1640 - mean_absolute_error: 0.1640 - val_loss: 0.1640 - val_mean_absolute_error: 0.1640
# Epoch 00411: early stopping

# %%
model = keras.models.load_model("best_model3.5.h5")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test error", test_acc)
print("Test loss", test_loss)
# Out:
# 1/1 [==============================] - 0s 108ms/step - loss: 0.1623 - mean_absolute_error: 0.1623
# Test error 0.16229082643985748
# Test loss 0.16229082643985748

# %%
mua = np.zeros((x_train.shape[0],))
mus = np.zeros((x_train.shape[0],))
d = np.zeros((x_train.shape[0],))
miu = np.zeros((x_train.shape[0],2))

miu = model.predict(x_train)
mua = miu[:,0]
mus = miu[:,1]
d = x_train[:,0,0]

# %%
err = np.zeros((x_train.shape[0],2))

err[:,0] = y_train[:,0]-mua
err[:,1] = y_train[:,1]-mus
# print(mua[k],mus[k],d[k])
# print(y_train[k])

# %%
k=np.random.randint(0,x_train.shape[0],1)[0]
print(mua[k],mus[k],d[k])
print(y_train[k])
# Out:
# 0.37721196 0.22592066 0.15000000000000002
# [0.45801701 0.2675394 ]

# %%
plt.plot(d,err[:,1],alpha=0.5)
plt.plot(d,err[:,0],alpha=0.5)
plt.show()

# %%
# print(mua,mus,d)
# print(an2[i,1],an2[i,2],an2[i,0])
# plt.plot(abs(an1[:,1]-mua))
# plt.plot(abs(an1[:,2]-mus))
plt.hist((y_train[:,0]-mua), bins=40,  facecolor="blue", edgecolor="black", alpha=0.7)
plt.hist((y_train[:,1]-mus), bins=40,  facecolor="green", edgecolor="black", alpha=0.7)
plt.show()

# %%
metric = "mean_absolute_error"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()

# %%
# 你可以用pca或者一些降维方法把特征搞一下
