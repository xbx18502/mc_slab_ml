# %%
import os  
import numpy as np
import struct
import matplotlib.pyplot as plt
import gc
import random
from tensorflow import keras

# %%
with open("C:\\Users\\Administrator\\source\\data\\dataset - 副本.bin", "rb") as file0:
    data1 = file0.read(4)
    NM1 = struct.unpack("i", data1)[0]
    sig1 = np.zeros((NM1,200),dtype = np.float32)
    an1 = np.zeros((NM1,4),dtype = np.float32)
    for i in range(NM1):
        for k in range(4):
            data1 = file0.read(4)
            an1[i,k] = struct.unpack("f", data1)[0]
        for k in range(200):
            data1 = file0.read(4)
            sig1[i,k] = struct.unpack("f", data1)[0]  
    # data1 = file0.read(len('end\0'))
    # end = struct.unpack("4s", data1)[0]

# %%
with open("C:\\Users\\Administrator\\source\\data\\dataset.bin", "rb") as file0:
    data1 = file0.read(4)
    NM1 = struct.unpack("i", data1)[0]
    sig2 = np.zeros((NM1,200),dtype = np.float32)
    an2 = np.zeros((NM1,4),dtype = np.float32)
    for i in range(NM1):
        for k in range(4):
            data1 = file0.read(4)
            an2[i,k] = struct.unpack("f", data1)[0]
        for k in range(200):
            data1 = file0.read(4)
            sig2[i,k] = struct.unpack("f", data1)[0]  
    # data1 = file0.read(len('end\0'))
    # end = struct.unpack("4s", data1)[0]

# %%
plt.axes(yscale = "log") 
for n in range(NM1):
    plt.plot(sig1[n])
plt.show()
print(NM1)
print(an1[-1])
# Out:
# 167
# [9.169034e-04 7.802959e+01 8.731936e+03 8.500000e-01]

# %%
def labeling(y,N):
    ##############
    a,b = y.shape
    min0 = np.min(y,0)
    max0 = np.max(y,0)
    step = (max0-min0)/N
    y2 = np.zeros((a,b,N))
    for i in range(a):
        for j in range(b):
            if(step[j]!=0):
                idx = (y[i,j]-min0[j])/step[j]-1
                y2[i,j,int(idx)] = 1
            else:
                y2[i,j,0] = 1

    return y2

# %%
print(sig1.shape)
print(an1.shape)
print(sig2.shape)
print(an2.shape)
num_labels = 10
x_train = sig1
y_train = an1
x_test = sig2
y_test = an2
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))
y_train = labeling(y_train,num_labels)[:,0,:]
y_test = labeling(y_test,num_labels)[:,0,:]
print('x_train.shape = '+str(x_train.shape)) 
print('y_train.shape = '+str(y_train.shape))
# Out:
# (167, 200)
# (167, 4)
# (266, 200)
# (266, 4)
# x_train.shape = (167, 200, 1)
# y_train.shape = (167, 10)

# %%
num_classes = y_train.shape[1]

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)

    conv1 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(input_layer)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)
    
    # range_ = keras.layers.Dense(1, input_shape=(1,), activation='relu')
    # merged = keras.layers.Concatenate()([gap, range_])
    # # merged.add(Dense(n_classes, activation='softmax'))

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])
keras.utils.plot_model(model, show_shapes=True)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %%
epochs = 500
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["categorical_accuracy"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/500
# 5/5 [==============================] - 1s 78ms/step - loss: 2.2832 - categorical_accuracy: 0.1203 - val_loss: 2.2894 - val_categorical_accuracy: 0.1176
# Epoch 2/500
# 5/5 [==============================] - 0s 17ms/step - loss: 2.2048 - categorical_accuracy: 0.1729 - val_loss: 2.3403 - val_categorical_accuracy: 0.1176
# Epoch 3/500
# 5/5 [==============================] - 0s 18ms/step - loss: 2.1523 - categorical_accuracy: 0.2256 - val_loss: 2.4275 - val_categorical_accuracy: 0.1176
# Epoch 4/500
# 5/5 [==============================] - 0s 17ms/step - loss: 2.1128 - categorical_accuracy: 0.2331 - val_loss: 2.5120 - val_categorical_accuracy: 0.1176
# Epoch 5/500
# 5/5 [==============================] - 0s 16ms/step - loss: 2.0778 - categorical_accuracy: 0.2331 - val_loss: 2.5904 - val_categorical_accuracy: 0.1176
# Epoch 6/500
# 5/5 [==============================] - 0s 16ms/step - loss: 2.0473 - categorical_accuracy: 0.2331 - val_loss: 2.6230 - val_categorical_accuracy: 0.0588
# Epoch 7/500
# 5/5 [==============================] - 0s 16ms/step - loss: 2.0234 - categorical_accuracy: 0.2932 - val_loss: 2.6425 - val_categorical_accuracy: 0.1176
# Epoch 8/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.9908 - categorical_accuracy: 0.4060 - val_loss: 2.6180 - val_categorical_accuracy: 0.1176
# Epoch 9/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.9508 - categorical_accuracy: 0.4060 - val_loss: 2.5845 - val_categorical_accuracy: 0.1176
# Epoch 10/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.9136 - categorical_accuracy: 0.3835 - val_loss: 2.5533 - val_categorical_accuracy: 0.1176
# Epoch 11/500
# 5/5 [==============================] - 0s 17ms/step - loss: 1.8799 - categorical_accuracy: 0.4211 - val_loss: 2.5633 - val_categorical_accuracy: 0.1176
# Epoch 12/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.8357 - categorical_accuracy: 0.3759 - val_loss: 2.5575 - val_categorical_accuracy: 0.1176
# Epoch 13/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.7935 - categorical_accuracy: 0.3308 - val_loss: 2.6747 - val_categorical_accuracy: 0.1176
# Epoch 14/500
# 5/5 [==============================] - 0s 17ms/step - loss: 1.7755 - categorical_accuracy: 0.3759 - val_loss: 2.7975 - val_categorical_accuracy: 0.1176
# Epoch 15/500
# 5/5 [==============================] - 0s 17ms/step - loss: 1.7384 - categorical_accuracy: 0.3835 - val_loss: 2.8988 - val_categorical_accuracy: 0.1176
# Epoch 16/500
# 5/5 [==============================] - 0s 17ms/step - loss: 1.7043 - categorical_accuracy: 0.4286 - val_loss: 3.0163 - val_categorical_accuracy: 0.1176
# Epoch 17/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.6846 - categorical_accuracy: 0.4511 - val_loss: 3.1103 - val_categorical_accuracy: 0.1176
# Epoch 18/500
# 5/5 [==============================] - 0s 17ms/step - loss: 1.6692 - categorical_accuracy: 0.4511 - val_loss: 3.2384 - val_categorical_accuracy: 0.1176
# Epoch 19/500
# 5/5 [==============================] - 0s 17ms/step - loss: 1.6785 - categorical_accuracy: 0.4135 - val_loss: 3.3892 - val_categorical_accuracy: 0.1176
# Epoch 20/500
# 5/5 [==============================] - 0s 17ms/step - loss: 1.6420 - categorical_accuracy: 0.4361 - val_loss: 3.5148 - val_categorical_accuracy: 0.1176
# Epoch 21/500
# 5/5 [==============================] - 0s 17ms/step - loss: 1.6217 - categorical_accuracy: 0.4436 - val_loss: 3.6319 - val_categorical_accuracy: 0.1176
# Epoch 22/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.6104 - categorical_accuracy: 0.4586 - val_loss: 3.6500 - val_categorical_accuracy: 0.1176
# Epoch 23/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.5976 - categorical_accuracy: 0.4737 - val_loss: 3.6732 - val_categorical_accuracy: 0.1176
# Epoch 24/500
# 5/5 [==============================] - 0s 17ms/step - loss: 1.6048 - categorical_accuracy: 0.4511 - val_loss: 3.7298 - val_categorical_accuracy: 0.1176
# Epoch 25/500
# 5/5 [==============================] - 0s 17ms/step - loss: 1.5841 - categorical_accuracy: 0.4586 - val_loss: 3.7879 - val_categorical_accuracy: 0.1176
# Epoch 26/500
# 5/5 [==============================] - 0s 17ms/step - loss: 1.5851 - categorical_accuracy: 0.5038 - val_loss: 3.8393 - val_categorical_accuracy: 0.1176
# Epoch 27/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.5795 - categorical_accuracy: 0.4586 - val_loss: 3.8941 - val_categorical_accuracy: 0.1176
# Epoch 28/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.5836 - categorical_accuracy: 0.4887 - val_loss: 3.9424 - val_categorical_accuracy: 0.1176
# Epoch 29/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.5672 - categorical_accuracy: 0.4662 - val_loss: 3.9807 - val_categorical_accuracy: 0.1176
# Epoch 30/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.5621 - categorical_accuracy: 0.4962 - val_loss: 4.0002 - val_categorical_accuracy: 0.1176
# Epoch 31/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.5544 - categorical_accuracy: 0.4812 - val_loss: 3.9674 - val_categorical_accuracy: 0.1176
# Epoch 32/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.5604 - categorical_accuracy: 0.4737 - val_loss: 3.9616 - val_categorical_accuracy: 0.1176
# Epoch 33/500
# 5/5 [==============================] - 0s 17ms/step - loss: 1.5525 - categorical_accuracy: 0.4962 - val_loss: 3.9403 - val_categorical_accuracy: 0.0588
# Epoch 34/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.5640 - categorical_accuracy: 0.4737 - val_loss: 3.9365 - val_categorical_accuracy: 0.0588
# Epoch 35/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.5551 - categorical_accuracy: 0.4812 - val_loss: 3.9905 - val_categorical_accuracy: 0.0588
# Epoch 36/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.5344 - categorical_accuracy: 0.4812 - val_loss: 4.0306 - val_categorical_accuracy: 0.0588
# Epoch 37/500
# 5/5 [==============================] - 0s 17ms/step - loss: 1.5366 - categorical_accuracy: 0.4662 - val_loss: 4.0041 - val_categorical_accuracy: 0.0588
# Epoch 38/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.5383 - categorical_accuracy: 0.5038 - val_loss: 3.9881 - val_categorical_accuracy: 0.0588
# Epoch 39/500
# 5/5 [==============================] - 0s 17ms/step - loss: 1.5315 - categorical_accuracy: 0.4737 - val_loss: 3.9927 - val_categorical_accuracy: 0.0588
# Epoch 40/500
# 5/5 [==============================] - 0s 17ms/step - loss: 1.5384 - categorical_accuracy: 0.4737 - val_loss: 4.0164 - val_categorical_accuracy: 0.0882
# Epoch 41/500
# 5/5 [==============================] - 0s 17ms/step - loss: 1.5330 - categorical_accuracy: 0.4436 - val_loss: 4.0349 - val_categorical_accuracy: 0.0882
# Epoch 42/500
# 5/5 [==============================] - 0s 17ms/step - loss: 1.5192 - categorical_accuracy: 0.5188 - val_loss: 4.0176 - val_categorical_accuracy: 0.0588
# Epoch 43/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.5132 - categorical_accuracy: 0.4887 - val_loss: 4.0392 - val_categorical_accuracy: 0.0588
# Epoch 44/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.5122 - categorical_accuracy: 0.5188 - val_loss: 4.0269 - val_categorical_accuracy: 0.0588
# Epoch 45/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.5067 - categorical_accuracy: 0.5188 - val_loss: 4.0080 - val_categorical_accuracy: 0.0588
# Epoch 46/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.5125 - categorical_accuracy: 0.4737 - val_loss: 3.9863 - val_categorical_accuracy: 0.0588
# Epoch 47/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.4993 - categorical_accuracy: 0.5038 - val_loss: 3.9544 - val_categorical_accuracy: 0.0588
# Epoch 48/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.4940 - categorical_accuracy: 0.5038 - val_loss: 3.9559 - val_categorical_accuracy: 0.0588
# Epoch 49/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.4957 - categorical_accuracy: 0.4962 - val_loss: 3.9741 - val_categorical_accuracy: 0.0588
# Epoch 50/500
# 5/5 [==============================] - 0s 16ms/step - loss: 1.4935 - categorical_accuracy: 0.4962 - val_loss: 3.9715 - val_categorical_accuracy: 0.0588
# Epoch 51/500
# 5/5 [==============================] - 0s 17ms/step - loss: 1.5225 - categorical_accuracy: 0.4737 - val_loss: 3.9873 - val_categorical_accuracy: 0.0588
# Epoch 00051: early stopping

# %%
model = keras.models.load_model("best_model.h5")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 9/9 [==============================] - 1s 42ms/step - loss: 2.2377 - categorical_accuracy: 0.0752
# Test accuracy 0.07518796622753143
# Test loss 2.237664222717285

# %%
metric = "categorical_accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()
