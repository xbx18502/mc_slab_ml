# %%
import os  
import numpy as np
import struct
import matplotlib.pyplot as plt
import gc
import random
import math
from tensorflow import keras

# %%
with open("C:\\Users\\Administrator\\source\\data\\dataset.bin", "rb") as file0:
    data1 = file0.read(4)
    NM1 = struct.unpack("i", data1)[0]
    sig1 = np.zeros((NM1,200),dtype = np.float32)
    an1 = np.zeros((NM1,4),dtype = np.float32)
    for i in range(NM1):
        for k in range(4):
            data1 = file0.read(4)
            an1[i,k] = struct.unpack("f", data1)[0]
        for k in range(200):
            data1 = file0.read(4)
            sig1[i,k] = struct.unpack("f", data1)[0]  
    # data1 = file0.read(len('end\0'))
    # end = struct.unpack("4s", data1)[0]

# %%
with open("C:\\Users\\Administrator\\source\\data\\dataset_test.bin", "rb") as file0:
    data1 = file0.read(4)
    NM1 = struct.unpack("i", data1)[0]
    sig2 = np.zeros((NM1,200),dtype = np.float32)
    an2 = np.zeros((NM1,4),dtype = np.float32)
    for i in range(NM1):
        for k in range(4):
            data1 = file0.read(4)
            an2[i,k] = struct.unpack("f", data1)[0]
        for k in range(200):
            data1 = file0.read(4)
            sig2[i,k] = struct.unpack("f", data1)[0]  
    # data1 = file0.read(len('end\0'))
    # end = struct.unpack("4s", data1)[0]

# %%
plt.axes(yscale = "log") 
for n in range(NM1):
    plt.plot(sig2[n])
plt.show()
print(NM1)
print(an2[-1])
# Out:
# 167
# [9.169034e-04 7.802959e+01 8.731936e+03 8.500000e-01]

# %%
# def labeling(y,N):
#     ##############
#     a,b = y.shape
#     min0 = np.min(y,0)
#     max0 = np.max(y,0)
#     step = (max0-min0)/N
#     y2 = np.zeros((a,b,N))
    
#     # kernel = np.array([1]) 
#     # kernel = kernel/np.sum(kernel)
    
#     for i in range(a):
#         for j in range(b):
#             if(step[j]!=0):
#                 idx = (y[i,j]-min0[j])/step[j]-1
#                 y2[i,j,int(idx)] = 1
#             else:
#                 y2[i,j,0] = 1
#             # y2[i,j] = np.convolve(y2[i,j],kernel,mode='same')
            
#     return y2

# %%
print(sig1.shape)
print(an1.shape)
print(sig2.shape)
print(an2.shape)
# num_labels = 10
x_train = sig1
y_train = an1
x_test = sig2
y_test = an2

x_train = np.log10((x_train+1e-6)/1000)+11
x_test = np.log10((x_test+1e-6)/1000)+11
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))
d_train = np.reshape(y_train[:,0],(y_train[:,0].shape[0],1,1)) # add thickness of sample into input data
d_test = np.reshape(y_test[:,0],(y_test[:,0].shape[0],1,1))

x_train = np.concatenate((d_train,x_train),axis = 1) 
x_test = np.concatenate((d_test,x_test),axis = 1)
y_train[:,1] = y_train[:,1]/1e2
y_test[:,1] = y_test[:,1]/1e2
y_train[:,2] = y_train[:,2]/200e2
y_test[:,2] = y_test[:,2]/200e2
y_train = y_train[:,1:3]
y_test = y_test[:,1:3]
# y_train = labeling(y_train,num_labels)[:,1,:] # select to predict what : 0:thickness 1:mua 2: mus
# y_test = labeling(y_test,num_labels)[:,1,:]
print('x_train.shape = '+str(x_train.shape)) 
print('y_train.shape = '+str(y_train.shape))
# Out:
# (666, 200)
# (666, 4)
# (30, 200)
# (30, 4)
# x_train.shape = (666, 201, 1)
# y_train.shape = (666, 2)

# %%
for n in range(x_train.shape[0]):
    plt.plot(x_train[n,1:])
plt.show()

# %%
# num_classes = y_train.shape[1]
########################################
# input_shape = (1,5,1)
# x = np.arange(np.prod(input_shape)).reshape(input_shape)      # test cropping#
# print(x)
# y = keras.layers.Cropping1D(cropping=(0,4))(x)
# z = keras.layers.Cropping1D(cropping=(1,0))(x)
# print(y)
# print(z)

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)
    
    d_1 = keras.layers.Cropping1D(cropping=(0,200))(input_layer)
    sig = keras.layers.Cropping1D(cropping=(1,0))(input_layer)
    
    conv1 = keras.layers.Conv1D(filters=32, kernel_size=3, padding="same")(sig)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=32, kernel_size=3, padding="same")(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=32, kernel_size=3, padding="same")(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)
    
#     gap = keras.layers.Dense(16, activation='relu')(gap)
#     gap = keras.layers.BatchNormalization()(gap)
#     gap = keras.layers.Dropout(0.5)(gap)
#     gap = keras.layers.Dense(8, activation='relu')(gap)
    
    
#     d_1 = keras.layers.Dense(16, activation='relu')(d_1)
#     d_1 = keras.layers.Dense(8, activation='relu')(d_1)
#     d_1 = keras.layers.Reshape((8,))(d_1)
    
    
    
#     merged = keras.layers.Concatenate()([d_1, gap])
#     merged = keras.layers.Dense(8, activation='relu')(merged)
    
#     output_layer = keras.layers.Dense(2, activation="linear")(merged)
    d_1 = keras.layers.Dense(16, activation='relu')(d_1)
    # d_1 = keras.layers.Dense(10, activation='relu')(d_1)
    d_1 = keras.layers.Reshape((16,))(d_1)
    
    d_1 = keras.layers.BatchNormalization()(d_1)
    gap = keras.layers.Dense(8, activation='relu')(gap)
    gap = keras.layers.BatchNormalization()(gap)
    
    merged = keras.layers.Concatenate()([d_1, gap])
    merged = keras.layers.Dense(8, activation='relu')(merged)
    
    output_layer = keras.layers.Dense(2, activation="linear")(merged)
    
    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])
keras.utils.plot_model(model, show_shapes=True)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %%
epochs = 1000
batch_size = 32
#####################################################
index = [i for i in range(x_train.shape[0])]  
np.random.shuffle(index) 
x_train = x_train[index]
y_train = y_train[index]
####################################################
callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="mean_squared_logarithmic_error",
    metrics=["MeanAbsoluteError"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.4,
    verbose=1,
)
# Out:
# Epoch 1/1000
# 13/13 [==============================] - 2s 43ms/step - loss: 0.0096 - mean_absolute_error: 0.1089 - val_loss: 0.0253 - val_mean_absolute_error: 0.1868
# Epoch 2/1000
# 13/13 [==============================] - 0s 26ms/step - loss: 0.0067 - mean_absolute_error: 0.0931 - val_loss: 0.0375 - val_mean_absolute_error: 0.2150
# Epoch 3/1000
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0057 - mean_absolute_error: 0.0844 - val_loss: 0.0545 - val_mean_absolute_error: 0.2548
# Epoch 4/1000
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0061 - mean_absolute_error: 0.0893 - val_loss: 0.0224 - val_mean_absolute_error: 0.1864
# Epoch 5/1000
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0059 - mean_absolute_error: 0.0880 - val_loss: 0.0126 - val_mean_absolute_error: 0.1285
# Epoch 6/1000
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0071 - mean_absolute_error: 0.0924 - val_loss: 0.0382 - val_mean_absolute_error: 0.2259
# Epoch 7/1000
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0072 - mean_absolute_error: 0.0942 - val_loss: 0.0383 - val_mean_absolute_error: 0.2235
# Epoch 8/1000
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0072 - mean_absolute_error: 0.0932 - val_loss: 0.0078 - val_mean_absolute_error: 0.1033
# Epoch 9/1000
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0065 - mean_absolute_error: 0.0913 - val_loss: 0.0170 - val_mean_absolute_error: 0.1472
# Epoch 10/1000
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0059 - mean_absolute_error: 0.0850 - val_loss: 0.0149 - val_mean_absolute_error: 0.1494
# Epoch 11/1000
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0063 - mean_absolute_error: 0.0885 - val_loss: 0.0061 - val_mean_absolute_error: 0.0922
# Epoch 12/1000
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0073 - mean_absolute_error: 0.0957 - val_loss: 0.0178 - val_mean_absolute_error: 0.1695
# Epoch 13/1000
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0074 - mean_absolute_error: 0.0984 - val_loss: 0.0078 - val_mean_absolute_error: 0.0989
# Epoch 14/1000
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0061 - mean_absolute_error: 0.0885 - val_loss: 0.0071 - val_mean_absolute_error: 0.0986
# Epoch 15/1000
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0057 - mean_absolute_error: 0.0838 - val_loss: 0.0054 - val_mean_absolute_error: 0.0831
# Epoch 16/1000
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0058 - mean_absolute_error: 0.0840 - val_loss: 0.0101 - val_mean_absolute_error: 0.1238
# Epoch 17/1000
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0060 - mean_absolute_error: 0.0876 - val_loss: 0.0143 - val_mean_absolute_error: 0.1408
# Epoch 18/1000
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0064 - mean_absolute_error: 0.0906 - val_loss: 0.0119 - val_mean_absolute_error: 0.1323
# Epoch 19/1000
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0063 - mean_absolute_error: 0.0882 - val_loss: 0.0250 - val_mean_absolute_error: 0.1923
# Epoch 20/1000
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0067 - mean_absolute_error: 0.0905 - val_loss: 0.0188 - val_mean_absolute_error: 0.1533
# Epoch 21/1000
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0066 - mean_absolute_error: 0.0908 - val_loss: 0.0114 - val_mean_absolute_error: 0.1238
# Epoch 22/1000
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0053 - mean_absolute_error: 0.0816 - val_loss: 0.0109 - val_mean_absolute_error: 0.1222
# Epoch 23/1000
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0065 - mean_absolute_error: 0.0901 - val_loss: 0.0064 - val_mean_absolute_error: 0.0857
# Epoch 24/1000
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0064 - mean_absolute_error: 0.0885 - val_loss: 0.0106 - val_mean_absolute_error: 0.1251
# Epoch 25/1000
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0053 - mean_absolute_error: 0.0820 - val_loss: 0.0340 - val_mean_absolute_error: 0.2513
# Epoch 26/1000
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0063 - mean_absolute_error: 0.0895 - val_loss: 0.0107 - val_mean_absolute_error: 0.1317
# Epoch 27/1000
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0061 - mean_absolute_error: 0.0897 - val_loss: 0.0065 - val_mean_absolute_error: 0.0882
# Epoch 28/1000
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0073 - mean_absolute_error: 0.0961 - val_loss: 0.0095 - val_mean_absolute_error: 0.1130
# Epoch 29/1000
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0058 - mean_absolute_error: 0.0875 - val_loss: 0.0269 - val_mean_absolute_error: 0.2065
# Epoch 30/1000
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0060 - mean_absolute_error: 0.0881 - val_loss: 0.0061 - val_mean_absolute_error: 0.0868
# Epoch 31/1000
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0056 - mean_absolute_error: 0.0849 - val_loss: 0.0267 - val_mean_absolute_error: 0.2188
# Epoch 32/1000
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0051 - mean_absolute_error: 0.0794 - val_loss: 0.0159 - val_mean_absolute_error: 0.1732
# Epoch 33/1000
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0057 - mean_absolute_error: 0.0841 - val_loss: 0.0190 - val_mean_absolute_error: 0.1720
# Epoch 34/1000
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0051 - mean_absolute_error: 0.0812 - val_loss: 0.0110 - val_mean_absolute_error: 0.1209
# Epoch 35/1000
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0064 - mean_absolute_error: 0.0890 - val_loss: 0.0228 - val_mean_absolute_error: 0.1946
# Epoch 36/1000
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0060 - mean_absolute_error: 0.0898 - val_loss: 0.0115 - val_mean_absolute_error: 0.1345
# Epoch 37/1000
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0059 - mean_absolute_error: 0.0862 - val_loss: 0.0186 - val_mean_absolute_error: 0.1727
# Epoch 38/1000
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0060 - mean_absolute_error: 0.0864 - val_loss: 0.0216 - val_mean_absolute_error: 0.1953
# Epoch 39/1000
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0056 - mean_absolute_error: 0.0839 - val_loss: 0.0064 - val_mean_absolute_error: 0.0890
# Epoch 40/1000
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0053 - mean_absolute_error: 0.0807 - val_loss: 0.0227 - val_mean_absolute_error: 0.1930
# Epoch 41/1000
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0045 - mean_absolute_error: 0.0761 - val_loss: 0.0099 - val_mean_absolute_error: 0.1159
# Epoch 42/1000
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0053 - mean_absolute_error: 0.0814 - val_loss: 0.0087 - val_mean_absolute_error: 0.1068
# Epoch 43/1000
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0058 - mean_absolute_error: 0.0873 - val_loss: 0.0153 - val_mean_absolute_error: 0.1468
# Epoch 44/1000
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0053 - mean_absolute_error: 0.0825 - val_loss: 0.0313 - val_mean_absolute_error: 0.2480
# Epoch 45/1000
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0047 - mean_absolute_error: 0.0785 - val_loss: 0.0268 - val_mean_absolute_error: 0.2163
# Epoch 46/1000
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0049 - mean_absolute_error: 0.0805 - val_loss: 0.0191 - val_mean_absolute_error: 0.1680
# Epoch 47/1000
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0051 - mean_absolute_error: 0.0788 - val_loss: 0.0154 - val_mean_absolute_error: 0.1501
# Epoch 48/1000
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0050 - mean_absolute_error: 0.0809 - val_loss: 0.0097 - val_mean_absolute_error: 0.1174
# Epoch 49/1000
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0047 - mean_absolute_error: 0.0767 - val_loss: 0.0294 - val_mean_absolute_error: 0.2270
# Epoch 50/1000
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0045 - mean_absolute_error: 0.0755 - val_loss: 0.0231 - val_mean_absolute_error: 0.1892
# Epoch 51/1000
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0050 - mean_absolute_error: 0.0791 - val_loss: 0.0061 - val_mean_absolute_error: 0.0916
# Epoch 52/1000
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0060 - mean_absolute_error: 0.0862 - val_loss: 0.0092 - val_mean_absolute_error: 0.1116
# Epoch 53/1000
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0054 - mean_absolute_error: 0.0793 - val_loss: 0.0186 - val_mean_absolute_error: 0.1699
# Epoch 54/1000
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0055 - mean_absolute_error: 0.0863 - val_loss: 0.0088 - val_mean_absolute_error: 0.1111
# Epoch 55/1000
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0049 - mean_absolute_error: 0.0801 - val_loss: 0.0128 - val_mean_absolute_error: 0.1299
# Epoch 56/1000
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0056 - mean_absolute_error: 0.0844 - val_loss: 0.0192 - val_mean_absolute_error: 0.1738
# Epoch 57/1000
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0045 - mean_absolute_error: 0.0764 - val_loss: 0.0085 - val_mean_absolute_error: 0.1087
# Epoch 58/1000
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0048 - mean_absolute_error: 0.0769 - val_loss: 0.0112 - val_mean_absolute_error: 0.1215
# Epoch 59/1000
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0042 - mean_absolute_error: 0.0735 - val_loss: 0.0128 - val_mean_absolute_error: 0.1340
# Epoch 60/1000
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0043 - mean_absolute_error: 0.0727 - val_loss: 0.0119 - val_mean_absolute_error: 0.1286
# Epoch 61/1000
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0045 - mean_absolute_error: 0.0754 - val_loss: 0.0120 - val_mean_absolute_error: 0.1255
# Epoch 62/1000
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0056 - mean_absolute_error: 0.0852 - val_loss: 0.0089 - val_mean_absolute_error: 0.1074
# Epoch 63/1000
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0043 - mean_absolute_error: 0.0736 - val_loss: 0.0092 - val_mean_absolute_error: 0.1142
# Epoch 64/1000
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0043 - mean_absolute_error: 0.0738 - val_loss: 0.0068 - val_mean_absolute_error: 0.0928
# Epoch 65/1000
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0048 - mean_absolute_error: 0.0786 - val_loss: 0.0054 - val_mean_absolute_error: 0.0767
# Epoch 00065: early stopping

# %%
model = keras.models.load_model("best_model.h5")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test error", test_acc)
print("Test loss", test_loss)
# Out:
# 1/1 [==============================] - 0s 215ms/step - loss: 0.0078 - mean_absolute_error: 0.0983
# Test error 0.09834365546703339
# Test loss 0.007762981113046408

# %%
mua = np.zeros((x_train.shape[0],))
mus = np.zeros((x_train.shape[0],))
d = np.zeros((x_train.shape[0],))
for i in range(x_train.shape[0]):
    miu = model.predict(x_train[i:i+1])
    mua[i] = miu[0,0]
    mus[i] = miu[0,1]
    d[i] = x_train[i,0,0]

# %%
# print(mua,mus,d)
# print(an2[i,1],an2[i,2],an2[i,0])
# plt.plot(abs(an1[:,1]-mua))
# plt.plot(abs(an1[:,2]-mus))
plt.hist(abs(an1[:,1]-mua), bins=40,  facecolor="blue", edgecolor="black", alpha=0.7)
plt.hist(abs(an1[:,2]-mus), bins=40,  facecolor="green", edgecolor="black", alpha=0.7)
plt.show()

# %%
def transmittance(d, t, c, g, miu_a, miu_s):
        miu_s_prime = (1-g)*miu_s
        Z0 = 1/(miu_s_prime)
        D = 1/(3*(miu_a + miu_s_prime))
        h1 = math.pow(4*math.pi*D*c, -0.5)
        h2 = math.pow(t, -1.5)*math.exp(-miu_a*c*t)
        h3 = (d-Z0)*math.exp(-(math.pow(d-Z0, 2))/(4*D*c*t))
        h4 = (d+Z0)*math.exp(-(math.pow(d+Z0, 2))/(4*D*c*t))
        h5 = (3*d-Z0)*math.exp(-(math.pow(3*d-Z0, 2))/(4*D*c*t))
        h6 = (3*d+Z0)*math.exp(-(math.pow(3*d+Z0, 2))/(4*D*c*t))
    #     return d,Z0,D,c,t
        return h1*h2*(h3-h4+h5-h6)
    
def error_cal(x,d,time,h):
        miu_a = x[0]
        miu_s = x[1]
        g = 0.85
        # d = 0.38e-3
        k=1
        c = 3e8/1.3314
        T = int(480)
#         time = np.array(range(1,T, 1))
#         time = time*1e-8*0.010345058455114822
        time = time*1e-9
        intensity1 = np.zeros((T, ), dtype = float)
        for i in range(time.shape[0] ):

            intensity1[i] = transmittance( d, time[i], c, g, miu_a, miu_s)
        
        y3 = np.convolve(intensity1, h)
        y2 = intensity1*k
        return y2,y3

# %%
optical_paramter = np.array([mua*1e2,mus*200e2])
time_index = np.linspace(0.01,2e-9,200)
h = np.zeros((200,))
h[0]=1
y2,y3 = error_cal(optical_paramter,d,time_index,h)

# %%
plt.figure(figsize = (4,2))
plt.subplot(1,3,1)
plt.plot(y2)
plt.subplot(1,3,2)
plt.plot(y3)
plt.subplot(1,3,3)
plt.plot(sig2[i,1:])
plt.tight_layout(pad=1.0)
plt.show()

# %%
metric = "mean_absolute_error"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()

# %%
# 你可以用pca或者一些降维方法把特征搞一下
