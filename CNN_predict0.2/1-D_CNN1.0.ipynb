# %%
import os  
import numpy as np
import struct
import matplotlib.pyplot as plt
import gc
import random
from tensorflow import keras

# %%
with open("C:\\Users\\Administrator\\source\\data\\dataset.bin", "rb") as file0:
    data1 = file0.read(4)
    NM1 = struct.unpack("i", data1)[0]
    sig1 = np.zeros((NM1,200),dtype = np.float32)
    an1 = np.zeros((NM1,4),dtype = np.float32)
    for i in range(NM1):
        for k in range(4):
            data1 = file0.read(4)
            an1[i,k] = struct.unpack("f", data1)[0]
        for k in range(200):
            data1 = file0.read(4)
            sig1[i,k] = struct.unpack("f", data1)[0]  
    # data1 = file0.read(len('end\0'))
    # end = struct.unpack("4s", data1)[0]

# %%
with open("C:\\Users\\Administrator\\source\\data\\dataset0.0.bin", "rb") as file0:
    data1 = file0.read(4)
    NM1 = struct.unpack("i", data1)[0]
    sig2 = np.zeros((NM1,200),dtype = np.float32)
    an2 = np.zeros((NM1,4),dtype = np.float32)
    for i in range(NM1):
        for k in range(4):
            data1 = file0.read(4)
            an2[i,k] = struct.unpack("f", data1)[0]
        for k in range(200):
            data1 = file0.read(4)
            sig2[i,k] = struct.unpack("f", data1)[0]  
    # data1 = file0.read(len('end\0'))
    # end = struct.unpack("4s", data1)[0]

# %%
plt.axes(yscale = "log") 
for n in range(NM1):
    plt.plot(sig2[n])
plt.show()
print(NM1)
print(an1[-1])
# Out:
# 167
# [1.0030099e-02 3.1123728e+01 7.9206685e+03 8.5000002e-01]

# %%
def labeling(y,N):
    ##############
    a,b = y.shape
    min0 = np.min(y,0)
    max0 = np.max(y,0)
    step = (max0-min0)/N
    y2 = np.zeros((a,b,N))
    
    # kernel = np.array([1]) 
    # kernel = kernel/np.sum(kernel)
    
    for i in range(a):
        for j in range(b):
            if(step[j]!=0):
                idx = (y[i,j]-min0[j])/step[j]-1
                y2[i,j,int(idx)] = 1
            else:
                y2[i,j,0] = 1
            # y2[i,j] = np.convolve(y2[i,j],kernel,mode='same')
            
    return y2

# %%
print(sig1.shape)
print(an1.shape)
print(sig2.shape)
print(an2.shape)
num_labels = 10
x_train = sig1
y_train = an1
x_test = sig2
y_test = an2

x_train = np.log((x_train+1e-10)/1000)+30
x_test = np.log((x_test+1e-10)/1000)+30
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))
d_train = np.reshape(y_train[:,0],(y_train[:,0].shape[0],1,1)) # add thickness of sample into input data
d_test = np.reshape(y_test[:,0],(y_test[:,0].shape[0],1,1))

x_train = np.concatenate((d_train,x_train),axis = 1) 
x_test = np.concatenate((d_test,x_test),axis = 1)

y_train = labeling(y_train,num_labels)[:,1,:] # select to predict what : 0:thickness 1:mua 2: mus
y_test = labeling(y_test,num_labels)[:,1,:]
print('x_train.shape = '+str(x_train.shape)) 
print('y_train.shape = '+str(y_train.shape))
# Out:
# (266, 200)
# (266, 4)
# (167, 200)
# (167, 4)
# x_train.shape = (266, 201, 1)
# y_train.shape = (266, 10)

# %%
for n in range(x_train.shape[0]):
    plt.plot(x_train[n,1:])
plt.show()

# %%
num_classes = y_train.shape[1]
# input_shape = (1,5,1)
# x = np.arange(np.prod(input_shape)).reshape(input_shape)
# print(x)
# y = keras.layers.Cropping1D(cropping=(0,4))(x)
# z = keras.layers.Cropping1D(cropping=(1,0))(x)
# print(y)
# print(z)

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)
    
    d_1 = keras.layers.Cropping1D(cropping=(0,200))(input_layer)
    sig = keras.layers.Cropping1D(cropping=(1,0))(input_layer)
    
    conv1 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(sig)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)
    
    #d_1 = keras.layers.BatchNormalization()(d_1)
    d_1 = keras.layers.Dense(16, activation='relu')(d_1)
    # d_1 = keras.layers.Dense(10, activation='relu')(d_1)
    d_1 = keras.layers.Reshape((16,))(d_1)
    
    d_1 = keras.layers.BatchNormalization()(d_1)
    gap = keras.layers.Dense(64, activation='relu')(gap)
    gap = keras.layers.BatchNormalization()(gap)
    
    merged = keras.layers.Concatenate()([d_1, gap])
    merged = keras.layers.Dense(16, activation='relu')(merged)
    
    output_layer = keras.layers.Dense(num_classes, activation="softmax")(merged)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])
keras.utils.plot_model(model, show_shapes=True)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %%
epochs = 500
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["categorical_accuracy"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/500
# 7/7 [==============================] - 2s 79ms/step - loss: 2.3363 - categorical_accuracy: 0.1274 - val_loss: 2.2998 - val_categorical_accuracy: 0.0926
# Epoch 2/500
# 7/7 [==============================] - 0s 30ms/step - loss: 2.1833 - categorical_accuracy: 0.2217 - val_loss: 2.2887 - val_categorical_accuracy: 0.0556
# Epoch 3/500
# 7/7 [==============================] - 0s 20ms/step - loss: 2.1367 - categorical_accuracy: 0.2642 - val_loss: 2.2756 - val_categorical_accuracy: 0.0556
# Epoch 4/500
# 7/7 [==============================] - 0s 19ms/step - loss: 2.0784 - categorical_accuracy: 0.2500 - val_loss: 2.2551 - val_categorical_accuracy: 0.1481
# Epoch 5/500
# 7/7 [==============================] - 0s 20ms/step - loss: 1.9948 - categorical_accuracy: 0.3160 - val_loss: 2.2388 - val_categorical_accuracy: 0.1852
# Epoch 6/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.9499 - categorical_accuracy: 0.3208 - val_loss: 2.2219 - val_categorical_accuracy: 0.1852
# Epoch 7/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.8754 - categorical_accuracy: 0.3726 - val_loss: 2.2101 - val_categorical_accuracy: 0.1852
# Epoch 8/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.8343 - categorical_accuracy: 0.3726 - val_loss: 2.2049 - val_categorical_accuracy: 0.1852
# Epoch 9/500
# 7/7 [==============================] - 0s 20ms/step - loss: 1.8280 - categorical_accuracy: 0.3585 - val_loss: 2.2013 - val_categorical_accuracy: 0.1852
# Epoch 10/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.7772 - categorical_accuracy: 0.3774 - val_loss: 2.1969 - val_categorical_accuracy: 0.1852
# Epoch 11/500
# 7/7 [==============================] - 0s 20ms/step - loss: 1.7081 - categorical_accuracy: 0.4151 - val_loss: 2.1928 - val_categorical_accuracy: 0.1852
# Epoch 12/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.6784 - categorical_accuracy: 0.4057 - val_loss: 2.1885 - val_categorical_accuracy: 0.1852
# Epoch 13/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.6811 - categorical_accuracy: 0.3915 - val_loss: 2.1849 - val_categorical_accuracy: 0.1852
# Epoch 14/500
# 7/7 [==============================] - 0s 20ms/step - loss: 1.6738 - categorical_accuracy: 0.4009 - val_loss: 2.1860 - val_categorical_accuracy: 0.1852
# Epoch 15/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.6374 - categorical_accuracy: 0.4104 - val_loss: 2.1871 - val_categorical_accuracy: 0.1852
# Epoch 16/500
# 7/7 [==============================] - 0s 20ms/step - loss: 1.6221 - categorical_accuracy: 0.3962 - val_loss: 2.1932 - val_categorical_accuracy: 0.1852
# Epoch 17/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.5846 - categorical_accuracy: 0.4198 - val_loss: 2.1964 - val_categorical_accuracy: 0.1852
# Epoch 18/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.5946 - categorical_accuracy: 0.4292 - val_loss: 2.1905 - val_categorical_accuracy: 0.1852
# Epoch 19/500
# 7/7 [==============================] - 0s 20ms/step - loss: 1.5096 - categorical_accuracy: 0.4434 - val_loss: 2.1903 - val_categorical_accuracy: 0.1852
# Epoch 20/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.5106 - categorical_accuracy: 0.4340 - val_loss: 2.1989 - val_categorical_accuracy: 0.1852
# Epoch 21/500
# 7/7 [==============================] - 0s 20ms/step - loss: 1.4788 - categorical_accuracy: 0.4717 - val_loss: 2.2032 - val_categorical_accuracy: 0.1852
# Epoch 22/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.5134 - categorical_accuracy: 0.4481 - val_loss: 2.2079 - val_categorical_accuracy: 0.1852
# Epoch 23/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.4965 - categorical_accuracy: 0.4528 - val_loss: 2.2093 - val_categorical_accuracy: 0.1852
# Epoch 24/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.4885 - categorical_accuracy: 0.4670 - val_loss: 2.2345 - val_categorical_accuracy: 0.1852
# Epoch 25/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.5085 - categorical_accuracy: 0.4434 - val_loss: 2.2860 - val_categorical_accuracy: 0.1852
# Epoch 26/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.4795 - categorical_accuracy: 0.4434 - val_loss: 2.2773 - val_categorical_accuracy: 0.1852
# Epoch 27/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.4343 - categorical_accuracy: 0.4811 - val_loss: 2.2958 - val_categorical_accuracy: 0.1852
# Epoch 28/500
# 7/7 [==============================] - 0s 20ms/step - loss: 1.3868 - categorical_accuracy: 0.5142 - val_loss: 2.2723 - val_categorical_accuracy: 0.1852
# Epoch 29/500
# 7/7 [==============================] - 0s 22ms/step - loss: 1.3829 - categorical_accuracy: 0.4858 - val_loss: 2.2364 - val_categorical_accuracy: 0.1852
# Epoch 30/500
# 7/7 [==============================] - 0s 20ms/step - loss: 1.3540 - categorical_accuracy: 0.5047 - val_loss: 2.2544 - val_categorical_accuracy: 0.1852
# Epoch 31/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.3427 - categorical_accuracy: 0.4953 - val_loss: 2.2538 - val_categorical_accuracy: 0.1852
# Epoch 32/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.4358 - categorical_accuracy: 0.4811 - val_loss: 2.2023 - val_categorical_accuracy: 0.1852
# Epoch 33/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.3653 - categorical_accuracy: 0.5000 - val_loss: 2.2389 - val_categorical_accuracy: 0.1852
# Epoch 34/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.3022 - categorical_accuracy: 0.5708 - val_loss: 2.2008 - val_categorical_accuracy: 0.1852
# Epoch 35/500
# 7/7 [==============================] - 0s 20ms/step - loss: 1.3339 - categorical_accuracy: 0.5000 - val_loss: 2.2237 - val_categorical_accuracy: 0.1852
# Epoch 36/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.2523 - categorical_accuracy: 0.5519 - val_loss: 2.2228 - val_categorical_accuracy: 0.2037
# Epoch 37/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.2538 - categorical_accuracy: 0.5330 - val_loss: 2.1838 - val_categorical_accuracy: 0.1852
# Epoch 38/500
# 7/7 [==============================] - 0s 20ms/step - loss: 1.3749 - categorical_accuracy: 0.4906 - val_loss: 2.1161 - val_categorical_accuracy: 0.2778
# Epoch 39/500
# 7/7 [==============================] - 0s 21ms/step - loss: 1.3325 - categorical_accuracy: 0.5094 - val_loss: 2.1814 - val_categorical_accuracy: 0.2222
# Epoch 40/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.2914 - categorical_accuracy: 0.5566 - val_loss: 2.1156 - val_categorical_accuracy: 0.2037
# Epoch 41/500
# 7/7 [==============================] - 0s 20ms/step - loss: 1.2643 - categorical_accuracy: 0.5802 - val_loss: 2.0923 - val_categorical_accuracy: 0.1852
# Epoch 42/500
# 7/7 [==============================] - 0s 21ms/step - loss: 1.2199 - categorical_accuracy: 0.5708 - val_loss: 2.0994 - val_categorical_accuracy: 0.1667
# Epoch 43/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.2575 - categorical_accuracy: 0.5330 - val_loss: 2.0745 - val_categorical_accuracy: 0.2037
# Epoch 44/500
# 7/7 [==============================] - 0s 21ms/step - loss: 1.2310 - categorical_accuracy: 0.5566 - val_loss: 2.0623 - val_categorical_accuracy: 0.2222
# Epoch 45/500
# 7/7 [==============================] - 0s 20ms/step - loss: 1.2554 - categorical_accuracy: 0.5283 - val_loss: 2.0530 - val_categorical_accuracy: 0.2222
# Epoch 46/500
# 7/7 [==============================] - 0s 21ms/step - loss: 1.2116 - categorical_accuracy: 0.5708 - val_loss: 2.0938 - val_categorical_accuracy: 0.1667
# Epoch 47/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.1967 - categorical_accuracy: 0.5943 - val_loss: 2.0549 - val_categorical_accuracy: 0.1852
# Epoch 48/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.2387 - categorical_accuracy: 0.5849 - val_loss: 2.1021 - val_categorical_accuracy: 0.1852
# Epoch 49/500
# 7/7 [==============================] - 0s 20ms/step - loss: 1.1846 - categorical_accuracy: 0.5849 - val_loss: 2.2099 - val_categorical_accuracy: 0.1667
# Epoch 50/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.1811 - categorical_accuracy: 0.5849 - val_loss: 2.1223 - val_categorical_accuracy: 0.2222
# Epoch 51/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.1790 - categorical_accuracy: 0.6179 - val_loss: 2.0598 - val_categorical_accuracy: 0.2407
# Epoch 52/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.1902 - categorical_accuracy: 0.5991 - val_loss: 2.0736 - val_categorical_accuracy: 0.2407
# Epoch 53/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.1675 - categorical_accuracy: 0.6132 - val_loss: 2.1275 - val_categorical_accuracy: 0.1667
# Epoch 54/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.1286 - categorical_accuracy: 0.6604 - val_loss: 2.1690 - val_categorical_accuracy: 0.1111
# Epoch 55/500
# 7/7 [==============================] - 0s 20ms/step - loss: 1.1331 - categorical_accuracy: 0.6179 - val_loss: 2.1025 - val_categorical_accuracy: 0.2593
# Epoch 56/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.1633 - categorical_accuracy: 0.6274 - val_loss: 2.3376 - val_categorical_accuracy: 0.1481
# Epoch 57/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.1101 - categorical_accuracy: 0.6651 - val_loss: 2.4407 - val_categorical_accuracy: 0.1481
# Epoch 58/500
# 7/7 [==============================] - 0s 20ms/step - loss: 1.1567 - categorical_accuracy: 0.5991 - val_loss: 2.2702 - val_categorical_accuracy: 0.1667
# Epoch 59/500
# 7/7 [==============================] - 0s 21ms/step - loss: 1.1487 - categorical_accuracy: 0.6321 - val_loss: 2.3820 - val_categorical_accuracy: 0.0926
# Epoch 60/500
# 7/7 [==============================] - 0s 21ms/step - loss: 1.1582 - categorical_accuracy: 0.6368 - val_loss: 2.1978 - val_categorical_accuracy: 0.2222
# Epoch 61/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.0991 - categorical_accuracy: 0.6274 - val_loss: 2.2904 - val_categorical_accuracy: 0.1852
# Epoch 62/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.1396 - categorical_accuracy: 0.6415 - val_loss: 2.4498 - val_categorical_accuracy: 0.1296
# Epoch 63/500
# 7/7 [==============================] - 0s 20ms/step - loss: 1.1624 - categorical_accuracy: 0.5943 - val_loss: 2.2300 - val_categorical_accuracy: 0.1852
# Epoch 64/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.0697 - categorical_accuracy: 0.6132 - val_loss: 2.4488 - val_categorical_accuracy: 0.2407
# Epoch 65/500
# 7/7 [==============================] - 0s 20ms/step - loss: 1.0891 - categorical_accuracy: 0.6368 - val_loss: 2.4897 - val_categorical_accuracy: 0.2407
# Epoch 66/500
# 7/7 [==============================] - 0s 20ms/step - loss: 1.0866 - categorical_accuracy: 0.6745 - val_loss: 2.3885 - val_categorical_accuracy: 0.1667
# Epoch 67/500
# 7/7 [==============================] - 0s 22ms/step - loss: 1.0715 - categorical_accuracy: 0.6651 - val_loss: 2.3539 - val_categorical_accuracy: 0.1667
# Epoch 68/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.0655 - categorical_accuracy: 0.6321 - val_loss: 2.3624 - val_categorical_accuracy: 0.2037
# Epoch 69/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.0331 - categorical_accuracy: 0.6745 - val_loss: 2.5199 - val_categorical_accuracy: 0.1296
# Epoch 70/500
# 7/7 [==============================] - 0s 19ms/step - loss: 0.9972 - categorical_accuracy: 0.7075 - val_loss: 2.4642 - val_categorical_accuracy: 0.1852
# Epoch 71/500
# 7/7 [==============================] - 0s 20ms/step - loss: 1.0511 - categorical_accuracy: 0.6698 - val_loss: 2.6752 - val_categorical_accuracy: 0.1296
# Epoch 72/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.0490 - categorical_accuracy: 0.6509 - val_loss: 2.4408 - val_categorical_accuracy: 0.1667
# Epoch 73/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.0287 - categorical_accuracy: 0.6792 - val_loss: 2.3272 - val_categorical_accuracy: 0.1481
# Epoch 74/500
# 7/7 [==============================] - 0s 19ms/step - loss: 0.9816 - categorical_accuracy: 0.7217 - val_loss: 2.6223 - val_categorical_accuracy: 0.1481
# Epoch 75/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.0394 - categorical_accuracy: 0.6792 - val_loss: 2.6509 - val_categorical_accuracy: 0.1296
# Epoch 76/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.0351 - categorical_accuracy: 0.6415 - val_loss: 2.3607 - val_categorical_accuracy: 0.2037
# Epoch 77/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.0464 - categorical_accuracy: 0.6274 - val_loss: 2.4530 - val_categorical_accuracy: 0.1852
# Epoch 78/500
# 7/7 [==============================] - 0s 20ms/step - loss: 0.9928 - categorical_accuracy: 0.6887 - val_loss: 2.5992 - val_categorical_accuracy: 0.1852
# Epoch 79/500
# 7/7 [==============================] - 0s 19ms/step - loss: 1.0012 - categorical_accuracy: 0.6792 - val_loss: 2.8957 - val_categorical_accuracy: 0.1481
# Epoch 80/500
# 7/7 [==============================] - 0s 20ms/step - loss: 0.9860 - categorical_accuracy: 0.6887 - val_loss: 2.7892 - val_categorical_accuracy: 0.1481
# Epoch 81/500
# 7/7 [==============================] - 0s 20ms/step - loss: 0.9528 - categorical_accuracy: 0.7311 - val_loss: 2.6679 - val_categorical_accuracy: 0.1481
# Epoch 82/500
# 7/7 [==============================] - 0s 20ms/step - loss: 1.0022 - categorical_accuracy: 0.6792 - val_loss: 2.6018 - val_categorical_accuracy: 0.1852
# Epoch 83/500
# 7/7 [==============================] - 0s 20ms/step - loss: 1.0158 - categorical_accuracy: 0.6604 - val_loss: 2.4469 - val_categorical_accuracy: 0.2037
# Epoch 84/500
# 7/7 [==============================] - 0s 20ms/step - loss: 0.9913 - categorical_accuracy: 0.6698 - val_loss: 2.5538 - val_categorical_accuracy: 0.1481
# Epoch 85/500
# 7/7 [==============================] - 0s 20ms/step - loss: 1.0204 - categorical_accuracy: 0.6651 - val_loss: 2.5237 - val_categorical_accuracy: 0.2593
# Epoch 86/500
# 7/7 [==============================] - 0s 20ms/step - loss: 0.9834 - categorical_accuracy: 0.7217 - val_loss: 2.5939 - val_categorical_accuracy: 0.1296
# Epoch 87/500
# 7/7 [==============================] - 0s 20ms/step - loss: 1.0055 - categorical_accuracy: 0.6698 - val_loss: 2.6812 - val_categorical_accuracy: 0.1111
# Epoch 88/500
# 7/7 [==============================] - 0s 21ms/step - loss: 0.9163 - categorical_accuracy: 0.6840 - val_loss: 2.6659 - val_categorical_accuracy: 0.1111
# Epoch 89/500
# 7/7 [==============================] - 0s 21ms/step - loss: 0.9476 - categorical_accuracy: 0.7170 - val_loss: 2.6418 - val_categorical_accuracy: 0.1481
# Epoch 90/500
# 7/7 [==============================] - 0s 20ms/step - loss: 0.9561 - categorical_accuracy: 0.6840 - val_loss: 2.6842 - val_categorical_accuracy: 0.1852
# Epoch 91/500
# 7/7 [==============================] - 0s 20ms/step - loss: 0.9988 - categorical_accuracy: 0.6462 - val_loss: 2.6533 - val_categorical_accuracy: 0.1481
# Epoch 92/500
# 7/7 [==============================] - 0s 21ms/step - loss: 0.9508 - categorical_accuracy: 0.7217 - val_loss: 2.6093 - val_categorical_accuracy: 0.1852
# Epoch 93/500
# 7/7 [==============================] - 0s 20ms/step - loss: 0.9803 - categorical_accuracy: 0.6745 - val_loss: 2.8449 - val_categorical_accuracy: 0.1481
# Epoch 94/500
# 7/7 [==============================] - 0s 19ms/step - loss: 0.9386 - categorical_accuracy: 0.7028 - val_loss: 2.7685 - val_categorical_accuracy: 0.1667
# Epoch 95/500
# 7/7 [==============================] - 0s 21ms/step - loss: 0.9498 - categorical_accuracy: 0.7075 - val_loss: 2.6918 - val_categorical_accuracy: 0.1667
# Epoch 00095: early stopping

# %%
model = keras.models.load_model("best_model.h5")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 6/6 [==============================] - 0s 13ms/step - loss: 1.8298 - categorical_accuracy: 0.3892
# Test accuracy 0.38922154903411865
# Test loss 1.82980477809906

# %%
metric = "categorical_accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()

# %%
# 你可以用pca或者一些降维方法把特征搞一下
