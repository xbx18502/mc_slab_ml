# %%
''' use pca to extract characteristic of signal
then use dnn to fit; probably voigt function/Gaussian line shape'''
import os  
import numpy as np
import struct
import matplotlib.pyplot as plt
import gc
import random
import math
from tensorflow import keras
import sklearn
# from scipy.interpolate import CubicSpline
from scipy.signal import find_peaks
from scipy.interpolate import interp1d
from sklearn.decomposition import PCA as PCA

# %%
with open("dataset_test.bin", "rb") as file0:
    data1 = file0.read(4)
    NM1 = struct.unpack("i", data1)[0]
    sig2 = np.zeros((NM1,200),dtype = np.float32)
    an2 = np.zeros((NM1,4),dtype = np.float32)
    for i in range(NM1):
        for k in range(4):
            data1 = file0.read(4)
            an2[i,k] = struct.unpack("f", data1)[0]
        for k in range(200):
            data1 = file0.read(4)
            sig2[i,k] = struct.unpack("f", data1)[0]  
    # data1 = file0.read(len('end\0'))
    # end = struct.unpack("4s", data1)[0]

# %%
with open("dataset.bin", "rb") as file0:
    data1 = file0.read(4)
    NM1 = struct.unpack("i", data1)[0]
    sig1 = np.zeros((NM1,200),dtype = np.float32)
    an1 = np.zeros((NM1,4),dtype = np.float32)
    for i in range(NM1):
        for k in range(4):
            data1 = file0.read(4)
            an1[i,k] = struct.unpack("f", data1)[0]
        for k in range(200):
            data1 = file0.read(4)
            sig1[i,k] = struct.unpack("f", data1)[0]  
    # data1 = file0.read(len('end\0'))
    # end = struct.unpack("4s", data1)[0]

# %%
plt.axes(yscale = "log") 
for n in range(sig1.shape[0]):
    plt.plot(sig1[n])
plt.show()
print(NM1)
print(an2[-1])
# Out:
# 1262
# [1.24224685e-02 9.14926987e+01 1.54261023e+03 8.50000024e-01]

# %%
xsig = sig1[0]
peaks, _ = find_peaks(xsig, height=0)
plt.plot(xsig)
plt.plot(peaks, xsig[peaks], "x")
plt.plot(np.zeros_like(xsig), "--", color="gray")
plt.show()

x = np.zeros((peaks.shape[0]+2,))
y = np.zeros((peaks.shape[0]+2,))
x[1:-1] = peaks
y[1:-1] = xsig[peaks]
x[-1] = sig1.shape[1]
plt.plot(x,y)
plt.show()

f2 = interp1d(x, y, kind='linear')
N = 200
xnew = np.linspace(0, N,num=N)
ynew = f2(xnew)

# plt.axes(yscale = "log") 
plt.plot(ynew)
plt.show()

# %%
def smooth_peak(xsig):
    peaks, _ = find_peaks(xsig, height=0)
    # plt.plot(xsig)
    # plt.plot(peaks, xsig[peaks], "x")
    # plt.plot(np.zeros_like(xsig), "--", color="gray")
    # plt.show()
    if(peaks.shape[0]!=0):
        x = np.zeros((peaks.shape[0]+3,))
        y = np.zeros((peaks.shape[0]+3,))
        x[1:-2] = peaks
        y[1:-2] = xsig[peaks]
        x[-1] = sig1.shape[1]
        y[-1] = 0
        x[-2] = peaks[-1]+5
        y[-2] = 0
        # plt.plot(x,y)
        # plt.show()

        f2 = interp1d(x, y, kind='linear')
        N = xsig.shape[0]
        xnew = np.linspace(0, N,num=N)
        ynew = f2(xnew)
    
    else:
        ynew = np.zeros((xsig.shape[0],))
    
    return ynew
#     # plt.axes(yscale = "log") 
#     plt.plot(ynew)
#     plt.show()

# %%
msig1 = np.zeros((sig1.shape[0],sig1.shape[1]))
for i in range(sig1.shape[0]):
    msig1[i] = smooth_peak(sig1[i])
    
msig2 = np.zeros((sig2.shape[0],sig2.shape[1]))
for i in range(sig2.shape[0]):
    msig2[i] = smooth_peak(sig2[i])

# %%
plt.axes(yscale = "log") 
for n in range(msig1.shape[0]):
    plt.plot(msig1[n])
plt.show()

# %%
print(sig1.shape)
print(an1.shape)
print(sig2.shape)
print(an2.shape)
# num_labels = 10
x_train = msig1
y_train = an1   # y_train : [thickness,mua,mus,g]
x_test = msig2
y_test = an2

x_train = (np.log10((x_train+1e-6)/1000)+9)/9   # 归一化
x_test = (np.log10((x_test+1e-6)/1000)+9)/9

n_components = 4
pca = PCA(n_components)
pca.fit(x_train)
# 转换数据并提取主成分
features = pca.transform(x_train)       # PCA
loading = pca.components_
x_train = features

n_components = 4
pca = PCA(n_components)
pca.fit(x_test)
# 转换数据并提取主成分
features = pca.transform(x_test)
loading = pca.components_
x_test = features

x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))    # reshape
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))
d_train = np.reshape(y_train[:,0],(y_train[:,0].shape[0],1,1)) # add thickness of sample into input data
d_test = np.reshape(y_test[:,0],(y_test[:,0].shape[0],1,1))

y_train[:,1] = y_train[:,1]/1e2
y_test[:,1] = y_test[:,1]/1e2
y_train[:,2] = y_train[:,2]/200e2
y_test[:,2] = y_test[:,2]/200e2
y_train = y_train[:,1:3] # determine the nn to output mua/mus or mua+mus
y_test = y_test[:,1:3]
# y_train = labeling(y_train,num_labels)[:,1,:] # select to predict what : 0:thickness 1:mua 2: mus
# y_test = labeling(y_test,num_labels)[:,1,:]
print('x_train.shape = '+str(x_train.shape)) 
print('y_train.shape = '+str(y_train.shape)) 
print('d_train.shape = '+str(d_train.shape))
# Out:
# (1262, 200)
# (1262, 4)
# (30, 200)
# (30, 4)
# x_train.shape = (1262, 4, 1)
# y_train.shape = (1262, 2)
# d_train.shape = (1262, 1, 1)

# %%
inputs1 = keras.layers.Input(shape=(4, 1))
inputs2 = keras.layers.Input(shape=(1,))
x = inputs1
# x = keras.layers.Conv1D(filters=32, kernel_size=3, activation='relu')(x)
# x = keras.layers.MaxPooling1D(pool_size=2)(x)
x = keras.layers.Flatten()(x)
concat = keras.layers.concatenate([x, inputs2])
x = keras.layers.Dense(64, activation='relu')(concat)
outputs = keras.layers.Dense(2, activation='linear')(x)
model = keras.Model(inputs=[inputs1, inputs2], outputs=outputs)

# %%
epochs = 500
batch_size = 32
#####################################################
index = [i for i in range(x_train.shape[0])]  
np.random.shuffle(index) 
x_train = x_train[index]
y_train = y_train[index]
####################################################
callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    # loss="mean_squared_error",
    loss="mean_absolute_error",
    metrics=["MeanAbsoluteError"],
)
history = model.fit(
    [x_train,d_train],
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.4,
    verbose=1,
)
# Out:
# Epoch 1/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.4580 - mean_absolute_error: 0.4580 - val_loss: 0.3128 - val_mean_absolute_error: 0.3128
# Epoch 2/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.2638 - mean_absolute_error: 0.2638 - val_loss: 0.2242 - val_mean_absolute_error: 0.2242
# Epoch 3/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.2195 - mean_absolute_error: 0.2195 - val_loss: 0.2105 - val_mean_absolute_error: 0.2105
# Epoch 4/500
# 24/24 [==============================] - 0s 7ms/step - loss: 0.2076 - mean_absolute_error: 0.2076 - val_loss: 0.2040 - val_mean_absolute_error: 0.2040
# Epoch 5/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.2008 - mean_absolute_error: 0.2008 - val_loss: 0.1987 - val_mean_absolute_error: 0.1987
# Epoch 6/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1963 - mean_absolute_error: 0.1963 - val_loss: 0.1933 - val_mean_absolute_error: 0.1933
# Epoch 7/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1921 - mean_absolute_error: 0.1921 - val_loss: 0.1892 - val_mean_absolute_error: 0.1892
# Epoch 8/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1881 - mean_absolute_error: 0.1881 - val_loss: 0.1850 - val_mean_absolute_error: 0.1850
# Epoch 9/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1850 - mean_absolute_error: 0.1850 - val_loss: 0.1822 - val_mean_absolute_error: 0.1822
# Epoch 10/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1817 - mean_absolute_error: 0.1817 - val_loss: 0.1777 - val_mean_absolute_error: 0.1777
# Epoch 11/500
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1787 - mean_absolute_error: 0.1787 - val_loss: 0.1755 - val_mean_absolute_error: 0.1755
# Epoch 12/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1761 - mean_absolute_error: 0.1761 - val_loss: 0.1729 - val_mean_absolute_error: 0.1729
# Epoch 13/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1736 - mean_absolute_error: 0.1736 - val_loss: 0.1700 - val_mean_absolute_error: 0.1700
# Epoch 14/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1710 - mean_absolute_error: 0.1710 - val_loss: 0.1674 - val_mean_absolute_error: 0.1674
# Epoch 15/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1684 - mean_absolute_error: 0.1684 - val_loss: 0.1642 - val_mean_absolute_error: 0.1642
# Epoch 16/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1667 - mean_absolute_error: 0.1667 - val_loss: 0.1623 - val_mean_absolute_error: 0.1623
# Epoch 17/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1649 - mean_absolute_error: 0.1649 - val_loss: 0.1592 - val_mean_absolute_error: 0.1592
# Epoch 18/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1635 - mean_absolute_error: 0.1635 - val_loss: 0.1583 - val_mean_absolute_error: 0.1583
# Epoch 19/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1616 - mean_absolute_error: 0.1616 - val_loss: 0.1566 - val_mean_absolute_error: 0.1566
# Epoch 20/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1594 - mean_absolute_error: 0.1594 - val_loss: 0.1555 - val_mean_absolute_error: 0.1555
# Epoch 21/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1575 - mean_absolute_error: 0.1575 - val_loss: 0.1532 - val_mean_absolute_error: 0.1532
# Epoch 22/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1562 - mean_absolute_error: 0.1562 - val_loss: 0.1528 - val_mean_absolute_error: 0.1528
# Epoch 23/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1549 - mean_absolute_error: 0.1549 - val_loss: 0.1516 - val_mean_absolute_error: 0.1516
# Epoch 24/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1543 - mean_absolute_error: 0.1543 - val_loss: 0.1502 - val_mean_absolute_error: 0.1502
# Epoch 25/500
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1528 - mean_absolute_error: 0.1528 - val_loss: 0.1501 - val_mean_absolute_error: 0.1501
# Epoch 26/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1526 - mean_absolute_error: 0.1526 - val_loss: 0.1481 - val_mean_absolute_error: 0.1481
# Epoch 27/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1513 - mean_absolute_error: 0.1513 - val_loss: 0.1472 - val_mean_absolute_error: 0.1472
# Epoch 28/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1491 - mean_absolute_error: 0.1491 - val_loss: 0.1465 - val_mean_absolute_error: 0.1465
# Epoch 29/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1493 - mean_absolute_error: 0.1493 - val_loss: 0.1462 - val_mean_absolute_error: 0.1462
# Epoch 30/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1483 - mean_absolute_error: 0.1483 - val_loss: 0.1449 - val_mean_absolute_error: 0.1449
# Epoch 31/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1475 - mean_absolute_error: 0.1475 - val_loss: 0.1454 - val_mean_absolute_error: 0.1454
# Epoch 32/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1470 - mean_absolute_error: 0.1470 - val_loss: 0.1470 - val_mean_absolute_error: 0.1470
# Epoch 33/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1474 - mean_absolute_error: 0.1474 - val_loss: 0.1438 - val_mean_absolute_error: 0.1438
# Epoch 34/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1461 - mean_absolute_error: 0.1461 - val_loss: 0.1432 - val_mean_absolute_error: 0.1432
# Epoch 35/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1456 - mean_absolute_error: 0.1456 - val_loss: 0.1439 - val_mean_absolute_error: 0.1439
# Epoch 36/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1453 - mean_absolute_error: 0.1453 - val_loss: 0.1447 - val_mean_absolute_error: 0.1447
# Epoch 37/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1448 - mean_absolute_error: 0.1448 - val_loss: 0.1431 - val_mean_absolute_error: 0.1431
# Epoch 38/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1448 - mean_absolute_error: 0.1448 - val_loss: 0.1423 - val_mean_absolute_error: 0.1423
# Epoch 39/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1445 - mean_absolute_error: 0.1445 - val_loss: 0.1447 - val_mean_absolute_error: 0.1447
# Epoch 40/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1446 - mean_absolute_error: 0.1446 - val_loss: 0.1431 - val_mean_absolute_error: 0.1431
# Epoch 41/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1439 - mean_absolute_error: 0.1439 - val_loss: 0.1419 - val_mean_absolute_error: 0.1419
# Epoch 42/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1444 - mean_absolute_error: 0.1444 - val_loss: 0.1412 - val_mean_absolute_error: 0.1412
# Epoch 43/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1430 - mean_absolute_error: 0.1430 - val_loss: 0.1424 - val_mean_absolute_error: 0.1424
# Epoch 44/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1428 - mean_absolute_error: 0.1428 - val_loss: 0.1426 - val_mean_absolute_error: 0.1426
# Epoch 45/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1428 - mean_absolute_error: 0.1428 - val_loss: 0.1419 - val_mean_absolute_error: 0.1419
# Epoch 46/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1429 - mean_absolute_error: 0.1429 - val_loss: 0.1423 - val_mean_absolute_error: 0.1423
# Epoch 47/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1426 - mean_absolute_error: 0.1426 - val_loss: 0.1407 - val_mean_absolute_error: 0.1407
# Epoch 48/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1429 - mean_absolute_error: 0.1429 - val_loss: 0.1420 - val_mean_absolute_error: 0.1420
# Epoch 49/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1429 - mean_absolute_error: 0.1429 - val_loss: 0.1412 - val_mean_absolute_error: 0.1412
# Epoch 50/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1422 - mean_absolute_error: 0.1422 - val_loss: 0.1403 - val_mean_absolute_error: 0.1403
# Epoch 51/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1426 - mean_absolute_error: 0.1426 - val_loss: 0.1406 - val_mean_absolute_error: 0.1406
# Epoch 52/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1422 - mean_absolute_error: 0.1422 - val_loss: 0.1408 - val_mean_absolute_error: 0.1408
# Epoch 53/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1417 - mean_absolute_error: 0.1417 - val_loss: 0.1399 - val_mean_absolute_error: 0.1399
# Epoch 54/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1415 - mean_absolute_error: 0.1415 - val_loss: 0.1411 - val_mean_absolute_error: 0.1411
# Epoch 55/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1416 - mean_absolute_error: 0.1416 - val_loss: 0.1421 - val_mean_absolute_error: 0.1421
# Epoch 56/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1419 - mean_absolute_error: 0.1419 - val_loss: 0.1416 - val_mean_absolute_error: 0.1416
# Epoch 57/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1410 - mean_absolute_error: 0.1410 - val_loss: 0.1411 - val_mean_absolute_error: 0.1411
# Epoch 58/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1414 - mean_absolute_error: 0.1414 - val_loss: 0.1401 - val_mean_absolute_error: 0.1401
# Epoch 59/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1423 - mean_absolute_error: 0.1423 - val_loss: 0.1400 - val_mean_absolute_error: 0.1400
# Epoch 60/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1408 - mean_absolute_error: 0.1408 - val_loss: 0.1398 - val_mean_absolute_error: 0.1398
# Epoch 61/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1402 - mean_absolute_error: 0.1402 - val_loss: 0.1404 - val_mean_absolute_error: 0.1404
# Epoch 62/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1411 - mean_absolute_error: 0.1411 - val_loss: 0.1389 - val_mean_absolute_error: 0.1389
# Epoch 63/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1414 - mean_absolute_error: 0.1414 - val_loss: 0.1389 - val_mean_absolute_error: 0.1389
# Epoch 64/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1401 - mean_absolute_error: 0.1401 - val_loss: 0.1396 - val_mean_absolute_error: 0.1396
# Epoch 65/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1399 - mean_absolute_error: 0.1399 - val_loss: 0.1392 - val_mean_absolute_error: 0.1392
# Epoch 66/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1402 - mean_absolute_error: 0.1402 - val_loss: 0.1393 - val_mean_absolute_error: 0.1393
# Epoch 67/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1394 - mean_absolute_error: 0.1394 - val_loss: 0.1386 - val_mean_absolute_error: 0.1386
# Epoch 68/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1402 - mean_absolute_error: 0.1402 - val_loss: 0.1389 - val_mean_absolute_error: 0.1389
# Epoch 69/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1397 - mean_absolute_error: 0.1397 - val_loss: 0.1414 - val_mean_absolute_error: 0.1414
# Epoch 70/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1395 - mean_absolute_error: 0.1395 - val_loss: 0.1381 - val_mean_absolute_error: 0.1381
# Epoch 71/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1402 - mean_absolute_error: 0.1402 - val_loss: 0.1404 - val_mean_absolute_error: 0.1404
# Epoch 72/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1400 - mean_absolute_error: 0.1400 - val_loss: 0.1393 - val_mean_absolute_error: 0.1393
# Epoch 73/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1391 - mean_absolute_error: 0.1391 - val_loss: 0.1379 - val_mean_absolute_error: 0.1379
# Epoch 74/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1400 - mean_absolute_error: 0.1400 - val_loss: 0.1391 - val_mean_absolute_error: 0.1391
# Epoch 75/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1391 - mean_absolute_error: 0.1391 - val_loss: 0.1376 - val_mean_absolute_error: 0.1376
# Epoch 76/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1402 - mean_absolute_error: 0.1402 - val_loss: 0.1379 - val_mean_absolute_error: 0.1379
# Epoch 77/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1394 - mean_absolute_error: 0.1394 - val_loss: 0.1378 - val_mean_absolute_error: 0.1378
# Epoch 78/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1383 - mean_absolute_error: 0.1383 - val_loss: 0.1382 - val_mean_absolute_error: 0.1382
# Epoch 79/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1391 - mean_absolute_error: 0.1391 - val_loss: 0.1378 - val_mean_absolute_error: 0.1378
# Epoch 80/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1392 - mean_absolute_error: 0.1392 - val_loss: 0.1385 - val_mean_absolute_error: 0.1385
# Epoch 81/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1383 - mean_absolute_error: 0.1383 - val_loss: 0.1376 - val_mean_absolute_error: 0.1376
# Epoch 82/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1381 - mean_absolute_error: 0.1381 - val_loss: 0.1372 - val_mean_absolute_error: 0.1372
# Epoch 83/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1383 - mean_absolute_error: 0.1383 - val_loss: 0.1372 - val_mean_absolute_error: 0.1372
# Epoch 84/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1386 - mean_absolute_error: 0.1386 - val_loss: 0.1389 - val_mean_absolute_error: 0.1389
# Epoch 85/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1398 - mean_absolute_error: 0.1398 - val_loss: 0.1370 - val_mean_absolute_error: 0.1370
# Epoch 86/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1378 - mean_absolute_error: 0.1378 - val_loss: 0.1369 - val_mean_absolute_error: 0.1369
# Epoch 87/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1375 - mean_absolute_error: 0.1375 - val_loss: 0.1370 - val_mean_absolute_error: 0.1370
# Epoch 88/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1382 - mean_absolute_error: 0.1382 - val_loss: 0.1362 - val_mean_absolute_error: 0.1362
# Epoch 89/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1386 - mean_absolute_error: 0.1386 - val_loss: 0.1375 - val_mean_absolute_error: 0.1375
# Epoch 90/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1381 - mean_absolute_error: 0.1381 - val_loss: 0.1360 - val_mean_absolute_error: 0.1360
# Epoch 91/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1374 - mean_absolute_error: 0.1374 - val_loss: 0.1374 - val_mean_absolute_error: 0.1374
# Epoch 92/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1369 - mean_absolute_error: 0.1369 - val_loss: 0.1368 - val_mean_absolute_error: 0.1368
# Epoch 93/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1375 - mean_absolute_error: 0.1375 - val_loss: 0.1372 - val_mean_absolute_error: 0.1372
# Epoch 94/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1368 - mean_absolute_error: 0.1368 - val_loss: 0.1370 - val_mean_absolute_error: 0.1370
# Epoch 95/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1370 - mean_absolute_error: 0.1370 - val_loss: 0.1360 - val_mean_absolute_error: 0.1360
# Epoch 96/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1365 - mean_absolute_error: 0.1365 - val_loss: 0.1358 - val_mean_absolute_error: 0.1358
# Epoch 97/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1371 - mean_absolute_error: 0.1371 - val_loss: 0.1367 - val_mean_absolute_error: 0.1367
# Epoch 98/500
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1371 - mean_absolute_error: 0.1371 - val_loss: 0.1368 - val_mean_absolute_error: 0.1368
# Epoch 99/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1366 - mean_absolute_error: 0.1366 - val_loss: 0.1365 - val_mean_absolute_error: 0.1365
# Epoch 100/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1372 - mean_absolute_error: 0.1372 - val_loss: 0.1356 - val_mean_absolute_error: 0.1356
# Epoch 101/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1370 - mean_absolute_error: 0.1370 - val_loss: 0.1358 - val_mean_absolute_error: 0.1358
# Epoch 102/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1366 - mean_absolute_error: 0.1366 - val_loss: 0.1355 - val_mean_absolute_error: 0.1355
# Epoch 103/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1357 - mean_absolute_error: 0.1357 - val_loss: 0.1365 - val_mean_absolute_error: 0.1365
# Epoch 104/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1361 - mean_absolute_error: 0.1361 - val_loss: 0.1359 - val_mean_absolute_error: 0.1359
# Epoch 105/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1363 - mean_absolute_error: 0.1363 - val_loss: 0.1361 - val_mean_absolute_error: 0.1361
# Epoch 106/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1359 - mean_absolute_error: 0.1359 - val_loss: 0.1372 - val_mean_absolute_error: 0.1372
# Epoch 107/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1357 - mean_absolute_error: 0.1357 - val_loss: 0.1352 - val_mean_absolute_error: 0.1352
# Epoch 108/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1357 - mean_absolute_error: 0.1357 - val_loss: 0.1355 - val_mean_absolute_error: 0.1355
# Epoch 109/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1356 - mean_absolute_error: 0.1356 - val_loss: 0.1353 - val_mean_absolute_error: 0.1353
# Epoch 110/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1353 - mean_absolute_error: 0.1353 - val_loss: 0.1354 - val_mean_absolute_error: 0.1354
# Epoch 111/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1361 - mean_absolute_error: 0.1361 - val_loss: 0.1351 - val_mean_absolute_error: 0.1351
# Epoch 112/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1355 - mean_absolute_error: 0.1355 - val_loss: 0.1343 - val_mean_absolute_error: 0.1343
# Epoch 113/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1351 - mean_absolute_error: 0.1351 - val_loss: 0.1362 - val_mean_absolute_error: 0.1362
# Epoch 114/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1359 - mean_absolute_error: 0.1359 - val_loss: 0.1342 - val_mean_absolute_error: 0.1342
# Epoch 115/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1353 - mean_absolute_error: 0.1353 - val_loss: 0.1364 - val_mean_absolute_error: 0.1364
# Epoch 116/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1357 - mean_absolute_error: 0.1357 - val_loss: 0.1355 - val_mean_absolute_error: 0.1355
# Epoch 117/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1349 - mean_absolute_error: 0.1349 - val_loss: 0.1356 - val_mean_absolute_error: 0.1356
# Epoch 118/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1351 - mean_absolute_error: 0.1351 - val_loss: 0.1342 - val_mean_absolute_error: 0.1342
# Epoch 119/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1351 - mean_absolute_error: 0.1351 - val_loss: 0.1369 - val_mean_absolute_error: 0.1369
# Epoch 120/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1361 - mean_absolute_error: 0.1361 - val_loss: 0.1351 - val_mean_absolute_error: 0.1351
# Epoch 121/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1370 - mean_absolute_error: 0.1370 - val_loss: 0.1358 - val_mean_absolute_error: 0.1358
# Epoch 122/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1373 - mean_absolute_error: 0.1373 - val_loss: 0.1351 - val_mean_absolute_error: 0.1351
# Epoch 123/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1357 - mean_absolute_error: 0.1357 - val_loss: 0.1351 - val_mean_absolute_error: 0.1351
# Epoch 124/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1354 - mean_absolute_error: 0.1354 - val_loss: 0.1337 - val_mean_absolute_error: 0.1337
# Epoch 125/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1357 - mean_absolute_error: 0.1357 - val_loss: 0.1349 - val_mean_absolute_error: 0.1349
# Epoch 126/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1355 - mean_absolute_error: 0.1355 - val_loss: 0.1340 - val_mean_absolute_error: 0.1340
# Epoch 127/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1353 - mean_absolute_error: 0.1353 - val_loss: 0.1337 - val_mean_absolute_error: 0.1337
# Epoch 128/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1346 - mean_absolute_error: 0.1346 - val_loss: 0.1352 - val_mean_absolute_error: 0.1352
# Epoch 129/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1342 - mean_absolute_error: 0.1342 - val_loss: 0.1361 - val_mean_absolute_error: 0.1361
# Epoch 130/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1352 - mean_absolute_error: 0.1352 - val_loss: 0.1342 - val_mean_absolute_error: 0.1342
# Epoch 131/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1347 - mean_absolute_error: 0.1347 - val_loss: 0.1352 - val_mean_absolute_error: 0.1352
# Epoch 132/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1357 - mean_absolute_error: 0.1357 - val_loss: 0.1364 - val_mean_absolute_error: 0.1364
# Epoch 133/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1354 - mean_absolute_error: 0.1354 - val_loss: 0.1347 - val_mean_absolute_error: 0.1347
# Epoch 134/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1354 - mean_absolute_error: 0.1354 - val_loss: 0.1352 - val_mean_absolute_error: 0.1352
# Epoch 135/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1346 - mean_absolute_error: 0.1346 - val_loss: 0.1340 - val_mean_absolute_error: 0.1340
# Epoch 136/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1345 - mean_absolute_error: 0.1345 - val_loss: 0.1347 - val_mean_absolute_error: 0.1347
# Epoch 137/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1346 - mean_absolute_error: 0.1346 - val_loss: 0.1353 - val_mean_absolute_error: 0.1353
# Epoch 138/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1342 - mean_absolute_error: 0.1342 - val_loss: 0.1335 - val_mean_absolute_error: 0.1335
# Epoch 139/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1340 - mean_absolute_error: 0.1340 - val_loss: 0.1345 - val_mean_absolute_error: 0.1345
# Epoch 140/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1334 - mean_absolute_error: 0.1334 - val_loss: 0.1342 - val_mean_absolute_error: 0.1342
# Epoch 141/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1340 - mean_absolute_error: 0.1340 - val_loss: 0.1333 - val_mean_absolute_error: 0.1333
# Epoch 142/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1342 - mean_absolute_error: 0.1342 - val_loss: 0.1336 - val_mean_absolute_error: 0.1336
# Epoch 143/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1340 - mean_absolute_error: 0.1340 - val_loss: 0.1330 - val_mean_absolute_error: 0.1330
# Epoch 144/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1341 - mean_absolute_error: 0.1341 - val_loss: 0.1345 - val_mean_absolute_error: 0.1345
# Epoch 145/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1331 - mean_absolute_error: 0.1331 - val_loss: 0.1328 - val_mean_absolute_error: 0.1328
# Epoch 146/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1336 - mean_absolute_error: 0.1336 - val_loss: 0.1344 - val_mean_absolute_error: 0.1344
# Epoch 147/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1335 - mean_absolute_error: 0.1335 - val_loss: 0.1332 - val_mean_absolute_error: 0.1332
# Epoch 148/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1347 - mean_absolute_error: 0.1347 - val_loss: 0.1335 - val_mean_absolute_error: 0.1335
# Epoch 149/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1343 - mean_absolute_error: 0.1343 - val_loss: 0.1342 - val_mean_absolute_error: 0.1342
# Epoch 150/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1339 - mean_absolute_error: 0.1339 - val_loss: 0.1336 - val_mean_absolute_error: 0.1336
# Epoch 151/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1331 - mean_absolute_error: 0.1331 - val_loss: 0.1334 - val_mean_absolute_error: 0.1334
# Epoch 152/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1346 - mean_absolute_error: 0.1346 - val_loss: 0.1357 - val_mean_absolute_error: 0.1357
# Epoch 153/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1344 - mean_absolute_error: 0.1344 - val_loss: 0.1336 - val_mean_absolute_error: 0.1336
# Epoch 154/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1338 - mean_absolute_error: 0.1338 - val_loss: 0.1353 - val_mean_absolute_error: 0.1353
# Epoch 155/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1339 - mean_absolute_error: 0.1339 - val_loss: 0.1369 - val_mean_absolute_error: 0.1369
# Epoch 156/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1340 - mean_absolute_error: 0.1340 - val_loss: 0.1360 - val_mean_absolute_error: 0.1360
# Epoch 157/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1333 - mean_absolute_error: 0.1333 - val_loss: 0.1324 - val_mean_absolute_error: 0.1324
# Epoch 158/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1330 - mean_absolute_error: 0.1330 - val_loss: 0.1325 - val_mean_absolute_error: 0.1325
# Epoch 159/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1329 - mean_absolute_error: 0.1329 - val_loss: 0.1342 - val_mean_absolute_error: 0.1342
# Epoch 160/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1342 - mean_absolute_error: 0.1342 - val_loss: 0.1334 - val_mean_absolute_error: 0.1334
# Epoch 161/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1334 - mean_absolute_error: 0.1334 - val_loss: 0.1324 - val_mean_absolute_error: 0.1324
# Epoch 162/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1330 - mean_absolute_error: 0.1330 - val_loss: 0.1339 - val_mean_absolute_error: 0.1339
# Epoch 163/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1335 - mean_absolute_error: 0.1335 - val_loss: 0.1330 - val_mean_absolute_error: 0.1330
# Epoch 164/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1335 - mean_absolute_error: 0.1335 - val_loss: 0.1324 - val_mean_absolute_error: 0.1324
# Epoch 165/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1339 - mean_absolute_error: 0.1339 - val_loss: 0.1325 - val_mean_absolute_error: 0.1325
# Epoch 166/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1331 - mean_absolute_error: 0.1331 - val_loss: 0.1334 - val_mean_absolute_error: 0.1334
# Epoch 167/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1332 - mean_absolute_error: 0.1332 - val_loss: 0.1328 - val_mean_absolute_error: 0.1328
# Epoch 168/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1328 - mean_absolute_error: 0.1328 - val_loss: 0.1338 - val_mean_absolute_error: 0.1338
# Epoch 169/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1329 - mean_absolute_error: 0.1329 - val_loss: 0.1340 - val_mean_absolute_error: 0.1340
# Epoch 170/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1333 - mean_absolute_error: 0.1333 - val_loss: 0.1355 - val_mean_absolute_error: 0.1355
# Epoch 171/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1340 - mean_absolute_error: 0.1340 - val_loss: 0.1329 - val_mean_absolute_error: 0.1329
# Epoch 172/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1325 - mean_absolute_error: 0.1325 - val_loss: 0.1327 - val_mean_absolute_error: 0.1327
# Epoch 173/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1335 - mean_absolute_error: 0.1335 - val_loss: 0.1329 - val_mean_absolute_error: 0.1329
# Epoch 174/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1334 - mean_absolute_error: 0.1334 - val_loss: 0.1343 - val_mean_absolute_error: 0.1343
# Epoch 175/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1328 - mean_absolute_error: 0.1328 - val_loss: 0.1336 - val_mean_absolute_error: 0.1336
# Epoch 176/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1326 - mean_absolute_error: 0.1326 - val_loss: 0.1327 - val_mean_absolute_error: 0.1327
# Epoch 177/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1334 - mean_absolute_error: 0.1334 - val_loss: 0.1324 - val_mean_absolute_error: 0.1324
# Epoch 178/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1315 - mean_absolute_error: 0.1315 - val_loss: 0.1328 - val_mean_absolute_error: 0.1328
# Epoch 179/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1318 - mean_absolute_error: 0.1318 - val_loss: 0.1323 - val_mean_absolute_error: 0.1323
# Epoch 180/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1317 - mean_absolute_error: 0.1317 - val_loss: 0.1322 - val_mean_absolute_error: 0.1322
# Epoch 181/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1316 - mean_absolute_error: 0.1316 - val_loss: 0.1325 - val_mean_absolute_error: 0.1325
# Epoch 182/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1314 - mean_absolute_error: 0.1314 - val_loss: 0.1323 - val_mean_absolute_error: 0.1323
# Epoch 183/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1315 - mean_absolute_error: 0.1315 - val_loss: 0.1322 - val_mean_absolute_error: 0.1322
# Epoch 184/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1316 - mean_absolute_error: 0.1316 - val_loss: 0.1322 - val_mean_absolute_error: 0.1322
# Epoch 185/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1316 - mean_absolute_error: 0.1316 - val_loss: 0.1328 - val_mean_absolute_error: 0.1328
# Epoch 186/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1319 - mean_absolute_error: 0.1319 - val_loss: 0.1328 - val_mean_absolute_error: 0.1328
# Epoch 187/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1316 - mean_absolute_error: 0.1316 - val_loss: 0.1335 - val_mean_absolute_error: 0.1335
# Epoch 188/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1312 - mean_absolute_error: 0.1312 - val_loss: 0.1320 - val_mean_absolute_error: 0.1320
# Epoch 189/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1314 - mean_absolute_error: 0.1314 - val_loss: 0.1327 - val_mean_absolute_error: 0.1327
# Epoch 190/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1314 - mean_absolute_error: 0.1314 - val_loss: 0.1321 - val_mean_absolute_error: 0.1321
# Epoch 191/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1321 - mean_absolute_error: 0.1321 - val_loss: 0.1324 - val_mean_absolute_error: 0.1324
# Epoch 192/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1315 - mean_absolute_error: 0.1315 - val_loss: 0.1327 - val_mean_absolute_error: 0.1327
# Epoch 193/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1311 - mean_absolute_error: 0.1311 - val_loss: 0.1320 - val_mean_absolute_error: 0.1320
# Epoch 194/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1314 - mean_absolute_error: 0.1314 - val_loss: 0.1330 - val_mean_absolute_error: 0.1330
# Epoch 195/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1310 - mean_absolute_error: 0.1310 - val_loss: 0.1321 - val_mean_absolute_error: 0.1321
# Epoch 196/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1314 - mean_absolute_error: 0.1314 - val_loss: 0.1323 - val_mean_absolute_error: 0.1323
# Epoch 197/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1314 - mean_absolute_error: 0.1314 - val_loss: 0.1332 - val_mean_absolute_error: 0.1332
# Epoch 198/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1312 - mean_absolute_error: 0.1312 - val_loss: 0.1321 - val_mean_absolute_error: 0.1321
# Epoch 199/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1311 - mean_absolute_error: 0.1311 - val_loss: 0.1326 - val_mean_absolute_error: 0.1326
# Epoch 200/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1313 - mean_absolute_error: 0.1313 - val_loss: 0.1323 - val_mean_absolute_error: 0.1323
# Epoch 201/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1311 - mean_absolute_error: 0.1311 - val_loss: 0.1326 - val_mean_absolute_error: 0.1326
# Epoch 202/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1314 - mean_absolute_error: 0.1314 - val_loss: 0.1316 - val_mean_absolute_error: 0.1316
# Epoch 203/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1318 - mean_absolute_error: 0.1318 - val_loss: 0.1323 - val_mean_absolute_error: 0.1323
# Epoch 204/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1312 - mean_absolute_error: 0.1312 - val_loss: 0.1327 - val_mean_absolute_error: 0.1327
# Epoch 205/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1308 - mean_absolute_error: 0.1308 - val_loss: 0.1318 - val_mean_absolute_error: 0.1318
# Epoch 206/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1312 - mean_absolute_error: 0.1312 - val_loss: 0.1337 - val_mean_absolute_error: 0.1337
# Epoch 207/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1309 - mean_absolute_error: 0.1309 - val_loss: 0.1320 - val_mean_absolute_error: 0.1320
# Epoch 208/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1313 - mean_absolute_error: 0.1313 - val_loss: 0.1329 - val_mean_absolute_error: 0.1329
# Epoch 209/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1313 - mean_absolute_error: 0.1313 - val_loss: 0.1328 - val_mean_absolute_error: 0.1328
# Epoch 210/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1308 - mean_absolute_error: 0.1308 - val_loss: 0.1323 - val_mean_absolute_error: 0.1323
# Epoch 211/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1308 - mean_absolute_error: 0.1308 - val_loss: 0.1337 - val_mean_absolute_error: 0.1337
# Epoch 212/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1315 - mean_absolute_error: 0.1315 - val_loss: 0.1330 - val_mean_absolute_error: 0.1330
# Epoch 213/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1312 - mean_absolute_error: 0.1312 - val_loss: 0.1321 - val_mean_absolute_error: 0.1321
# Epoch 214/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1306 - mean_absolute_error: 0.1306 - val_loss: 0.1321 - val_mean_absolute_error: 0.1321
# Epoch 215/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1310 - mean_absolute_error: 0.1310 - val_loss: 0.1320 - val_mean_absolute_error: 0.1320
# Epoch 216/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1307 - mean_absolute_error: 0.1307 - val_loss: 0.1323 - val_mean_absolute_error: 0.1323
# Epoch 217/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1307 - mean_absolute_error: 0.1307 - val_loss: 0.1322 - val_mean_absolute_error: 0.1322
# Epoch 218/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1305 - mean_absolute_error: 0.1305 - val_loss: 0.1324 - val_mean_absolute_error: 0.1324
# Epoch 219/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1305 - mean_absolute_error: 0.1305 - val_loss: 0.1324 - val_mean_absolute_error: 0.1324
# Epoch 220/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1313 - mean_absolute_error: 0.1313 - val_loss: 0.1324 - val_mean_absolute_error: 0.1324
# Epoch 221/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1307 - mean_absolute_error: 0.1307 - val_loss: 0.1323 - val_mean_absolute_error: 0.1323
# Epoch 222/500
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1309 - mean_absolute_error: 0.1309 - val_loss: 0.1322 - val_mean_absolute_error: 0.1322
# Epoch 223/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1302 - mean_absolute_error: 0.1302 - val_loss: 0.1321 - val_mean_absolute_error: 0.1321
# Epoch 224/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1301 - mean_absolute_error: 0.1301 - val_loss: 0.1321 - val_mean_absolute_error: 0.1321
# Epoch 225/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1303 - mean_absolute_error: 0.1303 - val_loss: 0.1321 - val_mean_absolute_error: 0.1321
# Epoch 226/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1301 - mean_absolute_error: 0.1301 - val_loss: 0.1318 - val_mean_absolute_error: 0.1318
# Epoch 227/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1301 - mean_absolute_error: 0.1301 - val_loss: 0.1322 - val_mean_absolute_error: 0.1322
# Epoch 228/500
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1299 - mean_absolute_error: 0.1299 - val_loss: 0.1321 - val_mean_absolute_error: 0.1321
# Epoch 229/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1299 - mean_absolute_error: 0.1299 - val_loss: 0.1320 - val_mean_absolute_error: 0.1320
# Epoch 230/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1300 - mean_absolute_error: 0.1300 - val_loss: 0.1317 - val_mean_absolute_error: 0.1317
# Epoch 231/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1301 - mean_absolute_error: 0.1301 - val_loss: 0.1320 - val_mean_absolute_error: 0.1320
# Epoch 232/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1299 - mean_absolute_error: 0.1299 - val_loss: 0.1320 - val_mean_absolute_error: 0.1320
# Epoch 233/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1303 - mean_absolute_error: 0.1303 - val_loss: 0.1323 - val_mean_absolute_error: 0.1323
# Epoch 234/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1302 - mean_absolute_error: 0.1302 - val_loss: 0.1323 - val_mean_absolute_error: 0.1323
# Epoch 235/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1300 - mean_absolute_error: 0.1300 - val_loss: 0.1318 - val_mean_absolute_error: 0.1318
# Epoch 236/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1300 - mean_absolute_error: 0.1300 - val_loss: 0.1317 - val_mean_absolute_error: 0.1317
# Epoch 237/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1301 - mean_absolute_error: 0.1301 - val_loss: 0.1321 - val_mean_absolute_error: 0.1321
# Epoch 238/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1300 - mean_absolute_error: 0.1300 - val_loss: 0.1318 - val_mean_absolute_error: 0.1318
# Epoch 239/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1298 - mean_absolute_error: 0.1298 - val_loss: 0.1317 - val_mean_absolute_error: 0.1317
# Epoch 240/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1302 - mean_absolute_error: 0.1302 - val_loss: 0.1318 - val_mean_absolute_error: 0.1318
# Epoch 241/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1299 - mean_absolute_error: 0.1299 - val_loss: 0.1319 - val_mean_absolute_error: 0.1319
# Epoch 242/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1298 - mean_absolute_error: 0.1298 - val_loss: 0.1322 - val_mean_absolute_error: 0.1322
# Epoch 243/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1297 - mean_absolute_error: 0.1297 - val_loss: 0.1319 - val_mean_absolute_error: 0.1319
# Epoch 244/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1297 - mean_absolute_error: 0.1297 - val_loss: 0.1320 - val_mean_absolute_error: 0.1320
# Epoch 245/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1298 - mean_absolute_error: 0.1298 - val_loss: 0.1320 - val_mean_absolute_error: 0.1320
# Epoch 246/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1297 - mean_absolute_error: 0.1297 - val_loss: 0.1318 - val_mean_absolute_error: 0.1318
# Epoch 247/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1297 - mean_absolute_error: 0.1297 - val_loss: 0.1319 - val_mean_absolute_error: 0.1319
# Epoch 248/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1297 - mean_absolute_error: 0.1297 - val_loss: 0.1318 - val_mean_absolute_error: 0.1318
# Epoch 249/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1296 - mean_absolute_error: 0.1296 - val_loss: 0.1320 - val_mean_absolute_error: 0.1320
# Epoch 250/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1297 - mean_absolute_error: 0.1297 - val_loss: 0.1319 - val_mean_absolute_error: 0.1319
# Epoch 251/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1295 - mean_absolute_error: 0.1295 - val_loss: 0.1319 - val_mean_absolute_error: 0.1319
# Epoch 252/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1297 - mean_absolute_error: 0.1297 - val_loss: 0.1319 - val_mean_absolute_error: 0.1319
# Epoch 00252: early stopping

# %%
model = keras.models.load_model("best_model.h5")

test_loss, test_acc = model.evaluate([x_test,d_test,], y_test)

print("Test error", test_acc)
print("Test loss", test_loss)
# Out:
# 1/1 [==============================] - 0s 80ms/step - loss: 0.2962 - mean_absolute_error: 0.2962
# Test error 0.29624488949775696
# Test loss 0.29624488949775696

# %%
mua = np.zeros((x_train.shape[0],))
# mus = np.zeros((x_train.shape[0],))
d = np.zeros((x_train.shape[0],))
miu = np.zeros((x_train.shape[0],1))

miu = model.predict([x_train,d_train])
mua = miu[:,0]
mus = miu[:,1]
d = d_train[:,0,0]

# %%
err = np.zeros((x_train.shape[0],2))

err[:,0] = y_train[:,0]-mua
err[:,1] = y_train[:,1]-mus

# print(mua[k],mus[k],d[k])
# print(y_train[k])

# %%
k=np.random.randint(0,x_train.shape[0],1)[0]
print(mua[k],mus[k])
print(y_train[k])
# Out:
# 0.422437 0.60051316
# [0.4455009 0.8953366]

# %%
plt.plot(d,err[:,0])
plt.plot(d,err[:,1])
plt.show()

# %%
# print(mua,mus,d)
# print(an2[i,1],an2[i,2],an2[i,0])
# plt.plot(abs(an1[:,1]-mua))
# plt.plot(abs(an1[:,2]-mus))
plt.hist(err[:,0], bins=40,  facecolor="blue", edgecolor="black", alpha=0.7)
plt.hist(err[:,1], bins=40,  facecolor="green", edgecolor="black", alpha=0.7)
# plt.hist(abs(y_train[:,1]-mus), bins=40,  facecolor="green", edgecolor="black", alpha=0.7)
plt.show()

# %%
metric = "mean_absolute_error"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()
