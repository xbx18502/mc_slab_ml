# %%
# 同时计算mua和mus,只输入波峰信息
import os  
import numpy as np
import struct
import matplotlib.pyplot as plt
import gc
import random
import math
from tensorflow import keras
import sklearn
# from scipy.interpolate import CubicSpline
from scipy.signal import find_peaks
from scipy.interpolate import interp1d

# %%
with open("C:\\Users\\Administrator\\source\\data\\dataset_test.bin", "rb") as file0:
    data1 = file0.read(4)
    NM1 = struct.unpack("i", data1)[0]
    sig2 = np.zeros((NM1,200),dtype = np.float32)
    an2 = np.zeros((NM1,4),dtype = np.float32)
    for i in range(NM1):
        for k in range(4):
            data1 = file0.read(4)
            an2[i,k] = struct.unpack("f", data1)[0]
        for k in range(200):
            data1 = file0.read(4)
            sig2[i,k] = struct.unpack("f", data1)[0]  
    # data1 = file0.read(len('end\0'))
    # end = struct.unpack("4s", data1)[0]

# %%
with open("C:\\Users\\Administrator\\source\\data\\dataset.bin", "rb") as file0:
    data1 = file0.read(4)
    NM1 = struct.unpack("i", data1)[0]
    sig1 = np.zeros((NM1,200),dtype = np.float32)
    an1 = np.zeros((NM1,4),dtype = np.float32)
    for i in range(NM1):
        for k in range(4):
            data1 = file0.read(4)
            an1[i,k] = struct.unpack("f", data1)[0]
        for k in range(200):
            data1 = file0.read(4)
            sig1[i,k] = struct.unpack("f", data1)[0]  
    # data1 = file0.read(len('end\0'))
    # end = struct.unpack("4s", data1)[0]

# %%
plt.axes(yscale = "log") 
for n in range(sig1.shape[0]):
    plt.plot(sig1[n])
plt.show()
print(NM1)
print(an2[-1])
# Out:
# 1262
# [1.24224685e-02 9.14926987e+01 1.54261023e+03 8.50000024e-01]

# %%
# def labeling(y,N):
#     ##############
#     a,b = y.shape
#     min0 = np.min(y,0)
#     max0 = np.max(y,0)
#     step = (max0-min0)/N
#     y2 = np.zeros((a,b,N))
    
#     # kernel = np.array([1]) 
#     # kernel = kernel/np.sum(kernel)
    
#     for i in range(a):
#         for j in range(b):
#             if(step[j]!=0):
#                 idx = (y[i,j]-min0[j])/step[j]-1
#                 y2[i,j,int(idx)] = 1
#             else:
#                 y2[i,j,0] = 1
#             # y2[i,j] = np.convolve(y2[i,j],kernel,mode='same')
            
#     return y2

# %%
xsig = sig1[0]
peaks, _ = find_peaks(xsig, height=0)
plt.plot(xsig)
plt.plot(peaks, xsig[peaks], "x")
plt.plot(np.zeros_like(xsig), "--", color="gray")
plt.show()

x = np.zeros((peaks.shape[0]+2,))
y = np.zeros((peaks.shape[0]+2,))
x[1:-1] = peaks
y[1:-1] = xsig[peaks]
x[-1] = sig1.shape[1]
plt.plot(x,y)
plt.show()

f2 = interp1d(x, y, kind='linear')
N = 200
xnew = np.linspace(0, N,num=N)
ynew = f2(xnew)

# plt.axes(yscale = "log") 
plt.plot(ynew)
plt.show()

# %%
def smooth_peak(xsig):
    peaks, _ = find_peaks(xsig, height=0)
    # plt.plot(xsig)
    # plt.plot(peaks, xsig[peaks], "x")
    # plt.plot(np.zeros_like(xsig), "--", color="gray")
    # plt.show()
    if(peaks.shape[0]!=0):
        x = np.zeros((peaks.shape[0]+3,))
        y = np.zeros((peaks.shape[0]+3,))
        x[1:-2] = peaks
        y[1:-2] = xsig[peaks]
        x[-1] = sig1.shape[1]
        y[-1] = 0
        x[-2] = peaks[-1]+5
        y[-2] = 0
        # plt.plot(x,y)
        # plt.show()

        f2 = interp1d(x, y, kind='linear')
        N = xsig.shape[0]
        xnew = np.linspace(0, N,num=N)
        ynew = f2(xnew)
    
    else:
        ynew = np.zeros((xsig.shape[0],))

    return ynew
#     # plt.axes(yscale = "log") 
#     plt.plot(ynew)
#     plt.show()

# %%
msig1 = np.zeros((sig1.shape[0],sig1.shape[1]))
an3 = np.zeros((an1.shape))
i_invalid = 0
flag = 0
for i in range(sig1.shape[0]):
    ynew = smooth_peak(sig1[i])
    if(np.all(ynew == 0)):
        i_invalid = i_invalid+1
    else:
        msig1[flag] = ynew
        an3[flag] = an1[i]
        flag = flag+1
msig1 = msig1[0:msig1.shape[0]-i_invalid,:]  
an3 = an3[0:an3.shape[0]-i_invalid,:]

i_invalid = 0
flag = 0
msig2 = np.zeros((sig2.shape[0],sig2.shape[1]))
an4 = np.zeros((an2.shape))
for i in range(sig2.shape[0]):
    ynew = smooth_peak(sig2[i])
    if(np.all(ynew == 0)):
        i_invalid = i_invalid+1
    
    else:
        msig2[flag] = ynew
        an4[flag] = an2[i]
        flag = flag+1
msig2 = msig2[0:msig2.shape[0]-i_invalid,:] 
an4 = an4[0:an4.shape[0]-i_invalid,:]

# %%
plt.axes(yscale = "log") 
for n in range(msig1.shape[0]): #msig1.shape[0]
    plt.plot(msig1[n])
plt.show()

# %%
# x_train = msig1
y_train = an3
# x_test = msig2
y_test = an4

x_train = np.zeros((msig1.shape[0],3))
x_test = np.zeros((msig2.shape[0],3))

x_train[:,0] = np.argmax(msig1,1)/200
x_train[:,1] = np.diagonal(msig1[:,np.argmax(msig1,1)])/1000 # t of peak, height of peak, thickness(d)
x_train[:,2] = an3[:,0]/20e-3
x_train = np.log10(x_train)+7

x_test[:,0] = np.argmax(msig2,1)/200
x_test[:,1] = np.diagonal(msig2[:,np.argmax(msig2,1)])/1000
x_test[:,2] = an4[:,0]/20e-3
x_test = np.log10(x_test)+7

x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))
# d_train = np.reshape(y_train[:,0],(y_train[:,0].shape[0],1,1)) # add thickness of sample into input data
# d_test = np.reshape(y_test[:,0],(y_test[:,0].shape[0],1,1))

# x_train = np.concatenate((d_train,x_train),axis = 1) 
# x_test = np.concatenate((d_test,x_test),axis = 1)
y_train[:,1] = y_train[:,1]/1e2
y_test[:,1] = y_test[:,1]/1e2
y_train[:,2] = y_train[:,2]/200e2
y_test[:,2] = y_test[:,2]/200e2
y_train = y_train[:,1:3]
y_test = y_test[:,1:3]
# y_train = labeling(y_train,num_labels)[:,1,:] # select to predict what : 0:thickness 1:mua 2: mus
# y_test = labeling(y_test,num_labels)[:,1,:]
print('x_train.shape = '+str(x_train.shape)) 
print('y_train.shape = '+str(y_train.shape))
# Out:
# x_train.shape = (1258, 3, 1)
# y_train.shape = (1258, 2)

# %%
for n in range(x_train.shape[0]):
    plt.plot(x_train[n,:])
plt.show()

# %%
# num_classes = y_train.shape[1]
########################################
# input_shape = (1,5,1)
# x = np.arange(np.prod(input_shape)).reshape(input_shape)      # test cropping#
# print(x)
# y = keras.layers.Cropping1D(cropping=(0,4))(x)
# z = keras.layers.Cropping1D(cropping=(1,0))(x)
# print(y)
# print(z)

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)
    
#     d_1 = keras.layers.Cropping1D(cropping=(0,2))(input_layer)
#     sig = keras.layers.Cropping1D(cropping=(1,0))(input_layer)
    
#     conv1 = keras.layers.Conv1D(filters=16, kernel_size=3, padding="same")(sig)
#     conv1 = keras.layers.BatchNormalization()(conv1)
#     conv1 = keras.layers.ReLU()(conv1)

#     conv2 = keras.layers.Conv1D(filters=16, kernel_size=3, padding="same")(conv1)
#     conv2 = keras.layers.BatchNormalization()(conv2)
#     conv2 = keras.layers.ReLU()(conv2)

#     conv3 = keras.layers.Conv1D(filters=16, kernel_size=3, padding="same")(conv2)
#     conv3 = keras.layers.BatchNormalization()(conv3)
#     conv3 = keras.layers.ReLU()(conv3)

    # gap = keras.layers.GlobalAveragePooling1D()(conv3)
    gap = keras.layers.Reshape((input_shape[0],))(input_layer)
    
    gap = keras.layers.Dense(8, activation='relu')(gap)
    gap = keras.layers.BatchNormalization()(gap)
    # gap = keras.layers.Dropout(0.5)(gap)
    gap = keras.layers.Dense(8, activation='relu')(gap)
    gap = keras.layers.BatchNormalization()(gap)
    # gap = keras.layers.Dropout(0.5)(gap)
    
    # d_1 = keras.layers.Dense(16, activation='relu')(d_1)
    # d_1 = keras.layers.Dense(16, activation='relu')(d_1)
    # gap = keras.layers.Reshape((16,))(gap)
    
    
    
    # merged = keras.layers.Concatenate()([d_1, gap])
    # merged = keras.layers.Dense(8, activation='relu')(merged)
    
    output_layer = keras.layers.Dense(2, activation="linear")(gap)  
    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])
keras.utils.plot_model(model, show_shapes=True)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %%
epochs = 500
batch_size = 32
#####################################################
index = [i for i in range(x_train.shape[0])]  
np.random.shuffle(index) 
x_train = x_train[index]
y_train = y_train[index]
####################################################
callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    # loss="mean_squared_error",
    loss="mean_absolute_error",
    metrics=["MeanAbsoluteError"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.4,
    verbose=1,
)
# Out:
# Epoch 1/500
# 24/24 [==============================] - 1s 14ms/step - loss: 0.8276 - mean_absolute_error: 0.8276 - val_loss: 3.6105 - val_mean_absolute_error: 3.6105
# Epoch 2/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.5944 - mean_absolute_error: 0.5944 - val_loss: 3.1794 - val_mean_absolute_error: 3.1794
# Epoch 3/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.4551 - mean_absolute_error: 0.4551 - val_loss: 2.7802 - val_mean_absolute_error: 2.7802
# Epoch 4/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.3764 - mean_absolute_error: 0.3764 - val_loss: 2.4485 - val_mean_absolute_error: 2.4485
# Epoch 5/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.2977 - mean_absolute_error: 0.2977 - val_loss: 2.1267 - val_mean_absolute_error: 2.1267
# Epoch 6/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.2470 - mean_absolute_error: 0.2470 - val_loss: 1.8324 - val_mean_absolute_error: 1.8324
# Epoch 7/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.2219 - mean_absolute_error: 0.2219 - val_loss: 1.5799 - val_mean_absolute_error: 1.5799
# Epoch 8/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1978 - mean_absolute_error: 0.1978 - val_loss: 1.3639 - val_mean_absolute_error: 1.3639
# Epoch 9/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1995 - mean_absolute_error: 0.1995 - val_loss: 1.1770 - val_mean_absolute_error: 1.1770
# Epoch 10/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1942 - mean_absolute_error: 0.1942 - val_loss: 1.0386 - val_mean_absolute_error: 1.0386
# Epoch 11/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1849 - mean_absolute_error: 0.1849 - val_loss: 0.9023 - val_mean_absolute_error: 0.9023
# Epoch 12/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1698 - mean_absolute_error: 0.1698 - val_loss: 0.7671 - val_mean_absolute_error: 0.7671
# Epoch 13/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1690 - mean_absolute_error: 0.1690 - val_loss: 0.6721 - val_mean_absolute_error: 0.6721
# Epoch 14/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1670 - mean_absolute_error: 0.1670 - val_loss: 0.6439 - val_mean_absolute_error: 0.6439
# Epoch 15/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1639 - mean_absolute_error: 0.1639 - val_loss: 0.5823 - val_mean_absolute_error: 0.5823
# Epoch 16/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1665 - mean_absolute_error: 0.1665 - val_loss: 0.4948 - val_mean_absolute_error: 0.4948
# Epoch 17/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1634 - mean_absolute_error: 0.1634 - val_loss: 0.4578 - val_mean_absolute_error: 0.4578
# Epoch 18/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1630 - mean_absolute_error: 0.1630 - val_loss: 0.4045 - val_mean_absolute_error: 0.4045
# Epoch 19/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1624 - mean_absolute_error: 0.1624 - val_loss: 0.3458 - val_mean_absolute_error: 0.3458
# Epoch 20/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1623 - mean_absolute_error: 0.1623 - val_loss: 0.3115 - val_mean_absolute_error: 0.3115
# Epoch 21/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1592 - mean_absolute_error: 0.1592 - val_loss: 0.2861 - val_mean_absolute_error: 0.2861
# Epoch 22/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1588 - mean_absolute_error: 0.1588 - val_loss: 0.2386 - val_mean_absolute_error: 0.2386
# Epoch 23/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1637 - mean_absolute_error: 0.1637 - val_loss: 0.1856 - val_mean_absolute_error: 0.1856
# Epoch 24/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1637 - mean_absolute_error: 0.1637 - val_loss: 0.2385 - val_mean_absolute_error: 0.2385
# Epoch 25/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1621 - mean_absolute_error: 0.1621 - val_loss: 0.2396 - val_mean_absolute_error: 0.2396
# Epoch 26/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1655 - mean_absolute_error: 0.1655 - val_loss: 0.2614 - val_mean_absolute_error: 0.2614
# Epoch 27/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1613 - mean_absolute_error: 0.1613 - val_loss: 0.2095 - val_mean_absolute_error: 0.2095
# Epoch 28/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1591 - mean_absolute_error: 0.1591 - val_loss: 0.2157 - val_mean_absolute_error: 0.2157
# Epoch 29/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1579 - mean_absolute_error: 0.1579 - val_loss: 0.2308 - val_mean_absolute_error: 0.2308
# Epoch 30/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1601 - mean_absolute_error: 0.1601 - val_loss: 0.2283 - val_mean_absolute_error: 0.2283
# Epoch 31/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1586 - mean_absolute_error: 0.1586 - val_loss: 0.2134 - val_mean_absolute_error: 0.2134
# Epoch 32/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1603 - mean_absolute_error: 0.1603 - val_loss: 0.2139 - val_mean_absolute_error: 0.2139
# Epoch 33/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1537 - mean_absolute_error: 0.1537 - val_loss: 0.2081 - val_mean_absolute_error: 0.2081
# Epoch 34/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1574 - mean_absolute_error: 0.1574 - val_loss: 0.1601 - val_mean_absolute_error: 0.1601
# Epoch 35/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1556 - mean_absolute_error: 0.1556 - val_loss: 0.1613 - val_mean_absolute_error: 0.1613
# Epoch 36/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1589 - mean_absolute_error: 0.1589 - val_loss: 0.1835 - val_mean_absolute_error: 0.1835
# Epoch 37/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1555 - mean_absolute_error: 0.1555 - val_loss: 0.1962 - val_mean_absolute_error: 0.1962
# Epoch 38/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1573 - mean_absolute_error: 0.1573 - val_loss: 0.1945 - val_mean_absolute_error: 0.1945
# Epoch 39/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1572 - mean_absolute_error: 0.1572 - val_loss: 0.2212 - val_mean_absolute_error: 0.2212
# Epoch 40/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1559 - mean_absolute_error: 0.1559 - val_loss: 0.1914 - val_mean_absolute_error: 0.1914
# Epoch 41/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1545 - mean_absolute_error: 0.1545 - val_loss: 0.1683 - val_mean_absolute_error: 0.1683
# Epoch 42/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1554 - mean_absolute_error: 0.1554 - val_loss: 0.2212 - val_mean_absolute_error: 0.2212
# Epoch 43/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1563 - mean_absolute_error: 0.1563 - val_loss: 0.2188 - val_mean_absolute_error: 0.2188
# Epoch 44/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1524 - mean_absolute_error: 0.1524 - val_loss: 0.1732 - val_mean_absolute_error: 0.1732
# Epoch 45/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1538 - mean_absolute_error: 0.1538 - val_loss: 0.2071 - val_mean_absolute_error: 0.2071
# Epoch 46/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1566 - mean_absolute_error: 0.1566 - val_loss: 0.2206 - val_mean_absolute_error: 0.2206
# Epoch 47/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1509 - mean_absolute_error: 0.1509 - val_loss: 0.1851 - val_mean_absolute_error: 0.1851
# Epoch 48/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1561 - mean_absolute_error: 0.1561 - val_loss: 0.2193 - val_mean_absolute_error: 0.2193
# Epoch 49/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1544 - mean_absolute_error: 0.1544 - val_loss: 0.1887 - val_mean_absolute_error: 0.1887
# Epoch 50/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1570 - mean_absolute_error: 0.1570 - val_loss: 0.1731 - val_mean_absolute_error: 0.1731
# Epoch 51/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1536 - mean_absolute_error: 0.1536 - val_loss: 0.1695 - val_mean_absolute_error: 0.1695
# Epoch 52/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1563 - mean_absolute_error: 0.1563 - val_loss: 0.1479 - val_mean_absolute_error: 0.1479
# Epoch 53/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1542 - mean_absolute_error: 0.1542 - val_loss: 0.1740 - val_mean_absolute_error: 0.1740
# Epoch 54/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1594 - mean_absolute_error: 0.1594 - val_loss: 0.2008 - val_mean_absolute_error: 0.2008
# Epoch 55/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1553 - mean_absolute_error: 0.1553 - val_loss: 0.1717 - val_mean_absolute_error: 0.1717
# Epoch 56/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1540 - mean_absolute_error: 0.1540 - val_loss: 0.1480 - val_mean_absolute_error: 0.1480
# Epoch 57/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1580 - mean_absolute_error: 0.1580 - val_loss: 0.1479 - val_mean_absolute_error: 0.1479
# Epoch 58/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1546 - mean_absolute_error: 0.1546 - val_loss: 0.1495 - val_mean_absolute_error: 0.1495
# Epoch 59/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1558 - mean_absolute_error: 0.1558 - val_loss: 0.1628 - val_mean_absolute_error: 0.1628
# Epoch 60/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1576 - mean_absolute_error: 0.1576 - val_loss: 0.1542 - val_mean_absolute_error: 0.1542
# Epoch 61/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1569 - mean_absolute_error: 0.1569 - val_loss: 0.1542 - val_mean_absolute_error: 0.1542
# Epoch 62/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1523 - mean_absolute_error: 0.1523 - val_loss: 0.1534 - val_mean_absolute_error: 0.1534
# Epoch 63/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1567 - mean_absolute_error: 0.1567 - val_loss: 0.1769 - val_mean_absolute_error: 0.1769
# Epoch 64/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1550 - mean_absolute_error: 0.1550 - val_loss: 0.1618 - val_mean_absolute_error: 0.1618
# Epoch 65/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1540 - mean_absolute_error: 0.1540 - val_loss: 0.1843 - val_mean_absolute_error: 0.1843
# Epoch 66/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1537 - mean_absolute_error: 0.1537 - val_loss: 0.1695 - val_mean_absolute_error: 0.1695
# Epoch 67/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1524 - mean_absolute_error: 0.1524 - val_loss: 0.1467 - val_mean_absolute_error: 0.1467
# Epoch 68/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1589 - mean_absolute_error: 0.1589 - val_loss: 0.1500 - val_mean_absolute_error: 0.1500
# Epoch 69/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1557 - mean_absolute_error: 0.1557 - val_loss: 0.1611 - val_mean_absolute_error: 0.1611
# Epoch 70/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1536 - mean_absolute_error: 0.1536 - val_loss: 0.1577 - val_mean_absolute_error: 0.1577
# Epoch 71/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1512 - mean_absolute_error: 0.1512 - val_loss: 0.1726 - val_mean_absolute_error: 0.1726
# Epoch 72/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1502 - mean_absolute_error: 0.1502 - val_loss: 0.1702 - val_mean_absolute_error: 0.1702
# Epoch 73/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1522 - mean_absolute_error: 0.1522 - val_loss: 0.1445 - val_mean_absolute_error: 0.1445
# Epoch 74/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1576 - mean_absolute_error: 0.1576 - val_loss: 0.1770 - val_mean_absolute_error: 0.1770
# Epoch 75/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1570 - mean_absolute_error: 0.1570 - val_loss: 0.1831 - val_mean_absolute_error: 0.1831
# Epoch 76/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1542 - mean_absolute_error: 0.1542 - val_loss: 0.1654 - val_mean_absolute_error: 0.1654
# Epoch 77/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1562 - mean_absolute_error: 0.1562 - val_loss: 0.1492 - val_mean_absolute_error: 0.1492
# Epoch 78/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1518 - mean_absolute_error: 0.1518 - val_loss: 0.1692 - val_mean_absolute_error: 0.1692
# Epoch 79/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1540 - mean_absolute_error: 0.1540 - val_loss: 0.1571 - val_mean_absolute_error: 0.1571
# Epoch 80/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1547 - mean_absolute_error: 0.1547 - val_loss: 0.1685 - val_mean_absolute_error: 0.1685
# Epoch 81/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1531 - mean_absolute_error: 0.1531 - val_loss: 0.1652 - val_mean_absolute_error: 0.1652
# Epoch 82/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1526 - mean_absolute_error: 0.1526 - val_loss: 0.1542 - val_mean_absolute_error: 0.1542
# Epoch 83/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1569 - mean_absolute_error: 0.1569 - val_loss: 0.1786 - val_mean_absolute_error: 0.1786
# Epoch 84/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1486 - mean_absolute_error: 0.1486 - val_loss: 0.1736 - val_mean_absolute_error: 0.1736
# Epoch 85/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1542 - mean_absolute_error: 0.1542 - val_loss: 0.1738 - val_mean_absolute_error: 0.1738
# Epoch 86/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1513 - mean_absolute_error: 0.1513 - val_loss: 0.1477 - val_mean_absolute_error: 0.1477
# Epoch 87/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1517 - mean_absolute_error: 0.1517 - val_loss: 0.1447 - val_mean_absolute_error: 0.1447
# Epoch 88/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1518 - mean_absolute_error: 0.1518 - val_loss: 0.1493 - val_mean_absolute_error: 0.1493
# Epoch 89/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1570 - mean_absolute_error: 0.1570 - val_loss: 0.1505 - val_mean_absolute_error: 0.1505
# Epoch 90/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1559 - mean_absolute_error: 0.1559 - val_loss: 0.1590 - val_mean_absolute_error: 0.1590
# Epoch 91/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1554 - mean_absolute_error: 0.1554 - val_loss: 0.1531 - val_mean_absolute_error: 0.1531
# Epoch 92/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1518 - mean_absolute_error: 0.1518 - val_loss: 0.1474 - val_mean_absolute_error: 0.1474
# Epoch 93/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1570 - mean_absolute_error: 0.1570 - val_loss: 0.1421 - val_mean_absolute_error: 0.1421
# Epoch 94/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1589 - mean_absolute_error: 0.1589 - val_loss: 0.1434 - val_mean_absolute_error: 0.1434
# Epoch 95/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1507 - mean_absolute_error: 0.1507 - val_loss: 0.1501 - val_mean_absolute_error: 0.1501
# Epoch 96/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1553 - mean_absolute_error: 0.1553 - val_loss: 0.1558 - val_mean_absolute_error: 0.1558
# Epoch 97/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1568 - mean_absolute_error: 0.1568 - val_loss: 0.1632 - val_mean_absolute_error: 0.1632
# Epoch 98/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1550 - mean_absolute_error: 0.1550 - val_loss: 0.1441 - val_mean_absolute_error: 0.1441
# Epoch 99/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1534 - mean_absolute_error: 0.1534 - val_loss: 0.1480 - val_mean_absolute_error: 0.1480
# Epoch 100/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1547 - mean_absolute_error: 0.1547 - val_loss: 0.1596 - val_mean_absolute_error: 0.1596
# Epoch 101/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1517 - mean_absolute_error: 0.1517 - val_loss: 0.1684 - val_mean_absolute_error: 0.1684
# Epoch 102/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1515 - mean_absolute_error: 0.1515 - val_loss: 0.1661 - val_mean_absolute_error: 0.1661
# Epoch 103/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1496 - mean_absolute_error: 0.1496 - val_loss: 0.1809 - val_mean_absolute_error: 0.1809
# Epoch 104/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1520 - mean_absolute_error: 0.1520 - val_loss: 0.1499 - val_mean_absolute_error: 0.1499
# Epoch 105/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1544 - mean_absolute_error: 0.1544 - val_loss: 0.1719 - val_mean_absolute_error: 0.1719
# Epoch 106/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1538 - mean_absolute_error: 0.1538 - val_loss: 0.1685 - val_mean_absolute_error: 0.1685
# Epoch 107/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1505 - mean_absolute_error: 0.1505 - val_loss: 0.1560 - val_mean_absolute_error: 0.1560
# Epoch 108/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1548 - mean_absolute_error: 0.1548 - val_loss: 0.1443 - val_mean_absolute_error: 0.1443
# Epoch 109/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1499 - mean_absolute_error: 0.1499 - val_loss: 0.1718 - val_mean_absolute_error: 0.1718
# Epoch 110/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1542 - mean_absolute_error: 0.1542 - val_loss: 0.1428 - val_mean_absolute_error: 0.1428
# Epoch 111/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1506 - mean_absolute_error: 0.1506 - val_loss: 0.1575 - val_mean_absolute_error: 0.1575
# Epoch 112/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1533 - mean_absolute_error: 0.1533 - val_loss: 0.1518 - val_mean_absolute_error: 0.1518
# Epoch 113/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1513 - mean_absolute_error: 0.1513 - val_loss: 0.1444 - val_mean_absolute_error: 0.1444
# Epoch 114/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1522 - mean_absolute_error: 0.1522 - val_loss: 0.1434 - val_mean_absolute_error: 0.1434
# Epoch 115/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1514 - mean_absolute_error: 0.1514 - val_loss: 0.1450 - val_mean_absolute_error: 0.1450
# Epoch 116/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1476 - mean_absolute_error: 0.1476 - val_loss: 0.1445 - val_mean_absolute_error: 0.1445
# Epoch 117/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1510 - mean_absolute_error: 0.1510 - val_loss: 0.1457 - val_mean_absolute_error: 0.1457
# Epoch 118/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1512 - mean_absolute_error: 0.1512 - val_loss: 0.1442 - val_mean_absolute_error: 0.1442
# Epoch 119/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1529 - mean_absolute_error: 0.1529 - val_loss: 0.1451 - val_mean_absolute_error: 0.1451
# Epoch 120/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1488 - mean_absolute_error: 0.1488 - val_loss: 0.1437 - val_mean_absolute_error: 0.1437
# Epoch 121/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1527 - mean_absolute_error: 0.1527 - val_loss: 0.1449 - val_mean_absolute_error: 0.1449
# Epoch 122/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1507 - mean_absolute_error: 0.1507 - val_loss: 0.1490 - val_mean_absolute_error: 0.1490
# Epoch 123/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1567 - mean_absolute_error: 0.1567 - val_loss: 0.1441 - val_mean_absolute_error: 0.1441
# Epoch 124/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1515 - mean_absolute_error: 0.1515 - val_loss: 0.1411 - val_mean_absolute_error: 0.1411
# Epoch 125/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1527 - mean_absolute_error: 0.1527 - val_loss: 0.1428 - val_mean_absolute_error: 0.1428
# Epoch 126/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1530 - mean_absolute_error: 0.1530 - val_loss: 0.1414 - val_mean_absolute_error: 0.1414
# Epoch 127/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1520 - mean_absolute_error: 0.1520 - val_loss: 0.1503 - val_mean_absolute_error: 0.1503
# Epoch 128/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1522 - mean_absolute_error: 0.1522 - val_loss: 0.1548 - val_mean_absolute_error: 0.1548
# Epoch 129/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1471 - mean_absolute_error: 0.1471 - val_loss: 0.1466 - val_mean_absolute_error: 0.1466
# Epoch 130/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1532 - mean_absolute_error: 0.1532 - val_loss: 0.1438 - val_mean_absolute_error: 0.1438
# Epoch 131/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1563 - mean_absolute_error: 0.1563 - val_loss: 0.1456 - val_mean_absolute_error: 0.1456
# Epoch 132/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1536 - mean_absolute_error: 0.1536 - val_loss: 0.1410 - val_mean_absolute_error: 0.1410
# Epoch 133/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1510 - mean_absolute_error: 0.1510 - val_loss: 0.1429 - val_mean_absolute_error: 0.1429
# Epoch 134/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1509 - mean_absolute_error: 0.1509 - val_loss: 0.1409 - val_mean_absolute_error: 0.1409
# Epoch 135/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1521 - mean_absolute_error: 0.1521 - val_loss: 0.1421 - val_mean_absolute_error: 0.1421
# Epoch 136/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1533 - mean_absolute_error: 0.1533 - val_loss: 0.1510 - val_mean_absolute_error: 0.1510
# Epoch 137/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1533 - mean_absolute_error: 0.1533 - val_loss: 0.1429 - val_mean_absolute_error: 0.1429
# Epoch 138/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1510 - mean_absolute_error: 0.1510 - val_loss: 0.1432 - val_mean_absolute_error: 0.1432
# Epoch 139/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1516 - mean_absolute_error: 0.1516 - val_loss: 0.1437 - val_mean_absolute_error: 0.1437
# Epoch 140/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1584 - mean_absolute_error: 0.1584 - val_loss: 0.1418 - val_mean_absolute_error: 0.1418
# Epoch 141/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1522 - mean_absolute_error: 0.1522 - val_loss: 0.1422 - val_mean_absolute_error: 0.1422
# Epoch 142/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1482 - mean_absolute_error: 0.1482 - val_loss: 0.1537 - val_mean_absolute_error: 0.1537
# Epoch 143/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1517 - mean_absolute_error: 0.1517 - val_loss: 0.1433 - val_mean_absolute_error: 0.1433
# Epoch 144/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1472 - mean_absolute_error: 0.1472 - val_loss: 0.1512 - val_mean_absolute_error: 0.1512
# Epoch 145/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1543 - mean_absolute_error: 0.1543 - val_loss: 0.1487 - val_mean_absolute_error: 0.1487
# Epoch 146/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1479 - mean_absolute_error: 0.1479 - val_loss: 0.1513 - val_mean_absolute_error: 0.1513
# Epoch 147/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1501 - mean_absolute_error: 0.1501 - val_loss: 0.1409 - val_mean_absolute_error: 0.1409
# Epoch 148/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1499 - mean_absolute_error: 0.1499 - val_loss: 0.1439 - val_mean_absolute_error: 0.1439
# Epoch 149/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1471 - mean_absolute_error: 0.1471 - val_loss: 0.1399 - val_mean_absolute_error: 0.1399
# Epoch 150/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1521 - mean_absolute_error: 0.1521 - val_loss: 0.1430 - val_mean_absolute_error: 0.1430
# Epoch 151/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1495 - mean_absolute_error: 0.1495 - val_loss: 0.1449 - val_mean_absolute_error: 0.1449
# Epoch 152/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1537 - mean_absolute_error: 0.1537 - val_loss: 0.1407 - val_mean_absolute_error: 0.1407
# Epoch 153/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1507 - mean_absolute_error: 0.1507 - val_loss: 0.1420 - val_mean_absolute_error: 0.1420
# Epoch 154/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1493 - mean_absolute_error: 0.1493 - val_loss: 0.1423 - val_mean_absolute_error: 0.1423
# Epoch 155/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1524 - mean_absolute_error: 0.1524 - val_loss: 0.1420 - val_mean_absolute_error: 0.1420
# Epoch 156/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1481 - mean_absolute_error: 0.1481 - val_loss: 0.1456 - val_mean_absolute_error: 0.1456
# Epoch 157/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1525 - mean_absolute_error: 0.1525 - val_loss: 0.1423 - val_mean_absolute_error: 0.1423
# Epoch 158/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1501 - mean_absolute_error: 0.1501 - val_loss: 0.1403 - val_mean_absolute_error: 0.1403
# Epoch 159/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1508 - mean_absolute_error: 0.1508 - val_loss: 0.1410 - val_mean_absolute_error: 0.1410
# Epoch 160/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1528 - mean_absolute_error: 0.1528 - val_loss: 0.1421 - val_mean_absolute_error: 0.1421
# Epoch 161/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1496 - mean_absolute_error: 0.1496 - val_loss: 0.1409 - val_mean_absolute_error: 0.1409
# Epoch 162/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1542 - mean_absolute_error: 0.1542 - val_loss: 0.1525 - val_mean_absolute_error: 0.1525
# Epoch 163/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1462 - mean_absolute_error: 0.1462 - val_loss: 0.1425 - val_mean_absolute_error: 0.1425
# Epoch 164/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1508 - mean_absolute_error: 0.1508 - val_loss: 0.1404 - val_mean_absolute_error: 0.1404
# Epoch 165/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1523 - mean_absolute_error: 0.1523 - val_loss: 0.1422 - val_mean_absolute_error: 0.1422
# Epoch 166/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1529 - mean_absolute_error: 0.1529 - val_loss: 0.1428 - val_mean_absolute_error: 0.1428
# Epoch 167/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1515 - mean_absolute_error: 0.1515 - val_loss: 0.1446 - val_mean_absolute_error: 0.1446
# Epoch 168/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1489 - mean_absolute_error: 0.1489 - val_loss: 0.1528 - val_mean_absolute_error: 0.1528
# Epoch 169/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1519 - mean_absolute_error: 0.1519 - val_loss: 0.1403 - val_mean_absolute_error: 0.1403
# Epoch 170/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1503 - mean_absolute_error: 0.1503 - val_loss: 0.1402 - val_mean_absolute_error: 0.1402
# Epoch 171/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1531 - mean_absolute_error: 0.1531 - val_loss: 0.1403 - val_mean_absolute_error: 0.1403
# Epoch 172/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1504 - mean_absolute_error: 0.1504 - val_loss: 0.1444 - val_mean_absolute_error: 0.1444
# Epoch 173/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1545 - mean_absolute_error: 0.1545 - val_loss: 0.1412 - val_mean_absolute_error: 0.1412
# Epoch 174/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1503 - mean_absolute_error: 0.1503 - val_loss: 0.1406 - val_mean_absolute_error: 0.1406
# Epoch 175/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1490 - mean_absolute_error: 0.1490 - val_loss: 0.1406 - val_mean_absolute_error: 0.1406
# Epoch 176/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1482 - mean_absolute_error: 0.1482 - val_loss: 0.1422 - val_mean_absolute_error: 0.1422
# Epoch 177/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1530 - mean_absolute_error: 0.1530 - val_loss: 0.1404 - val_mean_absolute_error: 0.1404
# Epoch 178/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1507 - mean_absolute_error: 0.1507 - val_loss: 0.1395 - val_mean_absolute_error: 0.1395
# Epoch 179/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1511 - mean_absolute_error: 0.1511 - val_loss: 0.1421 - val_mean_absolute_error: 0.1421
# Epoch 180/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1474 - mean_absolute_error: 0.1474 - val_loss: 0.1415 - val_mean_absolute_error: 0.1415
# Epoch 181/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1489 - mean_absolute_error: 0.1489 - val_loss: 0.1408 - val_mean_absolute_error: 0.1408
# Epoch 182/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1480 - mean_absolute_error: 0.1480 - val_loss: 0.1414 - val_mean_absolute_error: 0.1414
# Epoch 183/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1508 - mean_absolute_error: 0.1508 - val_loss: 0.1434 - val_mean_absolute_error: 0.1434
# Epoch 184/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1526 - mean_absolute_error: 0.1526 - val_loss: 0.1421 - val_mean_absolute_error: 0.1421
# Epoch 185/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1493 - mean_absolute_error: 0.1493 - val_loss: 0.1404 - val_mean_absolute_error: 0.1404
# Epoch 186/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1537 - mean_absolute_error: 0.1537 - val_loss: 0.1409 - val_mean_absolute_error: 0.1409
# Epoch 187/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1488 - mean_absolute_error: 0.1488 - val_loss: 0.1409 - val_mean_absolute_error: 0.1409
# Epoch 188/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1519 - mean_absolute_error: 0.1519 - val_loss: 0.1402 - val_mean_absolute_error: 0.1402
# Epoch 189/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1514 - mean_absolute_error: 0.1514 - val_loss: 0.1399 - val_mean_absolute_error: 0.1399
# Epoch 190/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1499 - mean_absolute_error: 0.1499 - val_loss: 0.1404 - val_mean_absolute_error: 0.1404
# Epoch 191/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1507 - mean_absolute_error: 0.1507 - val_loss: 0.1410 - val_mean_absolute_error: 0.1410
# Epoch 192/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1473 - mean_absolute_error: 0.1473 - val_loss: 0.1411 - val_mean_absolute_error: 0.1411
# Epoch 193/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1510 - mean_absolute_error: 0.1510 - val_loss: 0.1406 - val_mean_absolute_error: 0.1406
# Epoch 194/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1477 - mean_absolute_error: 0.1477 - val_loss: 0.1406 - val_mean_absolute_error: 0.1406
# Epoch 195/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1507 - mean_absolute_error: 0.1507 - val_loss: 0.1411 - val_mean_absolute_error: 0.1411
# Epoch 196/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1471 - mean_absolute_error: 0.1471 - val_loss: 0.1428 - val_mean_absolute_error: 0.1428
# Epoch 197/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1468 - mean_absolute_error: 0.1468 - val_loss: 0.1417 - val_mean_absolute_error: 0.1417
# Epoch 198/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1472 - mean_absolute_error: 0.1472 - val_loss: 0.1413 - val_mean_absolute_error: 0.1413
# Epoch 199/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1502 - mean_absolute_error: 0.1502 - val_loss: 0.1398 - val_mean_absolute_error: 0.1398
# Epoch 200/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1508 - mean_absolute_error: 0.1508 - val_loss: 0.1402 - val_mean_absolute_error: 0.1402
# Epoch 201/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1509 - mean_absolute_error: 0.1509 - val_loss: 0.1414 - val_mean_absolute_error: 0.1414
# Epoch 202/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1489 - mean_absolute_error: 0.1489 - val_loss: 0.1416 - val_mean_absolute_error: 0.1416
# Epoch 203/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1469 - mean_absolute_error: 0.1469 - val_loss: 0.1427 - val_mean_absolute_error: 0.1427
# Epoch 204/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1486 - mean_absolute_error: 0.1486 - val_loss: 0.1427 - val_mean_absolute_error: 0.1427
# Epoch 205/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1484 - mean_absolute_error: 0.1484 - val_loss: 0.1410 - val_mean_absolute_error: 0.1410
# Epoch 206/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1463 - mean_absolute_error: 0.1463 - val_loss: 0.1409 - val_mean_absolute_error: 0.1409
# Epoch 207/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1497 - mean_absolute_error: 0.1497 - val_loss: 0.1402 - val_mean_absolute_error: 0.1402
# Epoch 208/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1474 - mean_absolute_error: 0.1474 - val_loss: 0.1403 - val_mean_absolute_error: 0.1403
# Epoch 209/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1510 - mean_absolute_error: 0.1510 - val_loss: 0.1407 - val_mean_absolute_error: 0.1407
# Epoch 210/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1510 - mean_absolute_error: 0.1510 - val_loss: 0.1411 - val_mean_absolute_error: 0.1411
# Epoch 211/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1487 - mean_absolute_error: 0.1487 - val_loss: 0.1401 - val_mean_absolute_error: 0.1401
# Epoch 212/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1482 - mean_absolute_error: 0.1482 - val_loss: 0.1401 - val_mean_absolute_error: 0.1401
# Epoch 213/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1492 - mean_absolute_error: 0.1492 - val_loss: 0.1398 - val_mean_absolute_error: 0.1398
# Epoch 214/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1498 - mean_absolute_error: 0.1498 - val_loss: 0.1399 - val_mean_absolute_error: 0.1399
# Epoch 215/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1477 - mean_absolute_error: 0.1477 - val_loss: 0.1403 - val_mean_absolute_error: 0.1403
# Epoch 216/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1527 - mean_absolute_error: 0.1527 - val_loss: 0.1399 - val_mean_absolute_error: 0.1399
# Epoch 217/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1493 - mean_absolute_error: 0.1493 - val_loss: 0.1399 - val_mean_absolute_error: 0.1399
# Epoch 218/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1511 - mean_absolute_error: 0.1511 - val_loss: 0.1408 - val_mean_absolute_error: 0.1408
# Epoch 219/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1499 - mean_absolute_error: 0.1499 - val_loss: 0.1403 - val_mean_absolute_error: 0.1403
# Epoch 220/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1509 - mean_absolute_error: 0.1509 - val_loss: 0.1402 - val_mean_absolute_error: 0.1402
# Epoch 221/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1481 - mean_absolute_error: 0.1481 - val_loss: 0.1402 - val_mean_absolute_error: 0.1402
# Epoch 222/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1492 - mean_absolute_error: 0.1492 - val_loss: 0.1404 - val_mean_absolute_error: 0.1404
# Epoch 223/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1495 - mean_absolute_error: 0.1495 - val_loss: 0.1406 - val_mean_absolute_error: 0.1406
# Epoch 224/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1481 - mean_absolute_error: 0.1481 - val_loss: 0.1400 - val_mean_absolute_error: 0.1400
# Epoch 225/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1469 - mean_absolute_error: 0.1469 - val_loss: 0.1397 - val_mean_absolute_error: 0.1397
# Epoch 226/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1481 - mean_absolute_error: 0.1481 - val_loss: 0.1396 - val_mean_absolute_error: 0.1396
# Epoch 227/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1496 - mean_absolute_error: 0.1496 - val_loss: 0.1394 - val_mean_absolute_error: 0.1394
# Epoch 228/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1484 - mean_absolute_error: 0.1484 - val_loss: 0.1398 - val_mean_absolute_error: 0.1398
# Epoch 229/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1495 - mean_absolute_error: 0.1495 - val_loss: 0.1394 - val_mean_absolute_error: 0.1394
# Epoch 230/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1498 - mean_absolute_error: 0.1498 - val_loss: 0.1394 - val_mean_absolute_error: 0.1394
# Epoch 231/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1472 - mean_absolute_error: 0.1472 - val_loss: 0.1400 - val_mean_absolute_error: 0.1400
# Epoch 232/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1517 - mean_absolute_error: 0.1517 - val_loss: 0.1432 - val_mean_absolute_error: 0.1432
# Epoch 233/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1501 - mean_absolute_error: 0.1501 - val_loss: 0.1405 - val_mean_absolute_error: 0.1405
# Epoch 234/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1502 - mean_absolute_error: 0.1502 - val_loss: 0.1397 - val_mean_absolute_error: 0.1397
# Epoch 235/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1485 - mean_absolute_error: 0.1485 - val_loss: 0.1398 - val_mean_absolute_error: 0.1398
# Epoch 236/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1517 - mean_absolute_error: 0.1517 - val_loss: 0.1395 - val_mean_absolute_error: 0.1395
# Epoch 237/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1483 - mean_absolute_error: 0.1483 - val_loss: 0.1396 - val_mean_absolute_error: 0.1396
# Epoch 238/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1518 - mean_absolute_error: 0.1518 - val_loss: 0.1398 - val_mean_absolute_error: 0.1398
# Epoch 239/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1487 - mean_absolute_error: 0.1487 - val_loss: 0.1401 - val_mean_absolute_error: 0.1401
# Epoch 240/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1505 - mean_absolute_error: 0.1505 - val_loss: 0.1398 - val_mean_absolute_error: 0.1398
# Epoch 241/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1529 - mean_absolute_error: 0.1529 - val_loss: 0.1411 - val_mean_absolute_error: 0.1411
# Epoch 242/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1527 - mean_absolute_error: 0.1527 - val_loss: 0.1403 - val_mean_absolute_error: 0.1403
# Epoch 243/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1492 - mean_absolute_error: 0.1492 - val_loss: 0.1401 - val_mean_absolute_error: 0.1401
# Epoch 244/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1503 - mean_absolute_error: 0.1503 - val_loss: 0.1398 - val_mean_absolute_error: 0.1398
# Epoch 245/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1479 - mean_absolute_error: 0.1479 - val_loss: 0.1400 - val_mean_absolute_error: 0.1400
# Epoch 246/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1531 - mean_absolute_error: 0.1531 - val_loss: 0.1395 - val_mean_absolute_error: 0.1395
# Epoch 247/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1494 - mean_absolute_error: 0.1494 - val_loss: 0.1396 - val_mean_absolute_error: 0.1396
# Epoch 248/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1505 - mean_absolute_error: 0.1505 - val_loss: 0.1399 - val_mean_absolute_error: 0.1399
# Epoch 249/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1503 - mean_absolute_error: 0.1503 - val_loss: 0.1397 - val_mean_absolute_error: 0.1397
# Epoch 250/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1543 - mean_absolute_error: 0.1543 - val_loss: 0.1396 - val_mean_absolute_error: 0.1396
# Epoch 251/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1511 - mean_absolute_error: 0.1511 - val_loss: 0.1397 - val_mean_absolute_error: 0.1397
# Epoch 252/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1535 - mean_absolute_error: 0.1535 - val_loss: 0.1397 - val_mean_absolute_error: 0.1397
# Epoch 253/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1503 - mean_absolute_error: 0.1503 - val_loss: 0.1399 - val_mean_absolute_error: 0.1399
# Epoch 254/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1489 - mean_absolute_error: 0.1489 - val_loss: 0.1403 - val_mean_absolute_error: 0.1403
# Epoch 255/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1490 - mean_absolute_error: 0.1490 - val_loss: 0.1399 - val_mean_absolute_error: 0.1399
# Epoch 256/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1525 - mean_absolute_error: 0.1525 - val_loss: 0.1398 - val_mean_absolute_error: 0.1398
# Epoch 257/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1515 - mean_absolute_error: 0.1515 - val_loss: 0.1400 - val_mean_absolute_error: 0.1400
# Epoch 258/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1486 - mean_absolute_error: 0.1486 - val_loss: 0.1411 - val_mean_absolute_error: 0.1411
# Epoch 259/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1482 - mean_absolute_error: 0.1482 - val_loss: 0.1425 - val_mean_absolute_error: 0.1425
# Epoch 260/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1503 - mean_absolute_error: 0.1503 - val_loss: 0.1419 - val_mean_absolute_error: 0.1419
# Epoch 261/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1492 - mean_absolute_error: 0.1492 - val_loss: 0.1405 - val_mean_absolute_error: 0.1405
# Epoch 262/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1502 - mean_absolute_error: 0.1502 - val_loss: 0.1396 - val_mean_absolute_error: 0.1396
# Epoch 263/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1464 - mean_absolute_error: 0.1464 - val_loss: 0.1395 - val_mean_absolute_error: 0.1395
# Epoch 264/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1504 - mean_absolute_error: 0.1504 - val_loss: 0.1400 - val_mean_absolute_error: 0.1400
# Epoch 265/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1466 - mean_absolute_error: 0.1466 - val_loss: 0.1394 - val_mean_absolute_error: 0.1394
# Epoch 266/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1467 - mean_absolute_error: 0.1467 - val_loss: 0.1393 - val_mean_absolute_error: 0.1393
# Epoch 267/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1470 - mean_absolute_error: 0.1470 - val_loss: 0.1400 - val_mean_absolute_error: 0.1400
# Epoch 268/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1489 - mean_absolute_error: 0.1489 - val_loss: 0.1395 - val_mean_absolute_error: 0.1395
# Epoch 269/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1505 - mean_absolute_error: 0.1505 - val_loss: 0.1401 - val_mean_absolute_error: 0.1401
# Epoch 270/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1505 - mean_absolute_error: 0.1505 - val_loss: 0.1406 - val_mean_absolute_error: 0.1406
# Epoch 271/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1522 - mean_absolute_error: 0.1522 - val_loss: 0.1412 - val_mean_absolute_error: 0.1412
# Epoch 272/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1481 - mean_absolute_error: 0.1481 - val_loss: 0.1398 - val_mean_absolute_error: 0.1398
# Epoch 273/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1520 - mean_absolute_error: 0.1520 - val_loss: 0.1393 - val_mean_absolute_error: 0.1393
# Epoch 274/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1486 - mean_absolute_error: 0.1486 - val_loss: 0.1394 - val_mean_absolute_error: 0.1394
# Epoch 275/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1505 - mean_absolute_error: 0.1505 - val_loss: 0.1393 - val_mean_absolute_error: 0.1393
# Epoch 276/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1445 - mean_absolute_error: 0.1445 - val_loss: 0.1395 - val_mean_absolute_error: 0.1395
# Epoch 277/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1482 - mean_absolute_error: 0.1482 - val_loss: 0.1395 - val_mean_absolute_error: 0.1395
# Epoch 278/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1504 - mean_absolute_error: 0.1504 - val_loss: 0.1396 - val_mean_absolute_error: 0.1396
# Epoch 279/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1499 - mean_absolute_error: 0.1499 - val_loss: 0.1397 - val_mean_absolute_error: 0.1397
# Epoch 280/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1479 - mean_absolute_error: 0.1479 - val_loss: 0.1401 - val_mean_absolute_error: 0.1401
# Epoch 281/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1510 - mean_absolute_error: 0.1510 - val_loss: 0.1397 - val_mean_absolute_error: 0.1397
# Epoch 282/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1510 - mean_absolute_error: 0.1510 - val_loss: 0.1400 - val_mean_absolute_error: 0.1400
# Epoch 283/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1482 - mean_absolute_error: 0.1482 - val_loss: 0.1399 - val_mean_absolute_error: 0.1399
# Epoch 284/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1507 - mean_absolute_error: 0.1507 - val_loss: 0.1397 - val_mean_absolute_error: 0.1397
# Epoch 285/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1486 - mean_absolute_error: 0.1486 - val_loss: 0.1397 - val_mean_absolute_error: 0.1397
# Epoch 286/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1485 - mean_absolute_error: 0.1485 - val_loss: 0.1398 - val_mean_absolute_error: 0.1398
# Epoch 287/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1493 - mean_absolute_error: 0.1493 - val_loss: 0.1397 - val_mean_absolute_error: 0.1397
# Epoch 288/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1478 - mean_absolute_error: 0.1478 - val_loss: 0.1398 - val_mean_absolute_error: 0.1398
# Epoch 289/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1494 - mean_absolute_error: 0.1494 - val_loss: 0.1406 - val_mean_absolute_error: 0.1406
# Epoch 290/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1520 - mean_absolute_error: 0.1520 - val_loss: 0.1404 - val_mean_absolute_error: 0.1404
# Epoch 291/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1440 - mean_absolute_error: 0.1440 - val_loss: 0.1402 - val_mean_absolute_error: 0.1402
# Epoch 292/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1471 - mean_absolute_error: 0.1471 - val_loss: 0.1399 - val_mean_absolute_error: 0.1399
# Epoch 293/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1532 - mean_absolute_error: 0.1532 - val_loss: 0.1396 - val_mean_absolute_error: 0.1396
# Epoch 294/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1488 - mean_absolute_error: 0.1488 - val_loss: 0.1398 - val_mean_absolute_error: 0.1398
# Epoch 295/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1513 - mean_absolute_error: 0.1513 - val_loss: 0.1408 - val_mean_absolute_error: 0.1408
# Epoch 296/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1501 - mean_absolute_error: 0.1501 - val_loss: 0.1396 - val_mean_absolute_error: 0.1396
# Epoch 297/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1481 - mean_absolute_error: 0.1481 - val_loss: 0.1399 - val_mean_absolute_error: 0.1399
# Epoch 298/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1513 - mean_absolute_error: 0.1513 - val_loss: 0.1398 - val_mean_absolute_error: 0.1398
# Epoch 299/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1517 - mean_absolute_error: 0.1517 - val_loss: 0.1397 - val_mean_absolute_error: 0.1397
# Epoch 300/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1505 - mean_absolute_error: 0.1505 - val_loss: 0.1395 - val_mean_absolute_error: 0.1395
# Epoch 301/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1470 - mean_absolute_error: 0.1470 - val_loss: 0.1399 - val_mean_absolute_error: 0.1399
# Epoch 302/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1503 - mean_absolute_error: 0.1503 - val_loss: 0.1402 - val_mean_absolute_error: 0.1402
# Epoch 303/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1524 - mean_absolute_error: 0.1524 - val_loss: 0.1397 - val_mean_absolute_error: 0.1397
# Epoch 304/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1501 - mean_absolute_error: 0.1501 - val_loss: 0.1396 - val_mean_absolute_error: 0.1396
# Epoch 305/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1455 - mean_absolute_error: 0.1455 - val_loss: 0.1393 - val_mean_absolute_error: 0.1393
# Epoch 306/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1463 - mean_absolute_error: 0.1463 - val_loss: 0.1393 - val_mean_absolute_error: 0.1393
# Epoch 307/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1497 - mean_absolute_error: 0.1497 - val_loss: 0.1391 - val_mean_absolute_error: 0.1391
# Epoch 308/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1530 - mean_absolute_error: 0.1530 - val_loss: 0.1394 - val_mean_absolute_error: 0.1394
# Epoch 309/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1521 - mean_absolute_error: 0.1521 - val_loss: 0.1396 - val_mean_absolute_error: 0.1396
# Epoch 310/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1456 - mean_absolute_error: 0.1456 - val_loss: 0.1403 - val_mean_absolute_error: 0.1403
# Epoch 311/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1502 - mean_absolute_error: 0.1502 - val_loss: 0.1403 - val_mean_absolute_error: 0.1403
# Epoch 312/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1475 - mean_absolute_error: 0.1475 - val_loss: 0.1413 - val_mean_absolute_error: 0.1413
# Epoch 313/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1478 - mean_absolute_error: 0.1478 - val_loss: 0.1412 - val_mean_absolute_error: 0.1412
# Epoch 314/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1496 - mean_absolute_error: 0.1496 - val_loss: 0.1402 - val_mean_absolute_error: 0.1402
# Epoch 315/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1511 - mean_absolute_error: 0.1511 - val_loss: 0.1398 - val_mean_absolute_error: 0.1398
# Epoch 316/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1518 - mean_absolute_error: 0.1518 - val_loss: 0.1401 - val_mean_absolute_error: 0.1401
# Epoch 317/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1526 - mean_absolute_error: 0.1526 - val_loss: 0.1402 - val_mean_absolute_error: 0.1402
# Epoch 318/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1494 - mean_absolute_error: 0.1494 - val_loss: 0.1403 - val_mean_absolute_error: 0.1403
# Epoch 319/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1487 - mean_absolute_error: 0.1487 - val_loss: 0.1401 - val_mean_absolute_error: 0.1401
# Epoch 320/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1515 - mean_absolute_error: 0.1515 - val_loss: 0.1393 - val_mean_absolute_error: 0.1393
# Epoch 321/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1473 - mean_absolute_error: 0.1473 - val_loss: 0.1401 - val_mean_absolute_error: 0.1401
# Epoch 322/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1474 - mean_absolute_error: 0.1474 - val_loss: 0.1408 - val_mean_absolute_error: 0.1408
# Epoch 323/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1491 - mean_absolute_error: 0.1491 - val_loss: 0.1420 - val_mean_absolute_error: 0.1420
# Epoch 324/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1479 - mean_absolute_error: 0.1479 - val_loss: 0.1416 - val_mean_absolute_error: 0.1416
# Epoch 325/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1475 - mean_absolute_error: 0.1475 - val_loss: 0.1406 - val_mean_absolute_error: 0.1406
# Epoch 326/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1532 - mean_absolute_error: 0.1532 - val_loss: 0.1397 - val_mean_absolute_error: 0.1397
# Epoch 327/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1514 - mean_absolute_error: 0.1514 - val_loss: 0.1395 - val_mean_absolute_error: 0.1395
# Epoch 328/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1503 - mean_absolute_error: 0.1503 - val_loss: 0.1394 - val_mean_absolute_error: 0.1394
# Epoch 329/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1470 - mean_absolute_error: 0.1470 - val_loss: 0.1394 - val_mean_absolute_error: 0.1394
# Epoch 330/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1497 - mean_absolute_error: 0.1497 - val_loss: 0.1392 - val_mean_absolute_error: 0.1392
# Epoch 331/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1487 - mean_absolute_error: 0.1487 - val_loss: 0.1393 - val_mean_absolute_error: 0.1393
# Epoch 332/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1511 - mean_absolute_error: 0.1511 - val_loss: 0.1395 - val_mean_absolute_error: 0.1395
# Epoch 333/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1481 - mean_absolute_error: 0.1481 - val_loss: 0.1395 - val_mean_absolute_error: 0.1395
# Epoch 334/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1490 - mean_absolute_error: 0.1490 - val_loss: 0.1393 - val_mean_absolute_error: 0.1393
# Epoch 335/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1506 - mean_absolute_error: 0.1506 - val_loss: 0.1397 - val_mean_absolute_error: 0.1397
# Epoch 336/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1452 - mean_absolute_error: 0.1452 - val_loss: 0.1399 - val_mean_absolute_error: 0.1399
# Epoch 337/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1498 - mean_absolute_error: 0.1498 - val_loss: 0.1414 - val_mean_absolute_error: 0.1414
# Epoch 338/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1514 - mean_absolute_error: 0.1514 - val_loss: 0.1401 - val_mean_absolute_error: 0.1401
# Epoch 339/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1503 - mean_absolute_error: 0.1503 - val_loss: 0.1401 - val_mean_absolute_error: 0.1401
# Epoch 340/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1489 - mean_absolute_error: 0.1489 - val_loss: 0.1402 - val_mean_absolute_error: 0.1402
# Epoch 341/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1515 - mean_absolute_error: 0.1515 - val_loss: 0.1395 - val_mean_absolute_error: 0.1395
# Epoch 342/500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1505 - mean_absolute_error: 0.1505 - val_loss: 0.1392 - val_mean_absolute_error: 0.1392
# Epoch 343/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1461 - mean_absolute_error: 0.1461 - val_loss: 0.1393 - val_mean_absolute_error: 0.1393
# Epoch 344/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1519 - mean_absolute_error: 0.1519 - val_loss: 0.1394 - val_mean_absolute_error: 0.1394
# Epoch 345/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1530 - mean_absolute_error: 0.1530 - val_loss: 0.1398 - val_mean_absolute_error: 0.1398
# Epoch 346/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1467 - mean_absolute_error: 0.1467 - val_loss: 0.1398 - val_mean_absolute_error: 0.1398
# Epoch 347/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1498 - mean_absolute_error: 0.1498 - val_loss: 0.1397 - val_mean_absolute_error: 0.1397
# Epoch 348/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1489 - mean_absolute_error: 0.1489 - val_loss: 0.1394 - val_mean_absolute_error: 0.1394
# Epoch 349/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1519 - mean_absolute_error: 0.1519 - val_loss: 0.1399 - val_mean_absolute_error: 0.1399
# Epoch 350/500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1466 - mean_absolute_error: 0.1466 - val_loss: 0.1399 - val_mean_absolute_error: 0.1399
# Epoch 351/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1481 - mean_absolute_error: 0.1481 - val_loss: 0.1397 - val_mean_absolute_error: 0.1397
# Epoch 352/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1475 - mean_absolute_error: 0.1475 - val_loss: 0.1399 - val_mean_absolute_error: 0.1399
# Epoch 353/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1478 - mean_absolute_error: 0.1478 - val_loss: 0.1401 - val_mean_absolute_error: 0.1401
# Epoch 354/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1492 - mean_absolute_error: 0.1492 - val_loss: 0.1398 - val_mean_absolute_error: 0.1398
# Epoch 355/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1474 - mean_absolute_error: 0.1474 - val_loss: 0.1399 - val_mean_absolute_error: 0.1399
# Epoch 356/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1502 - mean_absolute_error: 0.1502 - val_loss: 0.1405 - val_mean_absolute_error: 0.1405
# Epoch 357/500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1492 - mean_absolute_error: 0.1492 - val_loss: 0.1405 - val_mean_absolute_error: 0.1405
# Epoch 00357: early stopping

# %%
model = keras.models.load_model("best_model.h5")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test error", test_acc)
print("Test loss", test_loss)
# Out:
# 1/1 [==============================] - 0s 120ms/step - loss: 0.1673 - mean_absolute_error: 0.1673
# Test error 0.16730563342571259
# Test loss 0.16730563342571259

# %%
mua = np.zeros((x_train.shape[0],))
mus = np.zeros((x_train.shape[0],))
d = np.zeros((x_train.shape[0],))
miu = np.zeros((x_train.shape[0],2))

miu = model.predict(x_train)
mua = miu[:,0]
mus = miu[:,1]
d = x_train[:,0,0]

# %%
err = np.zeros((x_train.shape[0],2))

err[:,0] = y_train[:,0]-mua
err[:,1] = y_train[:,1]-mus
# print(mua[k],mus[k],d[k])
# print(y_train[k])

# %%
plt.plot(d,err[:,1],alpha=0.5)
plt.plot(d,err[:,0],alpha=0.5)
plt.show()

# %%
# print(mua,mus,d)
# print(an2[i,1],an2[i,2],an2[i,0])
# plt.plot(abs(an1[:,1]-mua))
# plt.plot(abs(an1[:,2]-mus))
plt.hist((y_train[:,0]-mua), bins=40,  facecolor="blue", edgecolor="black", alpha=0.7)
plt.hist((y_train[:,1]-mus), bins=40,  facecolor="green", edgecolor="black", alpha=0.7)
plt.show()

# %%
metric = "mean_absolute_error"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()

# %%
# 你可以用pca或者一些降维方法把特征搞一下
